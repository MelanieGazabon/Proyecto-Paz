# %% [markdown]
# # importar recursos

# %%
import requests
from bs4 import BeautifulSoup
import csv
import os
import re
import csv
import spacy
from collections import Counter
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# !pip install -U spacy
# !python -m spacy download es_core_news_sm
# !python -m spacy download es_core_news_lg


# Definir la ruta del archivo en el escritorio
archivo_csv = os.path.join(os.path.expanduser("~"), "Escritorio", "datos_extraidos.csv")
# Out:
# Requirement already satisfied: spacy in c:\users\user\anaconda3\lib\site-packages (3.7.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\user\anaconda3\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\user\anaconda3\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\user\anaconda3\lib\site-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\user\anaconda3\lib\site-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\user\anaconda3\lib\site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\users\user\anaconda3\lib\site-packages (from spacy) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\user\anaconda3\lib\site-packages (from spacy) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\user\anaconda3\lib\site-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\user\anaconda3\lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in c:\users\user\anaconda3\lib\site-packages (from spacy) (0.3.4)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\users\user\anaconda3\lib\site-packages (from spacy) (0.9.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\user\anaconda3\lib\site-packages (from spacy) (4.65.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\user\anaconda3\lib\site-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\user\anaconda3\lib\site-packages (from spacy) (1.10.8)
# Requirement already satisfied: jinja2 in c:\users\user\anaconda3\lib\site-packages (from spacy) (3.1.2)
# Requirement already satisfied: setuptools in c:\users\user\anaconda3\lib\site-packages (from spacy) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\anaconda3\lib\site-packages (from spacy) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\user\anaconda3\lib\site-packages (from spacy) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\user\anaconda3\lib\site-packages (from spacy) (1.24.4)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\user\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\user\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\user\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.4)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\user\anaconda3\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.0.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\user\anaconda3\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.16.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\user\anaconda3\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy) (5.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\user\anaconda3\lib\site-packages (from jinja2->spacy) (2.1.1)
# Collecting es-core-news-sm==3.7.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/es_core_news_sm-3.7.0/es_core_news_sm-3.7.0-py3-none-any.whl (12.9 MB)
#      ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#      --------------------------------------- 0.0/12.9 MB 325.1 kB/s eta 0:00:40
#      --------------------------------------- 0.1/12.9 MB 409.6 kB/s eta 0:00:32
#      --------------------------------------- 0.1/12.9 MB 599.1 kB/s eta 0:00:22
#       -------------------------------------- 0.2/12.9 MB 827.9 kB/s eta 0:00:16
#       --------------------------------------- 0.3/12.9 MB 1.1 MB/s eta 0:00:12
#      - -------------------------------------- 0.5/12.9 MB 1.5 MB/s eta 0:00:09
#      - -------------------------------------- 0.6/12.9 MB 1.5 MB/s eta 0:00:09
#      -- ------------------------------------- 0.8/12.9 MB 1.9 MB/s eta 0:00:07
#      --- ------------------------------------ 1.1/12.9 MB 2.3 MB/s eta 0:00:06
#      --- ------------------------------------ 1.1/12.9 MB 2.2 MB/s eta 0:00:06
#      ---- ----------------------------------- 1.3/12.9 MB 2.3 MB/s eta 0:00:05
#      ---- ----------------------------------- 1.3/12.9 MB 2.3 MB/s eta 0:00:05
#      ---- ----------------------------------- 1.4/12.9 MB 2.1 MB/s eta 0:00:06
#      ----- ---------------------------------- 1.8/12.9 MB 2.5 MB/s eta 0:00:05
#      ------ --------------------------------- 2.0/12.9 MB 2.6 MB/s eta 0:00:05
#      ------ --------------------------------- 2.2/12.9 MB 2.7 MB/s eta 0:00:04
#      ------- -------------------------------- 2.4/12.9 MB 2.8 MB/s eta 0:00:04
#      -------- ------------------------------- 2.7/12.9 MB 3.0 MB/s eta 0:00:04
#      -------- ------------------------------- 2.8/12.9 MB 2.9 MB/s eta 0:00:04
#      --------- ------------------------------ 3.1/12.9 MB 3.1 MB/s eta 0:00:04
#      --------- ------------------------------ 3.2/12.9 MB 3.1 MB/s eta 0:00:04
#      --------- ------------------------------ 3.2/12.9 MB 2.9 MB/s eta 0:00:04
#      ---------- ----------------------------- 3.4/12.9 MB 3.0 MB/s eta 0:00:04
#      ----------- ---------------------------- 3.6/12.9 MB 3.1 MB/s eta 0:00:04
#      ------------ --------------------------- 3.9/12.9 MB 3.2 MB/s eta 0:00:03
#      ------------- -------------------------- 4.3/12.9 MB 3.3 MB/s eta 0:00:03
#      -------------- ------------------------- 4.8/12.9 MB 3.6 MB/s eta 0:00:03
#      --------------- ------------------------ 5.1/12.9 MB 3.7 MB/s eta 0:00:03
#      ---------------- ----------------------- 5.2/12.9 MB 3.6 MB/s eta 0:00:03
#      ---------------- ----------------------- 5.4/12.9 MB 3.6 MB/s eta 0:00:03
#      ------------------ --------------------- 5.8/12.9 MB 3.8 MB/s eta 0:00:02
#      ------------------- -------------------- 6.3/12.9 MB 4.0 MB/s eta 0:00:02
#      -------------------- ------------------- 6.5/12.9 MB 4.0 MB/s eta 0:00:02
#      -------------------- ------------------- 6.5/12.9 MB 4.0 MB/s eta 0:00:02
#      --------------------- ------------------ 6.9/12.9 MB 4.0 MB/s eta 0:00:02
#      ---------------------- ----------------- 7.2/12.9 MB 4.1 MB/s eta 0:00:02
#      ----------------------- ---------------- 7.5/12.9 MB 4.1 MB/s eta 0:00:02
#      ------------------------ --------------- 7.9/12.9 MB 4.2 MB/s eta 0:00:02
#      ------------------------ --------------- 8.0/12.9 MB 4.3 MB/s eta 0:00:02
#      ------------------------- -------------- 8.1/12.9 MB 4.2 MB/s eta 0:00:02
#      ------------------------- -------------- 8.4/12.9 MB 4.2 MB/s eta 0:00:02
#      --------------------------- ------------ 8.7/12.9 MB 4.3 MB/s eta 0:00:01
#      --------------------------- ------------ 8.9/12.9 MB 4.3 MB/s eta 0:00:01
#      ---------------------------- ----------- 9
core-news-lg==3.7.0) (3.7.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-lg==3.7.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-lg==3.7.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-lg==3.7.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-lg==3.7.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-lg==3.7.0) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-lg==3.7.0) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-lg==3.7.0) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-lg==3.7.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-lg==3.7.0) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-lg==3.7.0) (0.3.4)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-lg==3.7.0) (0.9.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-lg==3.7.0) (4.65.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-lg==3.7.0) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-lg==3.7.0) (1.10.8)
# Requirement already satisfied: jinja2 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-lg==3.7.0) (3.1.2)
# Requirement already satisfied: setuptools in c:\users\user\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-lg==3.7.0) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-lg==3.7.0) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-lg==3.7.0) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-lg==3.7.0) (1.24.4)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\user\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->es-core-news-lg==3.7.0) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->es-core-news-lg==3.7.0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->es-core-news-lg==3.7.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->es-core-news-lg==3.7.0) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->es-core-news-lg==3.7.0) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\user\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->es-core-news-lg==3.7.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\user\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->es-core-news-lg==3.7.0) (0.1.4)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.8.0,>=3.7.0->es-core-news-lg==3.7.0) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\user\anaconda3\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->es-core-news-lg==3.7.0) (8.0.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\user\anaconda3\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->es-core-news-lg==3.7.0) (0.16.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\user\anaconda3\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->es-core-news-lg==3.7.0) (5.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\user\anaconda3\lib\site-packages (from jinja2->spacy<3.8.0,>=3.7.0->es-core-news-lg==3.7.0) (2.1.1)
# ✔ Download and installation successful
# You can now load the package via spacy.load('es_core_news_lg')

# %% [markdown]
# # Bases de datos periodico semana

# %%
# Lista de URLs de la base de datos semana
BASE_DATOS_SEMANA= [
"https://www.semana.com/opinion/articulo/sin-autonomia-regional-no-habra-paz/202348/",
"https://www.semana.com/opinion/articulo/acabar-los-procesos-de-paz-una-opcion/202334/",
"https://www.semana.com/opinion/articulo/clausewitz-y-el-laberinto-de-la-paz-total/202300/",
"https://www.semana.com/opinion/articulo/de-la-paz-total-a-la-paz-criminal/202300/",
"https://www.semana.com/opinion/articulo/paz-total-o-entrega-total/202353/",
"https://www.semana.com/opinion/articulo/eln-cinismo-para-la-paz/202310/",
"https://www.semana.com/opinion/articulo/por-que-los-procesos-de-paz-no-obtienen-resultados-tangibles/202351/",
"https://www.semana.com/opinion/articulo/la-paz-y-sus-incumplimientos/202340/",
"https://www.semana.com/opinion/articulo/la-paz-total-es-una-guerra-total/202342/",
"https://www.semana.com/opinion/articulo/no-mas-con-la-farsa-de-la-paz-total/202334/",
"https://www.semana.com/opinion/articulo/la-politica-de-paz-del-gobierno-es-mas-que-vergonzosa/202331/",
"https://www.semana.com/opinion/articulo/paz-total-con-seguridad-y-cero-tolerancia/202358/",
"https://www.semana.com/opinion/articulo/ley-y-proyectos-sobre-paz-total-primero-las-victimas/202335/",
"https://www.semana.com/opinion/articulo/paz-total-lobos-con-piel-de-oveja/202347/",
"https://www.semana.com/opinion/articulo/hora-de-hablar-con-verdades-de-la-paz-total/202309/",
"https://www.semana.com/opinion/articulo/el-fracaso-de-la-paz-totalmente-mafiosa/202316/",
"https://www.semana.com/opinion/articulo/una-paz-titanica/202346/",
"https://www.semana.com/opinion/articulo/un-proceso-de-paz-a-pesar-de-sus-promotores/202321/",
"https://www.semana.com/opinion/articulo/pisoteadores-de-la-paz/202334/"
]
# Crear una lista para almacenar los datos extraídos
datos_extraidos = []

# Iterar sobre cada URL de la base de datos
for URL_BASE in BASE_DATOS_SEMANA:
    pedido_obtenido = requests.get(URL_BASE)
    html_obtenido = pedido_obtenido.text
    soup = BeautifulSoup(html_obtenido, "html.parser")

    # Encontrar los elementos <div> con la clase "font--secondary"
    divs = soup.find_all(class_="max-w-screen-md prose prose-lg mx-auto mb-5")

    # Crear una lista para almacenar los textos del artículo
    texto_articulo = []
    for div in divs:
        texto_articulo.append(div.text.strip())

    # Unir todos los textos del artículo en una cadena
    articulo_completo = " ".join(texto_articulo)

    # Agregar solo el texto del artículo a la lista de datos_extraidos
    datos_extraidos.append(articulo_completo)

# Escribir los datos extraídos en un archivo CSV
with open('datos_extraidossemana.csv', 'w', newline='', encoding='utf-8-sig') as archivo:
    escritor_csv = csv.writer(archivo)
    for texto_articulo in datos_extraidos:
        escritor_csv.writerow([texto_articulo])

# %% [markdown]
# # preprocesamiento

# %%
# Definir la función para eliminar caracteres no deseados
def eliminar_caracteres(texto):
    # Definir una expresión regular para encontrar caracteres no alfabéticos o espacios
    patron = r'[^a-zA-ZáéíóúüñÁÉÍÓÚÜÑ\s]'
    # Reemplazar los caracteres no deseados por espacios en blanco
    texto_limpio = re.sub(patron, ' ', str(texto))
    return texto_limpio
#------

import spacy
from spacy.lang.es.stop_words import STOP_WORDS

# Descargar y cargar el modelo de spaCy para español
spacy.cli.download("es_core_news_sm")
nlp = spacy.load("es_core_news_sm")

# Obtener la lista de stopwords en español de spaCy
stopwords_espanol = STOP_WORDS

# Definir una función para eliminar stopwords utilizando spaCy
def eliminar_stopwords(texto):
    # Procesar el texto con spaCy
    doc = nlp(texto)
    # Filtrar las palabras que no son stopwords
    palabras_filtradas = [token.text for token in doc if token.text.lower() not in stopwords_espanol]
    # Unir las palabras filtradas en un texto nuevamente
    texto_filtrado = ' '.join(palabras_filtradas)
    return texto_filtrado

# Definir una función para tokenizar el texto utilizando spaCy
def tokenizar_texto(texto):
    # Procesar el texto con spaCy
    doc = nlp(texto)
    # Extraer los tokens
    tokens = [token.text for token in doc]
    return tokens


# Definir una función para lematizar el texto
def lematizar_texto(tokens):
    # Unir los tokens en una cadena de texto
    texto = ' '.join(tokens)
    # Procesar el texto con el modelo de lenguaje en español
    doc = nlp(texto)
    # Extraer las formas base (lemas) de cada palabra
    lemas = [token.lemma_ for token in doc]
    return lemas
#------

def eliminar_verbos(texto):
    # Procesar el texto con spaCy
    doc = nlp(texto)
    # Filtrar las palabras que no son verbos
    palabras_filtradas = [token.text for token in doc if token.pos_ != 'VERB']
    # Unir las palabras filtradas en un texto nuevamente
    texto_filtrado = ' '.join(palabras_filtradas)
    return texto_filtrado
# Out:
# ✔ Download and installation successful
# You can now load the package via spacy.load('es_core_news_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
# Leer el archivo CSV con los datos extraídos
with open('datos_extraidossemana.csv', 'r', encoding='utf-8-sig') as archivo:
    lector_csv = csv.reader(archivo)
    # Extraer los datos de la primera columna en una lista
    datos_extraidos_total = [fila[0] for fila in lector_csv]
    
# Aplicar la función eliminar_caracteres a cada texto en la lista datos_extraidos_total
contenido_limpiado = [eliminar_caracteres(texto) for texto in datos_extraidos_total]

# Convertir el texto limpiado a minúsculas
contenido_limpiado_minusculas = [texto.lower() for texto in contenido_limpiado]

# Aplicar la función eliminar_verbos a cada texto en la lista
contenido_sin_verbos = [eliminar_verbos(texto) for texto in contenido_limpiado_minusculas]

# Aplicar la función eliminar_stopword a cada texto en la lista
contenido_sin_stopword = [eliminar_stopwords(texto) for texto in contenido_sin_verbos]

# Aplicar la función de tokenización a cada texto en la lista
contenido_tokens= [tokenizar_texto(texto) for texto in contenido_sin_stopword]

# Aplicar la función de lematización a cada lista de tokens en la lista de contenidos
contenido_lemas= [lematizar_texto(tokens) for tokens in contenido_tokens]

# Escribir los datos en un nuevo archivo CSV
with open('lemas_semana.csv', 'w', newline='', encoding='utf-8-sig') as archivo:
    escritor_csv = csv.writer(archivo)
    for lemas in contenido_lemas:
        escritor_csv.writerow(lemas)

# %% [markdown]
# # Palabras claves

# %%
# Crear un contador para almacenar la frecuencia de las palabras
contador_palabras = Counter()

# Abrir el archivo CSV y contar la frecuencia de las palabras
with open('lemas_semana.csv', 'r', newline='', encoding='utf-8-sig') as archivo:
    lector_csv = csv.reader(archivo)
    for fila in lector_csv:
        # Filtrar palabras que no sean solo espacios en blanco
        palabras_filtradas = [palabra.strip() for palabra in fila if palabra.strip()]
        contador_palabras.update(palabras_filtradas)

# Ordenar las palabras por frecuencia de mayor a menor
palabras_ordenadas = contador_palabras.most_common()

# Imprimir la tabla de frecuencia de las palabras ordenadas
print("Tabla de frecuencia de las palabras revista semana:")
print("{:<15} {:<10}".format("Palabra", "Frecuencia"))
for palabra, frecuencia in palabras_ordenadas:
    print("{:<15} {:<10}".format(palabra, frecuencia))
# Out:
# Tabla de frecuencia de las palabras revista semana:
# Palabra         Frecuencia
# paz             157
# gobierno        93
# país            62
# grupo           56
# político        53
# petro           50
# fuerza          42
# farc            42
# presidente      41
# proceso         40
# eln             39
# ley             35
# público         30
# criminal        29
# colombia        28
# colombiano      27
# armado          27
# negociación     26
# militar         23
# año             20
# ilegal          20
# justicia        20
# nacional        19
# territorio      19
# guerrilla       19
# derecho         17
# social          16
# narcotráfico    15
# secuestro       15
# acuerdo         15
# violencia       15
# guerra          14
# deber           14
# constitucional  14
# actual          14
# cambio          14
# diálogo         14
# organización    14
# política        14
# constitución    13
# tiempo          13
# acción          13
# tema            12
# general         12
# institución     12
# orden           12
# seguridad       12
# elección        12
# resultado       12
# frente          12
# fuego           11
# santos          11
# arma            11
# sometimiento    11
# policía         11
# situación       11
# margen          11
# región          10
# caso            10
# ejemplo         10
# negociador      10
# més             10
# banda           10
# víctima         10
# miembro         10
# cárcel          10
# modelo          9
# camino          9
# cesar           9
# cosa            9
# derechos        9
# iván            9
# mesa            9
# conflicto       9
# estrategia      9
# punto           9
# vida            9
# mes             9
# civil           9
# disidencia      9
# proyecto        9
# delincuente     9
# único           9
# oportunidad     9
# negocio         9
# legal           9
# internacional   9
# regional        8
# delegación      8
# corte           8
# alto            8
# haber           8
# zona            8
# jurídico        8
# líder           8
# interés         8
# momento         8
# aliado          8
# marco           8
# beneficio       8
# congreso        7
# decisión        7
# consecuencia    7
# razón           7
# habán           7
# propósito       7
# guerrillero     7
# cumplimiento    7
# hecho           7
# clausewitz      7
# jefe            7
# condición       7
# contrario       7
# realidad        7
# institucionalidad 7
# origen          7
# sociedad        7
# entrevista      7
# juan            7
# grave           7
# márquez         7
# delincuencial   7
# niño            7
# alias           7
# década          6
# problema        6
# lugar           6
# gustavo         6
# pueblo          6
# persona         6
# extorsión       6
# recientemente   6
# soldado         6
# comisionado     6
# económico       6
# idea            6
# humanos         6
# penal           6
# ciudadano       6
# autoridad       6
# forzado         6
# futuro          6
# millón          6
# actor           6
# indígena        6
# llamado         6
# jamás           6
# reclutamiento   6
# fortalecimiento 6
# administración  6
# forma           6
# jep             6
# necesidad       5
# propuesta       5
# departamento    5
# territorial     5
# servicio        5
# mayoría         5
# objetivo        5
# intento         5
# oposición       5
# dispuesto       5
# costo           5
# historio        5
# papel           5
# palabra         5
# solicitud       5
# inicio          5
# población       5
# insurgente      5
# especialmente   5
# protección      5
# ilícito         5
# contexto        5
# central         5
# importante      5
# izquierdo       5
# manuel          5
# actividad       5
# municipio       5
# pena            5
# concesión       5
# control         5
# candidato       5
# imposible       5
# semana          5
# clar            5
# golfo           5
# marquetalia     5
# famoso          5
# cero            5
# delito          5
# carácter        5
# espacio         4
# artículo        4
# sistema         4
# iniciativo      4
# pacífico        4
# antonio         4
# garcía          4
# firmado         4
# convivencia     4
# equipo          4
# ejército        4
# éxito           4
# cualquiera      4
# claridad        4
# acto            4
# naturaleza      4
# circunstancia   4
# norma           4
# homicidio       4
# ciento          4
# economía        4
# incertidumbre   4
# respuesta       4
# humberto        4
# calle           4
# libertad        4
# asesinado       4
# atentado        4
# terrorista      4
# ilegalidad      4
# legalidad       4
# discurso        4
# torno           4
# siglo           4
# completo        4
# evidente        4
# anterior        4
# fe              4
# faltar          4
# pacto           4
# voto            4
# apoyo           4
# ideológico      4
# colombio        4
# responsabilidad 4
# ciclo           4
# méxico          4
# santo           4
# gobernador      4
# error           4
# defensa         4
# labor           4
# tranquilidad    4
# relacionado     4
# fin             4
# francia         4
# línea           4
# mando           4
# campaña         4
# tolerancia      4
# delincuencia    4
# estar           4
# interno         4
# crimar          4
# fiscal          4
# favor           4
# vigencia        3
# voz             3
# debate          3
# audiencia       3
# diciembre       3
# ciudad          3
# amplio          3
# terminado       3
# materio         3
# fundamento      3
# función         3
# capacidad       3
# conjunto        3
# c               3
# vigente         3
# materia         3
# intención       3
# república       3
# fracaso         3
# bandera         3
# convencido      3
# actualmente     3
# caucar          3
# financiación    3
# doctor          3
# tropa           3
# octubre         3
# gent            3
# presenciar      3
# moral           3
# plebiscito      3
# fundamental     3
# valor           3
# vido            3
# integridad      3
# representante   3
# principal       3
# partido         3
# centro          3
# democrático     3
# senador         3
# experto         3
# criterio        3
# camilo          3
# dicho           3
# mínimo          3
# voluntad        3
# nación          3
# rebelión        3
# mordisco        3
# especial        3
# comunidad       3
# distinto        3
# formar          3
# cese            3
# suspensión      3
# paramilitar     3
# rural           3
# familiar        3
# violencio       3
# normativo       3
# lés             3
# humanidad       3
# escenario       3
# tipo            3
# parcial         3
# institucional   3
# luz             3
# m               3
# indulto         3
# base            3
# importancia     3
# recomendación   3
# fuerzas         3
# popular         3
# vía             3
# entrega         3
# rumbo           3
# delictivo       3
# entregar        3
# impacto         3
# respaldo        3
# personal        3
# similar         3
# significativo   3
# histórico       3
# salvador        3
# presidencial    3
# presión         3
# poder           3
# minería         3
# obstante        3
# perjudicial     3
# hombre          3
# mandato         3
# desigualdad     3
# sentido         3
# mano            3
# medida          3
# empresa         3
# amnistía        3
# revolución      3
# historia        3
# presencia       3
# martínez        3
# comandante      3
# carta           3
# real            3
# nariño          3
# explico         3
# comunicado      3
# bilateral       3
# ministro        3
# supuesto        3
# prioridad       3
# impunidad       3
# eduardo         3
# experiencia     3
# transitorio     3
# desmovilización 3
# gaitanista      3
# cabo            3
# urbano          3
# polémico        3
# cifra           3
# máximo          3
# crecimiento     3
# estructura      3
# transicional    3
# componente      3
# reparación      3
# ruta            3
# violento        3
# perdón          3
# capo            3
# narcotraficant  3
# estatus         3
# propuesto       3
# querer          3
# autodefensa     3
# agrupación      3
# menor           3
# masacre         3
# humanitario     3
# negociado       3
# tesis           3
# eleno           3
# perspectiva     3
# expresidente    3
# asunto          2
# geopolítico     2
# luchar          2
# centralismo     2
# patria          2
# período         2
# presidencia     2
# autonómico      2
# debatir         2
# antioquia       2
# desacuerdo      2
# sustento        2
# sencillo        2
# delegatario     2
# terminación     2
# sentencia       2
# excepción       2
# destino         2
# vocación        2
# profundamente   2
# tanto           2
# inmenso         2
# pobre           2
# ingreso         2
# planteamiento   2
# álvaro          2
# recurso         2
# solución        2
# manutención     2
# etapar          2
# televisión      2
# radio           2
# prenso          2
# red             2
# inseguridad     2
# estilo          2
# mayoritario     2
# unidad          2
# obligatorio     2
# indispensable   2
# manifestación   2
# asalto          2
# espectador      2
# noviembre       2
# mil             2


# Aplanar el corpus a una sola lista de palabras y eliminar duplicados
palabras_corpus = list(set([palabra for sublist in contenido_lemas for palabra in sublist]))

# Procesar la palabra objetivo con el modelo spaCy
doc_objetivo = nlp(palabra_objetivo)

# Encuentra palabras similares a la palabra objetivo en el corpus definido
palabras_similares = []

# Calcular la similitud entre la palabra objetivo y cada palabra del corpus
for palabra in palabras_corpus:
    doc_p = nlp(palabra)
    similitud = doc_objetivo.similarity(doc_p)
    palabras_similares.append((palabra, similitud))

# Ordenar las palabras por similitud en orden descendente
palabras_similares = sorted(palabras_similares, key=lambda item: -item[1])

# Preparar los datos para escribir en el archivo CSV
contenido_lemas_csv = [['Palabra', 'Similitud']]  # Encabezados del CSV
for palabra, similitud in palabras_similares:  
    contenido_lemas_csv.append([palabra, f"{similitud:.4f}"])

# Escribir los datos en un nuevo archivo CSV
with open('similitud_paz_semana.csv', 'w', newline='', encoding='utf-8-sig') as archivo:
    escritor_csv = csv.writer(archivo)
    escritor_csv.writerows(contenido_lemas_csv)

# Leer y mostrar el contenido del archivo CSV
with open('similitud_paz_semana.csv', 'r', newline='', encoding='utf-8-sig') as archivo:
    lector_csv = csv.reader(archivo)
    for fila in lector_csv:
        print(fila)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_15560\1222381014.py:19: UserWarning: [W008] Evaluating Doc.similarity based on empty vectors.
#   similitud = doc_objetivo.similarity(doc_p)
# ['Palabra', 'Similitud']
# ['paz', '1.0000']
# ['reconciliación', '0.5732']
# ['esperanza', '0.5374']
# ['pacífico', '0.5349']
# ['democracia', '0.5209']
# ['libertad', '0.5198']
# ['tregua', '0.5152']
# ['justicia', '0.5142']
# ['tranquilidad', '0.5116']
# ['dignidad', '0.4840']
# ['patria', '0.4744']
# ['desarme', '0.4654']
# ['impunidad', '0.4524']
# ['voluntad', '0.4509']
# ['pacto', '0.4465']
# ['democrático', '0.4452']
# ['gobernabilidad', '0.4436']
# ['convivencia', '0.4405']
# ['diálogo', '0.4317']
# ['humanitario', '0.4314']
# ['pacificado', '0.4274']
# ['pacificación', '0.4240']
# ['fortaleza', '0.4229']
# ['confianza', '0.4206']
# ['guerra', '0.4110']
# ['humanidad', '0.4106']
# ['liberación', '0.4087']
# ['promesa', '0.4079']
# ['democráticamente', '0.4069']
# ['perdón', '0.4025']
# ['espíritu', '0.4009']
# ['fe', '0.3996']
# ['pueblo', '0.3982']
# ['respeto', '0.3972']
# ['beligerancia', '0.3971']
# ['hostilidad', '0.3948']
# ['guerrilla', '0.3921']
# ['insurgencia', '0.3912']
# ['insurgente', '0.3903']
# ['libertades', '0.3900']
# ['nación', '0.3885']
# ['legitimidad', '0.3883']
# ['bilateralidad', '0.3876']
# ['silencio', '0.3851']
# ['convicción', '0.3845']
# ['rendición', '0.3837']
# ['conflicto', '0.3825']
# ['ciudadanía', '0.3820']
# ['desconfianza', '0.3790']
# ['desilusión', '0.3786']
# ['desmovilización', '0.3775']
# ['verdadero', '0.3758']
# ['inocencia', '0.3756']
# ['tolerancia', '0.3749']
# ['gobernante', '0.3741']
# ['esperanzador', '0.3738']
# ['salvador', '0.3703']
# ['consenso', '0.3692']
# ['anhelo', '0.3685']
# ['complacencia', '0.3682']
# ['conciencia', '0.3680']
# ['insurrecto', '0.3603']
# ['anhelado', '0.3599']
# ['amor', '0.3593']
# ['próspero', '0.3586']
# ['firmemente', '0.3584']
# ['autodefensa', '0.3583']
# ['confrontación', '0.3574']
# ['república', '0.3571']
# ['vida', '0.3549']
# ['paciencia', '0.3543']
# ['verdaderamente', '0.3542']
# ['compromiso', '0.3533']
# ['traición', '0.3526']
# ['cooperación', '0.3515']
# ['incansablemente', '0.3512']
# ['generosidad', '0.3508']
# ['santismo', '0.3500']
# ['imperio', '0.3499']
# ['disidencia', '0.3447']
# ['luchar', '0.3444']
# ['paramilitarismo', '0.3431']
# ['revolución', '0.3421']
# ['integridad', '0.3381']
# ['honradamente', '0.3367']
# ['celeridad', '0.3366']
# ['optimismo', '0.3366']
# ['política', '0.3331']
# ['bilateral', '0.3329']
# ['misión', '0.3329']
# ['profundamente', '0.3324']
# ['plebiscito', '0.3312']
# ['gobernación', '0.3310']
# ['revolucionario', '0.3309']
# ['gobierno', '0.3294']
# ['conquistadora', '0.3281']
# ['guerrillero', '0.3277']
# ['incertidumbre', '0.3273']
# ['prioridad', '0.3271']
# ['amnistía', '0.3269']
# ['coherencia', '0.3263']
# ['creencia', '0.3261']
# ['violencia', '0.3256']
# ['negociación', '0.3244']
# ['humanización', '0.3239']
# ['indefensa', '0.3216']
# ['nuevamente', '0.3204']
# ['definitivamente', '0.3202']
# ['negociable', '0.3199']
# ['certeza', '0.3195']
# ['legalidad', '0.3193']
# ['respetar', '0.3193']
# ['equitativo', '0.3185']
# ['futuro', '0.3180']
# ['unidad', '0.3180']
# ['procurar', '0.3177']
# ['institucionalidad', '0.3165']
# ['autonomía', '0.3159']
# ['neoliberalismo', '0.3158']
# ['prontamente', '0.3131']
# ['federalismo', '0.3129']
# ['fuerza', '0.3126']
# ['piedad', '0.3125']
# ['mente', '0.3125']
# ['sacrificarla', '0.3115']
# ['paramilitar', '0.3105']
# ['rebelión', '0.3102']
# ['negociador', '0.3101']
# ['geopolítico', '0.3098']
# ['desigualdad', '0.3097']
# ['políticamente', '0.3091']
# ['distensión', '0.3087']
# ['gente', '0.3086']
# ['coalición', '0.3073']
# ['aniquilamiento', '0.3073']
# ['francia', '0.3071']
# ['narcoguerrilla', '0.3069']
# ['claridad', '0.3064']
# ['oposición', '0.3061']
# ['aspiración', '0.3059']
# ['desesperado', '0.3057']
# ['sociedad', '0.3056']
# ['inseguridad', '0.3055']
# ['naturaleza', '0.3053']
# ['salvadoreño', '0.3044']
# ['arrogancia', '0.3040']
# ['preocupación', '0.3037']
# ['autoridad', '0.3035']
# ['encaminarlo', '0.3032']
# ['permanente', '0.3029']
# ['sangriento', '0.3028']
# ['político', '0.3021']
# ['ambición', '0.3016']
# ['indignación', '0.3012']
# ['comunidad', '0.3011']
# ['convencido', '0.3007']
# ['riqueza', '0.3001']
# ['indefenso', '0.2999']
# ['feliz', '0.2999']
# ['defensa', '0.2999']
# ['sometimiento', '0.2995']
# ['virtud', '0.2991']
# ['fin', '0.2990']
# ['indefensión', '0.2985']
# ['fuerzas', '0.2984']
# ['desacuerdo', '0.2984']
# ['combatiente', '0.2980']
# ['inequidad', '0.2978']
# ['cesar', '0.2968']
# ['profundo', '0.2946']
# ['insatisfacción', '0.2945']
# ['reflexión', '0.2941']
# ['orden', '0.2935']
# ['humanos', '0.2931']
# ['oportunidad', '0.2925']
# ['subversión', '0.2919']
# ['legado', '0.2914']
# ['muerte', '0.2913']
# ['conclusión', '0.2907']
# ['regreso', '0.2905']
# ['victoria', '0.2897']
# ['fortalecimiento', '0.2888']
# ['impotencia', '0.2887']
# ['lucho', '0.2877']
# ['fuerzo', '0.2874']
# ['lastimosamente', '0.2874']
# ['actitud', '0.2871']
# ['aliado', '0.2871']
# ['narcoterrorista', '0.2869']
# ['seguridad', '0.2863']
# ['realidad', '0.2846']
# ['veladamente', '0.2836']
# ['camino', '0.2835']
# ['enemigo', '0.2824']
# ['país', '0.2823']
# ['moral', '0.2821']
# ['mandatario', '0.2819']
# ['destrucción', '0.2811']
# ['activamente', '0.2803']
# ['favor', '0.2799']
# ['poder', '0.2797']
# ['discernimiento', '0.2797']
# ['debilidad', '0.2792']
# ['confusión', '0.2790']
# ['consecución', '0.2781']
# ['terrorista', '0.2778']
# ['campesino', '0.2777']
# ['amenazar', '0.2775']
# ['santos', '0.2769']
# ['campesina', '0.2767']
# ['civil', '0.2766']
# ['progresar', '0.2759']
# ['precisamente', '0.2755']
# ['mandato', '0.2749']
# ['expectativa', '0.2748']
# ['disidente', '0.2747']
# ['ciudadano', '0.2746']
# ['exterminio', '0.2745']
# ['sensación', '0.2745']
# ['paradójicamente', '0.2738']
# ['discusión', '0.2738']
# ['familia', '0.2736']
# ['bolivariano', '0.2736']
# ['milicia', '0.2730']
# ['secreto', '0.2729']
# ['coherente', '0.2726']
# ['desmoralización', '0.2721']
# ['libremente', '0.2720']
# ['doctrina', '0.2715']
# ['seguramente', '0.2714']
# ['carlos', '0.2711']
# ['condición', '0.2708']
# ['agenda', '0.2707']
# ['constituyente', '0.2707']
# ['farc', '0.2705']
# ['pleno', '0.2702']
# ['barbarie', '0.2699']
# ['conversación', '0.2699']
# ['sentencia', '0.2696']
# ['tristemente', '0.2695']
# ['corrupción', '0.2693']
# ['superioridad', '0.2693']
# ['sincero', '0.2691']
# ['pretexto', '0.2682']
# ['contundencia', '0.2681']
# ['constitucional', '0.2679']
# ['rebelde', '0.2677']
# ['neoliberal', '0.2675']
# ['negociado', '0.2675']
# ['imperativo', '0.2674']
# ['cercanía', '0.2671']
# ['contribuir', '0.2666']
# ['seriamente', '0.2666']
# ['triunfo', '0.2663']
# ['resquebrajamiento', '0.2662']
# ['consciente', '0.2656']
# ['decisión', '0.2653']
# ['secular', '0.2643']
# ['reforma', '0.2640']
# ['lamentablemente', '0.2637']
# ['transicional', '0.2635']
# ['amazonía', '0.2635']
# ['enteramente', '0.2632']
# ['vocación', '0.2632']
# ['santo', '0.2632']
# ['inocente', '0.2631']
# ['contrario', '0.2630']
# ['retorno', '0.2630']
# ['íntimamente', '0.2628']
# ['desastroso', '0.2628']
# ['solución', '0.2612']
# ['incoherencia', '0.2612']
# ['atrocidad', '0.2606']
# ['estatus', '0.2600']
# ['acuerdo', '0.2597']
# ['legítimo', '0.2596']
# ['ilegalidad', '0.2596']
# ['propósito', '0.2595']
# ['injerencia', '0.2591']
# ['forzosamente', '0.2588']
# ['capitalista', '0.2585']
# ['absoluto', '0.2579']
# ['presidencia', '0.2579']
# ['combatientes', '0.2578']
# ['razón', '0.2574']
# ['intención', '0.2571']
# ['económico', '0.2570']
# ['desgraciadamente', '0.2569']
# ['campamento', '0.2567']
# ['electoral', '0.2557']
# ['sustento', '0.2554']
# ['constitución', '0.2552']
# ['economía', '0.2544']
# ['exigencia', '0.2541']
# ['inconformidad', '0.2536']
# ['ministerio', '0.2536']
# ['contraparte', '0.2535']
# ['militar', '0.2534']
# ['motivación', '0.2532']
# ['pro', '0.2531']
# ['empeño', '0.2531']
# ['situación', '0.2530']
# ['terror', '0.2528']
# ['resucitado', '0.2526']
# ['desear', '0.2526']
# ['delincuencia', '0.2525']
# ['excarcelación', '0.2525']
# ['liderazgo', '0.2524']
# ['duradero', '0.2523']
# ['realmente', '0.2522']
# ['crisis', '0.2517']
# ['acercamiento', '0.2514']
# ['territorio', '0.2510']
# ['jamás', '0.2510']
# ['necesidad', '0.2504']
# ['ejército', '0.2500']
# ['inevitable', '0.2498']
# ['imposibilidad', '0.2496']
# ['inteligencia', '0.2495']
# ['momento', '0.2490']
# ['dejación', '0.2490']
# ['argelia', '0.2485']
# ['responsabilidad', '0.2483']
# ['territorial', '0.2479']
# ['firmante', '0.2476']
# ['autenticidad', '0.2475']
# ['manifestación', '0.2471']
# ['órden', '0.2471']
# ['irreversible', '0.2461']
# ['convenio', '0.2457']
# ['logro', '0.2457']
# ['mensaje', '0.2454']
# ['uribe', '0.2449']
# ['cambio', '0.2448']
# ['legislativo', '0.2448']
# ['indígena', '0.2446']
# ['sueño', '0.2445']
# ['obstáculo', '0.2440']
# ['fundamento', '0.2435']
# ['esfuerzo', '0.2433']
# ['voluntario', '0.2431']
# ['fracaso', '0.2431']
# ['alegre', '0.2429']
# ['candidez', '0.2428']
# ['presidencial', '0.2428']
# ['cese', '0.2427']
# ['imposible', '0.2424']
# ['condena', '0.2422']
# ['palabra', '0.2417']
# ['inmediatamente', '0.2417']
# ['criminalidad', '0.2410']
# ['paragua', '0.2407']
# ['sentido', '0.2407']
# ['gobernador', '0.2405']
# ['importancia', '0.2404']
# ['unilateral', '0.2395']
# ['digno', '0.2394']
# ['expresidente', '0.2393']
# ['inmenso', '0.2391']
# ['visión', '0.2390']
# ['institucional', '0.2387']
# ['apoyo', '0.2386']
# ['constante', '0.2382']
# ['partidista', '0.2378']
# ['asimismo', '0.2372']
# ['honesto', '0.2368']
# ['continuo', '0.2368']
# ['adopción', '0.2365']
# ['gravemente', '0.2364']
# ['desconcertante', '0.2361']
# ['posiblemente', '0.2355']
# ['renovación', '0.2353']
# ['indulto', '0.2351']
# ['vigencia', '0.2350']
# ['penitenciario', '0.2350']
# ['preservación', '0.2348']
# ['simplemente', '0.2346']
# ['destructivo', '0.2344']
# ['estadista', '0.2344']
# ['legalización', '0.2344']
# ['violento', '0.2341']
# ['social', '0.2339']
# ['gubernamental', '0.2339']
# ['antioquia', '0.2327']
# ['reconocimiento', '0.2325']
# ['respuesta', '0.2325']
# ['competitividad', '0.2324']
# ['restaurativo', '0.2322']
# ['históricamente', '0.2322']
# ['ciudad', '0.2321']
# ['fundante', '0.2321']
# ['centroamericano', '0.2321']
# ['fortuna', '0.2318']
# ['condicionalidad', '0.2317']
# ['narcotráfico', '0.2316']
# ['asamblea', '0.2316']
# ['resistencia', '0.2310']
# ['circunstancia', '0.2307']
# ['intento', '0.2302']
# ['idea', '0.2300']
# ['abrazo', '0.2299']
# ['existencia', '0.2294']
# ['colombia', '0.2294']
# ['lugar', '0.2293']
# ['fracasado', '0.2292']
# ['contundente', '0.2291']
# ['reunión', '0.2291']
# ['ideología', '0.2290']
# ['pactado', '0.2288']
# ['ciencia', '0.2287']
# ['reinsertado', '0.2287']
# ['armado', '0.2285']
# ['terminación', '0.2282']
# ['derecho', '0.2275']
# ['parlamentario', '0.2275']
# ['lamentable', '0.2275']
# ['derechos', '0.2272']
# ['desenfreno', '0.2272']
# ['postura', '0.2272']
# ['ayuda', '0.2268']
# ['hombre', '0.2265']
# ['cinismo', '0.2262']
# ['colombiano', '0.2256']
# ['siquiera', '0.2255']
# ['excomandante', '0.2255']
# ['involucramiento', '0.2253']
# ['institución', '0.2250']
# ['tensión', '0.2249']
# ['despropósito', '0.2249']
# ['reincorporación', '0.2244']
# ['fundamental', '0.2241']
# ['concertado', '0.2234']
# ['miedo', '0.2233']
# ['ambicioso', '0.2229']
# ['posibilidad', '0.2229']
# ['posterioridad', '0.2227']
# ['fuerte', '0.2221']
# ['abandono', '0.2220']
# ['ánimo', '0.2210']
# ['perspectiva', '0.2208']
# ['incapacidad', '0.2205']
# ['igualmente', '0.2203']
# ['sustentar', '0.2199']
# ['ser él', '0.2198']
# ['deliberado', '0.2194']
# ['bandera', '0.2192']
# ['niñez', '0.2191']
# ['intentar', '0.2188']
# ['ente', '0.2186']
# ['cooptación', '0.2185']
# ['tentación', '0.2183']
# ['relación', '0.2181']
# ['organización', '0.2176']
# ['suficiente', '0.2175']
# ['asunción', '0.2175']
# ['jerarquía', '0.2172']
# ['posible', '0.2170']
# ['tercamente', '0.2168']
# ['discurso', '0.2167']
# ['rogar', '0.2164']
# ['estallido', '0.2163']
# ['sevicia', '0.2162']
# ['amenazado', '0.2162']
# ['afinidad', '0.2159']
# ['justificación', '0.2158']
# ['adoctrinamiento', '0.2154']
# ['debatir', '0.2154']
# ['irrespetuoso', '0.2151']
# ['debate', '0.2148']
# ['tiempo', '0.2142']
# ['crucial', '0.2141']
# ['brevedad', '0.2141']
# ['ambiciosa', '0.2140']
# ['secuestrar', '0.2138']
# ['acordado', '0.2138']
# ['garantir', '0.2138']
# ['ley', '0.2138']
# ['alguien', '0.2133']
# ['narcotraficante', '0.2129']
# ['destino', '0.2129']
# ['régimen', '0.2127']
# ['declaración', '0.2126']
# ['estratégico', '0.2125']
# ['infortunio', '0.2125']
# ['legislativa', '0.2122']
# ['transitar', '0.2122']
# ['anticonstitucional', '0.2121']
# ['claramente', '0.2121']
# ['posición', '0.2120']
# ['genocidio', '0.2119']
# ['saciedad', '0.2116']
# ['dispuesto', '0.2115']
# ['esencial', '0.2115']
# ['tutelar', '0.2115']
# ['oportunista', '0.2113']
# ['presente', '0.2113']
# ['debilitamiento', '0.2112']
# ['personalmente', '0.2111']
# ['desencantado', '0.2109']
# ['vandalismo', '0.2106']
# ['iniciativa', '0.2102']
# ['acción', '0.2102']
# ['lejos', '0.2101']
# ['presidente', '0.2100']
# ['facto', '0.2098']
# ['guatemala', '0.2097']
# ['querer', '0.2092']
# ['interior', '0.2090']
# ['ilusorio', '0.2076']
# ['indispensable', '0.2075']
# ['historia', '0.2069']
# ['centralismo', '0.2068']
# ['ideológico', '0.2064']
# ['ministro', '0.2063']
# ['acaso', '0.2058']
# ['consejo', '0.2058']
# ['indefinido', '0.2057']
# ['precedente', '0.2053']
# ['semejante', '0.2052']
# ['lección', '0.2051']
# ['dios', '0.2048']
# ['distinción', '0.2046']
# ['cumplimiento', '0.2045']
# ['tanto', '0.2045']
# ['importante', '0.2044']
# ['merced', '0.2043']
# ['juicio', '0.2043']
# ['protección', '0.2041']
# ['asegurable', '0.2040']
# ['aprobación', '0.2037']
# ['deber', '0.2035']
# ['consecuencia', '0.2035']
# ['delegación', '0.2033']
# ['comicio', '0.2032']
# ['familiar', '0.2032']
# ['persona', '0.2029']
# ['bienvenido', '0.2027']
# ['necesitado', '0.2024']
# ['medio', '0.2023']
# ['cuestión', '0.2022']
# ['secuestrado', '0.2020']
# ['posesión', '0.2018']
# ['seguro', '0.2013']
# ['interno', '0.2011']
# ['presencia', '0.2011']
# ['desconcentración', '0.2009']
# ['adolescencia', '0.2008']
# ['integralmente', '0.2005']
# ['nariño', '0.2003']
# ['tragedia', '0.2002']
# ['ordenado', '0.1995']
# ['respaldo', '0.1995']
# ['manifiesto', '0.1991']
# ['jurisdicción', '0.1989']
# ['inexplicablemente', '0.1988']
# ['opinión', '0.1988']
# ['cubano', '0.1987']
# ['secuestro', '0.1984']
# ['forzar', '0.1983']
# ['delincuente', '0.1983']
# ['transitorio', '0.1982']
# ['cárcel', '0.1980']
# ['lema', '0.1980']
# ['repudio', '0.1974']
# ['fundamentalmente', '0.1973']
# ['avance', '0.1973']
# ['aldea', '0.1971']
# ['revelación', '0.1971']
# ['vilmente', '0.1968']
# ['elección', '0.1965']
# ['evidente', '0.1957']
# ['yugo', '0.1955']
# ['inexperiencia', '0.1953']
# ['fernando', '0.1951']
# ['subversivo', '0.1951']
# ['promuevo', '0.1950']
# ['garantía', '0.1949']
# ['humilde', '0.1949']
# ['narco', '0.1945']
# ['tarea', '0.1944']
# ['comprensible', '0.1941']
# ['trinchera', '0.1937']
# ['comunicación', '0.1935']
# ['defendido', '0.1933']
# ['paradójico', '0.1932']
# ['serio', '0.1931']
# ['hermano', '0.1931']
# ['desprotegido', '0.1930']
# ['mistificación', '0.1929']
# ['vuelta', '0.1928']
# ['garant', '0.1927']
# ['alcanzarla', '0.1927']
# ['senado', '0.1927']
# ['invitándola', '0.1921']
# ['beneficio', '0.1920']
# ['respalda', '0.1918']
# ['invocado', '0.1915']
# ['recordar', '0.1914']
# ['necesario', '0.1914']
# ['santander', '0.1913']
# ['sumido', '0.1908']
# ['expedito', '0.1908']
# ['mejoramiento', '0.1907']
# ['esperado', '0.1905']
# ['preso', '0.1901']
# ['viabilidad', '0.1900']
# ['región', '0.1899']
# ['quieto', '0.1896']
# ['población', '0.1891']
# ['atentatorio', '0.1889']
# ['enormemente', '0.1889']
# ['triste', '0.1889']
# ['agradecido', '0.1888']
# ['meta', '0.1886']
# ['sedición', '0.1882']
# ['capital', '0.1879']
# ['devoto', '0.1876']
# ['único', '0.1874']
# ['influencia', '0.1873']
# ['experiencia', '0.1872']
# ['occidental', '0.1870']
# ['flexibilidad', '0.1868']
# ['común', '0.1868']
# ['participación', '0.1864']
# ['casa', '0.1862']
# ['gent', '0.1862']
# ['búsqueda', '0.1862']
# ['cometido', '0.1861']
# ['completamente', '0.1859']
# ['concesión', '0.1858']
# ['contexto', '0.1855']
# ['prisa', '0.1851']
# ['cosa', '0.1849']
# ['violación', '0.1848']
# ['conocimiento', '0.1848']
# ['objeción', '0.1845']
# ['movimiento', '0.1840']
# ['tropa', '0.1838']
# ['eln', '0.1838']
# ['obstante', '0.1838']
# ['claro', '0.1837']
# ['propuesta', '0.1837']
# ['atentado', '0.1834']
# ['frente', '0.1833']
# ['filosofía', '0.1832']
# ['terminado', '0.1831']
# ['masacre', '0.1830']
# ['razonable', '0.1829']
# ['cauca', '0.1829']
# ['suficientemente', '0.1828']
# ['ordenamiento', '0.1827']
# ['objetivo', '0.1817']
# ['complementariedad', '0.1814']
# ['retroceso', '0.1811']
# ['compatriota', '0.1808']
# ['preámbulo', '0.1807']
# ['judicial', '0.1805']
# ['marco', '0.1802']
# ['reparación', '0.1801']
# ['nacional', '0.1801']
# ['mínimamente', '0.1799']
# ['doloroso', '0.1797']
# ['librado', '0.1796']
# ['nacionalización', '0.1795']
# ['internacional', '0.1793']
# ['defensor', '0.1793']
# ['reiterado', '0.1792']
# ['antioqueño', '0.1791']
# ['supuesto', '0.1790']
# ['positivo', '0.1789']
# ['integral', '0.1786']
# ['comandante', '0.1785']
# ['maniatado', '0.1782']
# ['trabajar', '0.1782']
# ['estrategia', '0.1781']
# ['universidad', '0.1778']
# ['dicho', '0.1771']
# ['espacio', '0.1771']
# ['perverso', '0.1771']
# ['deslegitimado', '0.1769']
# ['cura', '0.1767']
# ['audiencia', '0.1766']
# ['delincuencial', '0.1765']
# ['infinito', '0.1761']
# ['condenado', '0.1760']
# ['trance', '0.1756']
# ['apresurado', '0.1751']
# ['enseñanza', '0.1751']
# ['oportuna', '0.1750']
# ['asunto', '0.1749']
# ['disputa', '0.1748']
# ['manos', '0.1746']
# ['competencia', '0.1745']
# ['cobarde', '0.1744']
# ['burocrático', '0.1743']
# ['soberbio', '0.1739']
# ['estatutario', '0.1735']
# ['particularidad', '0.1734']
# ['eficacia', '0.1732']
# ['excusa', '0.1731']
# ['resguardo', '0.1729']
# ['tangible', '0.1725']
# ['medida', '0.1723']
# ['perspectivo', '0.1722']
# ['señor', '0.1722']
# ['causa', '0.1720']
# ['hacerlo', '0.1720']
# ['muerto', '0.1719']
# ['votación', '0.1717']
# ['partida', '0.1717']
# ['designación', '0.1708']
# ['vigente', '0.1705']
# ['extranjero', '0.1704']
# ['jurídico', '0.1702']
# ['perdido', '0.1702']
# ['nobel', '0.1698']
# ['éxito', '0.1698']
# ['voto', '0.1698']
# ['implementación', '0.1694']
# ['fiel', '0.1694']
# ['motivo', '0.1694']
# ['sarmiento', '0.1691']
# ['allá', '0.1685']
# ['prolongado', '0.1681']
# ['propuesto', '0.1680']
# ['someterlo', '0.1680']
# ['mujer', '0.1677']
# ['negativamente', '0.1675']
# ['criminal', '0.1675']
# ['milagroso', '0.1673']
# ['retiro', '0.1671']
# ['escollo', '0.1668']
# ['establecimiento', '0.1668']
# ['noticia', '0.1667']
# ['comisión', '0.1664']
# ['campaña', '0.1662']
# ['perfectamente', '0.1659']
# ['arreglo', '0.1659']
# ['clar', '0.1658']
# ['delimitación', '0.1657']
# ['decreto', '0.1657']
# ['victimario', '0.1655']
# ['pilar', '0.1654']
# ['fuego', '0.1654']
# ['mara', '0.1654']
# ['lado', '0.1653']
# ['congresista', '0.1653']
# ['pobre', '0.1653']
# ['sujeción', '0.1652']
# ['escenario', '0.1652']
# ['atención', '0.1652']
# ['fusilamiento', '0.1652']
# ['temer', '0.1651']
# ['partido', '0.1646']
# ['tajante', '0.1643']
# ['primero', '0.1640']
# ['pena', '0.1639']
# ['inteligente', '0.1636']
# ['consideración', '0.1632']
# ['soldado', '0.1628']
# ['comisionado', '0.1624']
# ['pesar', '0.1623']
# ['virgilio', '0.1623']
# ['bloqueo', '0.1623']
# ['francisco', '0.1621']
# ['histórico', '0.1616']
# ['contrato', '0.1614']
# ['dolor', '0.1611']
# ['apertura', '0.1611']
# ['tutela', '0.1608']
# ['allegado', '0.1607']
# ['alcaldía', '0.1607']
# ['trabajo', '0.1606']
# ['vulnerable', '0.1605']
# ['gradualmente', '0.1601']
# ['congreso', '0.1600']
# ['cerco', '0.1600']
# ['alternativo', '0.1599']
# ['empeñado', '0.1598']
# ['trabajen', '0.1594']
# ['protegido', '0.1593']
# ['cobijado', '0.1593']
# ['indeseable', '0.1592']
# ['putumayo', '0.1591']
# ['mayoritario', '0.1588']
# ['invención', '0.1587']
# ['oriental', '0.1586']
# ['ocasión', '0.1585']
# ['significativo', '0.1581']
# ['aprendido', '0.1581']
# ['patraña', '0.1573']
# ['puesto', '0.1571']
# ['presión', '0.1567']
# ['almirante', '0.1566']
# ['mayoría', '0.1566']
# ['utópico', '0.1563']
# ['incierto', '0.1562']
# ['siguiente', '0.1561']
# ['crecimiento', '0.1560']
# ['crimen', '0.1559']
# ['alternativa', '0.1559']
# ['valioso', '0.1559']
# ['querido', '0.1555']
# ['comunicado', '0.1552']
# ['monopolio', '0.1552']
# ['costa', '0.1550']
# ['mentiroso', '0.1550']
# ['expedita', '0.1550']
# ['instrumentalización', '0.1548']
# ['éxtasis', '0.1547']
# ['real', '0.1545']
# ['mando', '0.1543']
# ['carta', '0.1541']
# ['heleno', '0.1541']
# ['engaño', '0.1540']
# ['cuestionamiento', '0.1539']
# ['estrictamente', '0.1536']
# ['nadies', '0.1534']
# ['administración', '0.1533']
# ['labor', '0.1531']
# ['blando', '0.1530']
# ['viable', '0.1529']
# ['legal', '0.1528']
# ['principado', '0.1528']
# ['sorprendente', '0.1527']
# ['unido', '0.1525']
# ['hecho', '0.1525']
# ['violadores', '0.1524']
# ['presenciar', '0.1524']
# ['unánime', '0.1522']
# ['cualquiera', '0.1518']
# ['firmado', '0.1514']
# ['prometedor', '0.1510']
# ['pertinente', '0.1509']
# ['desarrollo', '0.1503']
# ['vecino', '0.1502']
# ['populista', '0.1499']
# ['excepción', '0.1497']
# ['rumbo', '0.1497']
# ['colectivo', '0.1487']
# ['violado', '0.1485']
# ['historio', '0.1483']
# ['cooptado', '0.1482']
# ['meramente', '0.1478']
# ['entrante', '0.1471']
# ['recientemente', '0.1470']
# ['extorsión', '0.1468']
# ['paso', '0.1466']
# ['discutible', '0.1465']
# ['promoción', '0.1464']
# ['estrofa', '0.1462']
# ['puerto', '0.1461']
# ['conducta', '0.1461']
# ['escudo', '0.1457']
# ['crítica', '0.1456']
# ['diferenciación', '0.1455']
# ['argumento', '0.1452']
# ['tontería', '0.1451']
# ['fuente', '0.1450']
# ['incentivo', '0.1448']
# ['dominio', '0.1446']
# ['financiación', '0.1446']
# ['plan', '0.1444']
# ['perjudicial', '0.1442']
# ['resultado', '0.1437']
# ['específicamente', '0.1436']
# ['suspensión', '0.1435']
# ['laboral', '0.1435']
# ['petro', '0.1434']
# ['cesión', '0.1433']
# ['planteamiento', '0.1432']
# ['interés', '0.1429']
# ['trar', '0.1428']
# ['sustancia', '0.1426']
# ['definición', '0.1423']
# ['horacio', '0.1423']
# ['establecido', '0.1422']
# ['operación', '0.1418']
# ['proceso', '0.1416']
# ['rural', '0.1416']
# ['enterado', '0.1416']
# ['veredal', '0.1415']
# ['votante', '0.1413']
# ['diverso', '0.1411']
# ['acto', '0.1409']
# ['mecanismo', '0.1403']
# ['espinoso', '0.1400']
# ['considerablemente', '0.1395']
# ['guardias', '0.1394']
# ['policía', '0.1393']
# ['complejidad', '0.1392']
# ['danilo', '0.1390']
# ['obligado', '0.1389']
# ['trino', '0.1389']
# ['parte', '0.1387']
# ['sugerencia', '0.1386']
# ['eficiente', '0.1383']
# ['lineamiento', '0.1382']
# ['estar', '0.1380']
# ['significativamente', '0.1379']
# ['eufemismos', '0.1378']
# ['dificultad', '0.1375']
# ['mesa', '0.1373']
# ['obstrucción', '0.1373']
# ['víctima', '0.1372']
# ['resto', '0.1360']
# ['candidato', '0.1358']
# ['forzado', '0.1351']
# ['espontáneo', '0.1350']
# ['agente', '0.1349']
# ['cabecilla', '0.1346']
# ['prosélito', '0.1344']
# ['mexicano', '0.1342']
# ['actualidad', '0.1340']
# ['botín', '0.1339']
# ['líder', '0.1335']
# ['cimarrona', '0.1334']
# ['representante', '0.1333']
# ['escudero', '0.1332']
# ['ocurrencia', '0.1331']
# ['norteamericano', '0.1331']
# ['irresponsable', '0.1329']
# ['inicuo', '0.1329']
# ['costado', '0.1329']
# ['asesinado', '0.1325']
# ['violatorio', '0.1323']
# ['particular', '0.1322']
# ['atraso', '0.1320']
# ['sanción', '0.1320']
# ['prestigio', '0.1318']
# ['duda', '0.1318']
# ['torturado', '0.1315']
# ['cuba', '0.1314']
# ['productivo', '0.1313']
# ['maestro', '0.1311']
# ['materia', '0.1310']
# ['orientación', '0.1310']
# ['nariñense', '0.1307']
# ['voz', '0.1303']
# ['atrás', '0.1303']
# ['cuerpo', '0.1302']
# ['subyacente', '0.1301']
# ['punitivo', '0.1298']
# ['inalcanzable', '0.1298']
# ['directamente', '0.1298']
# ['prusiano', '0.1297']
# ['niñas', '0.1297']
# ['damnificado', '0.1293']
# ['deporte', '0.1291']
# ['autorización', '0.1288']
# ['convocatoria', '0.1287']
# ['inicio', '0.1286']
# ['viejo', '0.1286']
# ['ordinario', '0.1283']
# ['regional', '0.1282']
# ['observación', '0.1282']
# ['américa', '0.1281']
# ['arbitrario', '0.1281']
# ['dictaría', '0.1274']
# ['formal', '0.1273']
# ['bonificación', '0.1272']
# ['nadi', '0.1272']
# ['escobar', '0.1266']
# ['sucedáneo', '0.1265']
# ['adecuado', '0.1254']
# ['ojalá', '0.1251']
# ['orilla', '0.1250']
# ['posteriormente', '0.1250']
# ['personal', '0.1248']
# ['poético', '0.1246']
# ['reclutamiento', '0.1245']
# ['multiplicación', '0.1245']
# ['capacidad', '0.1243']
# ['funcionario', '0.1240']
# ['regalía', '0.1239']
# ['documento', '0.1239']
# ['problema', '0.1234']
# ['divulgación', '0.1232']
# ['existente', '0.1231']
# ['drogar', '0.1230']
# ['manutención', '0.1228']
# ['débil', '0.1227']
# ['especie', '0.1226']
# ['agrupación', '0.1225']
# ['entregar', '0.1224']
# ['especialmente', '0.1220']
# ['opción', '0.1217']
# ['niño', '0.1215']
# ['inversión', '0.1214']
# ['desgastar', '0.1214']
# ['confundida', '0.1213']
# ['precedido', '0.1213']
# ['diferencia', '0.1212']
# ['mafia', '0.1206']
# ['recomendación', '0.1201']
# ['admisible', '0.1195']
# ['innumerable', '0.1194']
# ['afectación', '0.1193']
# ['minería', '0.1190']
# ['mundial', '0.1187']
# ['popular', '0.1187']
# ['improbable', '0.1183']
# ['norma', '0.1174']
# ['decepcionante', '0.1171']
# ['bombardeo', '0.1171']
# ['largo', '0.1170']
# ['cuestionable', '0.1160']
# ['asesinato', '0.1157']
# ['mayor', '0.1156']
# ['estructural', '0.1156']
# ['vocero', '0.1155']
# ['entrado', '0.1155']
# ['sierra', '0.1148']
# ['rampante', '0.1147']
# ['crítico', '0.1146']
# ['plaza', '0.1146']
# ['altamente', '0.1144']
# ['época', '0.1144']
# ['unísono', '0.1143']
# ['disposición', '0.1142']
# ['mañana', '0.1142']
# ['duro', '0.1141']
# ['actividad', '0.1141']
# ['penal', '0.1138']
# ['mal', '0.1136']
# ['fiscal', '0.1134']
# ['afán', '0.1133']
# ['escandaloso', '0.1133']
# ['calidad', '0.1131']
# ['gómez', '0.1131']
# ['próximo', '0.1128']
# ['incidente', '0.1126']
# ['refundido', '0.1124']
# ['rincón', '0.1123']
# ['desconcentrado', '0.1122']
# ['margen', '0.1121']
# ['responsable', '0.1118']
# ['consistente', '0.1117']
# ['información', '0.1113']
# ['olivo', '0.1112']
# ['forma', '0.1109']
# ['abundante', '0.1106']
# ['precepto', '0.1105']
# ['gracias', '0.1102']
# ['problemático', '0.1100']
# ['cegado', '0.1098']
# ['sindicato', '0.1096']
# ['efectivo', '0.1089']
# ['formar', '0.1088']
# ['sabotaje', '0.1087']
# ['arma', '0.1086']
# ['preciso', '0.1083']
# ['luz', '0.1082']
# ['gerencia', '0.1075']
# ['ficción', '0.1075']
# ['cercano', '0.1072']
# ['actual', '0.1072']
# ['normativo', '0.1072']
# ['costillar', '0.1070']
# ['enorme', '0.1069']
# ['carácter', '0.1063']
# ['alcalde', '0.1059']
# ['firma', '0.1059']
# ['amparado', '0.1058']
# ['tremendo', '0.1054']
# ['droga', '0.1051']
# ['ilimitado', '0.1049']
# ['velo', '0.1047']
# ['propiedad', '0.1045']
# ['trágico', '0.1043']
# ['herrera', '0.1038']
# ['concreto', '0.1036']
# ['proyecto', '0.1032']
# ['distinto', '0.1029']
# ['estructura', '0.1028']
# ['norte', '0.1028']
# ['vergonzoso', '0.1028']
# ['activo', '0.1027']
# ['tozudez', '0.1027']
# ['pregunta', '0.1026']
# ['sistemático', '0.1022']
# ['vido', '0.1022']
# ['preguntar', '0.1020']
# ['temprano', '0.1020']
# ['retributivo', '0.1017']
# ['estatal', '0.1015']
# ['golfo', '0.1014']
# ['objeto', '0.1013']
# ['sentado', '0.1013']
# ['concedido', '0.1012']
# ['integrante', '0.1009']
# ['entrega', '0.1008']
# ['elemento', '0.1007']
# ['generalizado', '0.1005']
# ['ola', '0.1004']
# ['investigación', '0.1003']
# ['control', '0.1003']
# ['capturo', '0.1003']
# ['precioso', '0.1002']
# ['minero', '0.1002']
# ['psique', '0.0999']
# ['perniciosa', '0.0994']
# ['reciente', '0.0989']
# ['referente', '0.0989']
# ['fútbol', '0.0989']
# ['mediático', '0.0988']
# ['importador', '0.0987']
# ['tributario', '0.0987']
# ['abrumador', '0.0986']
# ['extraño', '0.0984']
# ['perjuicio', '0.0983']
# ['público', '0.0981']
# ['artificio', '0.0981']
# ['obra', '0.0976']
# ['retención', '0.0974']
# ['agravante', '0.0973']
# ['narrativa', '0.0973']
# ['conjunto', '0.0972']
# ['teoría', '0.0970']
# ['méxico', '0.0967']
# ['reducción', '0.0967']
# ['ganar', '0.0965']
# ['cómodo', '0.0962']
# ['cabeza', '0.0961']
# ['sancionar', '0.0959']
# ['desventaja', '0.0958']
# ['universidades', '0.0956']
# ['personaje', '0.0955']
# ['exequible', '0.0954']
# ['absurdo', '0.0952']
# ['mantenimiento', '0.0948']
# ['costero', '0.0947']
# ['general', '0.0947']
# ['fresco', '0.0943']
# ['lider', '0.0943']
# ['compareciente', '0.0941']
# ['caracol', '0.0940']
# ['grave', '0.0935']
# ['incontrolable', '0.0934']
# ['papel', '0.0932']
# ['respectivo', '0.0931']
# ['paralelo', '0.0930']
# ['enmarcado', '0.0929']
# ['organizado', '0.0929']
# ['comandado', '0.0928']
# ['repetido', '0.0927']
# ['falta', '0.0927']
# ['inspirado', '0.0926']
# ['delegatario', '0.0926']
# ['magistrado', '0.0921']
# ['san', '0.0921']
# ['brillante', '0.0919']
# ['rentable', '0.0918']
# ['espectador', '0.0916']
# ['planteado', '0.0914']
# ['construido', '0.0911']
# ['haberlo', '0.0909']
# ['polémica', '0.0908']
# ['influencio', '0.0907']
# ['reclutado', '0.0903']
# ['ingenuo', '0.0903']
# ['exitosos', '0.0902']
# ['benavides', '0.0901']
# ['sorprendido', '0.0897']
# ['afinidades', '0.0897']
# ['león', '0.0897']
# ['especial', '0.0896']
# ['permeada', '0.0895']
# ['arriesgado', '0.0894']
# ['verificación', '0.0892']
# ['campo', '0.0892']
# ['apuesto', '0.0890']
# ['panfleto', '0.0889']
# ['parálisis', '0.0887']
# ['similitud', '0.0887']
# ['observador', '0.0887']
# ['municipio', '0.0886']
# ['clase', '0.0881']
# ['germinal', '0.0874']
# ['iner yo', '0.0874']
# ['ricardo', '0.0873']
# ['actualmente', '0.0872']
# ['mano', '0.0871']
# ['senador', '0.0861']
# ['ostensible', '0.0860']
# ['obligatorio', '0.0860']
# ['paro', '0.0856']
# ['enmarcada', '0.0856']
# ['entrada', '0.0855']
# ['fría', '0.0853']
# ['flotar', '0.0851']
# ['setenta', '0.0850']
# ['representado', '0.0847']
# ['exsenador', '0.0845']
# ['central', '0.0844']
# ['centro', '0.0843']
# ['enunciado', '0.0841']
# ['pablo', '0.0840']
# ['hora', '0.0837']
# ['mafioso', '0.0836']
# ['rebajar', '0.0836']
# ['regla', '0.0833']
# ['abogado', '0.0833']
# ['barco', '0.0831']
# ['antijurídico', '0.0831']
# ['caracterización', '0.0831']
# ['lastrar', '0.0830']
# ['entrevista', '0.0827']
# ['emporio', '0.0825']
# ['categórico', '0.0824']
# ['devenida', '0.0821']
# ['desdén', '0.0820']
# ['impuesto', '0.0820']
# ['improvisado', '0.0816']
# ['aspecto', '0.0814']
# ['prensa', '0.0812']
# ['ocurrido', '0.0809']
# ['amazona', '0.0809']
# ['plazo', '0.0809']
# ['relacionado', '0.0808']
# ['tesis', '0.0798']
# ['completo', '0.0795']
# ['laberinto', '0.0795']
# ['evaluación', '0.0795']
# ['nonagésimo', '0.0793']
# ['participaciones', '0.0792']
# ['siglo', '0.0792']
# ['postrada', '0.0792']
# ['función', '0.0791']
# ['centralizador', '0.0786']
# ['términos', '0.0781']
# ['poema', '0.0781']
# ['barranquillo', '0.0779']
# ['negocio', '0.0778']
# ['atrapado', '0.0778']
# ['mejía', '0.0776']
# ['lengua', '0.0776']
# ['estructurado', '0.0774']
# ['aportar', '0.0770']
# ['frent', '0.0770']
# ['consulta', '0.0768']
# ['cuidadoso', '0.0767']
# ['liderado', '0.0766']
# ['capaz', '0.0764']
# ['alias', '0.0762']
# ['reconocido', '0.0761']
# ['definir', '0.0760']
# ['invito', '0.0758']
# ['despacho', '0.0757']
# ['individual', '0.0756']
# ['burlar', '0.0755']
# ['delictivo', '0.0755']
# ['solicitud', '0.0754']
# ['modificación', '0.0754']
# ['patrocinio', '0.0754']
# ['peor', '0.0753']
# ['vinculado', '0.0750']
# ['invento', '0.0747']
# ['borrador', '0.0745']
# ['servicio', '0.0744']
# ['zona', '0.0744']
# ['ejercicio', '0.0743']
# ['manchada', '0.0740']
# ['llamado', '0.0740']
# ['anoche', '0.0737']
# ['academia', '0.0737']
# ['camisa', '0.0736']
# ['criterio', '0.0733']
# ['reincorporado', '0.0732']
# ['reposado', '0.0731']
# ['haber', '0.0730']
# ['verificable', '0.0729']
# ['diferenciar', '0.0728']
# ['niña', '0.0728']
# ['rico', '0.0727']
# ['daño', '0.0726']
# ['abogados', '0.0725']
# ['apostar', '0.0722']
# ['joven', '0.0720']
# ['considerado', '0.0718']
# ['ser', '0.0716']
# ['período', '0.0715']
# ['burla', '0.0714']
# ['uniforme', '0.0713']
# ['pese', '0.0711']
# ['conceptual', '0.0711']
# ['verso', '0.0711']
# ['juan', '0.0709']
# ['ilegal', '0.0709']
# ['departamento', '0.0708']
# ['abuelo', '0.0708']
# ['piedra', '0.0707']
# ['concepto', '0.0704']
# ['alto', '0.0701']
# ['antiguo', '0.0697']
# ['maltrato', '0.0697']
# ['pérdida', '0.0697']
# ['conectado', '0.0697']
# ['disputo', '0.0697']
# ['fines', '0.0695']
# ['década', '0.0695']
# ['fondo', '0.0694']
# ['jorge', '0.0689']
# ['ataque', '0.0684']
# ['escrito', '0.0683']
# ['colegio', '0.0682']
# ['reinterpretado', '0.0681']
# ['comercial', '0.0680']
# ['infundada', '0.0678']
# ['revisión', '0.0674']
# ['punto', '0.0674']
# ['increíble', '0.0666']
# ['gustavo', '0.0666']
# ['errática', '0.0664']
# ['antonio', '0.0662']
# ['sujeto', '0.0662']
# ['ilícito', '0.0659']
# ['autonómico', '0.0658']
# ['mérito', '0.0655']
# ['aplicación', '0.0655']
# ['gamonal', '0.0654']
# ['regaño', '0.0653']
# ['carvajal', '0.0653']
# ['financiador', '0.0652']
# ['normativa', '0.0650']
# ['reja', '0.0649']
# ['narrativo', '0.0645']
# ['extorsivo', '0.0645']
# ['ramírez', '0.0644']
# ['procedente', '0.0642']
# ['lector', '0.0641']
# ['proveniente', '0.0640']
# ['vicepresidenta', '0.0640']
# ['barrio', '0.0634']
# ['torno', '0.0632']
# ['cabo', '0.0631']
# ['requerimiento', '0.0628']
# ['raíz', '0.0626']
# ['faltar', '0.0624']
# ['límite', '0.0623']
# ['tema', '0.0622']
# ['periodo', '0.0621']
# ['periodista', '0.0619']
# ['diario', '0.0618']
# ['oro', '0.0618']
# ['plano', '0.0617']
# ['disimulada', '0.0613']
# ['semana', '0.0612']
# ['jefe', '0.0612']
# ['imputado', '0.0610']
# ['analista', '0.0606']
# ['pie', '0.0606']
# ['monumental', '0.0605']
# ['cínico', '0.0604']
# ['simple', '0.0599']
# ['elegido', '0.0599']
# ['insignia', '0.0596']
# ['causado', '0.0595']
# ['dinámico', '0.0594']
# ['torpeza', '0.0588']
# ['brizna', '0.0586']
# ['opinadores', '0.0583']
# ['relegado', '0.0581']
# ['explorador', '0.0578']
# ['origen', '0.0572']
# ['anterior', '0.0568']
# ['prescripción', '0.0567']
# ['oscuro', '0.0567']
# ['fecha', '0.0565']
# ['renta', '0.0562']
# ['cerca', '0.0560']
# ['gestión', '0.0559']
# ['latino', '0.0558']
# ['amplio', '0.0557']
# ['anti', '0.0556']
# ['táctico', '0.0553']
# ['delito', '0.0552']
# ['enfocar', '0.0551']
# ['siniestro', '0.0551']
# ['libro', '0.0550']
# ['procedimiento', '0.0549']
# ['vía', '0.0547']
# ['podido', '0.0544']
# ['académico', '0.0540']
# ['valor', '0.0539']
# ['prematuro', '0.0538']
# ['brava', '0.0536']
# ['diciembre', '0.0535']
# ['ridículo', '0.0534']
# ['acierto', '0.0533']
# ['mínimo', '0.0532']
# ['zarpó', '0.0531']
# ['ruta', '0.0529']
# ['inicial', '0.0529']
# ['premura', '0.0527']
# ['capo', '0.0527']
# ['impacto', '0.0523']
# ['hincapié', '0.0522']
# ['asalto', '0.0520']
# ['herramienta', '0.0519']
# ['decena', '0.0507']
# ['agravado', '0.0507']
# ['posterior', '0.0507']
# ['rafael', '0.0506']
# ['enunciada', '0.0502']
# ['ff', '0.0496']
# ['empresa', '0.0495']
# ['centrado', '0.0494']
# ['cargo', '0.0492']
# ['componente', '0.0491']
# ['cincuenta', '0.0491']
# ['mermar', '0.0486']
# ['máximo', '0.0485']
# ['televisión', '0.0484']
# ['válido', '0.0483']
# ['bién', '0.0480']
# ['obtención', '0.0477']
# ['cao', '0.0475']
# ['luis', '0.0472']
# ['díaz', '0.0472']
# ['zón', '0.0471']
# ['aéreo', '0.0470']
# ['principal', '0.0469']
# ['recurso', '0.0466']
# ['gigantesco', '0.0462']
# ['junto', '0.0460']
# ['manuel', '0.0459']
# ['base', '0.0459']
# ['nevado', '0.0456']
# ['suboficial', '0.0456']
# ['equipo', '0.0456']
# ['trayectoria', '0.0449']
# ['parcial', '0.0443']
# ['revés', '0.0442']
# ['drástico', '0.0439']
# ['dpi', '0.0438']
# ['treinta', '0.0434']
# ['ofensivo', '0.0432']
# ['susceptible', '0.0430']
# ['profesional', '0.0429']
# ['camilo', '0.0429']
# ['corte', '0.0424']
# ['mencionado', '0.0423']
# ['millón', '0.0422']
# ['movido', '0.0421']
# ['hueso', '0.0420']
# ['lista', '0.0413']
# ['meses', '0.0411']
# ['incremento', '0.0407']
# ['ingreso', '0.0404']
# ['infracción', '0.0403']
# ['rápido', '0.0403']
# ['tratamiento', '0.0401']
# ['noviembre', '0.0400']
# ['noticiero', '0.0400']
# ['eje', '0.0397']
# ['publicación', '0.0395']
# ['ganado', '0.0395']
# ['juvenil', '0.0394']
# ['calle', '0.0392']
# ['práctico', '0.0392']
# ['humberto', '0.0390']
# ['septiembre', '0.0385']
# ['fenómeno', '0.0379']
# ['izquierdo', '0.0378']
# ['garcía', '0.0374']
# ['tajo', '0.0373']
# ['funciones', '0.0372']
# ['banda', '0.0369']
# ['cocaína', '0.0368']
# ['anunciado', '0.0362']
# ['característica', '0.0360']
# ['cargado', '0.0360']
# ['aumento', '0.0358']
# ['sumar', '0.0352']
# ['prueba', '0.0350']
# ['equivalente', '0.0348']
# ['polémico', '0.0345']
# ['término', '0.0330']
# ['ayer', '0.0327']
# ['urbano', '0.0326']
# ['transporte', '0.0325']
# ['alberto', '0.0324']
# ['red', '0.0324']
# ['ciego', '0.0323']
# ['lobo', '0.0323']
# ['explico', '0.0322']
# ['robusto', '0.0321']
# ['piel', '0.0318']
# ['mercado', '0.0316']
# ['cabezo', '0.0306']
# ['experto', '0.0306']
# ['josé', '0.0305']
# ['vestido', '0.0303']
# ['presunto', '0.0302']
# ['fabricación', '0.0301']
# ['agua', '0.0300']
# ['cés', '0.0291']
# ['sencillo', '0.0291']
# ['miembro', '0.0282']
# ['homicida', '0.0279']
# ['balazo', '0.0278']
# ['altibajo', '0.0278']
# ['sector', '0.0267']
# ['ilustrado', '0.0264']
# ['utilización', '0.0263']
# ['papá', '0.0261']
# ['eduardo', '0.0258']
# ['veinte', '0.0258']
# ['sistema', '0.0254']
# ['rambo', '0.0253']
# ['torcido', '0.0250']
# ['notorio', '0.0249']
# ['columna', '0.0247']
# ['economist', '0.0247']
# ['fallo', '0.0244']
# ['geográfico', '0.0241']
# ['dedicado', '0.0240']
# ['ciento', '0.0239']
# ['paseo', '0.0238']
# ['pesca', '0.0238']
# ['subrogado', '0.0236']
# ['oficina', '0.0234']
# ['confirmado', '0.0234']
# ['proporcionado', '0.0230']
# ['martes', '0.0226']
# ['més', '0.0225']
# ['previo', '0.0225']
# ['disímil', '0.0223']
# ['homenaje', '0.0221']
# ['remitente', '0.0221']
# ['v', '0.0220']
# ['enero', '0.0214']
# ['superado', '0.0211']
# ['chance', '0.0210']
# ['arquitecto', '0.0208']
# ['iván', '0.0206']
# ['producción', '0.0206']
# ['bastones', '0.0205']
# ['uniformado', '0.0200']
# ['rodríguez', '0.0199']
# ['bala', '0.0198']
# ['calificado', '0.0193']
# ['octubre', '0.0191']
# ['grupo', '0.0190']
# ['oferta', '0.0186']
# ['porte', '0.0185']
# ['abril', '0.0180']
# ['ilustrativo', '0.0170']
# ['carga', '0.0169']
# ['álvaro', '0.0168']
# ['martínez', '0.0162']
# ['agosto', '0.0162']
# ['dolo', '0.0161']
# ['comparado', '0.0159']
# ['hilvanado', '0.0156']
# ['fondos', '0.0156']
# ['colega', '0.0151']
# ['realizable', '0.0151']
# ['ejemplo', '0.0143']
# ['febrero', '0.0137']
# ['llego', '0.0132']
# ['vaso', '0.0130']
# ['superfluo', '0.0129']
# ['barbosa', '0.0125']
# ['julián', '0.0123']
# ['acevedo', '0.0123']
# ['edad', '0.0123']
# ['nivel', '0.0121']
# ['cuyo', '0.0119']
# ['marzo', '0.0117']
# ['riesgo', '0.0116']
# ['déjelo', '0.0106']
# ['von', '0.0103']
# ['mero', '0.0098']
# ['error', '0.0097']
# ['elit', '0.0088']
# ['texto', '0.0086']
# ['código', '0.0085']
# ['cero', '0.0085']
# ['salido', '0.0082']
# ['dólares', '0.0081']
# ['alfil', '0.0077']
# ['torre', '0.0069']
# ['cifra', '0.0069']
# ['oveja', '0.0066']
# ['alemán', '0.0056']
# ['irregular', '0.0056']
# ['teórico', '0.0055']
# ['cpi', '0.0052']
# ['otorgado', '0.0046']
# ['espectro', '0.0043']
# ['homicidio', '0.0040']
# ['patrón', '0.0040']
# ['dañino', '0.0032']
# ['mil', '0.0030']
# ['revista', '0.0026']
# ['basado', '0.0020']
# ['muestra', '0.0019']
# ['caso', '0.0017']
# ['sesenta', '0.0012']
# ['            ', '0.0000']
# ['inciertar', '0.0000']
# ['violenciir', '0.0000']
# ['     ', '0.0000']
# ['tierro', '0.0000']
# ['tutir', '0.0000']
# ['autodefensar', '0.0000']
# ['caús', '0.0000']
# ['semán', '0.0000']
# ['westfalia', '0.0000']
# ['pachelly', '0.0000']
# ['persón', '0.0000']
# ['trián', '0.0000']
# ['partícip', '0.0000']
# ['empresariar', '0.0000']
# ['prós', '0.0000']
# ['taparl', '0.0000']
# ['agc', '0.0000']
# ['regañadient', '0.0000']
# ['pobrecer', '0.0000']
# ['crimar', '0.0000']
# ['habán', '0.0000']
# ['catatumbo', '0.0000']
# ['triza', '0.0000']
# ['ordir', '0.0000']
# ['iniciativo', '0.0000']
# ['colombiar', '0.0000']
# ['inquín', '0.0000']
# ['araucir', '0.0000']
# ['prenso', '0.0000']
# ['tibú', '0.0000']
# ['\xa0      ', '0.0000']
# ['esperanzo', '0.0000']
# ['sabienda', '0.0000']
# ['deseándol', '0.0000']
# ['márquez', '0.0000']
# ['mayoer', '0.0000']
# ['indígenar', '0.0000']
# ['             ', '0.0000']
# ['complacientemente', '0.0000']
# ['cartar', '0.0000']
# [' ', '0.0000']
# ['perduro', '0.0000']
# ['acsn', '0.0000']
# ['    ', '0.0000']
# ['incontabl', '0.0000']
# ['extraditabl', '0.0000']
# ['gaitanista', '0.0000']
# ['narcotraficant', '0.0000']
# ['guerrillo', '0.0000']
# ['modu', '0.0000']
# ['cínicar', '0.0000']
# ['tolimo', '0.0000']
# ['pós', '0.0000']
# ['dih', '0.0000']
# ['marquetalia', '0.0000']
# ['ranguir', '0.0000']
# ['                ', '0.0000']
# ['gildardo', '0.0000']
# ['  ', '0.0000']
# ['mosdisco', '0.0000']
# ['combatient', '0.0000']
# ['           ', '0.0000']
# ['timbiquí', '0.0000']
# ['picoto', '0.0000']
# ['               ', '0.0000']
# ['misar', '0.0000']
# ['márgén', '0.0000']
# ['castrens', '0.0000']
# ['cabezar', '0.0000']
# ['epl', '0.0000']
# ['eleno', '0.0000']
# ['páramir', '0.0000']
# ['ramar', '0.0000']
# ['otoniel', '0.0000']
# ['restrepo', '0.0000']
# ['caquetá', '0.0000']
# ['sumapaz', '0.0000']
# ['opiac', '0.0000']
# ['édgar', '0.0000']
# ['frar', '0.0000']
# ['jep', '0.0000']
# ['cúpular', '0.0000']
# ['caicedo', '0.0000']
# ['utopir', '0.0000']
# ['ruán', '0.0000']
# ['echandeír', '0.0000']
# ['amnistir', '0.0000']
# ['esmeraldero', '0.0000']
# ['érar', '0.0000']
# ['peloponeso', '0.0000']
# ['promés', '0.0000']
# ['premisar', '0.0000']
# ['fiscaliar', '0.0000']
# ['cachetado', '0.0000']
# ['negándono', '0.0000']
# ['reincident', '0.0000']
# ['violencio', '0.0000']
# ['mineer', '0.0000']
# ['zonar', '0.0000']
# ['velandia', '0.0000']
# ['lés', '0.0000']
# ['pasaportir', '0.0000']
# ['          ', '0.0000']
# ['tragediir', '0.0000']
# ['oleado', '0.0000']
# ['catequizado', '0.0000']
# ['cinturo', '0.0000']
# ['caguán', '0.0000']
# ['frecuencio', '0.0000']
# ['selir', '0.0000']
# ['instrumentalizándolo', '0.0000']
# ['bukelir', '0.0000']
# ['heroínar', '0.0000']
# ['dilemar', '0.0000']
# ['procuraduriar', '0.0000']
# ['colombio', '0.0000']
# ['olindillo', '0.0000']
# ['infecundamente', '0.0000']
# ['indepaz', '0.0000']
# ['polir', '0.0000']
# ['cadén', '0.0000']
# ['boyacá', '0.0000']
# ['misivo', '0.0000']
# ['etapar', '0.0000']
# ['exigírsel', '0.0000']
# ['embestidar', '0.0000']
# ['         ', '0.0000']
# ['vejámén', '0.0000']
# ['guerro', '0.0000']
# ['caucar', '0.0000']
# ['reglo', '0.0000']
# ['brodway', '0.0000']
# ['nortar', '0.0000']
# ['defensoer', '0.0000']
# ['vacunir', '0.0000']
# ['giraldo', '0.0000']
# ['materio', '0.0000']
# ['dárselir', '0.0000']
# ['carolín', '0.0000']
# ['asonado', '0.0000']
# ['cumplirl', '0.0000']
# ['              ', '0.0000']
# ['fortalecimientir', '0.0000']
# ['preocuparno', '0.0000']
# ['guerrillar', '0.0000']
# ['retóricar', '0.0000']
# ['maloco', '0.0000']
# ['petrista', '0.0000']
# ['almirant', '0.0000']
# ['senadoro', '0.0000']
# ['distopir', '0.0000']
# ['informir', '0.0000']
# ['recalcitrant', '0.0000']
# ['coyunturar', '0.0000']
# ['clausewitz', '0.0000']
# ['araucar', '0.0000']
# ['ausencio', '0.0000']
# ['       ', '0.0000']
# ['rotún', '0.0000']
# ['líneo', '0.0000']
# ['hipersimplificación', '0.0000']
# ['retinar', '0.0000']
# ['anhelamo', '0.0000']
# ['córdobo', '0.0000']
# ['décado', '0.0000']
# ['cordillero', '0.0000']
# ['        ', '0.0000']
# ['poniéndol', '0.0000']
# ['democraciar', '0.0000']
# ['ilimitar', '0.0000']
# ['farso', '0.0000']
# ['      ', '0.0000']
# ['ambulant', '0.0000']
# ['destacado', '-0.0002']
# ['rebaja', '-0.0012']
# ['superior', '-0.0017']
# ['original', '-0.0020']
# ['programa', '-0.0037']
# ['premio', '-0.0043']
# ['ginebra', '-0.0069']
# ['pasivo', '-0.0070']
# ['caño', '-0.0079']
# ['excesivo', '-0.0081']
# ['tráfico', '-0.0081']
# ['pastel', '-0.0082']
# ['caído', '-0.0083']
# ['emitido', '-0.0087']
# ['ramo', '-0.0103']
# ['estilo', '-0.0104']
# ['lagarto', '-0.0108']
# ['poncho', '-0.0110']
# ['conexo', '-0.0112']
# ['emc', '-0.0113']
# ['actor', '-0.0120']
# ['resumen', '-0.0127']
# ['barbacoas', '-0.0145']
# ['nulo', '-0.0149']
# ['conocido', '-0.0149']
# ['serie', '-0.0149']
# ['probar', '-0.0154']
# ['perteneciente', '-0.0156']
# ['karl', '-0.0166']
# ['apellido', '-0.0167']
# ['menor', '-0.0168']
# ['básico', '-0.0172']
# ['dueño', '-0.0175']
# ['producto', '-0.0179']
# ['doctor', '-0.0180']
# ['carriel', '-0.0184']
# ['falla', '-0.0195']
# ['dirigido', '-0.0195']
# ['cúmulo', '-0.0202']
# ['exponencial', '-0.0206']
# ['barato', '-0.0207']
# ['barra', '-0.0210']
# ['año', '-0.0211']
# ['giro', '-0.0212']
# ['sumado', '-0.0221']
# ['ciclo', '-0.0223']
# ['laboratorio', '-0.0241']
# ['modelo', '-0.0244']
# ['episodio', '-0.0247']
# ['aproveché', '-0.0247']
# ['áreas', '-0.0250']
# ['botero', '-0.0250']
# ['compuesto', '-0.0252']
# ['denominado', '-0.0253']
# ['car', '-0.0254']
# ['leve', '-0.0257']
# ['román', '-0.0259']
# ['pez', '-0.0265']
# ['artículo', '-0.0275']
# ['tasa', '-0.0279']
# ['inducida', '-0.0291']
# ['operandi', '-0.0302']
# ['acumulado', '-0.0313']
# ['curso', '-0.0317']
# ['dio', '-0.0333']
# ['parodia', '-0.0347']
# ['nota', '-0.0347']
# ['artilugio', '-0.0348']
# ['ex', '-0.0351']
# ['costoso', '-0.0353']
# ['turno', '-0.0355']
# ['empleado', '-0.0358']
# ['edición', '-0.0363']
# ['vendedor', '-0.0364']
# ['afín', '-0.0365']
# ['goto', '-0.0371']
# ['quejo', '-0.0371']
# ['cámara', '-0.0389']
# ['radio', '-0.0391']
# ['mes', '-0.0395']
# ['derivado', '-0.0402']
# ['infractor', '-0.0405']
# ['curioso', '-0.0417']
# ['peso', '-0.0435']
# ['costo', '-0.0456']
# ['c', '-0.0477']
# ['lavado', '-0.0483']
# ['estándar', '-0.0485']
# ['similar', '-0.0492']
# ['análisis', '-0.0492']
# ['publicado', '-0.0503']
# ['cayetano', '-0.0513']
# ['colón', '-0.0531']
# ['arrollador', '-0.0532']
# ['línea', '-0.0544']
# ['gestor', '-0.0562']
# ['mordisco', '-0.0572']
# ['gasto', '-0.0573']
# ['adrián', '-0.0574']
# ['precio', '-0.0576']
# ['bar', '-0.0592']
# ['usado', '-0.0614']
# ['sesudo', '-0.0615']
# ['palo', '-0.0622']
# ['reportero', '-0.0631']
# ['rojo', '-0.0650']
# ['ancho', '-0.0664']
# ['mm', '-0.0673']
# ['diseño', '-0.0695']
# ['pizarro', '-0.0740']
# ['utilizado', '-0.0764']
# ['famoso', '-0.0773']
# ['vío', '-0.0780']
# ['rodar', '-0.0788']
# ['m', '-0.0806']
# ['facturo', '-0.0817']
# ['ojo', '-0.0826']
# ['pico', '-0.0830']
# ['tipo', '-0.0836']
# ['trimestre', '-0.0856']
# ['guapi', '-0.0932']
# ['rondón', '-0.0948']
# ['times', '-0.0951']
# ['dato', '-0.1027']
# ['ficha', '-0.1092']
# ['etc', '-0.1212']
# ['pirueta', '-0.1344']
# ['video', '-0.1346']
# ['gancho', '-0.1409']
# ['the', '-0.1670']
# ['square', '-0.1690']
# ['flip', '-0.2088']

# %%
# Generar una nube de palabras
word_freq = {palabra: float(similitud) for palabra, similitud in palabras_similares}

wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(word_freq)

# Mostrar la nube de palabras
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
# Define la palabra objetivo
palabra_objetivo = 'guerra'

# Aplanar el corpus a una sola lista de palabras y eliminar duplicados
palabras_corpus = list(set([palabra for sublist in contenido_lemas for palabra in sublist]))

# Procesar la palabra objetivo con el modelo spaCy
doc_objetivo = nlp(palabra_objetivo)

# Encuentra palabras similares a la palabra objetivo en el corpus definido
palabras_similares = []

# Calcular la similitud entre la palabra objetivo y cada palabra del corpus
for palabra in palabras_corpus:
    doc_p = nlp(palabra)
    similitud = doc_objetivo.similarity(doc_p)
    palabras_similares.append((palabra, similitud))

# Ordenar las palabras por similitud en orden descendente
palabras_similares = sorted(palabras_similares, key=lambda item: -item[1])

# Preparar los datos para escribir en el archivo CSV
contenido_lemas_csv = [['Palabra', 'Similitud']]  # Encabezados del CSV
for palabra, similitud in palabras_similares:  
    contenido_lemas_csv.append([palabra, f"{similitud:.4f}"])

# Escribir los datos en un nuevo archivo CSV
with open('similitud_guerra_semana.csv', 'w', newline='', encoding='utf-8-sig') as archivo:
    escritor_csv = csv.writer(archivo)
    escritor_csv.writerows(contenido_lemas_csv)

# Leer y mostrar el contenido del archivo CSV
with open('similitud_guerra_semana.csv', 'r', newline='', encoding='utf-8-sig') as archivo:
    lector_csv = csv.reader(archivo)
    for fila in lector_csv:
        print(fila)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_15560\4012571989.py:16: UserWarning: [W008] Evaluating Doc.similarity based on empty vectors.
#   similitud = doc_objetivo.similarity(doc_p)
# ['Palabra', 'Similitud']
# ['guerra', '1.0000']
# ['rebelión', '0.6699']
# ['guerrilla', '0.6411']
# ['revolución', '0.6406']
# ['insurgencia', '0.6352']
# ['conflicto', '0.6187']
# ['sangriento', '0.6032']
# ['combatiente', '0.5914']
# ['militar', '0.5857']
# ['traición', '0.5840']
# ['insurgente', '0.5835']
# ['beligerancia', '0.5804']
# ['imperio', '0.5675']
# ['confrontación', '0.5670']
# ['destrucción', '0.5607']
# ['hostilidad', '0.5599']
# ['ejército', '0.5574']
# ['insurrecto', '0.5498']
# ['milicia', '0.5459']
# ['combatientes', '0.5443']
# ['exterminio', '0.5358']
# ['bombardeo', '0.5348']
# ['nación', '0.5343']
# ['guerrillero', '0.5326']
# ['subversión', '0.5323']
# ['crisis', '0.5313']
# ['masacre', '0.5308']
# ['liberación', '0.5298']
# ['paramilitarismo', '0.5136']
# ['francia', '0.5104']
# ['desmoralización', '0.5091']
# ['aniquilamiento', '0.5089']
# ['terrorista', '0.5070']
# ['atrocidad', '0.5040']
# ['república', '0.5020']
# ['disidencia', '0.4999']
# ['autodefensa', '0.4993']
# ['violencia', '0.4987']
# ['desmovilización', '0.4985']
# ['conquistadora', '0.4979']
# ['paramilitar', '0.4969']
# ['políticamente', '0.4935']
# ['revolucionario', '0.4935']
# ['narcoguerrilla', '0.4907']
# ['genocidio', '0.4889']
# ['muerte', '0.4843']
# ['indefensa', '0.4827']
# ['política', '0.4823']
# ['desastroso', '0.4780']
# ['humanidad', '0.4780']
# ['gobernación', '0.4764']
# ['democracia', '0.4741']
# ['pacificación', '0.4721']
# ['coalición', '0.4704']
# ['fusilamiento', '0.4684']
# ['campaña', '0.4678']
# ['tristemente', '0.4663']
# ['reconciliación', '0.4661']
# ['neoliberalismo', '0.4632']
# ['oposición', '0.4623']
# ['rebelde', '0.4617']
# ['enemigo', '0.4611']
# ['geopolítico', '0.4603']
# ['gobernante', '0.4576']
# ['historia', '0.4567']
# ['defensa', '0.4564']
# ['desilusión', '0.4558']
# ['ambición', '0.4553']
# ['estallido', '0.4541']
# ['sedición', '0.4532']
# ['tragedia', '0.4507']
# ['occidental', '0.4492']
# ['época', '0.4492']
# ['narcoterrorista', '0.4491']
# ['tropa', '0.4490']
# ['capitalista', '0.4484']
# ['confusión', '0.4475']
# ['indignación', '0.4467']
# ['terror', '0.4459']
# ['resistencia', '0.4439']
# ['delincuencia', '0.4438']
# ['históricamente', '0.4434']
# ['patria', '0.4432']
# ['corrupción', '0.4409']
# ['barbarie', '0.4408']
# ['rendición', '0.4393']
# ['luchar', '0.4387']
# ['fuerza', '0.4376']
# ['indefensión', '0.4372']
# ['forzosamente', '0.4371']
# ['fuerzas', '0.4356']
# ['influencia', '0.4354']
# ['tregua', '0.4351']
# ['impotencia', '0.4325']
# ['gravemente', '0.4293']
# ['violento', '0.4288']
# ['fortaleza', '0.4279']
# ['década', '0.4277']
# ['gobierno', '0.4276']
# ['misión', '0.4268']
# ['superioridad', '0.4264']
# ['democráticamente', '0.4253']
# ['desgraciadamente', '0.4243']
# ['ataque', '0.4219']
# ['situación', '0.4194']
# ['federalismo', '0.4194']
# ['definitivamente', '0.4186']
# ['consecuencia', '0.4182']
# ['vandalismo', '0.4181']
# ['acción', '0.4181']
# ['invención', '0.4168']
# ['desarme', '0.4165']
# ['operación', '0.4147']
# ['tercamente', '0.4132']
# ['injerencia', '0.4122']
# ['paz', '0.4110']
# ['debilidad', '0.4108']
# ['disidente', '0.4106']
# ['manifestación', '0.4104']
# ['seriamente', '0.4103']
# ['paradójicamente', '0.4081']
# ['ideología', '0.4077']
# ['soldado', '0.4074']
# ['causa', '0.4073']
# ['sociedad', '0.4070']
# ['político', '0.4060']
# ['impunidad', '0.4057']
# ['sometimiento', '0.4057']
# ['población', '0.4056']
# ['criminalidad', '0.4053']
# ['violación', '0.4052']
# ['centralismo', '0.4051']
# ['lastimosamente', '0.4051']
# ['lamentablemente', '0.4046']
# ['comandante', '0.4046']
# ['criminal', '0.4044']
# ['creencia', '0.4037']
# ['prontamente', '0.4011']
# ['norteamericano', '0.4010']
# ['discusión', '0.4005']
# ['activamente', '0.4002']
# ['posiblemente', '0.3984']
# ['humanización', '0.3977']
# ['armado', '0.3973']
# ['convicción', '0.3965']
# ['existencia', '0.3945']
# ['destructivo', '0.3944']
# ['inteligencia', '0.3929']
# ['nacionalización', '0.3923']
# ['estadista', '0.3915']
# ['adoctrinamiento', '0.3910']
# ['asalto', '0.3898']
# ['tentación', '0.3882']
# ['vilmente', '0.3881']
# ['narcotráfico', '0.3880']
# ['territorio', '0.3876']
# ['campamento', '0.3874']
# ['incidente', '0.3870']
# ['economía', '0.3866']
# ['mistificación', '0.3861']
# ['preocupación', '0.3855']
# ['pacificado', '0.3853']
# ['debilitamiento', '0.3847']
# ['atentado', '0.3840']
# ['conciencia', '0.3838']
# ['arrogancia', '0.3837']
# ['presidencia', '0.3835']
# ['inmediatamente', '0.3830']
# ['desconfianza', '0.3829']
# ['amenazar', '0.3828']
# ['enteramente', '0.3824']
# ['contundencia', '0.3821']
# ['lucho', '0.3818']
# ['conversación', '0.3818']
# ['desconcentración', '0.3815']
# ['civil', '0.3808']
# ['gubernamental', '0.3788']
# ['cooptación', '0.3780']
# ['partida', '0.3777']
# ['precisamente', '0.3777']
# ['posesión', '0.3776']
# ['ilegalidad', '0.3769']
# ['profundamente', '0.3766']
# ['disputa', '0.3760']
# ['dejación', '0.3760']
# ['honradamente', '0.3754']
# ['victoria', '0.3750']
# ['adolescencia', '0.3749']
# ['nuevamente', '0.3744']
# ['cooperación', '0.3742']
# ['legitimidad', '0.3736']
# ['secular', '0.3735']
# ['contraparte', '0.3730']
# ['prusiano', '0.3715']
# ['asesinato', '0.3715']
# ['esperanza', '0.3714']
# ['deliberado', '0.3713']
# ['ficción', '0.3711']
# ['revelación', '0.3706']
# ['constitución', '0.3704']
# ['inocencia', '0.3703']
# ['considerablemente', '0.3702']
# ['movimiento', '0.3696']
# ['negociación', '0.3693']
# ['justicia', '0.3690']
# ['almirante', '0.3689']
# ['posteriormente', '0.3686']
# ['excarcelación', '0.3684']
# ['realidad', '0.3681']
# ['inexplicablemente', '0.3679']
# ['reclutamiento', '0.3676']
# ['fundamentalmente', '0.3671']
# ['condena', '0.3664']
# ['fracaso', '0.3650']
# ['humanitario', '0.3650']
# ['posterioridad', '0.3643']
# ['veladamente', '0.3643']
# ['vida', '0.3631']
# ['complacencia', '0.3622']
# ['condición', '0.3620']
# ['ola', '0.3613']
# ['secuestro', '0.3612']
# ['región', '0.3610']
# ['campesina', '0.3605']
# ['excomandante', '0.3604']
# ['presión', '0.3602']
# ['incertidumbre', '0.3600']
# ['distensión', '0.3598']
# ['partidista', '0.3597']
# ['firmemente', '0.3594']
# ['consecución', '0.3593']
# ['gobernabilidad', '0.3585']
# ['circunstancia', '0.3584']
# ['pacífico', '0.3584']
# ['crimen', '0.3576']
# ['santismo', '0.3575']
# ['incansablemente', '0.3570']
# ['piedad', '0.3568']
# ['tensión', '0.3562']
# ['amenazado', '0.3556']
# ['lección', '0.3554']
# ['indefenso', '0.3553']
# ['desesperado', '0.3547']
# ['autoridad', '0.3547']
# ['justificación', '0.3544']
# ['campesino', '0.3541']
# ['verdaderamente', '0.3534']
# ['secuestrado', '0.3534']
# ['ciencia', '0.3524']
# ['extorsión', '0.3524']
# ['desigualdad', '0.3521']
# ['unidad', '0.3510']
# ['democrático', '0.3509']
# ['abandono', '0.3497']
# ['aspiración', '0.3497']
# ['recientemente', '0.3493']
# ['trinchera', '0.3493']
# ['historio', '0.3490']
# ['relación', '0.3485']
# ['incoherencia', '0.3484']
# ['populista', '0.3475']
# ['claramente', '0.3471']
# ['libertad', '0.3462']
# ['fuerzo', '0.3460']
# ['declaración', '0.3460']
# ['régimen', '0.3457']
# ['inseguridad', '0.3457']
# ['conclusión', '0.3451']
# ['centroamericano', '0.3446']
# ['excepción', '0.3444']
# ['legalización', '0.3444']
# ['frente', '0.3442']
# ['humanos', '0.3438']
# ['delincuente', '0.3437']
# ['doctrina', '0.3430']
# ['neoliberal', '0.3428']
# ['intento', '0.3426']
# ['jurisdicción', '0.3424']
# ['evidente', '0.3418']
# ['vigencia', '0.3414']
# ['aliado', '0.3413']
# ['bandera', '0.3409']
# ['sentencia', '0.3394']
# ['igualmente', '0.3391']
# ['sabotaje', '0.3388']
# ['organización', '0.3377']
# ['ocurrencia', '0.3372']
# ['seguramente', '0.3369']
# ['asunción', '0.3369']
# ['mente', '0.3359']
# ['territorial', '0.3356']
# ['convivencia', '0.3352']
# ['posición', '0.3348']
# ['siglo', '0.3348']
# ['terminación', '0.3339']
# ['oportunista', '0.3339']
# ['ciudad', '0.3336']
# ['cinismo', '0.3334']
# ['principado', '0.3325']
# ['amnistía', '0.3320']
# ['competencia', '0.3320']
# ['costa', '0.3320']
# ['enormemente', '0.3316']
# ['tolerancia', '0.3298']
# ['libertades', '0.3296']
# ['constituyente', '0.3292']
# ['polémica', '0.3289']
# ['inevitable', '0.3287']
# ['fracasado', '0.3281']
# ['contrario', '0.3280']
# ['insatisfacción', '0.3280']
# ['oriental', '0.3273']
# ['narcotraficante', '0.3264']
# ['gobernador', '0.3259']
# ['presencia', '0.3251']
# ['resquebrajamiento', '0.3251']
# ['administración', '0.3250']
# ['secuestrar', '0.3244']
# ['policía', '0.3233']
# ['intención', '0.3231']
# ['gradualmente', '0.3229']
# ['concesión', '0.3229']
# ['proveniente', '0.3228']
# ['instrumentalización', '0.3227']
# ['capital', '0.3226']
# ['completamente', '0.3224']
# ['ideológico', '0.3217']
# ['institucionalidad', '0.3217']
# ['inexperiencia', '0.3214']
# ['voluntad', '0.3214']
# ['fuego', '0.3213']
# ['especialmente', '0.3211']
# ['consideración', '0.3211']
# ['mayoría', '0.3209']
# ['bloqueo', '0.3204']
# ['decisión', '0.3203']
# ['patraña', '0.3197']
# ['monopolio', '0.3190']
# ['investigación', '0.3188']
# ['asesinado', '0.3180']
# ['dignidad', '0.3179']
# ['designación', '0.3174']
# ['precedente', '0.3171']
# ['pueblo', '0.3167']
# ['anticonstitucional', '0.3164']
# ['setenta', '0.3164']
# ['subversivo', '0.3160']
# ['significativamente', '0.3153']
# ['clase', '0.3149']
# ['delimitación', '0.3143']
# ['crítica', '0.3140']
# ['distinción', '0.3138']
# ['íntimamente', '0.3134']
# ['salvador', '0.3132']
# ['arma', '0.3130']
# ['condenado', '0.3129']
# ['obstante', '0.3113']
# ['facto', '0.3108']
# ['estrategia', '0.3108']
# ['imposibilidad', '0.3098']
# ['amazonía', '0.3092']
# ['contundente', '0.3087']
# ['vocación', '0.3086']
# ['delincuencial', '0.3084']
# ['elección', '0.3079']
# ['minería', '0.3068']
# ['comunidad', '0.3060']
# ['juicio', '0.3060']
# ['torturado', '0.3059']
# ['lamentable', '0.3059']
# ['mandato', '0.3056']
# ['argelia', '0.3055']
# ['consciente', '0.3051']
# ['votación', '0.3046']
# ['actualidad', '0.3044']
# ['moral', '0.3042']
# ['específicamente', '0.3042']
# ['bilateralidad', '0.3040']
# ['meramente', '0.3039']
# ['reforma', '0.3039']
# ['reclutado', '0.3038']
# ['visión', '0.3037']
# ['objeción', '0.3036']
# ['desconcertante', '0.3028']
# ['sustancia', '0.3017']
# ['producción', '0.3013']
# ['país', '0.3012']
# ['procedente', '0.3011']
# ['institución', '0.3010']
# ['fundante', '0.3004']
# ['negativamente', '0.2997']
# ['mafia', '0.2996']
# ['agrupación', '0.2996']
# ['ciudadanía', '0.2989']
# ['fuerte', '0.2981']
# ['incapacidad', '0.2979']
# ['caracterización', '0.2979']
# ['estrictamente', '0.2978']
# ['imperativo', '0.2978']
# ['adopción', '0.2977']
# ['mando', '0.2967']
# ['discurso', '0.2956']
# ['inocente', '0.2955']
# ['protección', '0.2955']
# ['especie', '0.2950']
# ['narco', '0.2949']
# ['desacuerdo', '0.2936']
# ['sistemático', '0.2934']
# ['naturaleza', '0.2931']
# ['reincorporación', '0.2928']
# ['desenfreno', '0.2926']
# ['responsabilidad', '0.2925']
# ['cuestión', '0.2925']
# ['definición', '0.2923']
# ['legalidad', '0.2921']
# ['autonomía', '0.2921']
# ['personalmente', '0.2917']
# ['reparación', '0.2902']
# ['mediático', '0.2898']
# ['influencio', '0.2897']
# ['delegación', '0.2893']
# ['teoría', '0.2892']
# ['cincuenta', '0.2889']
# ['generalizado', '0.2889']
# ['retroceso', '0.2884']
# ['expresidente', '0.2882']
# ['constitucional', '0.2880']
# ['convencido', '0.2874']
# ['actitud', '0.2871']
# ['presidencial', '0.2868']
# ['víctima', '0.2867']
# ['incontrolable', '0.2866']
# ['jerarquía', '0.2865']
# ['obstrucción', '0.2862']
# ['asimismo', '0.2857']
# ['parte', '0.2856']
# ['involucramiento', '0.2856']
# ['exigencia', '0.2853']
# ['cabecilla', '0.2850']
# ['gente', '0.2846']
# ['sensación', '0.2844']
# ['diferencia', '0.2841']
# ['económico', '0.2840']
# ['observación', '0.2840']
# ['altamente', '0.2838']
# ['comunicación', '0.2834']
# ['norte', '0.2833']
# ['despropósito', '0.2827']
# ['acercamiento', '0.2818']
# ['irreversible', '0.2808']
# ['regreso', '0.2807']
# ['guardias', '0.2795']
# ['pacto', '0.2794']
# ['semejante', '0.2786']
# ['extranjero', '0.2781']
# ['afectación', '0.2778']
# ['pesar', '0.2774']
# ['actividad', '0.2773']
# ['particularidad', '0.2768']
# ['burocrático', '0.2768']
# ['américa', '0.2767']
# ['presidente', '0.2766']
# ['importancia', '0.2765']
# ['integridad', '0.2763']
# ['pretexto', '0.2757']
# ['estrofa', '0.2755']
# ['fabricación', '0.2754']
# ['permanente', '0.2754']
# ['violadores', '0.2749']
# ['comandado', '0.2747']
# ['argumento', '0.2746']
# ['realmente', '0.2744']
# ['período', '0.2743']
# ['inequidad', '0.2739']
# ['cobarde', '0.2737']
# ['generosidad', '0.2733']
# ['condicionalidad', '0.2732']
# ['librado', '0.2732']
# ['reconocimiento', '0.2731']
# ['histórico', '0.2729']
# ['familia', '0.2728']
# ['salvadoreño', '0.2726']
# ['muerto', '0.2721']
# ['internacional', '0.2719']
# ['audiencia', '0.2718']
# ['preservación', '0.2715']
# ['incierto', '0.2715']
# ['paciencia', '0.2713']
# ['universidad', '0.2711']
# ['problemático', '0.2702']
# ['libremente', '0.2701']
# ['cesión', '0.2700']
# ['perspectiva', '0.2697']
# ['dominio', '0.2687']
# ['transicional', '0.2686']
# ['contexto', '0.2682']
# ['firmante', '0.2680']
# ['estructura', '0.2677']
# ['postura', '0.2672']
# ['paragua', '0.2671']
# ['ocasión', '0.2664']
# ['esperanzador', '0.2661']
# ['intentar', '0.2659']
# ['razón', '0.2658']
# ['pérdida', '0.2656']
# ['inconformidad', '0.2654']
# ['errática', '0.2654']
# ['renovación', '0.2652']
# ['trágico', '0.2649']
# ['alemán', '0.2648']
# ['preso', '0.2644']
# ['riqueza', '0.2642']
# ['mundial', '0.2639']
# ['partido', '0.2639']
# ['diferenciación', '0.2636']
# ['desprotegido', '0.2634']
# ['nacional', '0.2633']
# ['reciente', '0.2631']
# ['narrativa', '0.2629']
# ['cerco', '0.2628']
# ['agente', '0.2628']
# ['afinidad', '0.2627']
# ['financiación', '0.2622']
# ['fortuna', '0.2621']
# ['sarmiento', '0.2617']
# ['aldea', '0.2617']
# ['participación', '0.2615']
# ['negociable', '0.2613']
# ['avance', '0.2612']
# ['coherencia', '0.2603']
# ['utilización', '0.2601']
# ['unilateral', '0.2597']
# ['actualmente', '0.2594']
# ['orden', '0.2593']
# ['serie', '0.2592']
# ['estratégico', '0.2590']
# ['considerado', '0.2585']
# ['constante', '0.2584']
# ['electoral', '0.2582']
# ['plebiscito', '0.2580']
# ['multiplicación', '0.2579']
# ['existente', '0.2578']
# ['fernando', '0.2577']
# ['órden', '0.2574']
# ['defendido', '0.2573']
# ['negociado', '0.2572']
# ['siniestro', '0.2571']
# ['tanto', '0.2571']
# ['motivación', '0.2570']
# ['compareciente', '0.2570']
# ['sevicia', '0.2569']
# ['cesar', '0.2565']
# ['invento', '0.2561']
# ['sanción', '0.2556']
# ['debate', '0.2554']
# ['construido', '0.2554']
# ['congresista', '0.2554']
# ['sacrificarla', '0.2552']
# ['búsqueda', '0.2551']
# ['rampante', '0.2551']
# ['cometido', '0.2543']
# ['origen', '0.2542']
# ['droga', '0.2542']
# ['amazona', '0.2539']
# ['indígena', '0.2538']
# ['perniciosa', '0.2537']
# ['resucitado', '0.2536']
# ['maniatado', '0.2533']
# ['cuestionamiento', '0.2529']
# ['claridad', '0.2524']
# ['estatus', '0.2523']
# ['mínimamente', '0.2523']
# ['tontería', '0.2521']
# ['defensor', '0.2519']
# ['tranquilidad', '0.2518']
# ['causado', '0.2517']
# ['suficientemente', '0.2512']
# ['comprensible', '0.2508']
# ['forzado', '0.2505']
# ['reducción', '0.2505']
# ['aprobación', '0.2499']
# ['periodo', '0.2497']
# ['directamente', '0.2497']
# ['control', '0.2493']
# ['fundamento', '0.2478']
# ['legado', '0.2475']
# ['manifiesto', '0.2475']
# ['verdadero', '0.2474']
# ['ilegal', '0.2472']
# ['explorador', '0.2471']
# ['saciedad', '0.2470']
# ['solución', '0.2470']
# ['negociador', '0.2469']
# ['parlamentario', '0.2468']
# ['innumerable', '0.2460']
# ['competitividad', '0.2459']
# ['compatriota', '0.2459']
# ['voluntario', '0.2458']
# ['celeridad', '0.2457']
# ['poder', '0.2453']
# ['escandaloso', '0.2447']
# ['prioridad', '0.2446']
# ['particular', '0.2446']
# ['conducta', '0.2441']
# ['infracción', '0.2438']
# ['agravante', '0.2433']
# ['orientación', '0.2430']
# ['desencantado', '0.2429']
# ['corte', '0.2429']
# ['ciudadano', '0.2426']
# ['medida', '0.2426']
# ['necesidad', '0.2423']
# ['simplemente', '0.2422']
# ['fenómeno', '0.2421']
# ['posibilidad', '0.2420']
# ['divulgación', '0.2419']
# ['trance', '0.2417']
# ['seguridad', '0.2416']
# ['general', '0.2411']
# ['sorprendente', '0.2404']
# ['tiempo', '0.2402']
# ['consenso', '0.2401']
# ['respuesta', '0.2401']
# ['planteamiento', '0.2398']
# ['popular', '0.2397']
# ['yugo', '0.2396']
# ['obra', '0.2396']
# ['reunión', '0.2393']
# ['confundida', '0.2388']
# ['mandatario', '0.2388']
# ['presenciar', '0.2388']
# ['publicación', '0.2387']
# ['interno', '0.2387']
# ['prescripción', '0.2387']
# ['momento', '0.2385']
# ['crítico', '0.2385']
# ['gigantesco', '0.2384']
# ['escenario', '0.2376']
# ['merced', '0.2374']
# ['complejidad', '0.2366']
# ['hombre', '0.2359']
# ['integralmente', '0.2357']
# ['manutención', '0.2354']
# ['victimario', '0.2344']
# ['cárcel', '0.2339']
# ['imposible', '0.2334']
# ['irresponsable', '0.2334']
# ['cambio', '0.2327']
# ['fortalecimiento', '0.2324']
# ['periodista', '0.2322']
# ['sesenta', '0.2320']
# ['desconcentrado', '0.2315']
# ['establecimiento', '0.2314']
# ['ministerio', '0.2314']
# ['experiencia', '0.2313']
# ['fuente', '0.2312']
# ['significativo', '0.2312']
# ['atención', '0.2310']
# ['representante', '0.2308']
# ['televisión', '0.2298']
# ['oportunidad', '0.2294']
# ['drástico', '0.2291']
# ['promesa', '0.2290']
# ['sierra', '0.2288']
# ['tesis', '0.2286']
# ['prolongado', '0.2286']
# ['desventaja', '0.2285']
# ['implementación', '0.2285']
# ['crecimiento', '0.2276']
# ['autorización', '0.2273']
# ['judicial', '0.2270']
# ['ambiciosa', '0.2268']
# ['manos', '0.2267']
# ['retorno', '0.2267']
# ['ocurrido', '0.2261']
# ['heleno', '0.2261']
# ['revisión', '0.2256']
# ['retención', '0.2252']
# ['penitenciario', '0.2252']
# ['perjudicial', '0.2250']
# ['sustento', '0.2248']
# ['escudo', '0.2248']
# ['vulnerable', '0.2246']
# ['institucional', '0.2246']
# ['estructural', '0.2244']
# ['iniciativa', '0.2242']
# ['interior', '0.2240']
# ['promoción', '0.2234']
# ['consistente', '0.2233']
# ['propiedad', '0.2231']
# ['decepcionante', '0.2230']
# ['filosofía', '0.2228']
# ['proceso', '0.2226']
# ['subyacente', '0.2214']
# ['atentatorio', '0.2213']
# ['tarea', '0.2212']
# ['interés', '0.2211']
# ['confianza', '0.2208']
# ['centralizador', '0.2203']
# ['ministro', '0.2202']
# ['enterado', '0.2195']
# ['analista', '0.2193']
# ['representado', '0.2190']
# ['comisión', '0.2186']
# ['apresurado', '0.2181']
# ['inversión', '0.2177']
# ['discernimiento', '0.2176']
# ['silencio', '0.2176']
# ['destino', '0.2176']
# ['abundante', '0.2169']
# ['virtud', '0.2169']
# ['supuesto', '0.2165']
# ['bonificación', '0.2165']
# ['antiguo', '0.2163']
# ['hermano', '0.2153']
# ['profundo', '0.2151']
# ['senado', '0.2151']
# ['expectativa', '0.2150']
# ['liderazgo', '0.2148']
# ['parálisis', '0.2148']
# ['treinta', '0.2145']
# ['asamblea', '0.2143']
# ['primero', '0.2140']
# ['insignia', '0.2139']
# ['homicida', '0.2138']
# ['asunto', '0.2138']
# ['mayoritario', '0.2136']
# ['perfectamente', '0.2135']
# ['observador', '0.2134']
# ['trayectoria', '0.2132']
# ['palabra', '0.2130']
# ['inmenso', '0.2129']
# ['suspensión', '0.2127']
# ['reinterpretado', '0.2125']
# ['frent', '0.2125']
# ['dictaría', '0.2125']
# ['derechos', '0.2123']
# ['decena', '0.2120']
# ['inteligente', '0.2119']
# ['tajante', '0.2118']
# ['táctico', '0.2109']
# ['presente', '0.2105']
# ['triunfo', '0.2105']
# ['impuesto', '0.2104']
# ['anti', '0.2104']
# ['perspectivo', '0.2101']
# ['absoluto', '0.2099']
# ['conocimiento', '0.2099']
# ['violado', '0.2092']
# ['engaño', '0.2091']
# ['contribuir', '0.2085']
# ['polémico', '0.2079']
# ['reflexión', '0.2078']
# ['social', '0.2077']
# ['costado', '0.2075']
# ['coherente', '0.2071']
# ['eufemismos', '0.2069']
# ['siquiera', '0.2068']
# ['ostensible', '0.2066']
# ['continuo', '0.2065']
# ['antioquia', '0.2065']
# ['monumental', '0.2062']
# ['aplicación', '0.2061']
# ['desarrollo', '0.2060']
# ['costero', '0.2059']
# ['ambicioso', '0.2059']
# ['miedo', '0.2057']
# ['indulto', '0.2054']
# ['petro', '0.2052']
# ['aéreo', '0.2051']
# ['modificación', '0.2051']
# ['guatemala', '0.2048']
# ['veinte', '0.2047']
# ['grave', '0.2047']
# ['opinión', '0.2046']
# ['importante', '0.2046']
# ['repudio', '0.2046']
# ['presunto', '0.2046']
# ['devenida', '0.2045']
# ['ordenamiento', '0.2039']
# ['suficiente', '0.2038']
# ['funcionario', '0.2033']
# ['ayuda', '0.2031']
# ['alternativa', '0.2031']
# ['comisionado', '0.2030']
# ['lengua', '0.2026']
# ['legislativa', '0.2026']
# ['legislativo', '0.2025']
# ['importador', '0.2024']
# ['farc', '0.2023']
# ['viabilidad', '0.2017']
# ['obtención', '0.2017']
# ['mujer', '0.2015']
# ['progresar', '0.2003']
# ['comicio', '0.2003']
# ['vigente', '0.2002']
# ['recordar', '0.1997']
# ['discutible', '0.1996']
# ['esperado', '0.1995']
# ['espíritu', '0.1995']
# ['tratamiento', '0.1993']
# ['protegido', '0.1985']
# ['problema', '0.1982']
# ['bolivariano', '0.1980']
# ['resultado', '0.1979']
# ['blando', '0.1975']
# ['cumplimiento', '0.1974']
# ['similitud', '0.1971']
# ['estatal', '0.1971']
# ['estructurado', '0.1967']
# ['delictivo', '0.1967']
# ['sustentar', '0.1966']
# ['cooptado', '0.1966']
# ['central', '0.1965']
# ['base', '0.1964']
# ['perverso', '0.1964']
# ['damnificado', '0.1963']
# ['liderado', '0.1962']
# ['infundada', '0.1960']
# ['postrada', '0.1960']
# ['paradójico', '0.1957']
# ['disposición', '0.1956']
# ['mexicano', '0.1955']
# ['golfo', '0.1954']
# ['cimarrona', '0.1954']
# ['capturo', '0.1953']
# ['cuestionable', '0.1953']
# ['fundamental', '0.1951']
# ['geográfico', '0.1950']
# ['puerto', '0.1947']
# ['transitorio', '0.1945']
# ['prueba', '0.1942']
# ['camino', '0.1940']
# ['minero', '0.1939']
# ['zona', '0.1939']
# ['ley', '0.1937']
# ['francisco', '0.1931']
# ['medio', '0.1931']
# ['sujeción', '0.1927']
# ['idea', '0.1923']
# ['posterior', '0.1919']
# ['temer', '0.1919']
# ['improbable', '0.1916']
# ['concertado', '0.1912']
# ['ser él', '0.1912']
# ['entrevista', '0.1911']
# ['obstáculo', '0.1909']
# ['derecho', '0.1908']
# ['invocado', '0.1908']
# ['orilla', '0.1907']
# ['labor', '0.1904']
# ['economist', '0.1902']
# ['eficacia', '0.1900']
# ['bilateral', '0.1900']
# ['acaso', '0.1899']
# ['terminado', '0.1895']
# ['vuelta', '0.1894']
# ['éxito', '0.1893']
# ['desgastar', '0.1890']
# ['enseñanza', '0.1884']
# ['crucial', '0.1884']
# ['atraso', '0.1883']
# ['emporio', '0.1879']
# ['noticia', '0.1878']
# ['materia', '0.1876']
# ['lineamiento', '0.1873']
# ['perteneciente', '0.1870']
# ['actual', '0.1868']
# ['ente', '0.1867']
# ['hecho', '0.1865']
# ['raíz', '0.1865']
# ['artificio', '0.1865']
# ['cubano', '0.1863']
# ['relacionado', '0.1863']
# ['brillante', '0.1863']
# ['punitivo', '0.1863']
# ['comercial', '0.1857']
# ['colombiano', '0.1854']
# ['tremendo', '0.1854']
# ['gerencia', '0.1851']
# ['panfleto', '0.1851']
# ['abrumador', '0.1851']
# ['suboficial', '0.1849']
# ['procedimiento', '0.1848']
# ['indeseable', '0.1846']
# ['secreto', '0.1846']
# ['academia', '0.1845']
# ['posible', '0.1844']
# ['evaluación', '0.1843']
# ['tráfico', '0.1839']
# ['edición', '0.1839']
# ['principal', '0.1838']
# ['prensa', '0.1836']
# ['enunciada', '0.1835']
# ['financiador', '0.1833']
# ['resto', '0.1832']
# ['prestigio', '0.1830']
# ['esfuerzo', '0.1829']
# ['pobre', '0.1829']
# ['establecido', '0.1828']
# ['ilícito', '0.1824']
# ['mencionado', '0.1822']
# ['personaje', '0.1815']
# ['disimulada', '0.1806']
# ['legítimo', '0.1800']
# ['asegurable', '0.1797']
# ['dificultad', '0.1795']
# ['sugerencia', '0.1791']
# ['apoyo', '0.1791']
# ['líder', '0.1790']
# ['opinadores', '0.1790']
# ['carga', '0.1789']
# ['colombia', '0.1789']
# ['cercanía', '0.1786']
# ['ilustrativo', '0.1782']
# ['campo', '0.1782']
# ['equivalente', '0.1782']
# ['componente', '0.1779']
# ['capacidad', '0.1778']
# ['candidez', '0.1776']
# ['costillar', '0.1772']
# ['verificación', '0.1768']
# ['futuro', '0.1766']
# ['forma', '0.1765']
# ['reconocido', '0.1764']
# ['diálogo', '0.1760']
# ['función', '0.1756']
# ['participaciones', '0.1756']
# ['refundido', '0.1754']
# ['reincorporado', '0.1749']
# ['ordenado', '0.1749']
# ['sancionar', '0.1744']
# ['indefinido', '0.1743']
# ['daño', '0.1736']
# ['acuerdo', '0.1735']
# ['acto', '0.1734']
# ['perdón', '0.1734']
# ['cabeza', '0.1734']
# ['mecanismo', '0.1732']
# ['dios', '0.1731']
# ['columna', '0.1731']
# ['bala', '0.1728']
# ['persona', '0.1728']
# ['impacto', '0.1725']
# ['antijurídico', '0.1724']
# ['sumido', '0.1718']
# ['perjuicio', '0.1716']
# ['información', '0.1714']
# ['optimismo', '0.1710']
# ['línea', '0.1706']
# ['esencial', '0.1706']
# ['referente', '0.1701']
# ['propuesta', '0.1700']
# ['santos', '0.1696']
# ['carácter', '0.1694']
# ['homicidio', '0.1693']
# ['diferenciar', '0.1680']
# ['paralelo', '0.1679']
# ['débil', '0.1674']
# ['mercado', '0.1672']
# ['integrante', '0.1672']
# ['narrativo', '0.1671']
# ['activo', '0.1671']
# ['perdido', '0.1671']
# ['sentido', '0.1669']
# ['aumento', '0.1665']
# ['alternativo', '0.1663']
# ['semana', '0.1660']
# ['uniformado', '0.1660']
# ['allegado', '0.1657']
# ['magistrado', '0.1655']
# ['propósito', '0.1654']
# ['convocatoria', '0.1650']
# ['comparado', '0.1649']
# ['recomendación', '0.1647']
# ['congreso', '0.1644']
# ['mentiroso', '0.1641']
# ['enorme', '0.1635']
# ['amparado', '0.1631']
# ['retiro', '0.1631']
# ['complementariedad', '0.1630']
# ['entrada', '0.1629']
# ['proporcionado', '0.1628']
# ['concedido', '0.1628']
# ['banda', '0.1626']
# ['carlos', '0.1625']
# ['jamás', '0.1620']
# ['penal', '0.1620']
# ['votante', '0.1618']
# ['infortunio', '0.1618']
# ['forzar', '0.1613']
# ['opción', '0.1613']
# ['precedido', '0.1612']
# ['incremento', '0.1611']
# ['haber', '0.1610']
# ['abogados', '0.1609']
# ['legal', '0.1606']
# ['eficiente', '0.1606']
# ['barco', '0.1602']
# ['cosa', '0.1601']
# ['arbitrario', '0.1599']
# ['reiterado', '0.1598']
# ['botín', '0.1597']
# ['mafioso', '0.1591']
# ['mayor', '0.1587']
# ['zarpó', '0.1586']
# ['formar', '0.1584']
# ['transitar', '0.1583']
# ['fe', '0.1582']
# ['alcanzarla', '0.1582']
# ['lista', '0.1579']
# ['autenticidad', '0.1578']
# ['mejoramiento', '0.1573']
# ['universidades', '0.1570']
# ['cegado', '0.1568']
# ['respalda', '0.1565']
# ['pertinente', '0.1564']
# ['entrega', '0.1563']
# ['responsable', '0.1560']
# ['común', '0.1557']
# ['espectro', '0.1556']
# ['afinidades', '0.1555']
# ['procurar', '0.1554']
# ['gestión', '0.1553']
# ['compromiso', '0.1547']
# ['ilimitado', '0.1545']
# ['irregular', '0.1543']
# ['prometedor', '0.1542']
# ['mantenimiento', '0.1542']
# ['entrado', '0.1542']
# ['violatorio', '0.1542']
# ['reinsertado', '0.1538']
# ['exitosos', '0.1533']
# ['cuba', '0.1529']
# ['drogar', '0.1529']
# ['inducida', '0.1526']
# ['santander', '0.1522']
# ['real', '0.1520']
# ['tributario', '0.1520']
# ['aprendido', '0.1518']
# ['siguiente', '0.1517']
# ['contrato', '0.1516']
# ['entrante', '0.1515']
# ['ofensivo', '0.1514']
# ['maltrato', '0.1513']
# ['cura', '0.1513']
# ['escollo', '0.1511']
# ['característica', '0.1511']
# ['ingenuo', '0.1506']
# ['empeñado', '0.1506']
# ['largo', '0.1504']
# ['espontáneo', '0.1496']
# ['manchada', '0.1496']
# ['delito', '0.1495']
# ['debatir', '0.1493']
# ['torre', '0.1493']
# ['superado', '0.1492']
# ['atrapado', '0.1490']
# ['próspero', '0.1488']
# ['repetido', '0.1488']
# ['eln', '0.1486']
# ['conceptual', '0.1480']
# ['izquierdo', '0.1479']
# ['soberbio', '0.1478']
# ['extraño', '0.1478']
# ['herrera', '0.1477']
# ['diverso', '0.1475']
# ['vinculado', '0.1468']
# ['mano', '0.1467']
# ['improvisado', '0.1466']
# ['empeño', '0.1461']
# ['doloroso', '0.1455']
# ['plaza', '0.1453']
# ['antioqueño', '0.1450']
# ['edad', '0.1450']
# ['niñez', '0.1444']
# ['exponencial', '0.1444']
# ['restaurativo', '0.1441']
# ['enunciado', '0.1441']
# ['respeto', '0.1438']
# ['disputo', '0.1436']
# ['falla', '0.1434']
# ['apertura', '0.1432']
# ['términos', '0.1431']
# ['parodia', '0.1430']
# ['cocaína', '0.1429']
# ['deslegitimado', '0.1425']
# ['someterlo', '0.1424']
# ['admisible', '0.1423']
# ['favor', '0.1423']
# ['inspirado', '0.1423']
# ['obligado', '0.1421']
# ['alias', '0.1418']
# ['trabajar', '0.1414']
# ['cualquiera', '0.1410']
# ['gamonal', '0.1408']
# ['inicio', '0.1406']
# ['sucedáneo', '0.1405']
# ['rentable', '0.1401']
# ['pese', '0.1399']
# ['tutela', '0.1395']
# ['cínico', '0.1395']
# ['familiar', '0.1392']
# ['decreto', '0.1389']
# ['mal', '0.1388']
# ['agravado', '0.1384']
# ['peor', '0.1383']
# ['elemento', '0.1383']
# ['puesto', '0.1383']
# ['uniforme', '0.1380']
# ['propuesto', '0.1379']
# ['dispuesto', '0.1373']
# ['germinal', '0.1372']
# ['burla', '0.1372']
# ['fútbol', '0.1371']
# ['excesivo', '0.1369']
# ['pactado', '0.1369']
# ['regional', '0.1368']
# ['público', '0.1366']
# ['escudero', '0.1365']
# ['imputado', '0.1363']
# ['dolor', '0.1363']
# ['conocido', '0.1359']
# ['serio', '0.1356']
# ['von', '0.1343']
# ['espectador', '0.1342']
# ['recurso', '0.1342']
# ['agenda', '0.1340']
# ['término', '0.1337']
# ['pregunta', '0.1336']
# ['cabo', '0.1335']
# ['certeza', '0.1334']
# ['requerimiento', '0.1326']
# ['transporte', '0.1325']
# ['notorio', '0.1324']
# ['senador', '0.1323']
# ['ser', '0.1319']
# ['respetar', '0.1318']
# ['utópico', '0.1315']
# ['arriesgado', '0.1314']
# ['equitativo', '0.1313']
# ['flexibilidad', '0.1311']
# ['cese', '0.1299']
# ['ilustrado', '0.1296']
# ['absurdo', '0.1296']
# ['renta', '0.1295']
# ['tutelar', '0.1293']
# ['norma', '0.1293']
# ['vicepresidenta', '0.1292']
# ['entregar', '0.1289']
# ['balazo', '0.1289']
# ['ciento', '0.1288']
# ['prematuro', '0.1281']
# ['inicial', '0.1281']
# ['lider', '0.1279']
# ['ruta', '0.1278']
# ['oscuro', '0.1276']
# ['extorsivo', '0.1273']
# ['jefe', '0.1270']
# ['concreto', '0.1269']
# ['revista', '0.1269']
# ['similar', '0.1266']
# ['fría', '0.1265']
# ['paro', '0.1263']
# ['prosélito', '0.1260']
# ['lugar', '0.1253']
# ['indispensable', '0.1252']
# ['joven', '0.1251']
# ['fondos', '0.1250']
# ['arquitecto', '0.1249']
# ['relegado', '0.1247']
# ['uribe', '0.1243']
# ['dicho', '0.1242']
# ['lejos', '0.1239']
# ['bastones', '0.1239']
# ['muestra', '0.1237']
# ['poético', '0.1234']
# ['jurídico', '0.1226']
# ['motivo', '0.1223']
# ['comunicado', '0.1222']
# ['amor', '0.1222']
# ['encaminarlo', '0.1221']
# ['piedra', '0.1220']
# ['colectivo', '0.1220']
# ['organizado', '0.1219']
# ['efectivo', '0.1218']
# ['fiscal', '0.1217']
# ['viejo', '0.1215']
# ['consejo', '0.1210']
# ['productivo', '0.1206']
# ['llamado', '0.1205']
# ['centrado', '0.1199']
# ['conjunto', '0.1199']
# ['utilizado', '0.1197']
# ['carta', '0.1196']
# ['personal', '0.1191']
# ['anterior', '0.1190']
# ['camisa', '0.1187']
# ['único', '0.1185']
# ['maestro', '0.1185']
# ['episodio', '0.1184']
# ['vía', '0.1184']
# ['torpeza', '0.1182']
# ['candidato', '0.1178']
# ['dólares', '0.1177']
# ['sorprendido', '0.1175']
# ['vido', '0.1175']
# ['tozudez', '0.1171']
# ['escobar', '0.1169']
# ['temprano', '0.1167']
# ['denominado', '0.1166']
# ['estatutario', '0.1163']
# ['concepto', '0.1160']
# ['estar', '0.1158']
# ['pro', '0.1157']
# ['consulta', '0.1153']
# ['vergonzoso', '0.1151']
# ['formal', '0.1145']
# ['ejemplo', '0.1138']
# ['paso', '0.1137']
# ['alcaldía', '0.1135']
# ['falta', '0.1132']
# ['espinoso', '0.1131']
# ['cuyo', '0.1126']
# ['sindicato', '0.1125']
# ['septiembre', '0.1124']
# ['necesitado', '0.1123']
# ['pesca', '0.1123']
# ['normativa', '0.1122']
# ['pena', '0.1121']
# ['funciones', '0.1116']
# ['sistema', '0.1116']
# ['grupo', '0.1112']
# ['excusa', '0.1112']
# ['lado', '0.1111']
# ['cabezo', '0.1111']
# ['fin', '0.1106']
# ['respectivo', '0.1106']
# ['beneficio', '0.1095']
# ['margen', '0.1091']
# ['ejercicio', '0.1090']
# ['trabajo', '0.1089']
# ['ordinario', '0.1084']
# ['calificado', '0.1084']
# ['derivado', '0.1081']
# ['preguntar', '0.1081']
# ['garantía', '0.1078']
# ['torno', '0.1075']
# ['sentado', '0.1075']
# ['razonable', '0.1069']
# ['firma', '0.1069']
# ['regla', '0.1062']
# ['compuesto', '0.1060']
# ['objetivo', '0.1059']
# ['papel', '0.1048']
# ['negocio', '0.1046']
# ['superfluo', '0.1045']
# ['cifra', '0.1045']
# ['empresa', '0.1044']
# ['unánime', '0.1044']
# ['abuelo', '0.1035']
# ['análisis', '0.1032']
# ['miembro', '0.1032']
# ['abogado', '0.1029']
# ['riesgo', '0.1028']
# ['lobo', '0.1026']
# ['cuerpo', '0.1023']
# ['susceptible', '0.1022']
# ['nobel', '0.1020']
# ['devoto', '0.1017']
# ['verificable', '0.1016']
# ['teórico', '0.1014']
# ['unido', '0.1014']
# ['acumulado', '0.1013']
# ['allá', '0.1012']
# ['karl', '0.1012']
# ['necesario', '0.1010']
# ['haberlo', '0.1010']
# ['lastrar', '0.1003']
# ['red', '0.1000']
# ['planteado', '0.1000']
# ['duda', '0.0997']
# ['claro', '0.0996']
# ['obligatorio', '0.0994']
# ['millón', '0.0994']
# ['ganado', '0.0992']
# ['herramienta', '0.0990']
# ['cargado', '0.0986']
# ['distinto', '0.0982']
# ['reportero', '0.0978']
# ['fines', '0.0975']
# ['vocero', '0.0975']
# ['práctico', '0.0967']
# ['departamento', '0.0966']
# ['incentivo', '0.0966']
# ['punto', '0.0965']
# ['clar', '0.0965']
# ['rumbo', '0.0959']
# ['inicuo', '0.0957']
# ['preámbulo', '0.0956']
# ['documento', '0.0955']
# ['león', '0.0954']
# ['duradero', '0.0953']
# ['plan', '0.0950']
# ['méxico', '0.0941']
# ['triste', '0.0938']
# ['operandi', '0.0938']
# ['irrespetuoso', '0.0938']
# ['inalcanzable', '0.0933']
# ['objeto', '0.0931']
# ['fecha', '0.0929']
# ['permeada', '0.0929']
# ['caso', '0.0923']
# ['definir', '0.0918']
# ['seguro', '0.0910']
# ['vecino', '0.0907']
# ['categórico', '0.0900']
# ['diciembre', '0.0899']
# ['escrito', '0.0895']
# ['hacerlo', '0.0895']
# ['sector', '0.0895']
# ['sujeto', '0.0891']
# ['caído', '0.0891']
# ['meses', '0.0890']
# ['viable', '0.0888']
# ['explico', '0.0886']
# ['noviembre', '0.0885']
# ['mara', '0.0883']
# ['verso', '0.0881']
# ['aspecto', '0.0880']
# ['respaldo', '0.0879']
# ['calidad', '0.0878']
# ['prisa', '0.0878']
# ['centro', '0.0873']
# ['sueño', '0.0870']
# ['mejía', '0.0869']
# ['menor', '0.0869']
# ['completo', '0.0867']
# ['oro', '0.0867']
# ['flotar', '0.0867']
# ['brevedad', '0.0865']
# ['virgilio', '0.0862']
# ['plano', '0.0862']
# ['trar', '0.0851']
# ['luz', '0.0849']
# ['santo', '0.0848']
# ['apuesto', '0.0842']
# ['año', '0.0842']
# ['experto', '0.0837']
# ['cargo', '0.0835']
# ['voz', '0.0830']
# ['cerca', '0.0827']
# ['convenio', '0.0824']
# ['error', '0.0823']
# ['hora', '0.0820']
# ['nadies', '0.0817']
# ['latino', '0.0816']
# ['atrás', '0.0816']
# ['basado', '0.0813']
# ['positivo', '0.0813']
# ['límite', '0.0809']
# ['desdén', '0.0802']
# ['laboratorio', '0.0791']
# ['enmarcada', '0.0791']
# ['rural', '0.0788']
# ['alcalde', '0.0787']
# ['usado', '0.0786']
# ['infractor', '0.0783']
# ['oportuna', '0.0779']
# ['capaz', '0.0778']
# ['actor', '0.0776']
# ['alguien', '0.0772']
# ['tasa', '0.0769']
# ['tangible', '0.0768']
# ['parcial', '0.0766']
# ['diario', '0.0756']
# ['expedito', '0.0755']
# ['anoche', '0.0749']
# ['querer', '0.0748']
# ['capo', '0.0744']
# ['cercano', '0.0743']
# ['ganar', '0.0743']
# ['destacado', '0.0741']
# ['mermar', '0.0737']
# ['empleado', '0.0734']
# ['tajo', '0.0734']
# ['plazo', '0.0731']
# ['junto', '0.0729']
# ['arrollador', '0.0729']
# ['casa', '0.0727']
# ['superior', '0.0726']
# ['confirmado', '0.0726']
# ['dirigido', '0.0726']
# ['urbano', '0.0724']
# ['laboral', '0.0717']
# ['preciso', '0.0715']
# ['logro', '0.0705']
# ['ginebra', '0.0703']
# ['firmado', '0.0703']
# ['enero', '0.0699']
# ['éxtasis', '0.0695']
# ['psique', '0.0689']
# ['servicio', '0.0685']
# ['cauca', '0.0683']
# ['movido', '0.0678']
# ['homenaje', '0.0671']
# ['dolo', '0.0666']
# ['nevado', '0.0663']
# ['gracias', '0.0661']
# ['brava', '0.0660']
# ['deporte', '0.0660']
# ['acordado', '0.0655']
# ['elit', '0.0653']
# ['garantir', '0.0651']
# ['octubre', '0.0648']
# ['enmarcado', '0.0644']
# ['normativo', '0.0636']
# ['agosto', '0.0634']
# ['putumayo', '0.0631']
# ['autonómico', '0.0625']
# ['ridículo', '0.0622']
# ['exsenador', '0.0621']
# ['hueso', '0.0621']
# ['alto', '0.0620']
# ['proyecto', '0.0619']
# ['agua', '0.0615']
# ['patrón', '0.0614']
# ['patrocinio', '0.0612']
# ['ingreso', '0.0612']
# ['cámara', '0.0611']
# ['cés', '0.0609']
# ['anunciado', '0.0608']
# ['especial', '0.0606']
# ['espacio', '0.0600']
# ['fondo', '0.0600']
# ['lavado', '0.0599']
# ['abril', '0.0598']
# ['ff', '0.0588']
# ['emitido', '0.0587']
# ['revés', '0.0587']
# ['olivo', '0.0585']
# ['artilugio', '0.0581']
# ['burlar', '0.0581']
# ['solicitud', '0.0579']
# ['exequible', '0.0576']
# ['señor', '0.0575']
# ['juvenil', '0.0567']
# ['individual', '0.0565']
# ['deber', '0.0561']
# ['nariñense', '0.0560']
# ['febrero', '0.0558']
# ['calle', '0.0555']
# ['estilo', '0.0555']
# ['marco', '0.0552']
# ['remitente', '0.0551']
# ['pasivo', '0.0547']
# ['dpi', '0.0544']
# ['pleno', '0.0543']
# ['cúmulo', '0.0539']
# ['libro', '0.0532']
# ['precepto', '0.0532']
# ['niñas', '0.0525']
# ['marzo', '0.0519']
# ['milagroso', '0.0517']
# ['costoso', '0.0512']
# ['académico', '0.0511']
# ['voto', '0.0507']
# ['publicado', '0.0503']
# ['podido', '0.0497']
# ['rojo', '0.0496']
# ['trabajen', '0.0493']
# ['anhelado', '0.0488']
# ['dedicado', '0.0485']
# ['invitándola', '0.0481']
# ['infinito', '0.0479']
# ['velo', '0.0477']
# ['otorgado', '0.0471']
# ['meta', '0.0471']
# ['delegatario', '0.0468']
# ['nivel', '0.0465']
# ['conectado', '0.0458']
# ['criterio', '0.0454']
# ['profesional', '0.0452']
# ['oficina', '0.0452']
# ['expedita', '0.0452']
# ['municipio', '0.0448']
# ['poema', '0.0440']
# ['famoso', '0.0438']
# ['alfil', '0.0435']
# ['noticiero', '0.0434']
# ['nadi', '0.0428']
# ['hincapié', '0.0428']
# ['niña', '0.0427']
# ['antonio', '0.0426']
# ['afán', '0.0423']
# ['apellido', '0.0420']
# ['integral', '0.0419']
# ['anhelo', '0.0416']
# ['humilde', '0.0406']
# ['vestido', '0.0405']
# ['cayetano', '0.0402']
# ['alberto', '0.0392']
# ['equipo', '0.0389']
# ['amplio', '0.0385']
# ['manuel', '0.0384']
# ['disímil', '0.0382']
# ['curso', '0.0377']
# ['rambo', '0.0377']
# ['borrador', '0.0373']
# ['ciclo', '0.0370']
# ['pablo', '0.0367']
# ['gent', '0.0367']
# ['mañana', '0.0363']
# ['piel', '0.0361']
# ['laberinto', '0.0358']
# ['trimestre', '0.0358']
# ['nulo', '0.0346']
# ['regaño', '0.0344']
# ['peso', '0.0343']
# ['subrogado', '0.0342']
# ['fallo', '0.0340']
# ['oferta', '0.0333']
# ['garant', '0.0326']
# ['sumado', '0.0326']
# ['salido', '0.0325']
# ['dio', '0.0314']
# ['cero', '0.0306']
# ['oveja', '0.0305']
# ['barra', '0.0302']
# ['despacho', '0.0302']
# ['original', '0.0299']
# ['veredal', '0.0299']
# ['áreas', '0.0284']
# ['promuevo', '0.0282']
# ['rebajar', '0.0281']
# ['producto', '0.0275']
# ['modelo', '0.0273']
# ['torcido', '0.0270']
# ['barrio', '0.0267']
# ['doctor', '0.0266']
# ['probar', '0.0262']
# ['honesto', '0.0259']
# ['més', '0.0258']
# ['barbosa', '0.0257']
# ['previo', '0.0256']
# ['rafael', '0.0254']
# ['ricardo', '0.0253']
# ['estándar', '0.0252']
# ['fiel', '0.0248']
# ['nonagésimo', '0.0248']
# ['apostar', '0.0246']
# ['tema', '0.0239']
# ['mensaje', '0.0234']
# ['arreglo', '0.0233']
# ['ánimo', '0.0231']
# ['duro', '0.0230']
# ['ilusorio', '0.0230']
# ['mil', '0.0226']
# ['lector', '0.0221']
# ['valor', '0.0215']
# ['lema', '0.0213']
# ['desear', '0.0208']
# ['elegido', '0.0186']
# ['premura', '0.0185']
# ['realizable', '0.0182']
# ['ex', '0.0182']
# ['gasto', '0.0180']
# ['josé', '0.0180']
# ['retributivo', '0.0179']
# ['aportar', '0.0178']
# ['v', '0.0177']
# ['radio', '0.0168']
# ['porte', '0.0165']
# ['regalía', '0.0157']
# ['san', '0.0156']
# ['tipo', '0.0153']
# ['querido', '0.0153']
# ['jorge', '0.0151']
# ['rogar', '0.0145']
# ['reja', '0.0127']
# ['enfocar', '0.0123']
# ['luis', '0.0119']
# ['caracol', '0.0113']
# ['chance', '0.0109']
# ['lagarto', '0.0106']
# ['valioso', '0.0105']
# ['resguardo', '0.0101']
# ['abrazo', '0.0099']
# ['rodríguez', '0.0098']
# ['goto', '0.0098']
# ['rebaja', '0.0092']
# ['hilvanado', '0.0092']
# ['colega', '0.0087']
# ['curioso', '0.0084']
# ['giro', '0.0079']
# ['texto', '0.0077']
# ['acierto', '0.0067']
# ['simple', '0.0064']
# ['díaz', '0.0056']
# ['juan', '0.0052']
# ['programa', '0.0048']
# ['sesudo', '0.0045']
# ['altibajo', '0.0036']
# ['dinámico', '0.0035']
# ['dañino', '0.0022']
# ['bién', '0.0022']
# ['julián', '0.0012']
# ['cuidadoso', '0.0006']
# ['bienvenido', '0.0004']
# ['rodar', '0.0002']
# ['            ', '0.0000']
# ['inciertar', '0.0000']
# ['violenciir', '0.0000']
# ['     ', '0.0000']
# ['tierro', '0.0000']
# ['tutir', '0.0000']
# ['autodefensar', '0.0000']
# ['caús', '0.0000']
# ['semán', '0.0000']
# ['westfalia', '0.0000']
# ['pachelly', '0.0000']
# ['persón', '0.0000']
# ['trián', '0.0000']
# ['partícip', '0.0000']
# ['empresariar', '0.0000']
# ['prós', '0.0000']
# ['taparl', '0.0000']
# ['agc', '0.0000']
# ['regañadient', '0.0000']
# ['pobrecer', '0.0000']
# ['crimar', '0.0000']
# ['habán', '0.0000']
# ['catatumbo', '0.0000']
# ['triza', '0.0000']
# ['ordir', '0.0000']
# ['iniciativo', '0.0000']
# ['colombiar', '0.0000']
# ['inquín', '0.0000']
# ['araucir', '0.0000']
# ['prenso', '0.0000']
# ['tibú', '0.0000']
# ['\xa0      ', '0.0000']
# ['esperanzo', '0.0000']
# ['sabienda', '0.0000']
# ['deseándol', '0.0000']
# ['márquez', '0.0000']
# ['mayoer', '0.0000']
# ['indígenar', '0.0000']
# ['             ', '0.0000']
# ['complacientemente', '0.0000']
# ['cartar', '0.0000']
# [' ', '0.0000']
# ['perduro', '0.0000']
# ['acsn', '0.0000']
# ['    ', '0.0000']
# ['incontabl', '0.0000']
# ['extraditabl', '0.0000']
# ['gaitanista', '0.0000']
# ['narcotraficant', '0.0000']
# ['guerrillo', '0.0000']
# ['modu', '0.0000']
# ['cínicar', '0.0000']
# ['tolimo', '0.0000']
# ['pós', '0.0000']
# ['dih', '0.0000']
# ['marquetalia', '0.0000']
# ['ranguir', '0.0000']
# ['                ', '0.0000']
# ['gildardo', '0.0000']
# ['  ', '0.0000']
# ['mosdisco', '0.0000']
# ['combatient', '0.0000']
# ['           ', '0.0000']
# ['timbiquí', '0.0000']
# ['picoto', '0.0000']
# ['               ', '0.0000']
# ['misar', '0.0000']
# ['márgén', '0.0000']
# ['castrens', '0.0000']
# ['cabezar', '0.0000']
# ['epl', '0.0000']
# ['eleno', '0.0000']
# ['páramir', '0.0000']
# ['ramar', '0.0000']
# ['otoniel', '0.0000']
# ['restrepo', '0.0000']
# ['caquetá', '0.0000']
# ['sumapaz', '0.0000']
# ['opiac', '0.0000']
# ['édgar', '0.0000']
# ['frar', '0.0000']
# ['jep', '0.0000']
# ['cúpular', '0.0000']
# ['caicedo', '0.0000']
# ['utopir', '0.0000']
# ['ruán', '0.0000']
# ['echandeír', '0.0000']
# ['amnistir', '0.0000']
# ['esmeraldero', '0.0000']
# ['érar', '0.0000']
# ['peloponeso', '0.0000']
# ['promés', '0.0000']
# ['premisar', '0.0000']
# ['fiscaliar', '0.0000']
# ['cachetado', '0.0000']
# ['negándono', '0.0000']
# ['reincident', '0.0000']
# ['violencio', '0.0000']
# ['mineer', '0.0000']
# ['zonar', '0.0000']
# ['velandia', '0.0000']
# ['lés', '0.0000']
# ['pasaportir', '0.0000']
# ['          ', '0.0000']
# ['tragediir', '0.0000']
# ['oleado', '0.0000']
# ['catequizado', '0.0000']
# ['cinturo', '0.0000']
# ['caguán', '0.0000']
# ['frecuencio', '0.0000']
# ['selir', '0.0000']
# ['instrumentalizándolo', '0.0000']
# ['bukelir', '0.0000']
# ['heroínar', '0.0000']
# ['dilemar', '0.0000']
# ['procuraduriar', '0.0000']
# ['colombio', '0.0000']
# ['olindillo', '0.0000']
# ['infecundamente', '0.0000']
# ['indepaz', '0.0000']
# ['polir', '0.0000']
# ['cadén', '0.0000']
# ['boyacá', '0.0000']
# ['misivo', '0.0000']
# ['etapar', '0.0000']
# ['exigírsel', '0.0000']
# ['embestidar', '0.0000']
# ['         ', '0.0000']
# ['vejámén', '0.0000']
# ['guerro', '0.0000']
# ['caucar', '0.0000']
# ['reglo', '0.0000']
# ['brodway', '0.0000']
# ['nortar', '0.0000']
# ['defensoer', '0.0000']
# ['vacunir', '0.0000']
# ['giraldo', '0.0000']
# ['materio', '0.0000']
# ['dárselir', '0.0000']
# ['carolín', '0.0000']
# ['asonado', '0.0000']
# ['cumplirl', '0.0000']
# ['              ', '0.0000']
# ['fortalecimientir', '0.0000']
# ['preocuparno', '0.0000']
# ['guerrillar', '0.0000']
# ['retóricar', '0.0000']
# ['maloco', '0.0000']
# ['petrista', '0.0000']
# ['almirant', '0.0000']
# ['senadoro', '0.0000']
# ['distopir', '0.0000']
# ['informir', '0.0000']
# ['recalcitrant', '0.0000']
# ['coyunturar', '0.0000']
# ['clausewitz', '0.0000']
# ['araucar', '0.0000']
# ['ausencio', '0.0000']
# ['       ', '0.0000']
# ['rotún', '0.0000']
# ['líneo', '0.0000']
# ['hipersimplificación', '0.0000']
# ['retinar', '0.0000']
# ['anhelamo', '0.0000']
# ['córdobo', '0.0000']
# ['décado', '0.0000']
# ['cordillero', '0.0000']
# ['        ', '0.0000']
# ['poniéndol', '0.0000']
# ['democraciar', '0.0000']
# ['ilimitar', '0.0000']
# ['farso', '0.0000']
# ['      ', '0.0000']
# ['ambulant', '0.0000']
# ['acevedo', '-0.0003']
# ['ciego', '-0.0005']
# ['barranquillo', '-0.0019']
# ['pico', '-0.0020']
# ['mérito', '-0.0028']
# ['pilar', '-0.0031']
# ['ramírez', '-0.0045']
# ['colegio', '-0.0062']
# ['costo', '-0.0063']
# ['cao', '-0.0075']
# ['rico', '-0.0084']
# ['unísono', '-0.0092']
# ['niño', '-0.0098']
# ['horacio', '-0.0101']
# ['ayer', '-0.0103']
# ['sumar', '-0.0123']
# ['rápido', '-0.0124']
# ['humberto', '-0.0125']
# ['garcía', '-0.0127']
# ['martes', '-0.0132']
# ['código', '-0.0133']
# ['danilo', '-0.0133']
# ['mes', '-0.0134']
# ['colón', '-0.0159']
# ['román', '-0.0179']
# ['sincero', '-0.0184']
# ['caño', '-0.0193']
# ['nariño', '-0.0211']
# ['álvaro', '-0.0216']
# ['afín', '-0.0224']
# ['agradecido', '-0.0226']
# ['mesa', '-0.0237']
# ['cobijado', '-0.0240']
# ['pirueta', '-0.0240']
# ['pie', '-0.0260']
# ['alegre', '-0.0265']
# ['robusto', '-0.0265']
# ['faltar', '-0.0271']
# ['llego', '-0.0282']
# ['cpi', '-0.0299']
# ['adecuado', '-0.0305']
# ['mero', '-0.0308']
# ['increíble', '-0.0310']
# ['brizna', '-0.0312']
# ['mm', '-0.0314']
# ['gómez', '-0.0314']
# ['paseo', '-0.0326']
# ['benavides', '-0.0329']
# ['aproveché', '-0.0341']
# ['próximo', '-0.0345']
# ['nota', '-0.0360']
# ['vendedor', '-0.0365']
# ['zón', '-0.0365']
# ['resumen', '-0.0371']
# ['quejo', '-0.0381']
# ['pez', '-0.0396']
# ['diseño', '-0.0399']
# ['precioso', '-0.0409']
# ['quieto', '-0.0417']
# ['mínimo', '-0.0423']
# ['carriel', '-0.0429']
# ['eje', '-0.0443']
# ['martínez', '-0.0443']
# ['conexo', '-0.0461']
# ['barbacoas', '-0.0464']
# ['reposado', '-0.0465']
# ['precio', '-0.0468']
# ['digno', '-0.0470']
# ['premio', '-0.0480']
# ['adrián', '-0.0485']
# ['carvajal', '-0.0487']
# ['mordisco', '-0.0493']
# ['déjelo', '-0.0495']
# ['car', '-0.0498']
# ['ancho', '-0.0501']
# ['feliz', '-0.0502']
# ['artículo', '-0.0506']
# ['leve', '-0.0507']
# ['eduardo', '-0.0511']
# ['dueño', '-0.0526']
# ['fresco', '-0.0542']
# ['turno', '-0.0550']
# ['máximo', '-0.0551']
# ['palo', '-0.0563']
# ['botero', '-0.0564']
# ['trino', '-0.0564']
# ['emc', '-0.0565']
# ['poncho', '-0.0581']
# ['ojo', '-0.0583']
# ['iván', '-0.0585']
# ['sencillo', '-0.0600']
# ['válido', '-0.0601']
# ['básico', '-0.0614']
# ['pastel', '-0.0615']
# ['pizarro', '-0.0621']
# ['iner yo', '-0.0626']
# ['camilo', '-0.0630']
# ['vío', '-0.0631']
# ['barato', '-0.0653']
# ['m', '-0.0668']
# ['facturo', '-0.0757']
# ['rondón', '-0.0758']
# ['the', '-0.0767']
# ['dato', '-0.0771']
# ['c', '-0.0797']
# ['vaso', '-0.0835']
# ['gestor', '-0.0841']
# ['rincón', '-0.0949']
# ['ojalá', '-0.1029']
# ['papá', '-0.1060']
# ['ramo', '-0.1079']
# ['invito', '-0.1094']
# ['square', '-0.1105']
# ['times', '-0.1119']
# ['cómodo', '-0.1127']
# ['gustavo', '-0.1186']
# ['etc', '-0.1222']
# ['ficha', '-0.1268']
# ['flip', '-0.1297']
# ['gancho', '-0.1346']
# ['video', '-0.1385']
# ['bar', '-0.1512']
# ['guapi', '-0.1900']

# %%
# Generar una nube de palabras
word_freq = {palabra: float(similitud) for palabra, similitud in palabras_similares}

wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(word_freq)

# Mostrar la nube de palabras
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# ## Word2vec

# %%
import gensim.downloader as api
import csv

# Descargar el modelo pre-entrenado de Word2Vec en español
modelo_word2vec = api.load('word2vec-google-news-300')

# Define la palabra objetivo
palabra_objetivo = 'paz'

# Aplanar el corpus a una sola lista de palabras y eliminar duplicados
palabras_corpus = list(set([palabra for sublist in contenido_lemas for palabra in sublist]))

# Encontrar palabras similares a la palabra objetivo en el corpus definido
palabras_similares = []

for palabra in palabras_corpus:
    if palabra in modelo_word2vec:
        similitud = modelo_word2vec.similarity(palabra_objetivo, palabra)
        palabras_similares.append((palabra, similitud))

# Ordenar las palabras por similitud en orden descendente
palabras_similares = sorted(palabras_similares, key=lambda item: -item[1])

# Preparar los datos para escribir en el archivo CSV
contenido_lemas_csv = [['Palabra', 'Similitud']]  # Encabezados del CSV
for palabra, similitud in palabras_similares:  
    contenido_lemas_csv.append([palabra, f"{similitud:.4f}"])

# Escribir los datos en un nuevo archivo CSV
with open('word2vec_paz_semana.csv', 'w', newline='', encoding='utf-8-sig') as archivo:
    escritor_csv = csv.writer(archivo)
    escritor_csv.writerows(contenido_lemas_csv)

# Leer y mostrar el contenido del archivo CSV
with open('word2vec_paz_semana.csv', 'r', newline='', encoding='utf-8-sig') as archivo:
    lector_csv = csv.reader(archivo)
    for fila in lector_csv:
        print(fila)
# Out:
# ['Palabra', 'Similitud']
# ['paz', '1.0000']
# ['estar', '0.7547']
# ['ciudad', '0.7374']
# ['falta', '0.7242']
# ['ganar', '0.7110']
# ['semana', '0.7101']
# ['noticia', '0.7078']
# ['guerra', '0.7072']
# ['destino', '0.7067']
# ['feliz', '0.7066']
# ['país', '0.7032']
# ['poder', '0.7029']
# ['trabajo', '0.7024']
# ['libertad', '0.7017']
# ['enorme', '0.6942']
# ['oportunidad', '0.6942']
# ['tiempo', '0.6925']
# ['muerto', '0.6922']
# ['entrevista', '0.6907']
# ['querido', '0.6902']
# ['palabra', '0.6888']
# ['voz', '0.6865']
# ['dios', '0.6863']
# ['hecho', '0.6860']
# ['trabajar', '0.6848']
# ['único', '0.6813']
# ['año', '0.6802']
# ['niño', '0.6778']
# ['duro', '0.6771']
# ['espacio', '0.6760']
# ['niña', '0.6758']
# ['hermano', '0.6758']
# ['respeto', '0.6750']
# ['realmente', '0.6746']
# ['gente', '0.6736']
# ['duda', '0.6698']
# ['muerte', '0.6691']
# ['amor', '0.6680']
# ['nacional', '0.6678']
# ['clase', '0.6649']
# ['siguiente', '0.6638']
# ['primero', '0.6635']
# ['mente', '0.6627']
# ['haber', '0.6618']
# ['recientemente', '0.6617']
# ['mujer', '0.6599']
# ['naturaleza', '0.6597']
# ['cuerpo', '0.6594']
# ['apoyo', '0.6591']
# ['atrás', '0.6590']
# ['ayuda', '0.6589']
# ['pobre', '0.6588']
# ['señor', '0.6587']
# ['motivo', '0.6577']
# ['candidato', '0.6566']
# ['actividad', '0.6562']
# ['miedo', '0.6561']
# ['actualmente', '0.6556']
# ['sentido', '0.6550']
# ['periodo', '0.6548']
# ['escrito', '0.6542']
# ['cuyo', '0.6540']
# ['gobierno', '0.6538']
# ['presente', '0.6537']
# ['seguro', '0.6524']
# ['límite', '0.6520']
# ['dominio', '0.6515']
# ['obra', '0.6513']
# ['internacional', '0.6503']
# ['situación', '0.6501']
# ['mexicano', '0.6493']
# ['comunidad', '0.6489']
# ['razón', '0.6487']
# ['llamado', '0.6482']
# ['fecha', '0.6480']
# ['éxito', '0.6479']
# ['proyecto', '0.6470']
# ['campaña', '0.6468']
# ['carga', '0.6461']
# ['voto', '0.6458']
# ['fuerte', '0.6456']
# ['conocido', '0.6455']
# ['justicia', '0.6446']
# ['líder', '0.6444']
# ['futuro', '0.6442']
# ['periodista', '0.6441']
# ['ayer', '0.6440']
# ['luz', '0.6428']
# ['jamás', '0.6424']
# ['papel', '0.6414']
# ['atención', '0.6413']
# ['código', '0.6413']
# ['droga', '0.6410']
# ['peor', '0.6408']
# ['calidad', '0.6399']
# ['cosa', '0.6387']
# ['manos', '0.6380']
# ['crecimiento', '0.6380']
# ['documento', '0.6370']
# ['ganado', '0.6360']
# ['orden', '0.6357']
# ['alguien', '0.6354']
# ['economía', '0.6350']
# ['inicial', '0.6346']
# ['completo', '0.6346']
# ['contrato', '0.6342']
# ['posición', '0.6340']
# ['mensaje', '0.6335']
# ['lado', '0.6332']
# ['público', '0.6331']
# ['prensa', '0.6320']
# ['barco', '0.6319']
# ['realidad', '0.6319']
# ['perdido', '0.6319']
# ['estrategia', '0.6311']
# ['importante', '0.6307']
# ['televisión', '0.6298']
# ['sueño', '0.6292']
# ['triste', '0.6291']
# ['esfuerzo', '0.6290']
# ['necesario', '0.6285']
# ['historia', '0.6281']
# ['vida', '0.6281']
# ['cualquiera', '0.6280']
# ['artículo', '0.6277']
# ['ejemplo', '0.6275']
# ['caso', '0.6268']
# ['diario', '0.6267']
# ['económico', '0.6266']
# ['especialmente', '0.6263']
# ['violencia', '0.6260']
# ['vuelta', '0.6255']
# ['claro', '0.6252']
# ['cubano', '0.6251']
# ['política', '0.6240']
# ['febrero', '0.6233']
# ['tipo', '0.6232']
# ['lejos', '0.6232']
# ['máximo', '0.6229']
# ['desarrollo', '0.6223']
# ['triunfo', '0.6223']
# ['representante', '0.6220']
# ['comunicado', '0.6219']
# ['período', '0.6217']
# ['opinión', '0.6216']
# ['siglo', '0.6215']
# ['territorio', '0.6206']
# ['línea', '0.6200']
# ['acuerdo', '0.6195']
# ['revolución', '0.6187']
# ['partido', '0.6176']
# ['impacto', '0.6176']
# ['ataque', '0.6176']
# ['ojo', '0.6169']
# ['curso', '0.6169']
# ['próximo', '0.6164']
# ['conocimiento', '0.6152']
# ['texto', '0.6151']
# ['servicio', '0.6149']
# ['edad', '0.6148']
# ['lista', '0.6139']
# ['juicio', '0.6138']
# ['martes', '0.6130']
# ['rico', '0.6125']
# ['premio', '0.6125']
# ['muestra', '0.6121']
# ['rojo', '0.6121']
# ['región', '0.6118']
# ['punto', '0.6114']
# ['presión', '0.6113']
# ['información', '0.6106']
# ['mañana', '0.6104']
# ['fortuna', '0.6103']
# ['fondos', '0.6102']
# ['modelo', '0.6101']
# ['carta', '0.6100']
# ['patria', '0.6098']
# ['oferta', '0.6097']
# ['turno', '0.6097']
# ['allá', '0.6095']
# ['joven', '0.6093']
# ['puesto', '0.6092']
# ['cerca', '0.6085']
# ['seguridad', '0.6084']
# ['defensa', '0.6079']
# ['parte', '0.6077']
# ['político', '0.6074']
# ['objetivo', '0.6073']
# ['bandera', '0.6073']
# ['deporte', '0.6064']
# ['población', '0.6064']
# ['humanos', '0.6061']
# ['confianza', '0.6060']
# ['dicho', '0.6053']
# ['viejo', '0.6052']
# ['resultado', '0.6049']
# ['producción', '0.6040']
# ['directamente', '0.6038']
# ['fuego', '0.6038']
# ['pez', '0.6028']
# ['norte', '0.6021']
# ['programa', '0.6012']
# ['cesar', '0.6007']
# ['importancia', '0.6006']
# ['respuesta', '0.6005']
# ['democracia', '0.5997']
# ['grupo', '0.5984']
# ['movimiento', '0.5982']
# ['silencio', '0.5976']
# ['familia', '0.5976']
# ['edición', '0.5969']
# ['derechos', '0.5965']
# ['meses', '0.5961']
# ['problema', '0.5961']
# ['común', '0.5953']
# ['compromiso', '0.5950']
# ['gobernador', '0.5948']
# ['relación', '0.5945']
# ['reciente', '0.5945']
# ['santo', '0.5941']
# ['revista', '0.5940']
# ['constante', '0.5931']
# ['tráfico', '0.5925']
# ['cura', '0.5920']
# ['negocio', '0.5919']
# ['ruta', '0.5918']
# ['estilo', '0.5913']
# ['empresa', '0.5911']
# ['menor', '0.5899']
# ['terrorista', '0.5896']
# ['dato', '0.5891']
# ['junto', '0.5888']
# ['inversión', '0.5885']
# ['operación', '0.5876']
# ['secreto', '0.5874']
# ['prueba', '0.5870']
# ['dolor', '0.5869']
# ['reforma', '0.5867']
# ['investigación', '0.5866']
# ['oficina', '0.5865']
# ['ministro', '0.5865']
# ['corte', '0.5857']
# ['lugar', '0.5856']
# ['octubre', '0.5849']
# ['lider', '0.5847']
# ['vía', '0.5838']
# ['esperanza', '0.5834']
# ['fuerzas', '0.5824']
# ['organización', '0.5821']
# ['discurso', '0.5818']
# ['carlos', '0.5808']
# ['entrada', '0.5803']
# ['puerto', '0.5802']
# ['juan', '0.5801']
# ['campo', '0.5799']
# ['opción', '0.5791']
# ['agosto', '0.5790']
# ['pesca', '0.5785']
# ['fuerza', '0.5785']
# ['libro', '0.5785']
# ['diciembre', '0.5782']
# ['trimestre', '0.5774']
# ['tema', '0.5768']
# ['camino', '0.5765']
# ['piel', '0.5757']
# ['entrega', '0.5757']
# ['objeto', '0.5748']
# ['oposición', '0.5745']
# ['abril', '0.5740']
# ['dio', '0.5739']
# ['abogado', '0.5737']
# ['pena', '0.5736']
# ['consecuencia', '0.5734']
# ['fuente', '0.5728']
# ['luis', '0.5727']
# ['noviembre', '0.5723']
# ['militar', '0.5715']
# ['frente', '0.5712']
# ['sociedad', '0.5704']
# ['contrario', '0.5702']
# ['agua', '0.5695']
# ['centro', '0.5693']
# ['cifra', '0.5681']
# ['senador', '0.5677']
# ['acción', '0.5664']
# ['causa', '0.5660']
# ['alemán', '0.5659']
# ['cabeza', '0.5656']
# ['agente', '0.5653']
# ['palo', '0.5651']
# ['estructura', '0.5647']
# ['obstante', '0.5640']
# ['inicio', '0.5632']
# ['miembro', '0.5625']
# ['origen', '0.5623']
# ['posibilidad', '0.5623']
# ['búsqueda', '0.5623']
# ['sistema', '0.5611']
# ['francisco', '0.5605']
# ['propuesta', '0.5598']
# ['experiencia', '0.5586']
# ['decisión', '0.5584']
# ['unido', '0.5582']
# ['interés', '0.5582']
# ['unidad', '0.5577']
# ['preso', '0.5572']
# ['producto', '0.5571']
# ['alternativa', '0.5566']
# ['conflicto', '0.5564']
# ['mara', '0.5554']
# ['transporte', '0.5552']
# ['beneficio', '0.5539']
# ['barato', '0.5530']
# ['fondo', '0.5491']
# ['ola', '0.5487']
# ['tratamiento', '0.5487']
# ['aplicación', '0.5485']
# ['camisa', '0.5485']
# ['diferencia', '0.5481']
# ['necesidad', '0.5481']
# ['mero', '0.5468']
# ['firma', '0.5465']
# ['fernando', '0.5462']
# ['resistencia', '0.5461']
# ['ricardo', '0.5459']
# ['costo', '0.5440']
# ['solución', '0.5439']
# ['permanente', '0.5431']
# ['presidente', '0.5430']
# ['gracias', '0.5427']
# ['suficiente', '0.5425']
# ['propiedad', '0.5421']
# ['proceso', '0.5421']
# ['departamento', '0.5416']
# ['responsabilidad', '0.5410']
# ['profundo', '0.5408']
# ['supuesto', '0.5391']
# ['abuelo', '0.5389']
# ['iniciativa', '0.5384']
# ['comunicación', '0.5377']
# ['protección', '0.5372']
# ['avance', '0.5372']
# ['participación', '0.5371']
# ['marzo', '0.5371']
# ['tanto', '0.5366']
# ['nota', '0.5356']
# ['aumento', '0.5348']
# ['rápido', '0.5338']
# ['oro', '0.5326']
# ['enero', '0.5326']
# ['estándar', '0.5316']
# ['bala', '0.5303']
# ['colombia', '0.5295']
# ['hora', '0.5284']
# ['función', '0.5277']
# ['dólares', '0.5268']
# ['plazo', '0.5268']
# ['medida', '0.5268']
# ['santos', '0.5268']
# ['largo', '0.5261']
# ['reunión', '0.5256']
# ['presidencial', '0.5253']
# ['mano', '0.5252']
# ['norma', '0.5252']
# ['propósito', '0.5242']
# ['mando', '0.5238']
# ['elección', '0.5228']
# ['brillante', '0.5221']
# ['precio', '0.5198']
# ['nivel', '0.5181']
# ['cabo', '0.5172']
# ['interno', '0.5169']
# ['equipo', '0.5162']
# ['policía', '0.5139']
# ['dih', '0.5122']
# ['capacidad', '0.5111']
# ['casa', '0.5108']
# ['torre', '0.5094']
# ['cuba', '0.5078']
# ['ser', '0.5061']
# ['paro', '0.5049']
# ['completamente', '0.5043']
# ['cao', '0.5038']
# ['costa', '0.5022']
# ['piedra', '0.5022']
# ['calle', '0.5019']
# ['pérdida', '0.5018']
# ['análisis', '0.5012']
# ['abrazo', '0.5003']
# ['manuel', '0.5000']
# ['mes', '0.4992']
# ['bloqueo', '0.4983']
# ['competencia', '0.4976']
# ['elit', '0.4964']
# ['marco', '0.4962']
# ['brava', '0.4959']
# ['publicado', '0.4950']
# ['acto', '0.4941']
# ['carácter', '0.4931']
# ['cero', '0.4914']
# ['antonio', '0.4909']
# ['septiembre', '0.4899']
# ['pablo', '0.4888']
# ['patrón', '0.4887']
# ['hombre', '0.4853']
# ['riesgo', '0.4844']
# ['pregunta', '0.4838']
# ['tarea', '0.4819']
# ['rebelde', '0.4806']
# ['rafael', '0.4744']
# ['plano', '0.4737']
# ['cambio', '0.4731']
# ['serio', '0.4720']
# ['imposible', '0.4703']
# ['funciones', '0.4694']
# ['zona', '0.4683']
# ['sierra', '0.4666']
# ['diseño', '0.4659']
# ['arma', '0.4636']
# ['lengua', '0.4574']
# ['ente', '0.4564']
# ['publicación', '0.4563']
# ['columna', '0.4547']
# ['paso', '0.4545']
# ['falla', '0.4467']
# ['karl', '0.4462']
# ['apertura', '0.4460']
# ['gestión', '0.4453']
# ['jefe', '0.4440']
# ['jorge', '0.4431']
# ['ilegal', '0.4396']
# ['convivencia', '0.4375']
# ['pesar', '0.4313']
# ['pacto', '0.4291']
# ['alcalde', '0.4236']
# ['fe', '0.4217']
# ['responsable', '0.4172']
# ['consulta', '0.4118']
# ['renta', '0.4084']
# ['serie', '0.4056']
# ['porte', '0.4050']
# ['comercial', '0.4039']
# ['forma', '0.4013']
# ['san', '0.3997']
# ['mundial', '0.3997']
# ['posible', '0.3995']
# ['latino', '0.3992']
# ['banda', '0.3963']
# ['masacre', '0.3953']
# ['fútbol', '0.3933']
# ['fiel', '0.3893']
# ['facto', '0.3861']
# ['caracol', '0.3829']
# ['mercado', '0.3816']
# ['vaso', '0.3809']
# ['derecho', '0.3794']
# ['ff', '0.3765']
# ['victoria', '0.3757']
# ['lobo', '0.3753']
# ['eduardo', '0.3747']
# ['profesional', '0.3728']
# ['municipio', '0.3725']
# ['robusto', '0.3678']
# ['crimen', '0.3674']
# ['conjunto', '0.3642']
# ['ancho', '0.3629']
# ['reposado', '0.3615']
# ['epl', '0.3612']
# ['mal', '0.3468']
# ['medio', '0.3466']
# ['paseo', '0.3457']
# ['previo', '0.3435']
# ['momento', '0.3378']
# ['ley', '0.3358']
# ['nadi', '0.3351']
# ['emc', '0.3320']
# ['goto', '0.3301']
# ['nobel', '0.3289']
# ['resto', '0.3276']
# ['escudo', '0.3164']
# ['rambo', '0.3141']
# ['velo', '0.3127']
# ['occidental', '0.3113']
# ['comandante', '0.3109']
# ['campesino', '0.3058']
# ['barrio', '0.3031']
# ['verso', '0.2913']
# ['leve', '0.2780']
# ['materia', '0.2636']
# ['giro', '0.2634']
# ['etc', '0.2621']
# ['mafioso', '0.2530']
# ['tutela', '0.2502']
# ['von', '0.2414']
# ['v', '0.2410']
# ['fin', '0.2373']
# ['pico', '0.2326']
# ['especial', '0.2313']
# ['pueblo', '0.2309']
# ['fresco', '0.2298']
# ['alias', '0.2294']
# ['lector', '0.2294']
# ['alto', '0.2282']
# ['oriental', '0.2277']
# ['capo', '0.2274']
# ['narco', '0.2253']
# ['meta', '0.2183']
# ['c', '0.2150']
# ['maestro', '0.2125']
# ['operandi', '0.2059']
# ['m', '0.2048']
# ['poncho', '0.2033']
# ['pastel', '0.2017']
# ['barra', '0.2010']
# ['trance', '0.1976']
# ['continuo', '0.1932']
# ['peso', '0.1930']
# ['ambulant', '0.1850']
# ['germinal', '0.1810']
# ['mil', '0.1775']
# ['cpi', '0.1750']
# ['guerrilla', '0.1746']
# ['neoliberal', '0.1614']
# ['insignia', '0.1544']
# ['mesa', '0.1517']
# ['valor', '0.1420']
# ['radio', '0.1337']
# ['anterior', '0.1272']
# ['indispensable', '0.1158']
# ['gent', '0.1157']
# ['mafia', '0.1142']
# ['modu', '0.1136']
# ['innumerable', '0.1134']
# ['lamentable', '0.1129']
# ['irreversible', '0.1113']
# ['plaza', '0.1105']
# ['ostensible', '0.1103']
# ['penal', '0.1001']
# ['social', '0.0968']
# ['posterior', '0.0951']
# ['dpi', '0.0932']
# ['civil', '0.0932']
# ['ex', '0.0928']
# ['popular', '0.0858']
# ['red', '0.0850']
# ['pro', '0.0836']
# ['electoral', '0.0820']
# ['anti', '0.0785']
# ['moral', '0.0741']
# ['realizable', '0.0723']
# ['rentable', '0.0714']
# ['persona', '0.0712']
# ['judicial', '0.0706']
# ['bilateral', '0.0702']
# ['terror', '0.0702']
# ['mm', '0.0699']
# ['grave', '0.0695']
# ['petro', '0.0681']
# ['criminal', '0.0608']
# ['conceptual', '0.0590']
# ['formal', '0.0569']
# ['territorial', '0.0567']
# ['secular', '0.0561']
# ['video', '0.0557']
# ['actor', '0.0539']
# ['pie', '0.0531']
# ['simple', '0.0509']
# ['irregular', '0.0481']
# ['cargo', '0.0464']
# ['bar', '0.0452']
# ['integral', '0.0451']
# ['square', '0.0448']
# ['capital', '0.0446']
# ['labor', '0.0444']
# ['flip', '0.0427']
# ['economist', '0.0407']
# ['monumental', '0.0396']
# ['interior', '0.0382']
# ['improbable', '0.0366']
# ['recalcitrant', '0.0348']
# ['real', '0.0334']
# ['debate', '0.0314']
# ['superior', '0.0262']
# ['mayor', '0.0257']
# ['academia', '0.0241']
# ['doctor', '0.0232']
# ['crisis', '0.0224']
# ['original', '0.0213']
# ['fundamental', '0.0195']
# ['inevitable', '0.0187']
# ['favor', '0.0165']
# ['actual', '0.0162']
# ['central', '0.0136']
# ['legal', '0.0105']
# ['fines', '0.0101']
# ['susceptible', '0.0059']
# ['familiar', '0.0039']
# ['error', '-0.0011']
# ['tangible', '-0.0013']
# ['unilateral', '-0.0025']
# ['chance', '-0.0049']
# ['times', '-0.0076']
# ['personal', '-0.0083']
# ['general', '-0.0129']
# ['principal', '-0.0155']
# ['car', '-0.0276']
# ['agenda', '-0.0388']
# ['viable', '-0.0406']
# ['regional', '-0.0435']
# ['crucial', '-0.0465']
# ['rural', '-0.0528']
# ['particular', '-0.0534']
# ['vulnerable', '-0.0640']
# ['similar', '-0.0650']
# ['sector', '-0.0661']
# ['idea', '-0.0717']
# ['fiscal', '-0.0766']
# ['base', '-0.0770']
# ['control', '-0.0853']
# ['plan', '-0.1037']
# ['individual', '-0.1143']
# ['the', '-0.1297']

# %%
# Generar una nube de palabras
word_freq = {palabra: float(similitud) for palabra, similitud in palabras_similares}

wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(word_freq)

# Mostrar la nube de palabras
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
# Define la palabra objetivo
palabra_objetivo = 'guerra'

# Aplanar el corpus a una sola lista de palabras y eliminar duplicados
palabras_corpus = list(set([palabra for sublist in contenido_lemas for palabra in sublist]))

# Encontrar palabras similares a la palabra objetivo en el corpus definido
palabras_similares = []

for palabra in palabras_corpus:
    if palabra in modelo_word2vec:
        similitud = modelo_word2vec.similarity(palabra_objetivo, palabra)
        palabras_similares.append((palabra, similitud))

# Ordenar las palabras por similitud en orden descendente
palabras_similares = sorted(palabras_similares, key=lambda item: -item[1])

# Preparar los datos para escribir en el archivo CSV
contenido_lemas_csv = [['Palabra', 'Similitud']]  # Encabezados del CSV
for palabra, similitud in palabras_similares:  
    contenido_lemas_csv.append([palabra, f"{similitud:.4f}"])

# Escribir los datos en un nuevo archivo CSV
with open('word2vec_guerra_semana.csv', 'w', newline='', encoding='utf-8-sig') as archivo:
    escritor_csv = csv.writer(archivo)
    escritor_csv.writerows(contenido_lemas_csv)

# Leer y mostrar el contenido del archivo CSV
with open('word2vec_guerra_semana.csv', 'r', newline='', encoding='utf-8-sig') as archivo:
    lector_csv = csv.reader(archivo)
    for fila in lector_csv:
       print(fila)
# Out:
# ['Palabra', 'Similitud']
# ['guerra', '1.0000']
# ['sentido', '0.7464']
# ['noticia', '0.7442']
# ['hecho', '0.7433']
# ['único', '0.7404']
# ['palabra', '0.7397']
# ['gobierno', '0.7322']
# ['estar', '0.7318']
# ['razón', '0.7290']
# ['actividad', '0.7290']
# ['trabajo', '0.7281']
# ['militar', '0.7277']
# ['país', '0.7272']
# ['político', '0.7262']
# ['campaña', '0.7257']
# ['recientemente', '0.7251']
# ['falta', '0.7250']
# ['trabajar', '0.7234']
# ['muerte', '0.7216']
# ['atrás', '0.7210']
# ['ciudad', '0.7209']
# ['ganar', '0.7208']
# ['proyecto', '0.7205']
# ['oportunidad', '0.7191']
# ['periodista', '0.7189']
# ['ejemplo', '0.7166']
# ['importancia', '0.7164']
# ['muerto', '0.7151']
# ['máximo', '0.7137']
# ['crecimiento', '0.7136']
# ['nacional', '0.7125']
# ['situación', '0.7124']
# ['respeto', '0.7123']
# ['poder', '0.7116']
# ['espacio', '0.7107']
# ['candidato', '0.7104']
# ['pobre', '0.7102']
# ['enorme', '0.7080']
# ['apoyo', '0.7074']
# ['paz', '0.7072']
# ['especialmente', '0.7064']
# ['ayer', '0.7053']
# ['miedo', '0.7046']
# ['tiempo', '0.7045']
# ['ayuda', '0.7038']
# ['escrito', '0.7038']
# ['destino', '0.7033']
# ['juicio', '0.7024']
# ['edad', '0.7024']
# ['artículo', '0.7020']
# ['año', '0.7016']
# ['cuyo', '0.7014']
# ['realmente', '0.7011']
# ['ataque', '0.7003']
# ['política', '0.7000']
# ['naturaleza', '0.6999']
# ['comunidad', '0.6991']
# ['jamás', '0.6990']
# ['límite', '0.6989']
# ['seguro', '0.6989']
# ['contrario', '0.6984']
# ['democracia', '0.6962']
# ['período', '0.6959']
# ['justicia', '0.6942']
# ['haber', '0.6938']
# ['gente', '0.6935']
# ['lejos', '0.6934']
# ['periodo', '0.6933']
# ['actualmente', '0.6933']
# ['deporte', '0.6930']
# ['terrorista', '0.6929']
# ['clase', '0.6924']
# ['movimiento', '0.6923']
# ['conocimiento', '0.6914']
# ['motivo', '0.6901']
# ['alguien', '0.6900']
# ['atención', '0.6898']
# ['necesario', '0.6897']
# ['producción', '0.6893']
# ['esfuerzo', '0.6889']
# ['organización', '0.6887']
# ['población', '0.6883']
# ['público', '0.6879']
# ['conocido', '0.6875']
# ['común', '0.6870']
# ['diario', '0.6866']
# ['fecha', '0.6865']
# ['económico', '0.6864']
# ['documento', '0.6860']
# ['mensaje', '0.6858']
# ['desarrollo', '0.6855']
# ['internacional', '0.6854']
# ['siguiente', '0.6852']
# ['estrategia', '0.6850']
# ['vuelta', '0.6849']
# ['opción', '0.6849']
# ['parte', '0.6843']
# ['presión', '0.6840']
# ['calidad', '0.6834']
# ['mexicano', '0.6833']
# ['querido', '0.6833']
# ['abogado', '0.6826']
# ['compromiso', '0.6820']
# ['línea', '0.6818']
# ['obra', '0.6814']
# ['fuerza', '0.6814']
# ['inversión', '0.6814']
# ['territorio', '0.6812']
# ['inicial', '0.6793']
# ['duro', '0.6789']
# ['respuesta', '0.6786']
# ['duda', '0.6784']
# ['caso', '0.6782']
# ['información', '0.6779']
# ['grupo', '0.6776']
# ['barco', '0.6774']
# ['semana', '0.6766']
# ['carga', '0.6762']
# ['siglo', '0.6758']
# ['contrato', '0.6756']
# ['entrevista', '0.6755']
# ['futuro', '0.6748']
# ['niño', '0.6747']
# ['orden', '0.6747']
# ['derechos', '0.6741']
# ['próximo', '0.6740']
# ['cuerpo', '0.6739']
# ['silencio', '0.6735']
# ['acuerdo', '0.6722']
# ['cosa', '0.6721']
# ['posición', '0.6718']
# ['impacto', '0.6714']
# ['corte', '0.6697']
# ['menor', '0.6694']
# ['libertad', '0.6694']
# ['reciente', '0.6687']
# ['responsabilidad', '0.6686']
# ['patria', '0.6685']
# ['constante', '0.6677']
# ['gobernador', '0.6674']
# ['droga', '0.6673']
# ['economía', '0.6671']
# ['frente', '0.6670']
# ['unido', '0.6654']
# ['joven', '0.6652']
# ['reforma', '0.6651']
# ['historia', '0.6638']
# ['curso', '0.6632']
# ['feliz', '0.6631']
# ['lugar', '0.6629']
# ['tráfico', '0.6624']
# ['agente', '0.6617']
# ['peor', '0.6615']
# ['claro', '0.6608']
# ['código', '0.6607']
# ['dominio', '0.6600']
# ['mujer', '0.6599']
# ['región', '0.6598']
# ['relación', '0.6597']
# ['importante', '0.6596']
# ['fuerte', '0.6587']
# ['defensa', '0.6582']
# ['lider', '0.6572']
# ['humanos', '0.6569']
# ['turno', '0.6563']
# ['sociedad', '0.6559']
# ['texto', '0.6549']
# ['oferta', '0.6529']
# ['comunicado', '0.6525']
# ['opinión', '0.6522']
# ['seguridad', '0.6520']
# ['norte', '0.6516']
# ['lado', '0.6506']
# ['primero', '0.6505']
# ['representante', '0.6500']
# ['voz', '0.6495']
# ['manos', '0.6488']
# ['meses', '0.6485']
# ['cualquiera', '0.6483']
# ['presente', '0.6481']
# ['llamado', '0.6474']
# ['luz', '0.6471']
# ['realidad', '0.6469']
# ['dolor', '0.6459']
# ['oposición', '0.6456']
# ['estructura', '0.6447']
# ['medida', '0.6442']
# ['televisión', '0.6432']
# ['resistencia', '0.6428']
# ['lista', '0.6424']
# ['proceso', '0.6424']
# ['puesto', '0.6419']
# ['éxito', '0.6419']
# ['negocio', '0.6417']
# ['amor', '0.6414']
# ['pesca', '0.6408']
# ['violencia', '0.6398']
# ['voto', '0.6385']
# ['partido', '0.6377']
# ['líder', '0.6373']
# ['resultado', '0.6367']
# ['departamento', '0.6363']
# ['cifra', '0.6362']
# ['niña', '0.6357']
# ['confianza', '0.6355']
# ['mente', '0.6355']
# ['discurso', '0.6353']
# ['cerca', '0.6340']
# ['fondos', '0.6338']
# ['papel', '0.6330']
# ['trimestre', '0.6326']
# ['supuesto', '0.6322']
# ['entrega', '0.6319']
# ['oficina', '0.6319']
# ['triste', '0.6313']
# ['elección', '0.6310']
# ['rojo', '0.6300']
# ['hermano', '0.6296']
# ['fuerzas', '0.6282']
# ['alternativa', '0.6281']
# ['investigación', '0.6276']
# ['prensa', '0.6274']
# ['consecuencia', '0.6271']
# ['tratamiento', '0.6268']
# ['prueba', '0.6266']
# ['acción', '0.6255']
# ['señor', '0.6255']
# ['revista', '0.6251']
# ['allá', '0.6249']
# ['servicio', '0.6239']
# ['permanente', '0.6234']
# ['vía', '0.6230']
# ['protección', '0.6229']
# ['perdido', '0.6228']
# ['senador', '0.6224']
# ['objeto', '0.6223']
# ['causa', '0.6213']
# ['directamente', '0.6213']
# ['cubano', '0.6207']
# ['programa', '0.6195']
# ['ministro', '0.6191']
# ['completo', '0.6189']
# ['modelo', '0.6163']
# ['propuesta', '0.6157']
# ['origen', '0.6156']
# ['inicio', '0.6146']
# ['pena', '0.6146']
# ['ojo', '0.6146']
# ['experiencia', '0.6137']
# ['sueño', '0.6137']
# ['edición', '0.6130']
# ['revolución', '0.6129']
# ['decisión', '0.6127']
# ['búsqueda', '0.6113']
# ['junto', '0.6107']
# ['posibilidad', '0.6106']
# ['puerto', '0.6094']
# ['viejo', '0.6094']
# ['fuente', '0.6091']
# ['fortuna', '0.6087']
# ['palo', '0.6082']
# ['costo', '0.6080']
# ['dicho', '0.6080']
# ['secreto', '0.6079']
# ['alemán', '0.6079']
# ['diferencia', '0.6074']
# ['rico', '0.6073']
# ['premio', '0.6066']
# ['carta', '0.6062']
# ['punto', '0.6057']
# ['operación', '0.6056']
# ['participación', '0.6051']
# ['interés', '0.6047']
# ['aplicación', '0.6043']
# ['nivel', '0.6042']
# ['objetivo', '0.6040']
# ['triunfo', '0.6034']
# ['comunicación', '0.6029']
# ['beneficio', '0.6023']
# ['campo', '0.6022']
# ['análisis', '0.6007']
# ['conflicto', '0.6006']
# ['fuego', '0.5999']
# ['presidencial', '0.5995']
# ['ruta', '0.5994']
# ['fondo', '0.5991']
# ['martes', '0.5987']
# ['bandera', '0.5986']
# ['producto', '0.5985']
# ['sistema', '0.5982']
# ['entrada', '0.5982']
# ['problema', '0.5976']
# ['miembro', '0.5974']
# ['propósito', '0.5972']
# ['suficiente', '0.5971']
# ['vida', '0.5970']
# ['tipo', '0.5970']
# ['plazo', '0.5956']
# ['unidad', '0.5952']
# ['transporte', '0.5950']
# ['tanto', '0.5949']
# ['muestra', '0.5948']
# ['mano', '0.5947']
# ['mando', '0.5947']
# ['competencia', '0.5939']
# ['estilo', '0.5926']
# ['febrero', '0.5913']
# ['policía', '0.5908']
# ['reunión', '0.5908']
# ['nota', '0.5897']
# ['empresa', '0.5896']
# ['agosto', '0.5886']
# ['ganado', '0.5883']
# ['barato', '0.5880']
# ['interno', '0.5877']
# ['rápido', '0.5867']
# ['dato', '0.5857']
# ['piel', '0.5848']
# ['bala', '0.5836']
# ['completamente', '0.5829']
# ['presidente', '0.5828']
# ['iniciativa', '0.5828']
# ['necesidad', '0.5824']
# ['carlos', '0.5823']
# ['cesar', '0.5817']
# ['patrón', '0.5795']
# ['familia', '0.5778']
# ['brillante', '0.5777']
# ['octubre', '0.5775']
# ['función', '0.5768']
# ['obstante', '0.5746']
# ['propiedad', '0.5730']
# ['costa', '0.5730']
# ['libro', '0.5721']
# ['bloqueo', '0.5712']
# ['centro', '0.5687']
# ['paro', '0.5679']
# ['dólares', '0.5679']
# ['capacidad', '0.5675']
# ['riesgo', '0.5672']
# ['carácter', '0.5669']
# ['dios', '0.5663']
# ['cabo', '0.5657']
# ['pez', '0.5652']
# ['norma', '0.5651']
# ['tema', '0.5646']
# ['fernando', '0.5643']
# ['santo', '0.5636']
# ['solución', '0.5632']
# ['mara', '0.5612']
# ['camisa', '0.5598']
# ['pérdida', '0.5583']
# ['cura', '0.5582']
# ['esperanza', '0.5564']
# ['dio', '0.5556']
# ['luis', '0.5554']
# ['largo', '0.5544']
# ['diciembre', '0.5541']
# ['marzo', '0.5531']
# ['rebelde', '0.5510']
# ['abuelo', '0.5506']
# ['cabeza', '0.5504']
# ['mañana', '0.5500']
# ['abril', '0.5490']
# ['juan', '0.5477']
# ['enero', '0.5463']
# ['profundo', '0.5454']
# ['avance', '0.5451']
# ['francisco', '0.5429']
# ['hora', '0.5412']
# ['sierra', '0.5407']
# ['funciones', '0.5406']
# ['pacto', '0.5396']
# ['cao', '0.5393']
# ['estándar', '0.5388']
# ['firma', '0.5384']
# ['agua', '0.5336']
# ['calle', '0.5331']
# ['serio', '0.5330']
# ['gestión', '0.5324']
# ['alcalde', '0.5322']
# ['acto', '0.5308']
# ['aumento', '0.5306']
# ['camino', '0.5305']
# ['santos', '0.5292']
# ['mero', '0.5269']
# ['precio', '0.5264']
# ['elit', '0.5237']
# ['zona', '0.5231']
# ['noviembre', '0.5228']
# ['torre', '0.5224']
# ['tarea', '0.5224']
# ['oro', '0.5210']
# ['septiembre', '0.5190']
# ['pablo', '0.5172']
# ['columna', '0.5131']
# ['ser', '0.5127']
# ['preso', '0.5122']
# ['hombre', '0.5089']
# ['publicado', '0.5078']
# ['diseño', '0.5069']
# ['cero', '0.5033']
# ['ola', '0.5018']
# ['piedra', '0.5008']
# ['publicación', '0.5007']
# ['cuba', '0.4991']
# ['casa', '0.4965']
# ['plano', '0.4950']
# ['marco', '0.4949']
# ['ilegal', '0.4936']
# ['karl', '0.4935']
# ['jorge', '0.4921']
# ['colombia', '0.4906']
# ['apertura', '0.4872']
# ['dih', '0.4866']
# ['gracias', '0.4833']
# ['imposible', '0.4822']
# ['ricardo', '0.4798']
# ['falla', '0.4791']
# ['pregunta', '0.4782']
# ['crimen', '0.4778']
# ['convivencia', '0.4763']
# ['equipo', '0.4741']
# ['masacre', '0.4714']
# ['jefe', '0.4704']
# ['paso', '0.4678']
# ['abrazo', '0.4673']
# ['lengua', '0.4647']
# ['porte', '0.4629']
# ['mes', '0.4617']
# ['consulta', '0.4592']
# ['responsable', '0.4589']
# ['municipio', '0.4588']
# ['ente', '0.4523']
# ['cambio', '0.4492']
# ['previo', '0.4487']
# ['latino', '0.4445']
# ['mundial', '0.4427']
# ['epl', '0.4424']
# ['brava', '0.4418']
# ['derecho', '0.4382']
# ['rafael', '0.4363']
# ['banda', '0.4351']
# ['antonio', '0.4347']
# ['facto', '0.4330']
# ['victoria', '0.4276']
# ['serie', '0.4262']
# ['caracol', '0.4246']
# ['pesar', '0.4244']
# ['eduardo', '0.4205']
# ['manuel', '0.4158']
# ['posible', '0.4154']
# ['campesino', '0.4149']
# ['mercado', '0.4143']
# ['arma', '0.4134']
# ['conjunto', '0.4126']
# ['forma', '0.4113']
# ['leve', '0.4102']
# ['comercial', '0.4071']
# ['rambo', '0.4061']
# ['renta', '0.4040']
# ['nobel', '0.4020']
# ['ancho', '0.4007']
# ['san', '0.4006']
# ['mal', '0.3980']
# ['emc', '0.3957']
# ['lobo', '0.3948']
# ['profesional', '0.3930']
# ['paseo', '0.3892']
# ['vaso', '0.3891']
# ['fiel', '0.3890']
# ['tutela', '0.3872']
# ['nadi', '0.3834']
# ['reposado', '0.3737']
# ['ff', '0.3712']
# ['fútbol', '0.3689']
# ['barrio', '0.3667']
# ['medio', '0.3650']
# ['occidental', '0.3648']
# ['escudo', '0.3613']
# ['fe', '0.3613']
# ['comandante', '0.3609']
# ['robusto', '0.3608']
# ['mafioso', '0.3518']
# ['verso', '0.3485']
# ['materia', '0.3458']
# ['velo', '0.3418']
# ['momento', '0.3384']
# ['especial', '0.3374']
# ['ley', '0.3304']
# ['continuo', '0.3232']
# ['giro', '0.3151']
# ['fresco', '0.3130']
# ['resto', '0.3090']
# ['guerrilla', '0.2999']
# ['alto', '0.2958']
# ['etc', '0.2947']
# ['civil', '0.2822']
# ['von', '0.2816']
# ['ambulant', '0.2807']
# ['pueblo', '0.2773']
# ['oriental', '0.2767']
# ['narco', '0.2732']
# ['operandi', '0.2715']
# ['neoliberal', '0.2713']
# ['capo', '0.2691']
# ['goto', '0.2666']
# ['peso', '0.2633']
# ['v', '0.2590']
# ['mesa', '0.2588']
# ['alias', '0.2557']
# ['pico', '0.2539']
# ['mafia', '0.2510']
# ['fin', '0.2505']
# ['penal', '0.2494']
# ['germinal', '0.2464']
# ['c', '0.2457']
# ['valor', '0.2387']
# ['m', '0.2379']
# ['pastel', '0.2375']
# ['meta', '0.2368']
# ['cpi', '0.2236']
# ['barra', '0.2199']
# ['trance', '0.2198']
# ['electoral', '0.2192']
# ['anterior', '0.2152']
# ['maestro', '0.2071']
# ['posterior', '0.2053']
# ['poncho', '0.2035']
# ['lector', '0.2013']
# ['mil', '0.1980']
# ['gent', '0.1959']
# ['judicial', '0.1934']
# ['bilateral', '0.1845']
# ['terror', '0.1816']
# ['criminal', '0.1766']
# ['anti', '0.1740']
# ['petro', '0.1714']
# ['plaza', '0.1703']
# ['unilateral', '0.1627']
# ['indispensable', '0.1620']
# ['moral', '0.1619']
# ['social', '0.1617']
# ['insignia', '0.1609']
# ['ostensible', '0.1602']
# ['lamentable', '0.1576']
# ['territorial', '0.1574']
# ['irregular', '0.1568']
# ['grave', '0.1568']
# ['mm', '0.1539']
# ['irreversible', '0.1515']
# ['secular', '0.1480']
# ['innumerable', '0.1480']
# ['square', '0.1425']
# ['persona', '0.1391']
# ['rentable', '0.1379']
# ['ex', '0.1362']
# ['modu', '0.1338']
# ['actor', '0.1291']
# ['recalcitrant', '0.1264']
# ['dpi', '0.1263']
# ['realizable', '0.1224']
# ['labor', '0.1083']
# ['conceptual', '0.1069']
# ['academia', '0.1065']
# ['red', '0.1006']
# ['mayor', '0.1005']
# ['pro', '0.0975']
# ['legal', '0.0943']
# ['pie', '0.0934']
# ['doctor', '0.0923']
# ['central', '0.0917']
# ['capital', '0.0810']
# ['fines', '0.0792']
# ['interior', '0.0765']
# ['crisis', '0.0749']
# ['radio', '0.0738']
# ['monumental', '0.0726']
# ['superior', '0.0715']
# ['favor', '0.0704']
# ['susceptible', '0.0655']
# ['economist', '0.0645']
# ['real', '0.0630']
# ['debate', '0.0627']
# ['agenda', '0.0597']
# ['cargo', '0.0591']
# ['particular', '0.0522']
# ['general', '0.0496']
# ['rural', '0.0459']
# ['video', '0.0459']
# ['actual', '0.0441']
# ['formal', '0.0428']
# ['popular', '0.0427']
# ['original', '0.0384']
# ['regional', '0.0380']
# ['fundamental', '0.0373']
# ['integral', '0.0366']
# ['tangible', '0.0359']
# ['inevitable', '0.0354']
# ['flip', '0.0339']
# ['principal', '0.0338']
# ['vulnerable', '0.0336']
# ['bar', '0.0288']
# ['sector', '0.0287']
# ['improbable', '0.0229']
# ['base', '0.0167']
# ['control', '0.0091']
# ['chance', '0.0036']
# ['fiscal', '-0.0050']
# ['familiar', '-0.0058']
# ['idea', '-0.0073']
# ['car', '-0.0079']
# ['error', '-0.0128']
# ['personal', '-0.0134']
# ['simple', '-0.0206']
# ['times', '-0.0214']
# ['individual', '-0.0237']
# ['viable', '-0.0307']
# ['crucial', '-0.0350']
# ['similar', '-0.0446']
# ['the', '-0.0555']
# ['plan', '-0.0605']

# %%
# Generar una nube de palabras
word_freq = {palabra: float(similitud) for palabra, similitud in palabras_similares}

wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(word_freq)

# Mostrar la nube de palabras
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# # Analisis de sentimiento

# %%
# %pip install torch
# %pip install torchvision
# %pip install transformers
# Out:
# Collecting torch
#   Obtaining dependency information for torch from https://files.pythonhosted.org/packages/d3/1d/a257913c89572de61316461db91867f87519146e58132cdeace3d9ffbe1f/torch-2.3.1-cp311-cp311-win_amd64.whl.metadata
#   Using cached torch-2.3.1-cp311-cp311-win_amd64.whl.metadata (26 kB)
# Requirement already satisfied: filelock in c:\users\user\anaconda3\lib\site-packages (from torch) (3.9.0)
# Collecting typing-extensions>=4.8.0 (from torch)
#   Obtaining dependency information for typing-extensions>=4.8.0 from https://files.pythonhosted.org/packages/26/9f/ad63fc0248c5379346306f8668cda6e2e2e9c95e01216d2b8ffd9ff037d0/typing_extensions-4.12.2-py3-none-any.whl.metadata
#   Using cached typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: sympy in c:\users\user\anaconda3\lib\site-packages (from torch) (1.11.1)
# Requirement already satisfied: networkx in c:\users\user\anaconda3\lib\site-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in c:\users\user\anaconda3\lib\site-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec in c:\users\user\anaconda3\lib\site-packages (from torch) (2023.4.0)
# Collecting mkl<=2021.4.0,>=2021.1.1 (from torch)
#   Obtaining dependency information for mkl<=2021.4.0,>=2021.1.1 from https://files.pythonhosted.org/packages/fe/1c/5f6dbf18e8b73e0a5472466f0ea8d48ce9efae39bd2ff38cebf8dce61259/mkl-2021.4.0-py2.py3-none-win_amd64.whl.metadata
#   Using cached mkl-2021.4.0-py2.py3-none-win_amd64.whl.metadata (1.4 kB)
# Collecting intel-openmp==2021.* (from mkl<=2021.4.0,>=2021.1.1->torch)
#   Obtaining dependency information for intel-openmp==2021.* from https://files.pythonhosted.org/packages/6f/21/b590c0cc3888b24f2ac9898c41d852d7454a1695fbad34bee85dba6dc408/intel_openmp-2021.4.0-py2.py3-none-win_amd64.whl.metadata
#   Using cached intel_openmp-2021.4.0-py2.py3-none-win_amd64.whl.metadata (1.2 kB)
# Collecting tbb==2021.* (from mkl<=2021.4.0,>=2021.1.1->torch)
#   Obtaining dependency information for tbb==2021.* from https://files.pythonhosted.org/packages/7b/2d/1e1c70fae8ace27e6200fb71c2372a9aeac2baba474b1609d7d466e969b4/tbb-2021.12.0-py3-none-win_amd64.whl.metadata
#   Using cached tbb-2021.12.0-py3-none-win_amd64.whl.metadata (1.1 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\user\anaconda3\lib\site-packages (from jinja2->torch) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\user\anaconda3\lib\site-packages (from sympy->torch) (1.3.0)
# Using cached torch-2.3.1-cp311-cp311-win_amd64.whl (159.8 MB)
# Using cached mkl-2021.4.0-py2.py3-none-win_amd64.whl (228.5 MB)
# Using cached intel_openmp-2021.4.0-py2.py3-none-win_amd64.whl (3.5 MB)
# Using cached tbb-2021.12.0-py3-none-win_amd64.whl (286 kB)
# Using cached typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Installing collected packages: tbb, intel-openmp, typing-extensions, mkl, torch
#   Attempting uninstall: tbb
#     Found existing installation: TBB 0.2
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Cannot uninstall 'TBB'. It is a distutils installed project and thus we cannot accurately determine which files belong to it which would lead to only a partial uninstall.
# Collecting torchvision
#   Obtaining dependency information for torchvision from https://files.pythonhosted.org/packages/e4/c3/a21a75dd2de8114a6876f16a36b033e3e62f8ade68085a711b24f4b57c17/torchvision-0.18.1-cp311-cp311-win_amd64.whl.metadata
#   Using cached torchvision-0.18.1-cp311-cp311-win_amd64.whl.metadata (6.6 kB)
# Requirement already satisfied: numpy in c:\users\user\anaconda3\lib\site-packages (from torchvision) (1.24.4)
# Collecting torch==2.3.1 (from torchvision)
#   Obtaining dependency information for torch==2.3.1 from https://files.pythonhosted.org/packages/d3/1d/a257913c89572de61316461db91867f87519146e58132cdeace3d9ffbe1f/torch-2.3.1-cp311-cp311-win_amd64.whl.metadata
#   Using cached torch-2.3.1-cp311-cp311-win_amd64.whl.metadata (26 kB)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\user\anaconda3\lib\site-packages (from torchvision) (9.4.0)
# Requirement already satisfied: filelock in c:\users\user\anaconda3\lib\site-packages (from torch==2.3.1->torchvision) (3.9.0)
# Collecting typing-extensions>=4.8.0 (from torch==2.3.1->torchvision)
#   Obtaining dependency information for typing-extensions>=4.8.0 from https://files.pythonhosted.org/packages/26/9f/ad63fc0248c5379346306f8668cda6e2e2e9c95e01216d2b8ffd9ff037d0/typing_extensions-4.12.2-py3-none-any.whl.metadata
#   Using cached typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: sympy in c:\users\user\anaconda3\lib\site-packages (from torch==2.3.1->torchvision) (1.11.1)
# Requirement already satisfied: networkx in c:\users\user\anaconda3\lib\site-packages (from torch==2.3.1->torchvision) (3.1)
# Requirement already satisfied: jinja2 in c:\users\user\anaconda3\lib\site-packages (from torch==2.3.1->torchvision) (3.1.2)
# Requirement already satisfied: fsspec in c:\users\user\anaconda3\lib\site-packages (from torch==2.3.1->torchvision) (2023.4.0)
# Collecting mkl<=2021.4.0,>=2021.1.1 (from torch==2.3.1->torchvision)
#   Obtaining dependency information for mkl<=2021.4.0,>=2021.1.1 from https://files.pythonhosted.org/packages/fe/1c/5f6dbf18e8b73e0a5472466f0ea8d48ce9efae39bd2ff38cebf8dce61259/mkl-2021.4.0-py2.py3-none-win_amd64.whl.metadata
#   Using cached mkl-2021.4.0-py2.py3-none-win_amd64.whl.metadata (1.4 kB)
# Collecting intel-openmp==2021.* (from mkl<=2021.4.0,>=2021.1.1->torch==2.3.1->torchvision)
#   Obtaining dependency information for intel-openmp==2021.* from https://files.pythonhosted.org/packages/6f/21/b590c0cc3888b24f2ac9898c41d852d7454a1695fbad34bee85dba6dc408/intel_openmp-2021.4.0-py2.py3-none-win_amd64.whl.metadata
#   Using cached intel_openmp-2021.4.0-py2.py3-none-win_amd64.whl.metadata (1.2 kB)
# Collecting tbb==2021.* (from mkl<=2021.4.0,>=2021.1.1->torch==2.3.1->torchvision)
#   Obtaining dependency information for tbb==2021.* from https://files.pythonhosted.org/packages/7b/2d/1e1c70fae8ace27e6200fb71c2372a9aeac2baba474b1609d7d466e969b4/tbb-2021.12.0-py3-none-win_amd64.whl.metadata
#   Using cached tbb-2021.12.0-py3-none-win_amd64.whl.metadata (1.1 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\user\anaconda3\lib\site-packages (from jinja2->torch==2.3.1->torchvision) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\user\anaconda3\lib\site-packages (from sympy->torch==2.3.1->torchvision) (1.3.0)
# Using cached torchvision-0.18.1-cp311-cp311-win_amd64.whl (1.2 MB)
# Using cached torch-2.3.1-cp311-cp311-win_amd64.whl (159.8 MB)
# Using cached mkl-2021.4.0-py2.py3-none-win_amd64.whl (228.5 MB)
# Using cached intel_openmp-2021.4.0-py2.py3-none-win_amd64.whl (3.5 MB)
# Using cached tbb-2021.12.0-py3-none-win_amd64.whl (286 kB)
# Using cached typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Installing collected packages: tbb, intel-openmp, typing-extensions, mkl, torch, torchvision
#   Attempting uninstall: tbb
#     Found existing installation: TBB 0.2
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Cannot uninstall 'TBB'. It is a distutils installed project and thus we cannot accurately determine which files belong to it which would lead to only a partial uninstall.
# Requirement already satisfied: transformers in c:\users\user\anaconda3\lib\site-packages (4.32.1)
# Requirement already satisfied: filelock in c:\users\user\anaconda3\lib\site-packages (from transformers) (3.9.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.15.1 in c:\users\user\anaconda3\lib\site-packages (from transformers) (0.15.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\user\anaconda3\lib\site-packages (from transformers) (1.24.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\anaconda3\lib\site-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\user\anaconda3\lib\site-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\user\anaconda3\lib\site-packages (from transformers) (2022.7.9)
# Requirement already satisfied: requests in c:\users\user\anaconda3\lib\site-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in c:\users\user\anaconda3\lib\site-packages (from transformers) (0.13.2)
# Requirement already satisfied: safetensors>=0.3.1 in c:\users\user\anaconda3\lib\site-packages (from transformers) (0.3.2)
# Requirement already satisfied: tqdm>=4.27 in c:\users\user\anaconda3\lib\site-packages (from transformers) (4.65.0)
# Requirement already satisfied: fsspec in c:\users\user\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.15.1->transformers) (2023.4.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\user\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.15.1->transformers) (4.7.1)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\anaconda3\lib\site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests->transformers) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests->transformers) (2023.7.22)
# Note: you may need to restart the kernel to use updated packages.

# %%
from transformers import BertTokenizer, BertForSequenceClassification
import torch

modelo_bert = BertForSequenceClassification.from_pretrained('dccuchile/bert-base-spanish-wwm-cased', num_labels=3)
tokenizer = BertTokenizer.from_pretrained('dccuchile/bert-base-spanish-wwm-cased')

# Definir una función para realizar el análisis de sentimiento
def analisis_sentimiento(texto):
    # Tokenizar el texto y agregar tokens especiales
    tokens = tokenizer.encode_plus(texto, max_length=512, truncation=True, padding='max_length', return_tensors='pt')
    
    # Obtener las predicciones de sentimiento del modelo
    with torch.no_grad():
        outputs = modelo_bert(**tokens)
        predicciones = torch.softmax(outputs.logits, dim=1).squeeze()

    # Convertir las predicciones a etiquetas de sentimiento
    etiquetas = ['Negativo', 'Neutral', 'Positivo']
    sentimiento = etiquetas[int(torch.argmax(predicciones))]

    return sentimiento, predicciones.numpy().tolist()

# Realizar el análisis de sentimiento para cada frase en el corpus
resultado_analisis = []
for frase in contenido_lemas_prueba:
    texto = ' '.join(frase)
    sentimiento, confianza = analisis_sentimiento(texto)
    resultado_analisis.append((frase, sentimiento, confianza))

# Imprimir los resultados
for frase, sentimiento, confianza in resultado_analisis:
    print('Frase:', ' '.join(frase))
    print('Sentimiento:', sentimiento)
    print('Confianza:', confianza)
    print()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[56], line 2
#       1 from transformers import BertTokenizer, BertForSequenceClassification
# ----> 2 import torch
#       4 modelo_bert = BertForSequenceClassification.from_pretrained('dccuchile/bert-base-spanish-wwm-cased', num_labels=3)
#       5 tokenizer = BertTokenizer.from_pretrained('dccuchile/bert-base-spanish-wwm-cased')
#
# ModuleNotFoundError: No module named 'torch'
