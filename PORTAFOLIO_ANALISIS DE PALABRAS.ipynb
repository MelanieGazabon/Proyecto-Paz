# %% [markdown]
# # importar recursos

# %%
import requests
from bs4 import BeautifulSoup
import csv
import os
import re
import csv
import spacy
from collections import Counter
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# !pip install -U spacy
# !python -m spacy download es_core_news_sm
# !python -m spacy download es_core_news_lg


# Definir la ruta del archivo en el escritorio
archivo_csv = os.path.join(os.path.expanduser("~"), "Escritorio", "datos_extraidos.csv")
# Out:
# Requirement already satisfied: spacy in c:\users\user\anaconda3\lib\site-packages (3.7.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\user\anaconda3\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\user\anaconda3\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\user\anaconda3\lib\site-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\user\anaconda3\lib\site-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\user\anaconda3\lib\site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\users\user\anaconda3\lib\site-packages (from spacy) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\user\anaconda3\lib\site-packages (from spacy) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\user\anaconda3\lib\site-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\user\anaconda3\lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in c:\users\user\anaconda3\lib\site-packages (from spacy) (0.3.4)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\users\user\anaconda3\lib\site-packages (from spacy) (0.9.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\user\anaconda3\lib\site-packages (from spacy) (4.65.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\user\anaconda3\lib\site-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\user\anaconda3\lib\site-packages (from spacy) (1.10.8)
# Requirement already satisfied: jinja2 in c:\users\user\anaconda3\lib\site-packages (from spacy) (3.1.2)
# Requirement already satisfied: setuptools in c:\users\user\anaconda3\lib\site-packages (from spacy) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\anaconda3\lib\site-packages (from spacy) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\user\anaconda3\lib\site-packages (from spacy) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\user\anaconda3\lib\site-packages (from spacy) (1.24.4)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\user\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\user\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\user\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.4)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\user\anaconda3\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.0.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\user\anaconda3\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.16.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\user\anaconda3\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy) (5.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\user\anaconda3\lib\site-packages (from jinja2->spacy) (2.1.1)
# Collecting es-core-news-sm==3.7.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/es_core_news_sm-3.7.0/es_core_news_sm-3.7.0-py3-none-any.whl (12.9 MB)
#      ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#      --------------------------------------- 0.0/12.9 MB 262.6 kB/s eta 0:00:49
#      --------------------------------------- 0.0/12.9 MB 262.6 kB/s eta 0:00:49
#      --------------------------------------- 0.0/12.9 MB 262.6 kB/s eta 0:00:49
#      --------------------------------------- 0.0/12.9 MB 140.9 kB/s eta 0:01:32
#      --------------------------------------- 0.1/12.9 MB 182.2 kB/s eta 0:01:11
#      --------------------------------------- 0.1/12.9 MB 179.1 kB/s eta 0:01:12
#      --------------------------------------- 0.1/12.9 MB 201.8 kB/s eta 0:01:04
#      --------------------------------------- 0.1/12.9 MB 226.0 kB/s eta 0:00:57
#      --------------------------------------- 0.1/12.9 MB 240.7 kB/s eta 0:00:54
#      --------------------------------------- 0.1/12.9 MB 240.7 kB/s eta 0:00:54
#      --------------------------------------- 0.2/12.9 MB 235.4 kB/s eta 0:00:55
#       -------------------------------------- 0.2/12.9 MB 249.8 kB/s eta 0:00:51
#       -------------------------------------- 0.2/12.9 MB 249.8 kB/s eta 0:00:51
#       -------------------------------------- 0.2/12.9 MB 256.7 kB/s eta 0:00:50
#       -------------------------------------- 0.2/12.9 MB 254.3 kB/s eta 0:00:50
#       -------------------------------------- 0.2/12.9 MB 264.8 kB/s eta 0:00:48
#       -------------------------------------- 0.2/12.9 MB 253.1 kB/s eta 0:00:50
#       -------------------------------------- 0.3/12.9 MB 262.3 kB/s eta 0:00:49
#       -------------------------------------- 0.3/12.9 MB 266.2 kB/s eta 0:00:48
#       -------------------------------------- 0.3/12.9 MB 268.2 kB/s eta 0:00:47
#       -------------------------------------- 0.3/12.9 MB 275.5 kB/s eta 0:00:46
#       -------------------------------------- 0.3/12.9 MB 277.0 kB/s eta 0:00:46
#       -------------------------------------- 0.3/12.9 MB 277.0 kB/s eta 0:00:46
#      - ------------------------------------- 0.3/12.9 MB 269.0 kB/s eta 0:00:47
#      - ------------------------------------- 0.3/12.9 MB 269.0 kB/s eta 0:00:47
#      - ------------------------------------- 0.3/12.9 MB 269.0 kB/s eta 0:00:47
#      - ------------------------------------- 0.4/12.9 MB 250.5 kB/s eta 0:00:51
#      - ------------------------------------- 0.4/12.9 MB 250.5 kB/s eta 0:00:51
#      - ------------------------------------- 0.4/12.9 MB 246.7 kB/s eta 0:00:51
#      - ------------------------------------- 0.4/12.9 MB 246.7 kB/s eta 0:00:51
#      - ------------------------------------- 0.4/12.9 MB 240.1 kB/s eta 0:00:53
#      - ------------------------------------- 0.4/12.9 MB 239.5 kB/s eta 0:00:53
#      - ------------------------------------- 0.4/12.9 MB 239.5 kB/s eta 0:00:53
#      - ------------------------------------- 0.4/12.9 MB 239.5 kB/s eta 0:00:53
#      - ------------------------------------- 0.4/12.9 MB 239.5 kB/s eta 0:00:53
#      - ------------------------------------- 0.4/12.9 MB 226.0 kB/s eta 0:00:56
#      - ------------------------------------- 0.4/12.9 MB 226.0 kB/s eta 0:00:56
#      - ------------------------------------- 0.4/12.9 MB 226.0 kB/s eta 0:00:56
#      - ------------------------------------- 0.4/12.9 MB 226.0 kB/s eta 0:00:56
#      - ------------------------------------- 0.4/12.9 MB 226.0 kB/s eta 0:00:56
#      - ------------------------------------- 0.4/12.9 MB 226.0 kB/s eta 0:00:56
#      - ------------------------------------- 0.4/12.9 MB 226.0 kB/s eta 0:00:56
#      - ------------------------------------- 0.4/12.9 MB 226.0 kB/s eta 0:00:56
#      - ------------------------------------- 0.4/12.9 MB 195.2 kB/s eta 0:01:04
#      - ------------------------------------- 0.4/12.9 MB 195.2 kB/s eta 0:01:04
#      - ------------------------------------- 0.4/12.9 MB 195.2 kB/s eta 0:01:04
#      - ------------------------------------- 0.4/12.9 MB 195.2 kB/s eta 0:01:04
#      - ------------------------------------- 0.4/12.9 MB 195.2 kB/s eta 0:01:04
#      - ------------------------------------- 0.4/12.9 MB 195.2 kB/s eta 0:01:04
#      - ------------------------------------- 0.5/12.9 MB 177.3 kB/s eta 0:01:11
#      - ------------------------------------- 0.5/12.9 MB 177.3 kB/s eta 0:01:11
#      - ------------------------------------- 0.5/12.9 MB 177.3 kB/s eta 0:01:11
#      - ------------------------------------- 0.5/12.9 MB 177.3 kB/s eta 0:01:11
#      - ------------------------------------- 0.5/12.9 MB 177.3 kB/s eta 0:01:11
#      - ------------------------------------- 0.5/12.9 MB 177.3 kB/s eta 0:01:11
#      - ------------------------------------- 0.5/12.9 MB 177.3 kB/s eta 0:01:11
#      - ------------------------------------- 0.5/12.9 MB 177.3 kB/s eta 0:01:11
#      - ------------------------------------- 0.5/12.9 MB 177.3 kB/s eta 0:01:11
#      - ------------------------------------- 0.5/12.9 MB 177.3 kB/s eta 0:01:11
#      - ------------------------------------- 0.5/12.9 MB 177.3 kB/s eta 0:01:11
#      - ------------------------------------- 0.5/12.9 MB 177.3 kB/s eta 0:01:11
#      - ------------------------------------- 0.5/12.9 MB 151.3 kB/s eta 0:01:23
#      - ------------------------------------- 0.5/12.9 MB 151.3 kB/s eta 0:01:23
#      - ------------------------------------- 0.5/12.9 MB 151.3 kB/s eta 0:01:23
#      - ------------------------------------- 0.5/12.9 MB 151.3 kB/s eta 0:01:23
#      - ------------------------------------- 0.5/12.9 MB 151.3 kB/s eta 0:01:23
#      - ------------------------------------- 0.5/12.9 MB 151.3 kB/s eta 0:01:23
#      - ------------------------------------- 0.5/12.9 MB 151.3 kB/s eta 0:01:23
#      - ------------------------------------- 0.5/12.9 MB 151.3 kB/s eta 0:01:23
#      - ------------------------------------- 0.5/12.9 MB 151.3 kB/s eta 0:01:23
#      - ------------------------------------- 0.5/12.9 MB 151.3 kB/s eta 0:01:23
#      - ------------------------------------- 0.5/12.9 MB 151.3 kB/s eta 0:01:23
#      - ------------------------------------- 0.5/12.9 MB 151.3 kB/s eta 0:01:23
#      - ------------------------------------- 0.5/12.9 MB 151.3 kB/s eta 0:01:23
#      - ------------------------------------- 0.5/12.9 MB 151.3 kB/s eta 0:01:23
#      - ------------------------------------- 0.5/12.9 MB 126.1 kB/s eta 0:01:39
#      - ------------------------------------- 0.5/12.9 MB 126.1 kB/s eta 0:01:39
#      - ------------------------------------- 0.5/12.9 MB 126.1 kB/s eta 0:01:39
#      - ------------------------------------- 0.5/12.9 MB 126.1 kB/s eta 0:01:39
#      - ------------------------------------- 0.5/12.9 MB 126.1 kB/s eta 0:01:39
#      - ------------------------------------- 0.5/12.9 MB 126.1 kB/s eta 0:01:39
#      - ------------------------------------- 0.5/12.9 MB 126.1 kB/s eta 0:01:39
#      - ------------------------------------- 0.5/12.9 MB 126.1 kB/s eta 0:01:39
#      - ------------------------------------- 0.5/12.9 MB 126.1 kB/s eta 0:01:39
#      - ------------------------------------- 0.5/12.9 MB 126.1 kB/s eta 0:01:39
#      - ------------------------------------- 0.5/12.9 MB 116.5 kB/s eta 0:01:47
#      - ------------------------------------- 0.5/12.9 MB 116.5 kB/s eta 0:01:47
#      - ------------------------------------- 0.5/12.9 MB 116.5 kB/s eta 0:01:47
#      - ------------------------------------- 0.5/12.9 MB 116.5 kB/s eta 0:01:47
#      - ------------------------------------- 0.5/12.9 MB 116.5 kB/s eta 0:01:47
#      - ------------------------------------- 0.5/12.9 MB 116.5 kB/s eta 0:01:47
#      - ------------------------------------- 0.5/12.9 MB 116.5 kB/s eta 0:01:47
#      - ------------------------------------- 0.5/12.9 MB 116.5 kB/s eta 0:01:47
#      - ------------------------------------- 0.5/12.9 MB 116.5 kB/s eta 0:01:47
#      - ------------------------------------- 0.5/12.9 MB 116.5 kB/s eta 0:01:47
#      - ------------------------------------- 0.5/12.9 MB 116.5 kB/s eta 0:01:47
#      - ------------------------------------- 0.5/12.9 MB 107.8 kB/s eta 0:01:55
#      - ------------------------------------- 0.5/12.9 MB 107.8 kB/s eta 0:01:55
#      - ------------------------------------- 0.5/12.9 MB 107.8 kB/s eta 0:01:55
#      - ------------------------------------- 0.5/12.9 MB 107.8 kB/s eta 0:01:55
#      - ------------------------------------- 0.5/12.9 MB 107.8 kB/s eta 0:01:55
#      - ------------------------------------- 0.5/12.9 MB 107.8 kB/s eta 0:01:55
#      - ------------------------------------- 0.5/12.9 MB 107.8 kB/s eta 0:01:55
#      - ------------------------------------- 0.5/12.9 MB 107.8 kB/s eta 0:01:55
#      - ------------------------------------- 0.5/12.9 MB 107.8 kB/s eta 0:01:55
#      - ------------------------------------- 0.5/12.9 MB 107.8 kB/s eta 0:01:55
#      - ------------------------------------- 0.5/12.9 MB 100.4 kB/s eta 0:02:04
#      - ------------------------------------- 0.5/12.9 MB 100.4 kB/s eta 0:02:04
#      - ------------------------------------- 0.5/12.9 MB 100.4 kB/s eta 0:02:04
#      - ------------------------------------- 0.5/12.9 MB 100.4 kB/s eta 0:02:04
#      - ------------------------------------- 0.5/12.9 MB 100.4 kB/s eta 0:02:04
#      - ------------------------------------- 0.5/12.9 MB 100.4 kB/s eta 0:02:04
#      - -------------------------------------- 0.6/12.9 MB 98.4 kB/s eta 0:02:06
#      - -------------------------------------- 0.6/12.9 MB 98.4 kB/s eta 0:02:06
#      - -------------------------------------- 0.6/12.9 MB 98.4 kB/s eta 0:02:06
#      - -------------------------------------- 0.6/12.9 MB 98.4 kB/s eta 0:02:06
#      - -------------------------------------- 0.6/12.9 MB 98.4 kB/s eta 0:02:06
#      - -------------------------------------- 0.6/12.9 MB 98.4 kB/s eta 0:02:06
#      - -------------------------------------- 0.6/12.9 MB 98.4 kB/s eta 0:02:06
#      - -------------------------------------- 0.6/12.9 MB 94.6 kB/s eta 0:02:11
#      - -------------------------------------- 0.6/12.9 MB 94.6 kB/s eta 0:02:11
#      - -------------------------------------- 0.6/12.9 MB 94.6 kB/s eta 0:02:11
#      - -------------------------------------- 0.6/12.9 MB 94.6 kB/s eta 0:02:11
#      - -------------------------------------- 0.6/12.9 MB 94.6 kB/s eta 0:02:11
#      - -------------------------------------- 0.6/12.9 MB 94.6 kB/s eta 0:02:11
#      - -------------------------------------- 0.6/12.9 MB 94.6 kB/s eta 0:02:11
#      - -------------------------------------- 0.6/12.9 MB 94.6 kB/s eta 0:02:11
#      - -------------------------------------- 0.6/12.9 MB 94.6 kB/s eta 0:02:11
#      - -------------------------------------- 0.6/12.9 MB 94.6 kB/s eta 0:02:11
#      - -------------------------------------- 0.6/12.9 MB 94.6 kB/s eta 0:02:11
#      - -------------------------------------- 0.6/12.9 MB 94.6 kB/s eta 0:02:11
#      - -------------------------------------- 0.6/12.9 MB 89.5 kB/s eta 0:02:18
#      - -------------------------------------- 0.6/12.9 MB 89.5 kB/s eta 0:02:18
#      - -------------------------------------- 0.6/12.9 MB 89.5 kB/s eta 0:02:18
#      - -------------------------------------- 0.6/12.9 MB 89.5 kB/s eta 0:02:18
#      - -------------------------------------- 0.6/12.9 MB 89.5 kB/s eta 0:02:18
#      - -------------------------------------- 0.6/12.9 MB 89.5 kB/s eta 0:02:18
#      - -------------------------------------- 0.6/12.9 MB 89.5 kB/s eta 0:02:18
#      - -------------------------------------- 0.6/12.9 MB 89.5 kB/s eta 0:02:18
#      - -------------------------------------- 0.6/12.9 MB 89.5 kB/s eta 0:02:18
#      - -------------------------------------- 0.6/12.9 MB 89.5 kB/s eta 0:02:18
#      - -------------------------------------- 0.6/12.9 MB 89.5 kB/s eta 0:02:18
#      - -------------------------------------- 0.6/12.9 MB 89.5 kB/s eta 0:02:18
#      - -------------------------------------- 0.6/12.9 MB 89.5 kB/s eta 0:02:18
#      - -------------------------------------- 0.6/12.9 MB 89.5 kB/s eta 0:02:18
#      - -------------------------------------- 0.6/12.9 MB 89.5 kB/s eta 0:02:18
#      - -------------------------------------- 0.6/12.9 MB 83.0 kB/s eta 0:02:28
#      - -------------------------------------- 0.6/12.9 MB 83.0 kB/s eta 0:02:28
#      - -------------------------------------- 0.6/12.9 MB 83.0 kB/s eta 0:02:28
#      - -------------------------------------- 0.6/12.9 MB 83.0 kB/s eta 0:02:28
#      - -------------------------------------- 0.6/12.9 MB 83.0 kB/s eta 0:02:28
#      - -------------------------------------- 0.6/12.9 MB 83.0 kB/s eta 0:02:28
#      - -------------------------------------- 0.6/12.9 MB 83.0 kB/s eta 0:02:28
#      - -------------------------------------- 0.6/12.9 MB 83.0 kB/s eta 0:02:28
#      - -------------------------------------- 0.6/12.9 MB 80.2 kB/s eta 0:02:33
#      - -------------------------------------- 0.6/12.9 MB 80.2 kB/s eta 0:02:33
#      - -------------------------------------- 0.6/12.9 MB 80.2 kB/s eta 0:02:33
#      - -------------------------------------- 0.6/12.9 MB 80.2 kB/s eta 0:02:33
#      - -------------------------------------- 0.6/12.9 MB 80.2 kB/s eta 0:02:33
#      - -------------------------------------- 0.6/12.9 MB 80.2 kB/s eta 0:02:33
#      - -------------------------------------- 0.6/12.9 MB 80.2 kB/s eta 0:02:33
#      - -------------------------------------- 0.6/12.9 MB 80.2 kB/s eta 0:02:33
#      - -------------------------------------- 0.6/12.9 MB 80.2 kB/s eta 0:02:33
#      - -------------------------------------- 0.6/12.9 MB 80.2 kB/s eta 0:02:33
#      - -------------------------------------- 0.6/12.9 MB 78.1 kB/s eta 0:02:37
#      - -------------------------------------- 0.6/12.9 MB 78.1 kB/s eta 0:02:37
#      - -------------------------------------- 0.6/12.9 MB 78.1 kB/s eta 0:02:37
#      - -------------------------------------- 0.6/12.9 MB 78.1 kB/s eta 0:02:37
#      - -------------------------------------- 0.6/12.9 MB 78.1 kB/s eta 0:02:37
#      - -------------------------------------- 0.6/12.9 MB 78.1 kB/s eta 0:02:37
#      - -------------------------------------- 0.6/12.9 MB 78.1 kB/s eta 0:02:37
#      - -------------------------------------- 0.6/12.9 MB 78.1 kB/s eta 0:02:37
#      -- ------------------------------------- 0.6/12.9 MB 75.7 kB/s eta 0:02:42
#      -- ------------------------------------- 0.6/12.9 MB 75.7 kB/s eta 0:02:42
#      -- ------------------------------------- 0.6/12.9 MB 75.7 kB/s eta 0:02:42
#      -- ------------------------------------- 0.6/12.9 MB 75.7 kB/s eta 0:02:42
#      -- ------------------------------------- 0.6/12.9 MB 75.7 kB/s eta 0:02:42
#      -- ------------------------------------- 0.6/12.9 MB 75.7 kB/s eta 0:02:42
#      -- ------------------------------------- 0.6/12.9 MB 75.7 kB/s eta 0:02:42
#      -- ------------------------------------- 0.6/12.9 MB 75.7 kB/s eta 0:02:42
#      -- ------------------------------------- 0.7/12.9 MB 74.6 kB/s eta 0:02:44
#      -- ------------------------------------- 0.7/12.9 MB 74.6 kB/s eta 0:02:44
#      -- ------------------------------------- 0.7/12.9 MB 74.6 kB/s eta 0:02:44
#      -- ------------------------------------- 0.7/12.9 MB 75.8 kB/s eta 0:02:42
#      -- ------------------------------------- 0.7/12.9 MB 75.8 kB/s eta 0:02:42
#      -- ------------------------------------- 0.7/12.9 MB 75.8 kB/s eta 0:02:42
#      -- ------------------------------------- 0.7/12.9 MB 75.8 kB/s eta 0:02:42
#      -- ------------------------------------- 0.7/12.9 MB 75.8 kB/s eta 0:02:42
#      -- ------------------------------------- 0.7/12.9 MB 75.8 kB/s eta 0:02:42
#      -- ------------------------------------- 0.7/12.9 MB 75.8 kB/s eta 0:02:42
#      -- ------------------------------------- 0.7/12.9 MB 75.8 kB/s eta 0:02:42
#      -- ------------------------------------- 0.7/12.9 MB 75.8 kB/s eta 0:02:42
#      -- ------------------------------------- 0.7/12.9 MB 73.1 kB/s eta 0:02:47
#      -- ------------------------------------- 0.7/12.9 MB 73.1 kB/s eta 0:02:47
#      -- ------------------------------------- 0.7/12.9 MB 73.1 kB/s eta 0:02:47
#      -- ------------------------------------- 0.7/12.9 MB 73.1 kB/s eta 0:02:47
#      -- ------------------------------------- 0.7/12.9 MB 73.1 kB/s eta 0:02:47
#      -- ------------------------------------- 0.7/12.9 MB 73.4 kB/s eta 0:02:46
#      -- ------------------------------------- 0.7/12.9 MB 73.4 kB/s eta 0:02:46
#      -- ------------------------------------- 0.7/12.9 MB 73.4 kB/s eta 0:02:46
#      -- ------------------------------------- 0.7/12.9 MB 73.4 kB/s eta 0:02:46
#      -- ------------------------------------- 0.7/12.9 MB 73.4 kB/s eta 0:02:46
#      -- ------------------------------------- 0.7/12.9 MB 73.4 kB/s eta 0:02:46
#      -- ------------------------------------- 0.7/12.9 MB 73.4 kB/s eta 0:02:46
#      -- ------------------------------------- 0.7/12.9 MB 73.4 kB/s eta 0:02:46
#      -- ------------------------------------- 0.7/12.9 MB 73.4 kB/s eta 0:02:46
#      -- ------------------------------------- 0.7/12.9 MB 73.4 kB/s eta 0:02:46
#      -- ------------------------------------- 0.7/12.9 MB 73.4 kB/s eta 0:02:46
#      -- ------------------------------------- 0.7/12.9 MB 70.4 kB/s eta 0:02:53
#      -- ------------------------------------- 0.7/12.9 MB 70.4 kB/s eta 0:02:53
#      -- ------------------------------------- 0.7/12.9 MB 70.4 kB/s eta 0:02:53
#      -- ------------------------------------- 0.7/12.9 MB 70.4 kB/s eta 0:02:53
#      -- ------------------------------------- 0.7/12.9 MB 70.4 kB/s eta 0:02:53
#      -- ------------------------------------- 0.7/12.9 MB 70.4 kB/s eta 0:02:53
#      -- ------------------------------------- 0.7/12.9 MB 70.4 kB/s eta 0:02:53
#      -- ------------------------------------- 0.7/12.9 MB 70.4 kB/s eta 0:02:53
#      -- ------------------------------------- 0.7/12.9 MB 70.4 kB/s eta 0:02:53
#      -- ------------------------------------- 0.7/12.9 MB 70.4 kB/s eta 0:02:53
#      -- ------------------------------------- 0.7/12.9 MB 70.4 kB/s eta 0:02:53
#      -- ------------------------------------- 0.7/12.9 MB 70.4 kB/s eta 0:02:53
#      -- ------------------------------------- 0.7/12.9 MB 70.4 kB/s eta 0:02:53
#      -- ------------------------------------- 0.7/12.9 MB 70.4 kB/s eta 0:02:53
#      -- ------------------------------------- 0.7/12.9 MB 70.4 kB/s eta 0:02:53
#      -- ------------------------------------- 0.7/12.9 MB 70.4 kB/s eta 0:02:53
#      -- ------------------------------------- 0.7/12.9 MB 70.4 kB/s eta 0:02:53
#      -- ------------------------------------- 0.7/12.9 MB 70.4 kB/s eta 0:02:53
#      -- ------------------------------------- 0.7/12.9 MB 70.4 kB/s eta 0:02:53
#      -- ------------------------------------- 0.7/12.9 MB 66.6 kB/s eta 0:03:03
#      -- ------------------------------------- 0.7/12.9 MB 66.6 kB/s eta 0:03:03
#      -- ------------------------------------- 0.7/12.9 MB 66.6 kB/s eta 0:03:03
#      -- ------------------------------------- 0.7/12.9 MB 66.6 kB/s eta 0:03:03
#      -- ------------------------------------- 0.7/12.9 MB 66.6 kB/s eta 0:03:03
#      -- ------------------------------------- 0.7/12.9 MB 66.6 kB/s eta 0:03:03
#      -- ------------------------------------- 0.7/12.9 MB 66.6 kB/s eta 0:03:03
#      -- ------------------------------------- 0.7/12.9 MB 66.6 kB/s eta 0:03:03
#      -- ------------------------------------- 0.8/12.9 MB 65.9 kB/s eta 0:03:04
#      -- ------------------------------------- 0.8/12.9 MB 65.9 kB/s eta 0:03:04
#      -- ------------------------------------- 0.8/12.9 MB 65.9 kB/s eta 0:03:04
#      -- ------------------------------------- 0.8/12.9 MB 65.9 kB/s eta 0:03:04
#      -- ------------------------------------- 0.8/12.9 MB 65.9 kB/s eta 0:03:04
#      -- ------------------------------------- 0.8/12.9 MB 65.9 kB/s eta 0:03:04
#      -- ------------------------------------- 0.8/12.9 MB 65.9 kB/s eta 0:03:04
#      -- ------------------------------------- 0.8/12.9 MB 65.9 kB/s eta 0:03:04
#      -- ------------------------------------- 0.8/12.9 MB 65.9 kB/s eta 0:03:04
#      -- ------------------------------------- 0.8/12.9 MB 65.9 kB/s eta 0:03:04
#      -- ------------------------------------- 0.8/12.9 MB 65.9 kB/s eta 0:03:04
#      -- ------------------------------------- 0.8/12.9 MB 65.9 kB/s eta 0:03:04
#      -- ------------------------------------- 0.8/12.9 MB 65.9 kB/s eta 0:03:04
#      -- ------------------------------------- 0.8/12.9 MB 65.9 kB/s eta 0:03:04
#      -- ------------------------------------- 0.8/12.9 MB 65.9 kB/s eta 0:03:04
#      -- ------------------------------------- 0.8/12.9 MB 65.9 kB/s eta 0:03:04
#      -- ------------------------------------- 0.8/12.9 MB 65.9 kB/s eta 0:03:04
#      -- ------------------------------------- 0.8/12.9 MB 65.9 kB/s eta 0:03:04
#      -- ------------------------------------- 0.8/12.9 MB 65.9 kB/s eta 0:03:04
#      -- ------------------------------------- 0.8/12.9 MB 65.9 kB/s eta 0:03:04
#      -- ------------------------------------- 0.8/12.9 MB 65.9 kB/s eta 0:03:04
#      -- ------------------------------------- 0.8/12.9 MB 65.9 kB/s eta 0:03:04
#      -- ------------------------------------- 0.8/12.9 MB 65.9 kB/s eta 0:03:04
#      -- ------------------------------------- 0.8/12.9 MB 65.9 kB/s eta 0:03:04
#      -- ------------------------------------- 0.8/12.9 MB 65.9 kB/s eta 0:03:04
#      -- ------------------------------------- 0.8/12.9 MB 65.9 kB/s eta 0:03:04
#      -- ------------------------------------- 0.8/12.9 MB 65.9 kB/s eta 0:03:04
#      -- ------------------------------------- 0.8/12.9 MB 60.1 kB/s eta 0:03:22
#      -- ------------------------------------- 0.8/12.9 MB 60.1 kB/s eta 0:03:22
#      -- ------------------------------------- 0.8/12.9 MB 60.1 kB/s eta 0:03:22
#      -- ------------------------------------- 0.8/12.9 MB 60.1 kB/s eta 0:03:22
#      -- ------------------------------------- 0.8/12.9 MB 60.1 kB/s eta 0:03:22
#      -- ------------------------------------- 0.8/12.9 MB 60.1 kB/s eta 0:03:22
#      -- ------------------------------------- 0.8/12.9 MB 60.1 kB/s eta 0:03:22
#      -- ------------------------------------- 0.8/12.9 MB 60.1 kB/s eta 0:03:22
#      -- ------------------------------------- 0.8/12.9 MB 60.1 kB/s eta 0:03:22
#      -- ------------------------------------- 0.8/12.9 MB 60.1 kB/s eta 0:03:22
#      -- ------------------------------------- 0.8/12.9 MB 60.1 kB/s eta 0:03:22
#      -- ------------------------------------- 0.8/12.9 MB 59.2 kB/s eta 0:03:25
#      -- ------------------------------------- 0.8/12.9 MB 59.2 kB/s eta 0:03:25
#      -- ------------------------------------- 0.8/12.9 MB 59.2 kB/s eta 0:03:25
#      -- ------------------------------------- 0.8/12.9 MB 59.2 kB/s eta 0:03:25
#      -- ------------------------------------- 0.8/12.9 MB 59.2 kB/s eta 0:03:25
#      -- ------------------------------------- 0.8/12.9 MB 59.2 kB/s eta 0:03:25
#      -- ------------------------------------- 0.8/12.9 MB 59.2 kB/s eta 0:03:25
#      -- ------------------------------------- 0.8/12.9 MB 59.2 kB/s eta 0:03:25
#      -- ------------------------------------- 0.8/12.9 MB 59.2 kB/s eta 0:03:25
#      -- ------------------------------------- 0.8/12.9 MB 59.2 kB/s eta 0:03:25
#      -- ------------------------------------- 0.8/12.9 MB 59.2 kB/s eta 0:03:25
#      -- ------------------------------------- 0.8/12.9 MB 59.2 kB/s eta 0:03:25
#      -- ------------------------------------- 0.8/12.9 MB 59.2 kB/s eta 0:03:25
#      -- ------------------------------------- 0.8/12.9 MB 59.2 kB/s eta 0:03:25
#      -- ------------------------------------- 0.8/12.9 MB 59.2 kB/s eta 0:03:25
#      -- ------------------------------------- 0.8/12.9 MB 59.2 kB/s eta 0:03:25
#      -- ------------------------------------- 0.8/12.9 MB 59.2 kB/s eta 0:03:25
#      -- ------------------------------------- 0.8/12.9 MB 59.2 kB/s eta 0:03:25
#      -- ------------------------------------- 0.8/12.9 MB 56.4 kB/s eta 0:03:35
#      -- ------------------------------------- 0.8/12.9 MB 56.4 kB/s eta 0:03:35
#      -- ------------------------------------- 0.8/12.9 MB 56.4 kB/s eta 0:03:35
#      -- ------------------------------------- 0.8/12.9 MB 56.4 kB/s eta 0:03:35
#      -- ------------------------------------- 0.8/12.9 MB 56.4 kB/s eta 0:03:35
#      -- ------------------------------------- 0.8/12.9 MB 56.4 kB/s eta 0:03:35
#      -- ------------------------------------- 0.8/12.9 MB 56.4 kB/s eta 0:03:35
#      -- ------------------------------------- 0.8/12.9 MB 56.4 kB/s eta 0:03:35
#      -- ------------------------------------- 0.8/12.9 MB 56.4 kB/s eta 0:03:35
#      -- ------------------------------------- 0.8/12.9 MB 56.4 kB/s eta 0:03:35
#      -- ------------------------------------- 0.8/12.9 MB 56.1 kB/s eta 0:03:35
#      -- ------------------------------------- 0.8/12.9 MB 56.1 kB/s eta 0:03:35
#      -- ------------------------------------- 0.8/12.9 MB 56.1 kB/s eta 0:03:35
#      -- ------------------------------------- 0.8/12.9 MB 56.1 kB/s eta 0:03:35
#      -- ------------------------------------- 0.8/12.9 MB 56.1 kB/s eta 0:03:35
#      -- ------------------------------------- 0.8/12.9 MB 56.1 kB/s eta 0:03:35
#      -- ------------------------------------- 0.8/12.9 MB 56.1 kB/s eta 0:03:35
#      -- ------------------------------------- 0.8/12.9 MB 56.1 kB/s eta 0:03:35
#      -- ------------------------------------- 0.8/12.9 MB 56.1 kB/s eta 0:03:35
#      -- ------------------------------------- 0.8/12.9 MB 56.1 kB/s eta 0:03:35
#      -- ------------------------------------- 0.8/12.9 MB 56.1 kB/s eta 0:03:35
#      -- ------------------------------------- 0.8/12.9 MB 56.1 kB/s eta 0:03:35
#      -- ------------------------------------- 0.9/12.9 MB 57.3 kB/s eta 0:03:30
#      -- ------------------------------------- 0.9/12.9 MB 57.3 kB/s eta 0:03:30
#      -- ------------------------------------- 0.9/12.9 MB 57.3 kB/s eta 0:03:30
#      -- ------------------------------------- 0.9/12.9 MB 57.3 kB/s eta 0:03:30
#      -- ------------------------------------- 0.9/12.9 MB 57.3 kB/s eta 0:03:30
#      -- ------------------------------------- 0.9/12.9 MB 57.1 kB/s eta 0:03:31
#      -- ------------------------------------- 0.9/12.9 MB 57.1 kB/s eta 0:03:31
#      -- ------------------------------------- 0.9/12.9 MB 57.1 kB/s eta 0:03:31
#      -- ------------------------------------- 0.9/12.9 MB 57.1 kB/s eta 0:03:31
#      -- ------------------------------------- 0.9/12.9 MB 57.1 kB/s eta 0:03:31
#      -- ------------------------------------- 0.9/12.9 MB 57.1 kB/s eta 0:03:31
#      -- ------------------------------------- 0.9/12.9 MB 57.1 kB/s eta 0:03:31
#      -- ------------------------------------- 0.9/12.9 MB 57.1 kB/s eta 0:03:31
#      -- ------------------------------------- 0.9/12.9 MB 57.1 kB/s eta 0:03:31
#      -- ------------------------------------- 0.9/12.9 MB 57.1 kB/s eta 0:03:31
#      -- ------------------------------------- 0.9/12.9 MB 56.7 kB/s eta 0:03:32
#      -- ------------------------------------- 0.9/12.9 MB 56.7 kB/s eta 0:03:32
#      -- ------------------------------------- 0.9/12.9 MB 56.7 kB/s eta 0:03:32
#      -- ------------------------------------- 0.9/12.9 MB 56.7 kB/s eta 0:03:32
#      -- ------------------------------------- 0.9/12.9 MB 56.7 kB/s eta 0:03:32
#      -- ------------------------------------- 0.9/12.9 MB 56.7 kB/s eta 0:03:32
#      -- ------------------------------------- 0.9/12.9 MB 56.7 kB/s eta 0:03:32
#      -- ------------------------------------- 0.9/12.9 MB 56.7 kB/s eta 0:03:32
#      -- ------------------------------------- 0.9/12.9 MB 56.7 kB/s eta 0:03:32
#      -- ------------------------------------- 0.9/12.9 MB 56.7 kB/s eta 0:03:32
#      -- ------------------------------------- 0.9/12.9 MB 56.7 kB/s eta 0:03:32
#      -- ------------------------------------- 0.9/12.9 MB 56.7 kB/s eta 0:03:32
#      -- ------------------------------------- 0.9/12.9 MB 56.7 kB/s eta 0:03:32
#      -- ------------------------------------- 0.9/12.9 MB 56.7 kB/s eta 0:03:32
#      -- ------------------------------------- 0.9/12.9 MB 56.7 kB/s eta 0:03:32
#      -- ------------------------------------- 0.9/12.9 MB 55.5 kB/s eta 0:03:36
#      -- ------------------------------------- 0.9/12.9 MB 55.5 kB/s eta 0:03:36
#      -- ------------------------------------- 0.9/12.9 MB 55.5 kB/s eta 0:03:36
#      -- ------------------------------------- 0.9/12.9 MB 55.5 kB/s eta 0:03:36
#      -- ------------------------------------- 0.9/12.9 MB 55.5 kB/s eta 0:03:36
#      -- ------------------------------------- 0.9/12.9 MB 55.5 kB/s eta 0:03:36
#      -- ------------------------------------- 0.9/12.9 MB 55.5 kB/s eta 0:03:36
#      -- ------------------------------------- 0.9/12.9 MB 55.5 kB/s eta 0:03:36
#      -- ------------------------------------- 0.9/12.9 MB 55.5 kB/s eta 0:03:36
#      -- ------------------------------------- 0.9/12.9 MB 55.5 kB/s eta 0:03:36
#      -- ------------------------------------- 0.9/12.9 MB 55.5 kB/s eta 0:03:36
#      -- ------------------------------------- 0.9/12.9 MB 55.5 kB/s eta 0:03:36
#      -- ------------------------------------- 0.9/12.9 MB 55.5 kB/s eta 0:03:36
#      -- ------------------------------------- 0.9/12.9 MB 54.1 kB/s eta 0:03:41
#      -- ------------------------------------- 0.9/12.9 MB 54.1 kB/s eta 0:03:41
#      -- ------------------------------------- 0.9/12.9 MB 54.1 kB/s eta 0:03:41
#      -- ------------------------------------- 0.9/12.9 MB 54.1 kB/s eta 0:03:41
#      -- ------------------------------------- 0.9/12.9 MB 54.1 kB/s eta 0:03:41
#      -- ------------------------------------- 0.9/12.9 MB 54.1 kB/s eta 0:03:41
#      -- ------------------------------------- 0.9/12.9 MB 54.1 kB/s eta 0:03:41
#      -- ------------------------------------- 0.9/12.9 MB 54.1 kB/s eta 0:03:41
#      -- ------------------------------------- 0.9/12.9 MB 54.1 kB/s eta 0:03:41
#      -- ------------------------------------- 0.9/12.9 MB 54.1 kB/s eta 0:03:41
#      -- ------------------------------------- 1.0/12.9 MB 53.8 kB/s eta 0:03:42
#      -- ------------------------------------- 1.0/12.9 MB 53.8 kB/s eta 0:03:42
#      -- ------------------------------------- 1.0/12.9 MB 53.8 kB/s eta 0:03:42
#      -- ------------------------------------- 1.0/12.9 MB 53.8 kB/s eta 0:03:42
#      -- ------------------------------------- 1.0/12.9 MB 53.8 kB/s eta 0:03:42
#      -- ------------------------------------- 1.0/12.9 MB 53.8 kB/s eta 0:03:42
#      -- ------------------------------------- 1.0/12.9 MB 53.8 kB/s eta 0:03:42
#      -- ------------------------------------- 1.0/12.9 MB 53.8 kB/s eta 0:03:42
#      -- ------------------------------------- 1.0/12.9 MB 53.8 kB/s eta 0:03:42
#      -- ------------------------------------- 1.0/12.9 MB 53.8 kB/s eta 0:03:42
#      -- ------------------------------------- 1.0/12.9 MB 53.8 kB/s eta 0:03:42
#      -- ------------------------------------- 1.0/12.9 MB 53.8 kB/s eta 0:03:42
#      -- ------------------------------------- 1.0/12.9 MB 53.8 kB/s eta 0:03:42
#      -- ------------------------------------- 1.0/12.9 MB 53.8 kB/s eta 0:03:42
#      -- ------------------------------------- 1.0/12.9 MB 53.8 kB/s eta 0:03:42
#      --- ------------------------------------ 1.0/12.9 MB 52.2 kB/s eta 0:03:49
#      --- ------------------------------------ 1.0/12.9 MB 52.2 kB/s eta 0:03:49
#      --- ------------------------------------ 1.0/12.9 MB 52.2 kB/s eta 0:03:49
#      --- ------------------------------------ 1.0/12.9 MB 52.2 kB/s eta 0:03:49
#      --- ------------------------------------ 1.0/12.9 MB 52.2 kB/s eta 0:03:49
#      --- ------------------------------------ 1.0/12.9 MB 52.2 kB/s eta 0:03:49
#      --- ------------------------------------ 1.0/12.9 MB 52.2 kB/s eta 0:03:49
#      --- ------------------------------------ 1.0/12.9 MB 52.2 kB/s eta 0:03:49
#      --- ------------------------------------ 1.0/12.9 MB 52.2 kB/s eta 0:03:49
#      --- ------------------------------------ 1.0/12.9 MB 52.2 kB/s eta 0:03:49
#      --- ------------------------------------ 1.0/12.9 MB 52.2 kB/s eta 0:03:49
#      --- ------------------------------------ 1.0/12.9 MB 51.3 kB/s eta 0:03:52
#      --- ------------------------------------ 1.0/12.9 MB 51.8 kB/s eta 0:03:50
#      --- ------------------------------------ 1.0/12.9 MB 51.8 kB/s eta 0:03:50
#      --- ------------------------------------ 1.0/12.9 MB 51.8 kB/s eta 0:03:50
#      --- ------------------------------------ 1.0/12.9 MB 51.8 kB/s eta 0:03:50
#      --- ------------------------------------ 1.0/12.9 MB 51.8 kB/s eta 0:03:50
#      --- ------------------------------------ 1.0/12.9 MB 51.8 kB/s eta 0:03:50
#      --- ------------------------------------ 1.0/12.9 MB 51.8 kB/s eta 0:03:50
#      --- ------------------------------------ 1.0/12.9 MB 51.8 kB/s eta 0:03:50
#      --- ------------------------------------ 1.0/12.9 MB 51.8 kB/s eta 0:03:50
#      --- ------------------------------------ 1.0/12.9 MB 51.7 kB/s eta 0:03:50
#      --- ------------------------------------ 1.0/12.9 MB 51.7 kB/s eta 0:03:50
#      --- ------------------------------------ 1.0/12.9 MB 51.7 kB/s eta 0:03:50
#      --- ------------------------------------ 1.0/12.9 MB 51.7 kB/s eta 0:03:50
#      --- ------------------------------------ 1.0/12.9 MB 51.7 kB/s eta 0:03:50
#      --- ------------------------------------ 1.0/12.9 MB 51.7 kB/s eta 0:03:50
#      --- ------------------------------------ 1.0/12.9 MB 51.7 kB/s eta 0:03:50
#      --- ------------------------------------ 1.0/12.9 MB 51.3 kB/s eta 0:03:52
#      --- ------------------------------------ 1.0/12.9 MB 51.3 kB/s eta 0:03:52
#      --- ------------------------------------ 1.0/12.9 MB 51.3 kB/s eta 0:03:52
#      --- ------------------------------------ 1.0/12.9 MB 51.3 kB/s eta 0:03:52
#      --- ------------------------------------ 1.0/12.9 MB 51.3 kB/s eta 0:03:52
#      --- ------------------------------------ 1.0/12.9 MB 51.3 kB/s eta 0:03:52
#      --- ------------------------------------ 1.0/12.9 MB 51.3 kB/s eta 0:03:52
#      --- ------------------------------------ 1.0/12.9 MB 51.3 kB/s eta 0:03:52
#      --- ------------------------------------ 1.0/12.9 MB 51.3 kB/s eta 0:03:52
#      --- ------------------------------------ 1.0/12.9 MB 51.3 kB/s eta 0:03:52
#      --- ------------------------------------ 1.0/12.9 MB 51.1 kB/s eta 0:03:52
#      --- ------------------------------------ 1.0/12.9 MB 51.1 kB/s eta 0:03:52
#      --- ------------------------------------ 1.0/12.9 MB 51.1 kB/s eta 0:03:52
#      --- ------------------------------------ 1.0/12.9 MB 51.1 kB/s eta 0:03:52
#      --- ------------------------------------ 1.0/12.9 MB 51.1 kB/s eta 0:03:52
#      --- ------------------------------------ 1.0/12.9 MB 51.1 kB/s eta 0:03:52
#      --- ------------------------------------ 1.0/12.9 MB 51.1 kB/s eta 0:03:52
#      --- ------------------------------------ 1.0/12.9 MB 51.1 kB/s eta 0:03:52
#      --- ------------------------------------ 1.0/12.9 MB 51.1 kB/s eta 0:03:52
#      --- ------------------------------------ 1.1/12.9 MB 50.5 kB/s eta 0:03:55
#      --- ------------------------------------ 1.1/12.9 MB 50.5 kB/s eta 0:03:55
#      --- ------------------------------------ 1.1/12.9 MB 50.5 kB/s eta 0:03:55
#      --- ------------------------------------ 1.1/12.9 MB 50.5 kB/s eta 0:03:55
#      --- ------------------------------------ 1.1/12.9 MB 50.5 kB/s eta 0:03:55
#      --- ------------------------------------ 1.1/12.9 MB 50.5 kB/s eta 0:03:55
#      --- ------------------------------------ 1.1/12.9 MB 50.8 kB/s eta 0:03:53
#      --- ------------------------------------ 1.1/12.9 MB 50.8 kB/s eta 0:03:53
#      --- ------------------------------------ 1.1/12.9 MB 50.8 kB/s eta 0:03:53
#      --- ------------------------------------ 1.1/12.9 MB 50.8 kB/s eta 0:03:53
#      --- ------------------------------------ 1.1/12.9 MB 50.8 kB/s eta 0:03:53
#      --- ------------------------------------ 1.1/12.9 MB 50.8 kB/s eta 0:03:53
#      --- ------------------------------------ 1.1/12.9 MB 50.8 kB/s eta 0:03:53
#      --- ------------------------------------ 1.1/12.9 MB 51.0 kB/s eta 0:03:52
#      --- ------------------------------------ 1.1/12.9 MB 51.0 kB/s eta 0:03:52
#      --- ------------------------------------ 1.1/12.9 MB 51.0 kB/s eta 0:03:52
#      --- ------------------------------------ 1.1/12.9 MB 51.0 kB/s eta 0:03:52
#      --- ------------------------------------ 1.1/12.9 MB 51.0 kB/s eta 0:03:52
#      --- ------------------------------------ 1.1/12.9 MB 51.0 kB/s eta 0:03:52
#      --- ------------------------------------ 1.1/12.9 MB 51.0 kB/s eta 0:03:52
#      --- ------------------------------------ 1.1/12.9 MB 51.0 kB/s eta 0:03:52
#      --- ------------------------------------ 1.1/12.9 MB 51.0 kB/s eta 0:03:52
#      --- ------------------------------------ 1.1/12.9 MB 51.0 kB/s eta 0:03:52
#      --- ------------------------------------ 1.1/12.9 MB 50.4 kB/s eta 0:03:54
#      --- ------------------------------------ 1.1/12.9 MB 50.4 kB/s eta 0:03:54
#      --- ------------------------------------ 1.1/12.9 MB 50.4 kB/s eta 0:03:54
#      --- ------------------------------------ 1.1/12.9 MB 50.4 kB/s eta 0:03:54
#      --- ------------------------------------ 1.1/12.9 MB 50.4 kB/s eta 0:03:54
#      --- ------------------------------------ 1.1/12.9 MB 50.4 kB/s eta 0:03:54
#      --- ------------------------------------ 1.1/12.9 MB 50.6 kB/s eta 0:03:53
#      --- ------------------------------------ 1.1/12.9 MB 50.6 kB/s eta 0:03:53
#      --- ------------------------------------ 1.1/12.9 MB 50.6 kB/s eta 0:03:53
#      --- ------------------------------------ 1.1/12.9 MB 50.6 kB/s eta 0:03:53
#      --- ------------------------------------ 1.1/12.9 MB 50.6 kB/s eta 0:03:53
#      --- ------------------------------------ 1.1/12.9 MB 50.6 kB/s eta 0:03:53
#      --- ------------------------------------ 1.1/12.9 MB 50.6 kB/s eta 0:03:53
#      --- ------------------------------------ 1.1/12.9 MB 50.6 kB/s eta 0:03:53
#      --- ------------------------------------ 1.1/12.9 MB 50.6 kB/s eta 0:03:53
#      --- ------------------------------------ 1.1/12.9 MB 50.6 kB/s eta 0:03:53
#      --- ------------------------------------ 1.1/12.9 MB 50.6 kB/s eta 0:03:53
#      --- ------------------------------------ 1.1/12.9 MB 50.6 kB/s eta 0:03:53
#      --- ------------------------------------ 1.1/12.9 MB 50.6 kB/s eta 0:03:53
#      --- ------------------------------------ 1.1/12.9 MB 50.6 kB/s eta 0:03:53
#      --- ------------------------------------ 1.1/12.9 MB 49.6 kB/s eta 0:03:57
#      --- ------------------------------------ 1.1/12.9 MB 49.6 kB/s eta 0:03:57
#      --- ------------------------------------ 1.1/12.9 MB 49.6 kB/s eta 0:03:57
#      --- ------------------------------------ 1.1/12.9 MB 49.6 kB/s eta 0:03:57
#      --- ------------------------------------ 1.1/12.9 MB 49.6 kB/s eta 0:03:57
#      --- ------------------------------------ 1.1/12.9 MB 49.6 kB/s eta 0:03:57
#      --- ------------------------------------ 1.1/12.9 MB 49.6 kB/s eta 0:03:57
#      --- ------------------------------------ 1.1/12.9 MB 49.6 kB/s eta 0:03:57
#      --- ------------------------------------ 1.1/12.9 MB 49.6 kB/s eta 0:03:57
#      --- ------------------------------------ 1.1/12.9 MB 49.6 kB/s eta 0:03:57
#      --- ------------------------------------ 1.1/12.9 MB 49.6 kB/s eta 0:03:57
#      --- ------------------------------------ 1.1/12.9 MB 49.6 kB/s eta 0:03:57
#      --- ------------------------------------ 1.1/12.9 MB 49.6 kB/s eta 0:03:57
#      --- ------------------------------------ 1.1/12.9 MB 49.6 kB/s eta 0:03:57
#      --- ------------------------------------ 1.2/12.9 MB 49.1 kB/s eta 0:04:00
#      --- ------------------------------------ 1.2/12.9 MB 49.1 kB/s eta 0:04:00
#      --- ------------------------------------ 1.2/12.9 MB 49.1 kB/s eta 0:04:00
#      --- ------------------------------------ 1.2/12.9 MB 49.1 kB/s eta 0:04:00
#      --- ------------------------------------ 1.2/12.9 MB 49.1 kB/s eta 0:04:00
#      --- ------------------------------------ 1.2/12.9 MB 49.1 kB/s eta 0:04:00
#      --- ------------------------------------ 1.2/12.9 MB 49.1 kB/s eta 0:04:00
#      --- ------------------------------------ 1.2/12.9 MB 49.1 kB/s eta 0:04:00
#      --- ------------------------------------ 1.2/12.9 MB 49.1 kB/s eta 0:04:00
#      --- ------------------------------------ 1.2/12.9 MB 48.9 kB/s eta 0:04:00
#      --- ------------------------------------ 1.2/12.9 MB 48.9 kB/s eta 0:04:00
#      --- ------------------------------------ 1.2/12.9 MB 48.9 kB/s eta 0:04:00
#      --- ------------------------------------ 1.2/12.9 MB 48.9 kB/s eta 0:04:00
#      --- ------------------------------------ 1.2/12.9 MB 48.9 kB/s eta 0:04:00
#      --- ------------------------------------ 1.2/12.9 MB 48.9 kB/s eta 0:04:00
#      --- ------------------------------------ 1.2/12.9 MB 48.9 kB/s eta 0:04:00
#      --- ------------------------------------ 1.2/12.9 MB 48.7 kB/s eta 0:04:00
#      --- ------------------------------------ 1.2/12.9 MB 48.7 kB/s eta 0:04:00
#      --- ------------------------------------ 1.2/12.9 MB 48.7 kB/s eta 0:04:00
#      --- ------------------------------------ 1.2/12.9 MB 48.7 kB/s eta 0:04:00
#      --- ------------------------------------ 1.2/12.9 MB 48.7 kB/s eta 0:04:00
#      --- ------------------------------------ 1.2/12.9 MB 48.7 kB/s eta 0:04:00
#      --- ------------------------------------ 1.2/12.9 MB 48.7 kB/s eta 0:04:00
#      --- ------------------------------------ 1.2/12.9 MB 48.7 kB/s eta 0:04:00
#      --- ------------------------------------ 1.2/12.9 MB 48.7 kB/s eta 0:04:00
#      --- ------------------------------------ 1.2/12.9 MB 48.7 kB/s eta 0:04:00
#      --- ------------------------------------ 1.2/12.9 MB 48.6 kB/s eta 0:04:01
#      --- ------------------------------------ 1.2/12.9 MB 48.6 kB/s eta 0:04:01
#      --- ------------------------------------ 1.2/12.9 MB 48.6 kB/s eta 0:04:01
#      --- ------------------------------------ 1.2/12.9 MB 48.6 kB/s eta 0:04:01
#      --- ------------------------------------ 1.2/12.9 MB 48.6 kB/s eta 0:04:01
#      --- ------------------------------------ 1.2/12.9 MB 48.6 kB/s eta 0:04:01
#      --- ------------------------------------ 1.2/12.9 MB 48.5 kB/s eta 0:04:01
#      --- ------------------------------------ 1.2/12.9 MB 48.5 kB/s eta 0:04:01
#      --- ------------------------------------ 1.2/12.9 MB 48.5 kB/s eta 0:04:01
#      --- ------------------------------------ 1.2/12.9 MB 48.5 kB/s eta 0:04:01
#      --- ------------------------------------ 1.2/12.9 MB 48.5 kB/s eta 0:04:01
#      --- ------------------------------------ 1.2/12.9 MB 48.5 kB/s eta 0:04:01
#      --- ------------------------------------ 1.2/12.9 MB 48.5 kB/s eta 0:04:01
#      --- ------------------------------------ 1.2/12.9 MB 48.5 kB/s eta 0:04:01
#      --- ------------------------------------ 1.2/12.9 MB 48.5 kB/s eta 0:04:01
#      --- ------------------------------------ 1.2/12.9 MB 48.5 kB/s eta 0:04:01
#      --- ------------------------------------ 1.2/12.9 MB 48.3 kB/s eta 0:04:01
#      --- ------------------------------------ 1.2/12.9 MB 48.3 kB/s eta 0:04:01
#      --- ------------------------------------ 1.2/12.9 MB 48.3 kB/s eta 0:04:01
#      --- ------------------------------------ 1.2/12.9 MB 48.3 kB/s eta 0:04:01
#      --- ------------------------------------ 1.2/12.9 MB 48.3 kB/s eta 0:04:01
#      --- ------------------------------------ 1.2/12.9 MB 48.3 kB/s eta 0:04:01
#      --- ------------------------------------ 1.2/12.9 MB 48.3 kB/s eta 0:04:01
#      --- ------------------------------------ 1.2/12.9 MB 48.3 kB/s eta 0:04:01
#      --- ------------------------------------ 1.2/12.9 MB 48.3 kB/s eta 0:04:01
#      --- ------------------------------------ 1.3/12.9 MB 48.3 kB/s eta 0:04:01
#      --- ------------------------------------ 1.3/12.9 MB 48.3 kB/s eta 0:04:01
#      --- ------------------------------------ 1.3/12.9 MB 48.3 kB/s eta 0:04:01
#      --- ------------------------------------ 1.3/12.9 MB 48.3 kB/s eta 0:04:01
#      --- ------------------------------------ 1.3/12.9 MB 48.3 kB/s eta 0:04:01
#      --- ------------------------------------ 1.3/12.9 MB 48.3 kB/s eta 0:04:01
#      --- ------------------------------------ 1.3/12.9 MB 48.3 kB/s eta 0:04:01
# ...
#      ------------------------------------ - 541.4/568.0 MB 3.6 MB/s eta 0:00:08
#      ------------------------------------ - 541.6/568.0 MB 3.6 MB/s eta 0:00:08
#      ------------------------------------ - 541.7/568.0 MB 3.6 MB/s eta 0:00:08
#      ------------------------------------ - 541.9/568.0 MB 3.6 MB/s eta 0:00:08
#      ------------------------------------ - 542.0/568.0 MB 3.6 MB/s eta 0:00:08
#      ------------------------------------ - 542.2/568.0 MB 3.7 MB/s eta 0:00:08
#      ------------------------------------ - 542.3/568.0 MB 3.6 MB/s eta 0:00:08
#      ------------------------------------ - 542.5/568.0 MB 3.7 MB/s eta 0:00:07
#      ------------------------------------ - 542.6/568.0 MB 3.8 MB/s eta 0:00:07
#      ------------------------------------ - 542.8/568.0 MB 3.8 MB/s eta 0:00:07
#      ------------------------------------ - 543.0/568.0 MB 3.8 MB/s eta 0:00:07
#      ------------------------------------ - 543.1/568.0 MB 3.8 MB/s eta 0:00:07
#      ------------------------------------ - 543.2/568.0 MB 3.8 MB/s eta 0:00:07
#      ------------------------------------ - 543.3/568.0 MB 3.7 MB/s eta 0:00:07
#      ------------------------------------ - 543.5/568.0 MB 3.7 MB/s eta 0:00:07
#      ------------------------------------ - 543.7/568.0 MB 3.7 MB/s eta 0:00:07
#      ------------------------------------ - 544.0/568.0 MB 3.7 MB/s eta 0:00:07
#      ------------------------------------ - 544.1/568.0 MB 3.6 MB/s eta 0:00:07
#      ------------------------------------ - 544.4/568.0 MB 3.7 MB/s eta 0:00:07
#      ------------------------------------ - 544.8/568.0 MB 3.7 MB/s eta 0:00:07
#      ------------------------------------ - 545.1/568.0 MB 3.7 MB/s eta 0:00:07
#      ------------------------------------ - 545.5/568.0 MB 3.8 MB/s eta 0:00:06
#      ------------------------------------ - 545.8/568.0 MB 3.9 MB/s eta 0:00:06
#      ------------------------------------ - 545.8/568.0 MB 3.9 MB/s eta 0:00:06
#      ------------------------------------ - 546.1/568.0 MB 3.9 MB/s eta 0:00:06
#      ------------------------------------ - 546.3/568.0 MB 4.0 MB/s eta 0:00:06
#      ------------------------------------ - 546.7/568.0 MB 4.1 MB/s eta 0:00:06
#      ------------------------------------ - 547.0/568.0 MB 4.1 MB/s eta 0:00:06
#      ------------------------------------ - 547.2/568.0 MB 4.2 MB/s eta 0:00:05
#      ------------------------------------ - 547.6/568.0 MB 4.2 MB/s eta 0:00:05
#      ------------------------------------ - 548.0/568.0 MB 4.4 MB/s eta 0:00:05
#      ------------------------------------ - 548.5/568.0 MB 4.5 MB/s eta 0:00:05
#      ------------------------------------ - 549.0/568.0 MB 4.6 MB/s eta 0:00:05
#      ------------------------------------ - 549.2/568.0 MB 4.6 MB/s eta 0:00:05
#      ------------------------------------ - 549.5/568.0 MB 4.6 MB/s eta 0:00:04
#      ------------------------------------ - 549.9/568.0 MB 4.9 MB/s eta 0:00:04
#      ------------------------------------ - 550.1/568.0 MB 4.8 MB/s eta 0:00:04
#      ------------------------------------ - 550.5/568.0 MB 4.9 MB/s eta 0:00:04
#      ------------------------------------ - 550.7/568.0 MB 5.0 MB/s eta 0:00:04
#      ------------------------------------ - 550.9/568.0 MB 4.9 MB/s eta 0:00:04
#      ------------------------------------ - 551.2/568.0 MB 4.9 MB/s eta 0:00:04
#      ------------------------------------ - 551.3/568.0 MB 4.8 MB/s eta 0:00:04
#      ------------------------------------ - 551.7/568.0 MB 4.9 MB/s eta 0:00:04
#      ------------------------------------ - 552.0/568.0 MB 5.0 MB/s eta 0:00:04
#      ------------------------------------ - 552.1/568.0 MB 5.0 MB/s eta 0:00:04
#      ------------------------------------ - 552.4/568.0 MB 5.0 MB/s eta 0:00:04
#      ------------------------------------ - 552.7/568.0 MB 5.3 MB/s eta 0:00:03
#      ------------------------------------ - 553.0/568.0 MB 5.4 MB/s eta 0:00:03
#      -------------------------------------  553.4/568.0 MB 5.8 MB/s eta 0:00:03
#      -------------------------------------  553.6/568.0 MB 5.7 MB/s eta 0:00:03
#      -------------------------------------  554.0/568.0 MB 5.9 MB/s eta 0:00:03
#      -------------------------------------  554.5/568.0 MB 6.2 MB/s eta 0:00:03
#      -------------------------------------  554.7/568.0 MB 6.1 MB/s eta 0:00:03
#      -------------------------------------  555.0/568.0 MB 6.1 MB/s eta 0:00:03
#      -------------------------------------  555.1/568.0 MB 6.0 MB/s eta 0:00:03
#      -------------------------------------  555.2/568.0 MB 5.8 MB/s eta 0:00:03
#      -------------------------------------  555.5/568.0 MB 5.7 MB/s eta 0:00:03
#      -------------------------------------  555.8/568.0 MB 5.7 MB/s eta 0:00:03
#      -------------------------------------  556.0/568.0 MB 5.8 MB/s eta 0:00:03
#      -------------------------------------  556.3/568.0 MB 5.8 MB/s eta 0:00:02
#      -------------------------------------  556.4/568.0 MB 5.8 MB/s eta 0:00:02
#      -------------------------------------  556.7/568.0 MB 5.7 MB/s eta 0:00:02
#      -------------------------------------  557.0/568.0 MB 5.8 MB/s eta 0:00:02
#      -------------------------------------  557.4/568.0 MB 5.8 MB/s eta 0:00:02
#      -------------------------------------  557.5/568.0 MB 5.8 MB/s eta 0:00:02
#      -------------------------------------  557.5/568.0 MB 5.8 MB/s eta 0:00:02
#      -------------------------------------  557.5/568.0 MB 5.6 MB/s eta 0:00:02
#      -------------------------------------  557.5/568.0 MB 5.6 MB/s eta 0:00:02
#      -------------------------------------  557.6/568.0 MB 5.2 MB/s eta 0:00:02
#      -------------------------------------  557.7/568.0 MB 5.1 MB/s eta 0:00:03
#      -------------------------------------  557.8/568.0 MB 5.0 MB/s eta 0:00:03
#      -------------------------------------  558.2/568.0 MB 5.0 MB/s eta 0:00:02
#      -------------------------------------  558.4/568.0 MB 4.9 MB/s eta 0:00:02
#      -------------------------------------  558.8/568.0 MB 4.9 MB/s eta 0:00:02
#      -------------------------------------  559.0/568.0 MB 4.9 MB/s eta 0:00:02
#      -------------------------------------  559.2/568.0 MB 4.7 MB/s eta 0:00:02
#      -------------------------------------  559.5/568.0 MB 4.8 MB/s eta 0:00:02
#      -------------------------------------  559.9/568.0 MB 4.8 MB/s eta 0:00:02
#      -------------------------------------  560.2/568.0 MB 4.8 MB/s eta 0:00:02
#      -------------------------------------  560.5/568.0 MB 4.8 MB/s eta 0:00:02
#      -------------------------------------  560.8/568.0 MB 4.8 MB/s eta 0:00:02
#      -------------------------------------  560.8/568.0 MB 4.8 MB/s eta 0:00:02
#      -------------------------------------  561.5/568.0 MB 5.0 MB/s eta 0:00:02
#      -------------------------------------  561.9/568.0 MB 5.0 MB/s eta 0:00:02
#      -------------------------------------  562.1/568.0 MB 5.0 MB/s eta 0:00:02
#      -------------------------------------  562.2/568.0 MB 4.9 MB/s eta 0:00:02
#      -------------------------------------  562.4/568.0 MB 4.9 MB/s eta 0:00:02
#      -------------------------------------  562.8/568.0 MB 4.9 MB/s eta 0:00:02
#      -------------------------------------  563.1/568.0 MB 4.9 MB/s eta 0:00:01
#      -------------------------------------  563.4/568.0 MB 5.0 MB/s eta 0:00:01
#      -------------------------------------  563.4/568.0 MB 4.9 MB/s eta 0:00:01
#      -------------------------------------  563.6/568.0 MB 4.7 MB/s eta 0:00:01
#      -------------------------------------  563.8/568.0 MB 4.8 MB/s eta 0:00:01
#      -------------------------------------  564.2/568.0 MB 4.8 MB/s eta 0:00:01
#      -------------------------------------  564.6/568.0 MB 4.7 MB/s eta 0:00:01
#      -------------------------------------  564.7/568.0 MB 4.7 MB/s eta 0:00:01
#      -------------------------------------  564.8/568.0 MB 4.6 MB/s eta 0:00:01
#      -------------------------------------  565.0/568.0 MB 4.6 MB/s eta 0:00:01
#      -------------------------------------  565.4/568.0 MB 4.8 MB/s eta 0:00:01
#      -------------------------------------  565.8/568.0 MB 4.8 MB/s eta 0:00:01
#      -------------------------------------  565.9/568.0 MB 4.7 MB/s eta 0:00:01
#      -------------------------------------  566.0/568.0 MB 4.7 MB/s eta 0:00:01
#      -------------------------------------  566.0/568.0 MB 4.5 MB/s eta 0:00:01
#      -------------------------------------  566.3/568.0 MB 4.5 MB/s eta 0:00:01
#      -------------------------------------  566.4/568.0 MB 4.5 MB/s eta 0:00:01
#      -------------------------------------  566.6/568.0 MB 4.5 MB/s eta 0:00:01
#      -------------------------------------  566.7/568.0 MB 4.5 MB/s eta 0:00:01
#      -------------------------------------  567.0/568.0 MB 4.5 MB/s eta 0:00:01
#      -------------------------------------  567.3/568.0 MB 4.5 MB/s eta 0:00:01
#      -------------------------------------  567.7/568.0 MB 4.5 MB/s eta 0:00:01
#      -------------------------------------  567.9/568.0 MB 5.0 MB/s eta 0:00:01
#      -------------------------------------  568.0/568.0 MB 4.9 MB/s eta 0:00:01
#      -------------------------------------  568.0/568.0 MB 4.9 MB/s eta 0:00:01
#      -------------------------------------  568.0/568.0 MB 4.9 MB/s eta 0:00:01
#      -------------------------------------  568.0/568.0 MB 4.9 MB/s eta 0:00:01
#      -------------------------------------  568.0/568.0 MB 4.9 MB/s eta 0:00:01
#      -------------------------------------  568.0/568.0 MB 4.9 MB/s eta 0:00:01
#      -------------------------------------  568.0/568.0 MB 4.9 MB/s eta 0:00:01
#      -------------------------------------  568.0/568.0 MB 4.9 MB/s eta 0:00:01
#      -------------------------------------  568.0/568.0 MB 4.9 MB/s eta 0:00:01
#      -------------------------------------  568.0/568.0 MB 4.9 MB/s eta 0:00:01
#      -------------------------------------  568.0/568.0 MB 4.9 MB/s eta 0:00:01
#      -------------------------------------  568.0/568.0 MB 4.9 MB/s eta 0:00:01
#      -------------------------------------  568.0/568.0 MB 4.9 MB/s eta 0:00:01
#      -------------------------------------  568.0/568.0 MB 4.9 MB/s eta 0:00:01
#      -------------------------------------  568.0/568.0 MB 4.9 MB/s eta 0:00:01
#      -------------------------------------  568.0/568.0 MB 4.9 MB/s eta 0:00:01
#      -------------------------------------  568.0/568.0 MB 4.9 MB/s eta 0:00:01
#      -------------------------------------  568.0/568.0 MB 4.9 MB/s eta 0:00:01
#      -------------------------------------  568.0/568.0 MB 4.9 MB/s eta 0:00:01
#      -------------------------------------  568.0/568.0 MB 4.9 MB/s eta 0:00:01
#      -------------------------------------  568.0/568.0 MB 4.9 MB/s eta 0:00:01
#      -------------------------------------- 568.0/568.0 MB 2.8 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.0 in c:\users\user\anaconda3\lib\site-packages (from es-core-news-lg==3.7.0) (3.7.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-lg==3.7.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-lg==3.7.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-lg==3.7.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-lg==3.7.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-lg==3.7.0) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-lg==3.7.0) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-lg==3.7.0) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-lg==3.7.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-lg==3.7.0) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-lg==3.7.0) (0.3.4)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-lg==3.7.0) (0.9.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-lg==3.7.0) (4.65.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-lg==3.7.0) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-lg==3.7.0) (1.10.8)
# Requirement already satisfied: jinja2 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-lg==3.7.0) (3.1.2)
# Requirement already satisfied: setuptools in c:\users\user\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-lg==3.7.0) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-lg==3.7.0) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-lg==3.7.0) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-lg==3.7.0) (1.24.4)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\user\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->es-core-news-lg==3.7.0) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->es-core-news-lg==3.7.0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->es-core-news-lg==3.7.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->es-core-news-lg==3.7.0) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->es-core-news-lg==3.7.0) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\user\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->es-core-news-lg==3.7.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\user\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->es-core-news-lg==3.7.0) (0.1.4)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.8.0,>=3.7.0->es-core-news-lg==3.7.0) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\user\anaconda3\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->es-core-news-lg==3.7.0) (8.0.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\user\anaconda3\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->es-core-news-lg==3.7.0) (0.16.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\user\anaconda3\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->es-core-news-lg==3.7.0) (5.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\user\anaconda3\lib\site-packages (from jinja2->spacy<3.8.0,>=3.7.0->es-core-news-lg==3.7.0) (2.1.1)
# ✔ Download and installation successful
# You can now load the package via spacy.load('es_core_news_lg')

# %% [markdown]
# # Bases de datos periodico portafolio

# %%
# Lista de URLs de la base de datos portafolio
BASE_DATOS_portafolio= [
"https://www.portafolio.co/opinion/otros-columnistas-1/la-seguridad-es-paz-la-politica-de-seguridad-578114",
"https://www.portafolio.co/opinion/mauricio-reina/vivan-la-libertad-y-la-paz-592093",
"https://www.portafolio.co/opinion/otros-columnistas-1/construyendo-el-camino-hacia-la-paz-rosmery-quintero-castro-576398",
"https://www.portafolio.co/opinion/maria-sol-navia-v/hablemos-de-paz-columnista-580039",
"https://www.portafolio.co/opinion/analisis/enemigo-interno-de-la-paz-total-opinion-589574",
"https://www.portafolio.co/opinion/analisis/paz-aqui-alla-y-mas-alla-opinion-590773",
"https://www.portafolio.co/opinion/analisis/ante-la-desesperanza-inclusion-se-trata-de-construir-paz-desde-la-empresa-opinion-594655",
"https://www.portafolio.co/opinion/editorial/doble-tenaza-editorial-portafolio-591918",
"https://www.portafolio.co/opinion/analisis/para-ninguna-parte-opinion-589571",
"https://www.portafolio.co/opinion/ricardo-santamaria/concesiones-para-la-paz-de-petro-584612",
"https://www.portafolio.co/opinion/editorial/politica-en-crisis-editorial-portafolio-583307",
"https://www.portafolio.co/paz-y-comunicaciones-opinion-583183",
"https://www.portafolio.co/opinion/salomon-kassin-tesone-1/venezuela-y-la-paz-total-puede-ayudar-con-el-eln-581325",
"https://www.portafolio.co/opinion/mauricio-reina/otra-semana-fatal-para-el-gobierno-580698",
"https://www.portafolio.co/el-que-mucho-abarca-poco-aprieta-opinion-579794"
]
# Crear una lista para almacenar los datos extraídos
datos_extraidos = []

# Iterar sobre cada URL de la base de datos
for URL_BASE in BASE_DATOS_portafolio:
    pedido_obtenido = requests.get(URL_BASE)
    html_obtenido = pedido_obtenido.text
    soup = BeautifulSoup(html_obtenido, "html.parser")

    # Encontrar los elementos <div> con la clase "font--secondary"
    divs = soup.find_all(class_="article-content")

    # Crear una lista para almacenar los textos del artículo
    texto_articulo = []
    for div in divs:
        texto_articulo.append(div.text.strip())

    # Unir todos los textos del artículo en una cadena
    articulo_completo = " ".join(texto_articulo)

    # Agregar solo el texto del artículo a la lista de datos_extraidos
    datos_extraidos.append(articulo_completo)

# Escribir los datos extraídos en un archivo CSV
with open('datos_extraidosportafolio.csv', 'w', newline='', encoding='utf-8-sig') as archivo:
    escritor_csv = csv.writer(archivo)
    for texto_articulo in datos_extraidos:
        escritor_csv.writerow([texto_articulo])

# %% [markdown]
# # preprocesamiento

# %%
# Definir la función para eliminar caracteres no deseados
def eliminar_caracteres(texto):
    # Definir una expresión regular para encontrar caracteres no alfabéticos o espacios
    patron = r'[^a-zA-ZáéíóúüñÁÉÍÓÚÜÑ\s]'
    # Reemplazar los caracteres no deseados por espacios en blanco
    texto_limpio = re.sub(patron, ' ', str(texto))
    return texto_limpio
#------

import spacy
from spacy.lang.es.stop_words import STOP_WORDS

# Descargar y cargar el modelo de spaCy para español
spacy.cli.download("es_core_news_sm")
nlp = spacy.load("es_core_news_sm")

# Obtener la lista de stopwords en español de spaCy
stopwords_espanol = STOP_WORDS

# Definir una función para eliminar stopwords utilizando spaCy
def eliminar_stopwords(texto):
    # Procesar el texto con spaCy
    doc = nlp(texto)
    # Filtrar las palabras que no son stopwords
    palabras_filtradas = [token.text for token in doc if token.text.lower() not in stopwords_espanol]
    # Unir las palabras filtradas en un texto nuevamente
    texto_filtrado = ' '.join(palabras_filtradas)
    return texto_filtrado

# Definir una función para tokenizar el texto utilizando spaCy
def tokenizar_texto(texto):
    # Procesar el texto con spaCy
    doc = nlp(texto)
    # Extraer los tokens
    tokens = [token.text for token in doc]
    return tokens


# Definir una función para lematizar el texto
def lematizar_texto(tokens):
    # Unir los tokens en una cadena de texto
    texto = ' '.join(tokens)
    # Procesar el texto con el modelo de lenguaje en español
    doc = nlp(texto)
    # Extraer las formas base (lemas) de cada palabra
    lemas = [token.lemma_ for token in doc]
    return lemas
#------

def eliminar_verbos(texto):
    # Procesar el texto con spaCy
    doc = nlp(texto)
    # Filtrar las palabras que no son verbos
    palabras_filtradas = [token.text for token in doc if token.pos_ != 'VERB']
    # Unir las palabras filtradas en un texto nuevamente
    texto_filtrado = ' '.join(palabras_filtradas)
    return texto_filtrado
# Out:
# ✔ Download and installation successful
# You can now load the package via spacy.load('es_core_news_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
# Leer el archivo CSV con los datos extraídos
with open('datos_extraidosportafolio.csv', 'r', encoding='utf-8-sig') as archivo:
    lector_csv = csv.reader(archivo)
    # Extraer los datos de la primera columna en una lista
    datos_extraidos_total = [fila[0] for fila in lector_csv]
    
# Aplicar la función eliminar_caracteres a cada texto en la lista datos_extraidos_total
contenido_limpiado = [eliminar_caracteres(texto) for texto in datos_extraidos_total]

# Convertir el texto limpiado a minúsculas
contenido_limpiado_minusculas = [texto.lower() for texto in contenido_limpiado]

# Aplicar la función eliminar_verbos a cada texto en la lista
contenido_sin_verbos = [eliminar_verbos(texto) for texto in contenido_limpiado_minusculas]

# Aplicar la función eliminar_stopword a cada texto en la lista
contenido_sin_stopword = [eliminar_stopwords(texto) for texto in contenido_sin_verbos]

# Aplicar la función de tokenización a cada texto en la lista
contenido_tokens= [tokenizar_texto(texto) for texto in contenido_sin_stopword]

# Aplicar la función de lematización a cada lista de tokens en la lista de contenidos
contenido_lemas= [lematizar_texto(tokens) for tokens in contenido_tokens]

# Escribir los datos en un nuevo archivo CSV
with open('lemas_portafolio.csv', 'w', newline='', encoding='utf-8-sig') as archivo:
    escritor_csv = csv.writer(archivo)
    for lemas in contenido_lemas:
        escritor_csv.writerow(lemas)

# %% [markdown]
# # Palabras claves

# %%
# Crear un contador para almacenar la frecuencia de las palabras
contador_palabras = Counter()

# Abrir el archivo CSV y contar la frecuencia de las palabras
with open('lemas_portafolio.csv', 'r', newline='', encoding='utf-8-sig') as archivo:
    lector_csv = csv.reader(archivo)
    for fila in lector_csv:
        # Filtrar palabras que no sean solo espacios en blanco
        palabras_filtradas = [palabra.strip() for palabra in fila if palabra.strip()]
        contador_palabras.update(palabras_filtradas)

# Ordenar las palabras por frecuencia de mayor a menor
palabras_ordenadas = contador_palabras.most_common()

# Imprimir la tabla de frecuencia de las palabras ordenadas
print("Tabla de frecuencia de las palabras revista semana:")
print("{:<15} {:<10}".format("Palabra", "Frecuencia"))
for palabra, frecuencia in palabras_ordenadas:
    print("{:<15} {:<10}".format(palabra, frecuencia))
# Out:
# Tabla de frecuencia de las palabras revista semana:
# Palabra         Frecuencia
# paz             63
# gobierno        53
# grupo           24
# eln             23
# político        22
# proceso         22
# negociación     19
# país            18
# seguridad       18
# petro           16
# año             15
# nacional        15
# farc            15
# conflicto       14
# social          13
# armado          13
# presidente      12
# tema            11
# fuerza          11
# público         11
# militar         11
# estrategia      11
# líder           10
# colombiano      10
# secuestro       10
# diálogo         9
# civil           9
# colombia        8
# guerra          8
# gustavo         8
# guerrilla       8
# empresa         8
# opinión         8
# territorio      7
# valle           7
# ciudadano       7
# derecho         7
# delegación      7
# guerrillero     7
# frente          7
# razón           7
# ministro        7
# congreso        7
# comunicación    7
# historia        6
# asesinato       6
# acuerdo         6
# actor           6
# ley             6
# espacio         6
# sociedad        6
# humanitario     6
# reacción        6
# complejo        6
# fuego           6
# económico       6
# mes             6
# equipo          6
# cambio          6
# arma            6
# mil             6
# proyecto        6
# disidencia      6
# calle           6
# semana          6
# elección        6
# reforma         6
# inseguridad     5
# resultado       5
# hecho           5
# violento        5
# humano          5
# ilícito         5
# ilegal          5
# necesidad       5
# institución     5
# cosa            5
# liberación      5
# luis            5
# manuel          5
# compromiso      5
# momento         5
# sector          5
# importante      5
# anterior        5
# empresarial     5
# experiencia     5
# situación       5
# escenario       5
# acción          5
# haber           5
# allá            5
# apoyo           5
# organización    5
# coalición       5
# caso            4
# indígena        4
# región          4
# esfuerzo        4
# lucha           4
# cultivo         4
# capacidad       4
# empresario      4
# acordado        4
# internacional   4
# jefe            4
# desmovilización 4
# violencia       4
# principal       4
# actual          4
# interés         4
# participación   4
# modelo          4
# cultura         4
# necesario       4
# fuerzas         4
# general         4
# vida            4
# interior        4
# reciente        4
# lugar           4
# población       4
# cesar           4
# formar          4
# república       4
# contrario       4
# difícil         4
# logro           4
# urgente         4
# estratégico     4
# deterioro       4
# claro           4
# ciudad          3
# cifra           3
# acto            3
# violencio       3
# bogotá          3
# preocupante     3
# alto            3
# economía        3
# transformación  3
# históricamente  3
# papel           3
# narcotráfico    3
# éxito           3
# confianza       3
# acopi           3
# efecto          3
# positivo        3
# propuesta       3
# distinto        3
# margen          3
# díaz            3
# padre           3
# política        3
# corazón         3
# término         3
# cese            3
# práctico        3
# mensaje         3
# libertad        3
# més             3
# crítico         3
# marco           3
# construcción    3
# grave           3
# profundo        3
# experto         3
# condición       3
# ejército        3
# real            3
# local           3
# responsabilidad 3
# realidad        3
# siglo           3
# planeación      3
# decisión        3
# miembro         3
# víctima         3
# servicio        3
# pérdida         3
# claramente      3
# tipo            3
# aspiración      3
# implementación  3
# habán           3
# actividad       3
# policía         3
# intención       3
# oficial         3
# presenciar      3
# criminal        3
# similar         3
# liberal         3
# m               3
# muerto          3
# persona         3
# protesta        3
# mediación       3
# capital         3
# urbano          3
# ciento          3
# administración  3
# central         3
# conversación    3
# llamado         3
# medio           3
# interesante     3
# sentido         3
# ricardo         3
# privado         3
# estar           3
# mostrar         3
# corto           3
# negociador      3
# pedagogía       3
# problema        3
# dimensión       3
# salud           3
# dudar           2
# desafío         2
# noticia         2
# caucar          2
# cauca           2
# departamento    2
# muerte          2
# particular      2
# marcado         2
# actualmente     2
# excombatiente   2
# masacr          2
# extorsión       2
# muert           2
# enfrentamiento  2
# acompañado      2
# asimismo        2
# cocaína         2
# sistema         2
# incremento      2
# tendencia       2
# reto            2
# materio         2
# confianzar      2
# dicho           2
# discusión       2
# justicia        2
# quintero        2
# castropresidente 2
# futbolista      2
# reflexión       2
# don             2
# parte           2
# protocolo       2
# adicional       2
# semejante       2
# cuyo            2
# desprecio       2
# completo        2
# presente        2
# próximo         2
# secuestrado     2
# financiación    2
# duda            2
# posibilidad     2
# mauricio        2
# reina           2
# investigador    2
# asociado        2
# fedesarrollo    2
# firmado         2
# objetivo        2
# noviembre       2
# pequeño         2
# respeto         2
# agenda          2
# punto           2
# democracia      2
# ciudadanía      2
# dinámico        2
# exclusión       2
# oportunidad     2
# relación        2
# aspecto         2
# narrativo       2
# causado         2
# certeza         2
# problemático    2
# invitación      2
# empleo          2
# ambición        2
# ser             2
# simple          2
# diverso         2
# forma           2
# simultáneamente 2
# debilidad       2
# desmotivación   2
# confusión       2
# golpe           2
# patria          2
# formación       2
# cerco           2
# inmenso         2
# enemigo         2
# zona            2
# drogar          2
# propuesto       2
# conducta        2
# partido         2
# panorama        2
# presidencia     2
# zozobrar        2
# miedo           2
# confrontación   2
# gubernamental   2
# paramilitar     2
# organizaciones  2
# destrucción     2
# medida          2
# soldado         2
# delito          2
# curso           2
# com             2
# imposible       2
# memorio         2
# período         2
# libro           2
# creación        2
# s               2
# pablo           2
# gallo           2
# opositor        2
# militante       2
# rápidamente     2
# odio            2
# expectativa     2
# cali            2
# anti            2
# suficiente      2
# múltiple        2
# comunitario     2
# exitoso         2
# importancia     2
# innovación      2
# emprendimiento  2
# mentoer         2
# tensión         2
# factor          2
# gestión         2
# poder           2
# basado          2
# recientemente   2
# preocupación    2
# mandatario      2
# electo          2
# alcald          2
# centro          2
# encuesta        2
# invamer         2
# delincuente     2
# juan            2
# atención        2
# luchar          2
# delincuencia    2
# eleno           2
# emc             2
# comisionado     2
# danilo          2
# redireccionamiento 2
# francisco       2
# miranda         2
# portafolio      2
# pachomirando    2
# concepto        2
# panel           2
# formador        2
# congresista     2
# director        2
# gremio          2
# digital         2
# nombre          2
# gobernabilidad  2
# estudio         2
# foro            2
# famoso          2
# posición        2
# ocurrencia      2
# vía             2
# villavez        2
# p               2
# consultor       2
# desmovilizado   2
# movimiento      2
# interno         2
# violenciir      2
# idea            2
# regional        2
# vocero          2
# mundo           2
# negociado       2
# ajeno           2
# santamaríaanalista 2
# crisis          2
# joven           2
# menor           2
# mano            2
# control         2
# iniciativo      2
# anuncio         2
# consecuencia    2
# simultáneo      2
# camino          2
# santos          2
# firma           2
# masacre         2
# plazo           2
# declaración     2
# tiempo          2
# legado          2
# lograr          2
# contrapeso      2
# limitación      2
# recurso         2
# popular         2
# ambicioso       2
# dedicación      2
# temo            2
# mando           2
# ingenuo         2
# incidencia      1
# plasmada        1
# numeroso        1
# falto           1
# pan             1
# homicidio       1
# antioquia       1
# atlántico       1
# mayor           1
# fiscalía        1
# contexto        1
# sufrimiento     1
# desplazamiento  1
# respectivo      1
# implicación     1
# socioeconómico  1
# tasa            1
# pese            1
# contundente     1
# estabilidad     1
# afectado        1
# tranquilidad    1
# urb             1
# inteligencia    1
# tecnología      1
# flagelo         1
# producción      1
# consumo         1
# monitoreo       1
# área            1
# sembrado        1
# alcista         1
# observatorio    1
# mipyme          1
# cargo           1
# defensa         1
# indepaz         1
# presentado      1
# apoyar          1
# desmantelamiento 1
# adecuado        1
# articulación    1
# gobernante      1
# rosmery         1
# lucho           1
# sano            1
# excelente       1
# familia         1
# único           1
# alegría         1
# perpetrado      1
# ii              1
# ginebra         1
# doble           1
# transgresión    1
# pactado         1
# afrenta         1
# ojo             1
# x               1
# escueto         1
# desconcertante  1
# sic             1
# fe              1
# comunicar       1
# execrable       1
# fasar           1
# reunión         1
# mecanismo       1
# sustancial      1
# inquietud       1
# perspectivo     1
# fase            1
# ilusión         1
# tremendamente   1
# acá             1
# efectividad     1
# exigencia       1
# gana            1
# vivo            1
# golpeado        1
# cicatriz        1
# búsqueda        1
# derechos        1
# cultural        1
# erradicación    1
# desigualdad     1
# duradero        1
# iniciado        1
# convocado       1
# interdisciplinario 1
# personal        1
# portavoz        1
# micro           1
# mediano         1
# objetividad     1
# compañía        1
# apropiado       1
# realización     1
# agendo          1
# conformado      1
# activo          1
# iniciativa      1
# ausencio        1
# ejecutado       1
# particularidad  1
# agricultura     1
# industrio       1
# fortalecimiento 1
# transición      1
# lograrer        1
# legitimidad     1
# entorno         1
# condena         1
# estigmatización 1
# territorial     1
# movilización    1
# empresariado    1
# motor           1
# postconflicto   1
# tejido          1
# trascendencia   1
# existente       1
# retroceso       1
# especialmente   1
# mipym           1
# meta            1
# nación          1
# disparidad      1
# consiguiente    1
# crecimiento     1
# época           1
# cristo          1
# motivado        1
# religión        1
# raza            1
# codicia         1
# duración        1
# disperso        1
# realmente       1
# universalmente  1
# absolutamente   1
# loable          1
# deseable        1
# factible        1
# variopinto      1
# movido          1
# enfrentado      1
# confuso         1
# falta           1
# improvisación   1
# finalmente      1
# sumido          1
# certero         1
# inhumano        1
# imposibilidad   1
# retiro          1
# forzoso         1
# estamento       1
# inicio          1
# cúpular         1
# registrado      1
# hombre          1
# vido            1
# carrera         1
# truncada        1
# adicionalmente  1
# palabra         1
# representación  1
# inaudito        1
# disímil         1
# fruto           1
# formalmente     1
# consecuencio    1
# estratégicamente 1
# derrotado       1
# agudo           1
# polarización    1
# clasificación   1
# amigo           1
# incrementado    1
# instigación     1
# clás            1
# suspensión      1
# fumigación      1
# cocar           1
# adopción        1
# laxa            1
# hectárea        1
# nivel           1
# negocio         1
# disputa         1
# renta           1
# tendient        1
# punible         1
# maría           1
# sol             1
# navia           1
# v               1
# exministra      1
# esperado        1
# geografía       1
# común           1
# ambiente        1
# sangre          1
# ansiado         1
# abandonado      1
# alzado          1
# frenazo         1
# introducido     1
# vacío           1
# aprovechado     1
# mineer          1
# respaldo        1
# ilegítimo       1
# autoridad       1
# nuevamente      1
# barbarie        1
# habitante       1
# recrudecimiento 1
# reflejado       1
# sacrificio      1
# uniformado      1
# reinsertado     1
# ataque          1
# misericordiar   1
# justificant     1
# impulsar        1
# mordisco        1
# avance          1
# irracional      1
# miserable       1
# timba           1
# vallar          1
# sucedido        1
# vereda          1
# manso           1
# tierraltar      1
# síntoma         1
# cáncer          1
# enquistado      1
# glorioso        1
# armadas         1
# doloroso        1
# demencial       1
# complicidad     1
# evidenciado     1
# testimonio      1
# rendido         1
# procesado       1
# jep             1
# sagrado         1
# especiar        1
# vigente         1
# insuficiente    1
# adoptado        1
# anunciado       1
# comandant       1
# sanción         1
# suboficial      1
# responsable     1
# tal             1
# drasticidad     1
# enmarcar        1
# lés             1
# humanidad       1
# contemplado     1
# art             1
# estatuto        1
# romar           1
# cuerpo          1
# niveles         1
# nocivo          1
# influencia      1
# perniciós       1
# contrainteligencia 1
# efectivo        1
# terreno         1
# herencia        1
# indeseado       1
# daño            1
# honor           1
# anhelado        1
# h               1
# cote            1
# peña            1
# exdirector      1
# diangcotep      1
# yahoo           1
# juegos          1
# palabras        1
# cuento          1
# infantil        1
# dr              1
# seuss           1
# tradicionalmente 1
# catastrofista   1
# soñador         1
# optimista       1
# calma           1
# reyerta         1
# cadén           1
# advenimiento    1
# epl             1
# ah              1
# alivio          1
# etcr            1
# remanent        1
# escobar         1
# clar            1
# golfo           1
# querido         1
# malcolm         1
# dea             1
# problemonón     1
# julián          1
# konrad          1
# adenauer        1
# er              1
# canciller       1
# federal         1
# alemán          1
# nazismo         1
# socialismo      1
# g               1
# ering           1
# himlers         1
# r               1
# reich           1
# aniquilado      1
# obvio           1
# explosión       1
# israel          1
# hamás           1
# destrozado      1
# horripilante    1
# matanza         1
# israelí         1
# sábado          1
# mañana          1
# estallido       1
# gaza            1
# hamá            1
# palestino       1
# escudo          1
# afortunadamente 1
# juego           1
# egipto          1
# ee              1
# uu              1
# campo           1
# diplomático     1
# cabeza          1
# fría            1
# dolor           1
# embrollo        1
# judío           1
# europa          1
# alemania        1
# shoá            1
# zelensky        1
# temporalmente   1
# consternación   1
# combatiente     1
# manera          1
# ucraniano       1
# orgullo         1
# injusto         1
# charl           1
# memorablemente  1
# carlos          1
# enrique         1
# cavelier        1
# carloscavelier  1
# gmail           1
# sur             1
# epicentrir      1
# acento          1
# protestar       1
# productivo      1
# élite           1
# respuesta       1
# autodefenso     1
# latente         1
# cincuenta       1
# manifestante    1
# reactiva        1
# protestante     1
# cualidad        1
# disciplina      1
# sensibilidad    1
# conocimiento    1
# honestidad      1
# ético           1
# organizado      1
# protagonismo    1
# discurso        1
# reconocimiento  1
# riqueza         1
# incendiado      1
# herida          1
# histórico       1
# fuerte          1
# contenido       1
# racista         1
# discriminación  1
# clasismo        1
# excluido        1
# cerrar          1
# brecha          1
# experimento     1
# líneas          1
# empleabilidad   1
# visible         1
# lideresa        1
# buenaventura    1
# siloé           1
# protección      1
# emprendedor     1
# acceso          1
# mercado         1
# emprendedorar   1
# valor           1
# diversidad      1
# segregación     1
# propacífico     1
# plataforma      1
# integración     1
# tradicional     1
# sostenibilidad  1
# tercerizado     1
# fundación       1
# directamente    1
# causa           1
# sistémico       1
# podido          1
# represión       1
# fuerzo          1
# inclusión       1
# esperanza       1
# jorge           1
# restrepox       1
# pérdidar        1
# rumbo           1
# celebrado       1
# especial        1
# poblado         1
# delincuencio    1
# prioridad       1
# cuatrienio      1
# enero           1
# octubre         1
# orden           1
# listo           1
# empate          1
# técnico         1
# agresión        1
# robo            1
# lunes           1
# banda           1
# caminant        1
# cerro           1
# oriental        1
# incluido        1
# reconocido      1
# hijo            1
# reflejo         1
# hurto           1
# sicarial        1
# asalto          1
# diario          1
# estadística     1
# serie           1
# propiedad       1
# saliente        1
# medellín        1
# barranquilla    1
# bucaramanguir   1
# campaña         1
# cuidado         1
# balance         1
# empalmes        1
# compelido       1
# gobernado       1
# línea           1
# grueso          1
# desplegado      1
# angustioso      1
# expectativo     1
# error           1
# paro            1
# hora            1
# comunidad       1
# corregimiento   1
# caucano         1
# plateado        1
# asonado         1
# centenar        1
# cuerdo          1
# flojo           1
# ayer            1
# prematuro       1
# insurgente      1
# gobiernista     1
# renunciar       1
# inaplazable     1
# ambos           1
# cara            1
# territorios     1
# entrante        1
# cox             1
# quince          1
# ejercicio       1
# identificado    1
# universo        1
# sindicato       1
# totalidad       1
# columnista      1
# informado       1
# análisis        1
# comentario      1
# trabajo         1
# recomposición   1
# influyente      1
# plano           1
# surgen          1
# opinador        1
# relevancia      1
# ámbito          1
# conclusión      1
# destacado       1
# mayoritario     1
# mencionado      1
# igualmente      1
# trabaje         1
# puntar          1
# twittero        1
# ángulo          1
# char él         1
# senador         1
# iván            1
# enfático        1
# previo          1
# ofrecimiento    1
# colaboración    1
# unido           1
# esencial        1
# desafortunadamente 1
# líneo           1
# profundidad     1
# democráticamente 1
# repúblico       1
# armas           1
# vanguardia      1
# agrupado        1
# coordinadora    1
# impulsado       1
# barco           1
# agua            1
# convicción      1
# guerro          1
# locura          1
# documentado     1
# informe         1
# comisión        1
# desmovilizada   1
# valioso         1
# pasado          1
# alcaldías       1
# turbaco         1
# puerto          1
# caicedo         1
# putumayo        1
# guapi           1
# curul           1
# preguntar       1
# forzar          1
# marchar         1
# temático        1
# frágil          1
# comienzo        1
# visto           1
# riesgo          1
# aire            1
# fondo           1
# impensable      1
# dinero          1
# municiones      1
# argumento       1
# fórmula         1
# trance          1
# incorporación   1
# ofrecerl        1
# alimentación    1
# viviendir       1
# médico          1
# asistencia      1
# españa          1
# triunfo         1
# rechazo         1
# presencio       1
# eta             1
# tolerancia      1
# concesión       1
# colombiar       1
# simultánear     1
# muestra         1
# trágico         1
# mayo            1
# edad            1
# reclutamiento   1
# forzado         1
# despreciable    1
# violación       1
# flagrante       1
# norma           1
# cás             1
# nariño          1
# subversiva      1
# determinación   1
# fortaleza       1
# tono            1
# voluntad        1
# presidencial    1
# firmezar        1
# requerida       1
# reprobable      1
# mirada          1
# rápido          1
# alerta          1
# sorpresar       1
# creciente       1
# dificultad      1
# públicamente    1
# complejidades   1
# organizativo    1
# demanda         1
# apresurado      1
# negativo        1
# capaz           1
# abanico         1
# amplio          1
# drásticamente   1
# reducido        1
# tajante         1
# definición      1
# concisa         1
# multiplicidad   1
# cuarto          1
# sencillo        1
# transmisión     1
# rutar           1
# medición        1
# abril           1
# indicador       1
# atentado        1
# terrorista      1
# petrolero       1
# minero          1
# ganadero        1
# columnar        1
# pecho           1
# espalda         1
# difusión        1
# explicación     1
# humberto        1
# mea             1
# culpa           1
# respetable      1
# enfocar         1
# excepción       1
# entrado         1
# convención      1
# divino          1
# vedado          1
# bananeras       1
# ocurrido        1
# prudente        1
# cumplido        1
# parcial         1
# futuro          1
# información     1
# relevante       1
# analizado       1
# explicado       1
# predicción      1
# futuristo       1
# asesor          1
# citar           1
# oslo            1
# pensado         1
# correcto        1
# mesa            1
# apliqué         1
# beneficio       1
# magnitud        1
# adversario      1
# ocasión         1
# feroz           1
# sinónimo        1
# paciencia       1
# prudenciir      1
# elaborado       1
# asunto          1
# táctico         1
# referendo       1
# falsedad        1
# matrimonio      1
# santo           1
# jaramillo       1
# ossa            1
# bejarano        1
# pardo           1
# rural           1
# solución        1
# verificación    1
# refrendación    1
# decreto         1
# recuerdo        1
# lutte           1
# finale          1
# viejo           1
# himno           1
# socialista      1
# inflama         1
# pasión          1
# tangible        1
# significativo   1
# cupu él         1
# rama            1
# petrir          1
# revolcón        1
# incógnita       1
# chávez          1
# régimen         1
# venezolano      1
# eco             1
# remoto          1
# maduro          1
# decisivo        1
# consecución     1
# particularmente 1
# desarme         1
# beneplácito     1
# cuba            1
# parlamento      1
# haberla         1
# aprobación      1
# fecho           1
# totalmente      1
# desear          1
# programa        1
# coyuntura       1
# venezuela       1
# energía         1
# desarmar        1
# hostilidad      1
# democrático     1
# ordenado        1
# izquierdo       1
# necesariamente  1
# disruptivo      1
# inevitablemente 1
# extremo         1
# probablemente   1
# autocrático     1
# gradualismo     1
# visión          1
# salomon         1
# kassin          1
# banquero        1
# inversión       1
# horrible        1
# remezón         1
# gabinete        1
# salido          1
# alejandro       1
# gaviria         1
# institucional   1
# ímpetu          1
# cautelar        1
# consejo         1
# intento         1
# función         1
# creg            1
# fijación        1
# tarifa          1
# campesino       1
# apoyado         1
# grieta          1
# serio           1
# increíble       1
# ultra           1
# air             1
# quiebra         1
# aerolíneo       1
# errática        1
# exceso          1
# semán           1
# rasgo           1
# quehacer        1
# incapacidad     1
# puent           1
# displicencio    1
# criterio        1
# conservador     1
# acercamiento    1
# ápizar          1
# preservación    1
# aseguramiento   1
# libre           1
# usuario         1
# prevención      1
# manejo          1
# financiero      1
# básico          1
# episodar        1
# rupturo         1
# surtir          1
# pensión         1
# laboral         1
# lentejismo      1
# individual      1
# emergenciar     1
# exponencial     1
# cometido        1
# catatumbir      1
# saldo           1
# desdén          1
# máximo          1
# utópico         1
# apostar         1
# acorralado      1
# sabiduer        1
# enseñanza       1
# clase           1
# carne           1
# fácil           1
# ojalá           1
# consenso        1
# incendio        1
# calificado      1
# propósito       1
# infinidad       1
# cantidad        1
# viaje           1
# polémico        1
# avatar          1
# limitado        1
# sólido          1
# revista         1
# titulado        1
# presentación    1
# eduardo         1
# pizarro         1
# conocedor       1
# diferencia      1
# origen          1
# estructurar     1
# opción          1
# disuasión       1
# mandato         1
# robusto         1
# inexistencia    1
# organismo       1
# ambigüedad      1
# directriz       1
# caquetá         1
# debilitado      1
# acumulado       1
# descabezado     1
# persón          1
# señor           1
# complejísimo    1
# ajedrez         1
# pena            1
# gestor          1
# episodio        1
# cinismo         1
# luz             1
# promisorio      1

# %% [markdown]
# ## SPACY

# %%
# Carga el modelo de lenguaje grande de spaCy en español
nlp = spacy.load('es_core_news_lg')

# Define la palabra objetivo
palabra_objetivo = 'paz'

# Aplanar el corpus a una sola lista de palabras y eliminar duplicados
palabras_corpus = list(set([palabra for sublist in contenido_lemas for palabra in sublist]))

# Procesar la palabra objetivo con el modelo spaCy
doc_objetivo = nlp(palabra_objetivo)

# Encuentra palabras similares a la palabra objetivo en el corpus definido
palabras_similares = []

# Calcular la similitud entre la palabra objetivo y cada palabra del corpus
for palabra in palabras_corpus:
    doc_p = nlp(palabra)
    similitud = doc_objetivo.similarity(doc_p)
    palabras_similares.append((palabra, similitud))

# Ordenar las palabras por similitud en orden descendente
palabras_similares = sorted(palabras_similares, key=lambda item: -item[1])

# Preparar los datos para escribir en el archivo CSV
contenido_lemas_csv = [['Palabra', 'Similitud']]  # Encabezados del CSV
for palabra, similitud in palabras_similares:  
    contenido_lemas_csv.append([palabra, f"{similitud:.4f}"])

# Escribir los datos en un nuevo archivo CSV
with open('similitud_paz_portafolio.csv', 'w', newline='', encoding='utf-8-sig') as archivo:
    escritor_csv = csv.writer(archivo)
    escritor_csv.writerows(contenido_lemas_csv)

# Leer y mostrar el contenido del archivo CSV
with open('similitud_paz_portafolio.csv', 'r', newline='', encoding='utf-8-sig') as archivo:
    lector_csv = csv.reader(archivo)
    for fila in lector_csv:
        print(fila)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_41484\3220395168.py:19: UserWarning: [W008] Evaluating Doc.similarity based on empty vectors.
#   similitud = doc_objetivo.similarity(doc_p)
# ['Palabra', 'Similitud']
# ['paz', '1.0000']
# ['esperanza', '0.5374']
# ['democracia', '0.5209']
# ['libertad', '0.5198']
# ['justicia', '0.5142']
# ['tranquilidad', '0.5116']
# ['calma', '0.4941']
# ['patria', '0.4744']
# ['desarme', '0.4654']
# ['voluntad', '0.4509']
# ['democrático', '0.4452']
# ['gobernabilidad', '0.4436']
# ['diálogo', '0.4317']
# ['humanitario', '0.4314']
# ['alegría', '0.4271']
# ['fortaleza', '0.4229']
# ['confianza', '0.4206']
# ['guerra', '0.4110']
# ['humanidad', '0.4106']
# ['liberación', '0.4087']
# ['democráticamente', '0.4069']
# ['palestino', '0.4010']
# ['lucha', '0.4002']
# ['fe', '0.3996']
# ['excombatiente', '0.3974']
# ['respeto', '0.3972']
# ['hostilidad', '0.3948']
# ['guerrilla', '0.3921']
# ['postconflicto', '0.3913']
# ['insurgente', '0.3903']
# ['nación', '0.3885']
# ['legitimidad', '0.3883']
# ['convicción', '0.3845']
# ['conflicto', '0.3825']
# ['ciudadanía', '0.3820']
# ['desmovilización', '0.3775']
# ['tolerancia', '0.3749']
# ['gobernante', '0.3741']
# ['consenso', '0.3692']
# ['ilusión', '0.3689']
# ['cristo', '0.3678']
# ['anhelado', '0.3599']
# ['confrontación', '0.3574']
# ['corazón', '0.3573']
# ['república', '0.3571']
# ['buenaventura', '0.3561']
# ['honestidad', '0.3558']
# ['vida', '0.3549']
# ['paciencia', '0.3543']
# ['complicidad', '0.3535']
# ['compromiso', '0.3533']
# ['sacrificio', '0.3499']
# ['estabilidad', '0.3495']
# ['desmovilizada', '0.3459']
# ['disidencia', '0.3447']
# ['socialismo', '0.3446']
# ['luchar', '0.3444']
# ['israel', '0.3339']
# ['política', '0.3331']
# ['gobierno', '0.3294']
# ['desmovilizado', '0.3282']
# ['guerrillero', '0.3277']
# ['prioridad', '0.3271']
# ['sufrimiento', '0.3256']
# ['violencia', '0.3256']
# ['ansiado', '0.3251']
# ['erradicación', '0.3245']
# ['negociación', '0.3244']
# ['nuevamente', '0.3204']
# ['certeza', '0.3195']
# ['religión', '0.3182']
# ['futuro', '0.3180']
# ['transición', '0.3170']
# ['glorioso', '0.3146']
# ['venezuela', '0.3143']
# ['marchar', '0.3142']
# ['fuerza', '0.3126']
# ['gobernado', '0.3126']
# ['paramilitar', '0.3105']
# ['sagrado', '0.3105']
# ['negociador', '0.3101']
# ['desigualdad', '0.3097']
# ['trascendencia', '0.3089']
# ['coalición', '0.3073']
# ['urgente', '0.3061']
# ['aspiración', '0.3059']
# ['refrendación', '0.3059']
# ['convención', '0.3058']
# ['sociedad', '0.3056']
# ['inseguridad', '0.3055']
# ['preocupación', '0.3037']
# ['autoridad', '0.3035']
# ['liberal', '0.3031']
# ['político', '0.3021']
# ['ambición', '0.3016']
# ['comunidad', '0.3011']
# ['riqueza', '0.3001']
# ['defensa', '0.2999']
# ['disuasión', '0.2992']
# ['fuerzas', '0.2984']
# ['combatiente', '0.2980']
# ['divino', '0.2979']
# ['cesar', '0.2968']
# ['profundo', '0.2946']
# ['reflexión', '0.2941']
# ['memorablemente', '0.2935']
# ['orden', '0.2935']
# ['pasión', '0.2935']
# ['oportunidad', '0.2925']
# ['beneplácito', '0.2915']
# ['legado', '0.2914']
# ['muerte', '0.2913']
# ['conclusión', '0.2907']
# ['zozobrar', '0.2904']
# ['ambiente', '0.2901']
# ['cuerdo', '0.2890']
# ['fortalecimiento', '0.2888']
# ['lucho', '0.2877']
# ['fuerzo', '0.2874']
# ['seguridad', '0.2863']
# ['protestante', '0.2854']
# ['recrudecimiento', '0.2854']
# ['promisorio', '0.2851']
# ['realidad', '0.2846']
# ['decisivo', '0.2842']
# ['autocrático', '0.2841']
# ['camino', '0.2835']
# ['enemigo', '0.2824']
# ['manifestante', '0.2824']
# ['país', '0.2823']
# ['mandatario', '0.2819']
# ['finalmente', '0.2817']
# ['desarmar', '0.2815']
# ['parlamento', '0.2815']
# ['destrucción', '0.2811']
# ['sostenibilidad', '0.2809']
# ['poder', '0.2797']
# ['debilidad', '0.2792']
# ['confusión', '0.2790']
# ['consecución', '0.2781']
# ['terrorista', '0.2778']
# ['campesino', '0.2777']
# ['santos', '0.2769']
# ['civil', '0.2766']
# ['represión', '0.2763']
# ['miserable', '0.2761']
# ['lograr', '0.2754']
# ['mandato', '0.2749']
# ['expectativa', '0.2748']
# ['territorios', '0.2748']
# ['ciudadano', '0.2746']
# ['gobiernista', '0.2738']
# ['discusión', '0.2738']
# ['familia', '0.2736']
# ['herencia', '0.2729']
# ['inquietud', '0.2722']
# ['carlos', '0.2711']
# ['condición', '0.2708']
# ['agenda', '0.2707']
# ['farc', '0.2705']
# ['diplomático', '0.2703']
# ['odio', '0.2700']
# ['barbarie', '0.2699']
# ['conversación', '0.2699']
# ['orgullo', '0.2695']
# ['reina', '0.2684']
# ['inevitablemente', '0.2681']
# ['desafortunadamente', '0.2678']
# ['negociado', '0.2675']
# ['socialista', '0.2673']
# ['protesta', '0.2663']
# ['triunfo', '0.2663']
# ['movilización', '0.2656']
# ['decisión', '0.2653']
# ['reforma', '0.2640']
# ['santo', '0.2632']
# ['contrario', '0.2630']
# ['char él', '0.2621']
# ['respetable', '0.2617']
# ['solución', '0.2612']
# ['enfrentamiento', '0.2598']
# ['acuerdo', '0.2597']
# ['propósito', '0.2595']
# ['testimonio', '0.2591']
# ['presidencia', '0.2579']
# ['razón', '0.2574']
# ['canciller', '0.2571']
# ['intención', '0.2571']
# ['económico', '0.2570']
# ['cupu él', '0.2569']
# ['cultura', '0.2567']
# ['protestar', '0.2563']
# ['absolutamente', '0.2563']
# ['integración', '0.2562']
# ['locura', '0.2558']
# ['economía', '0.2544']
# ['públicamente', '0.2544']
# ['exigencia', '0.2541']
# ['objetividad', '0.2539']
# ['enquistado', '0.2534']
# ['militar', '0.2534']
# ['situación', '0.2530']
# ['mediación', '0.2527']
# ['desear', '0.2526']
# ['delincuencia', '0.2525']
# ['duradero', '0.2523']
# ['realmente', '0.2522']
# ['crisis', '0.2517']
# ['acercamiento', '0.2514']
# ['territorio', '0.2510']
# ['alivio', '0.2508']
# ['necesidad', '0.2504']
# ['renunciar', '0.2502']
# ['ejército', '0.2500']
# ['imposibilidad', '0.2496']
# ['inteligencia', '0.2495']
# ['momento', '0.2490']
# ['prudente', '0.2487']
# ['apoyar', '0.2485']
# ['responsabilidad', '0.2483']
# ['adversario', '0.2481']
# ['territorial', '0.2479']
# ['matrimonio', '0.2466']
# ['logro', '0.2457']
# ['mensaje', '0.2454']
# ['desmotivación', '0.2450']
# ['necesariamente', '0.2450']
# ['cambio', '0.2448']
# ['indígena', '0.2446']
# ['estratégicamente', '0.2440']
# ['comunitario', '0.2434']
# ['esfuerzo', '0.2433']
# ['consternación', '0.2432']
# ['presidencial', '0.2428']
# ['cese', '0.2427']
# ['imposible', '0.2424']
# ['condena', '0.2422']
# ['palabra', '0.2417']
# ['transformación', '0.2411']
# ['aniquilado', '0.2411']
# ['sentido', '0.2407']
# ['importancia', '0.2404']
# ['gradualismo', '0.2401']
# ['venezolano', '0.2397']
# ['salud', '0.2395']
# ['inmenso', '0.2391']
# ['visión', '0.2390']
# ['institucional', '0.2387']
# ['libre', '0.2387']
# ['apoyo', '0.2386']
# ['electo', '0.2375']
# ['asimismo', '0.2372']
# ['invitación', '0.2371']
# ['universalmente', '0.2370']
# ['adopción', '0.2365']
# ['desconcertante', '0.2361']
# ['recomposición', '0.2359']
# ['nazismo', '0.2357']
# ['preservación', '0.2348']
# ['violento', '0.2341']
# ['social', '0.2339']
# ['gubernamental', '0.2339']
# ['recuerdo', '0.2338']
# ['impensable', '0.2334']
# ['desafío', '0.2334']
# ['antioquia', '0.2327']
# ['reconocimiento', '0.2325']
# ['respuesta', '0.2325']
# ['diversidad', '0.2323']
# ['históricamente', '0.2322']
# ['ciudad', '0.2321']
# ['narcotráfico', '0.2316']
# ['instigación', '0.2314']
# ['coyuntura', '0.2310']
# ['intento', '0.2302']
# ['idea', '0.2300']
# ['colombia', '0.2294']
# ['lugar', '0.2293']
# ['contundente', '0.2291']
# ['reunión', '0.2291']
# ['pactado', '0.2288']
# ['reinsertado', '0.2287']
# ['armado', '0.2285']
# ['discriminación', '0.2278']
# ['rechazo', '0.2277']
# ['advenimiento', '0.2276']
# ['derecho', '0.2275']
# ['derechos', '0.2272']
# ['impulsar', '0.2267']
# ['hombre', '0.2265']
# ['cinismo', '0.2262']
# ['angustioso', '0.2259']
# ['colombiano', '0.2256']
# ['afortunadamente', '0.2253']
# ['institución', '0.2250']
# ['tensión', '0.2249']
# ['disparidad', '0.2245']
# ['inclusión', '0.2243']
# ['estatuto', '0.2234']
# ['miedo', '0.2233']
# ['ambicioso', '0.2229']
# ['posibilidad', '0.2229']
# ['fuerte', '0.2221']
# ['optimista', '0.2220']
# ['estamento', '0.2219']
# ['sano', '0.2212']
# ['incapacidad', '0.2205']
# ['cualidad', '0.2204']
# ['igualmente', '0.2203']
# ['judío', '0.2201']
# ['inhumano', '0.2196']
# ['polarización', '0.2192']
# ['disciplina', '0.2191']
# ['corregimiento', '0.2189']
# ['latente', '0.2185']
# ['relación', '0.2181']
# ['organización', '0.2176']
# ['suficiente', '0.2175']
# ['contrapeso', '0.2174']
# ['chávez', '0.2169']
# ['desmantelamiento', '0.2167']
# ['pensión', '0.2167']
# ['discurso', '0.2167']
# ['estallido', '0.2163']
# ['contrainteligencia', '0.2160']
# ['israelí', '0.2153']
# ['mundo', '0.2149']
# ['codicia', '0.2148']
# ['deseable', '0.2146']
# ['tiempo', '0.2142']
# ['acordado', '0.2138']
# ['ley', '0.2138']
# ['régimen', '0.2127']
# ['declaración', '0.2126']
# ['estratégico', '0.2125']
# ['claramente', '0.2121']
# ['posición', '0.2120']
# ['transgresión', '0.2116']
# ['esencial', '0.2115']
# ['presente', '0.2113']
# ['saliente', '0.2107']
# ['iniciativa', '0.2102']
# ['acción', '0.2102']
# ['presidente', '0.2100']
# ['probablemente', '0.2092']
# ['multiplicidad', '0.2090']
# ['interior', '0.2090']
# ['exclusión', '0.2082']
# ['frágil', '0.2078']
# ['caucano', '0.2075']
# ['subversiva', '0.2074']
# ['formalmente', '0.2071']
# ['historia', '0.2069']
# ['ministro', '0.2063']
# ['consejo', '0.2058']
# ['determinación', '0.2056']
# ['semejante', '0.2052']
# ['consiguiente', '0.2050']
# ['importante', '0.2044']
# ['protección', '0.2041']
# ['loable', '0.2038']
# ['aprobación', '0.2037']
# ['consecuencia', '0.2035']
# ['dedicación', '0.2034']
# ['delegación', '0.2033']
# ['persona', '0.2029']
# ['medio', '0.2023']
# ['secuestrado', '0.2020']
# ['opositor', '0.2016']
# ['interno', '0.2011']
# ['fundación', '0.2009']
# ['armadas', '0.2007']
# ['implicación', '0.2005']
# ['nariño', '0.2003']
# ['ordenado', '0.1995']
# ['respaldo', '0.1995']
# ['agresión', '0.1994']
# ['preocupante', '0.1991']
# ['debilitado', '0.1988']
# ['opinión', '0.1988']
# ['secuestro', '0.1984']
# ['humano', '0.1984']
# ['cultural', '0.1983']
# ['forzar', '0.1983']
# ['delincuente', '0.1983']
# ['injusto', '0.1976']
# ['ambigüedad', '0.1976']
# ['mirada', '0.1975']
# ['avance', '0.1973']
# ['agricultura', '0.1967']
# ['elección', '0.1965']
# ['socioeconómico', '0.1938']
# ['vanguardia', '0.1938']
# ['comunicación', '0.1935']
# ['referendo', '0.1934']
# ['serio', '0.1931']
# ['sensibilidad', '0.1929']
# ['abandonado', '0.1926']
# ['manera', '0.1924']
# ['inexistencia', '0.1923']
# ['beneficio', '0.1920']
# ['necesario', '0.1914']
# ['muert', '0.1908']
# ['sumido', '0.1908']
# ['armas', '0.1907']
# ['esperado', '0.1905']
# ['región', '0.1899']
# ['segregación', '0.1897']
# ['rápidamente', '0.1893']
# ['planeación', '0.1893']
# ['población', '0.1891']
# ['militante', '0.1891']
# ['meta', '0.1886']
# ['sembrado', '0.1884']
# ['capital', '0.1879']
# ['tradicionalmente', '0.1875']
# ['único', '0.1874']
# ['influencia', '0.1873']
# ['experiencia', '0.1872']
# ['empresariado', '0.1870']
# ['común', '0.1868']
# ['participación', '0.1864']
# ['búsqueda', '0.1862']
# ['cometido', '0.1861']
# ['concesión', '0.1858']
# ['contexto', '0.1855']
# ['temporalmente', '0.1852']
# ['cosa', '0.1849']
# ['violación', '0.1848']
# ['conocimiento', '0.1848']
# ['egipto', '0.1847']
# ['desplegado', '0.1846']
# ['movimiento', '0.1840']
# ['emprendimiento', '0.1838']
# ['eln', '0.1838']
# ['claro', '0.1837']
# ['propuesta', '0.1837']
# ['atentado', '0.1834']
# ['frente', '0.1833']
# ['masacre', '0.1830']
# ['bananeras', '0.1829']
# ['cauca', '0.1829']
# ['dimensión', '0.1819']
# ['articulación', '0.1818']
# ['objetivo', '0.1817']
# ['aseguramiento', '0.1814']
# ['organizaciones', '0.1814']
# ['retroceso', '0.1811']
# ['difícil', '0.1805']
# ['marco', '0.1802']
# ['nacional', '0.1801']
# ['cumplido', '0.1798']
# ['doloroso', '0.1797']
# ['internacional', '0.1793']
# ['particularmente', '0.1792']
# ['positivo', '0.1789']
# ['totalidad', '0.1785']
# ['energía', '0.1784']
# ['alcaldías', '0.1782']
# ['estrategia', '0.1781']
# ['comienzo', '0.1781']
# ['estigmatización', '0.1778']
# ['colaboración', '0.1777']
# ['demencial', '0.1775']
# ['protagonismo', '0.1773']
# ['dicho', '0.1771']
# ['espacio', '0.1771']
# ['afrenta', '0.1769']
# ['quiebra', '0.1768']
# ['interdisciplinario', '0.1767']
# ['tremendamente', '0.1766']
# ['infinidad', '0.1762']
# ['fecho', '0.1759']
# ['trance', '0.1756']
# ['matanza', '0.1755']
# ['apresurado', '0.1751']
# ['enseñanza', '0.1751']
# ['asunto', '0.1749']
# ['disputa', '0.1748']
# ['particularidad', '0.1734']
# ['ético', '0.1731']
# ['lideresa', '0.1731']
# ['simultáneamente', '0.1731']
# ['tangible', '0.1725']
# ['medida', '0.1723']
# ['perspectivo', '0.1722']
# ['señor', '0.1722']
# ['desprecio', '0.1722']
# ['causa', '0.1720']
# ['construcción', '0.1720']
# ['innovación', '0.1719']
# ['muerto', '0.1719']
# ['atlántico', '0.1712']
# ['vigente', '0.1705']
# ['éxito', '0.1698']
# ['implementación', '0.1694']
# ['allá', '0.1685']
# ['padre', '0.1685']
# ['propuesto', '0.1680']
# ['profundidad', '0.1680']
# ['sangre', '0.1677']
# ['criminal', '0.1675']
# ['destrozado', '0.1672']
# ['retiro', '0.1671']
# ['himno', '0.1670']
# ['noticia', '0.1667']
# ['tal', '0.1666']
# ['comisión', '0.1664']
# ['campaña', '0.1662']
# ['clar', '0.1658']
# ['decreto', '0.1657']
# ['fuego', '0.1654']
# ['congresista', '0.1653']
# ['improvisación', '0.1653']
# ['escenario', '0.1652']
# ['jaramillo', '0.1652']
# ['atención', '0.1652']
# ['palabras', '0.1646']
# ['partido', '0.1646']
# ['ilegítimo', '0.1645']
# ['tajante', '0.1643']
# ['pena', '0.1639']
# ['reacción', '0.1636']
# ['flagrante', '0.1633']
# ['creciente', '0.1631']
# ['soldado', '0.1628']
# ['asistencia', '0.1628']
# ['creación', '0.1626']
# ['comisionado', '0.1624']
# ['honor', '0.1624']
# ['francisco', '0.1621']
# ['histórico', '0.1616']
# ['confuso', '0.1614']
# ['tendencia', '0.1613']
# ['dolor', '0.1611']
# ['trabajo', '0.1606']
# ['ambos', '0.1606']
# ['manso', '0.1603']
# ['efectividad', '0.1601']
# ['congreso', '0.1600']
# ['cerco', '0.1600']
# ['fumigación', '0.1594']
# ['putumayo', '0.1591']
# ['mayoritario', '0.1588']
# ['oriental', '0.1586']
# ['ocasión', '0.1585']
# ['conservador', '0.1584']
# ['significativo', '0.1581']
# ['curul', '0.1568']
# ['influyente', '0.1565']
# ['utópico', '0.1563']
# ['crecimiento', '0.1560']
# ['valioso', '0.1559']
# ['derrotado', '0.1557']
# ['querido', '0.1555']
# ['relevancia', '0.1553']
# ['alemania', '0.1550']
# ['ímpetu', '0.1547']
# ['real', '0.1545']
# ['flagelo', '0.1545']
# ['despreciable', '0.1544']
# ['mando', '0.1543']
# ['administración', '0.1533']
# ['totalmente', '0.1528']
# ['unido', '0.1525']
# ['hecho', '0.1525']
# ['presenciar', '0.1524']
# ['enrique', '0.1518']
# ['firmado', '0.1514']
# ['horripilante', '0.1513']
# ['organismo', '0.1513']
# ['correcto', '0.1508']
# ['habitante', '0.1500']
# ['urb', '0.1498']
# ['excepción', '0.1497']
# ['rumbo', '0.1497']
# ['entorno', '0.1489']
# ['ofrecimiento', '0.1488']
# ['representación', '0.1484']
# ['hijo', '0.1484']
# ['ajeno', '0.1482']
# ['dinero', '0.1480']
# ['visible', '0.1478']
# ['fruto', '0.1478']
# ['brecha', '0.1476']
# ['entrante', '0.1471']
# ['organizativo', '0.1471']
# ['recientemente', '0.1470']
# ['universo', '0.1469']
# ['extorsión', '0.1468']
# ['golpe', '0.1464']
# ['puerto', '0.1461']
# ['conducta', '0.1461']
# ['cuidado', '0.1460']
# ['reprobable', '0.1459']
# ['escudo', '0.1457']
# ['mauricio', '0.1454']
# ['uu', '0.1452']
# ['alejandro', '0.1452']
# ['argumento', '0.1452']
# ['financiación', '0.1446']
# ['élite', '0.1443']
# ['resultado', '0.1437']
# ['soñador', '0.1436']
# ['suspensión', '0.1435']
# ['laboral', '0.1435']
# ['revolcón', '0.1435']
# ['petro', '0.1434']
# ['maduro', '0.1434']
# ['inaplazable', '0.1434']
# ['inaudito', '0.1432']
# ['apropiado', '0.1429']
# ['interés', '0.1429']
# ['reyerta', '0.1428']
# ['quehacer', '0.1425']
# ['trabaje', '0.1424']
# ['prevención', '0.1423']
# ['definición', '0.1423']
# ['racista', '0.1418']
# ['fiscalía', '0.1416']
# ['proceso', '0.1416']
# ['rural', '0.1416']
# ['enfrentado', '0.1414']
# ['motivado', '0.1413']
# ['diverso', '0.1411']
# ['acto', '0.1409']
# ['explicación', '0.1408']
# ['barranquilla', '0.1408']
# ['mecanismo', '0.1403']
# ['pedagogía', '0.1396']
# ['policía', '0.1393']
# ['cautelar', '0.1393']
# ['cerrar', '0.1392']
# ['danilo', '0.1390']
# ['dudar', '0.1390']
# ['parte', '0.1387']
# ['acorralado', '0.1383']
# ['estar', '0.1380']
# ['dificultad', '0.1375']
# ['difusión', '0.1373']
# ['mesa', '0.1373']
# ['apoyado', '0.1373']
# ['víctima', '0.1372']
# ['emprendedor', '0.1370']
# ['predicción', '0.1367']
# ['vallar', '0.1367']
# ['petrolero', '0.1366']
# ['poblado', '0.1365']
# ['sustancial', '0.1363']
# ['eta', '0.1359']
# ['forzado', '0.1351']
# ['disperso', '0.1341']
# ['impulsado', '0.1337']
# ['bejarano', '0.1336']
# ['líder', '0.1335']
# ['convocado', '0.1332']
# ['ocurrencia', '0.1331']
# ['federal', '0.1328']
# ['fijación', '0.1326']
# ['empleabilidad', '0.1322']
# ['particular', '0.1322']
# ['sanción', '0.1320']
# ['duda', '0.1318']
# ['insuficiente', '0.1317']
# ['cuba', '0.1314']
# ['productivo', '0.1313']
# ['espalda', '0.1311']
# ['forzoso', '0.1304']
# ['falsedad', '0.1304']
# ['cuerpo', '0.1302']
# ['privado', '0.1299']
# ['directamente', '0.1298']
# ['iniciado', '0.1293']
# ['comunicar', '0.1292']
# ['amigo', '0.1291']
# ['formación', '0.1287']
# ['adoptado', '0.1287']
# ['inicio', '0.1286']
# ['viejo', '0.1286']
# ['municiones', '0.1284']
# ['enfático', '0.1283']
# ['regional', '0.1282']
# ['horrible', '0.1279']
# ['empleo', '0.1277']
# ['limitación', '0.1274']
# ['perpetrado', '0.1272']
# ['escobar', '0.1266']
# ['contemplado', '0.1260']
# ['adecuado', '0.1254']
# ['ojalá', '0.1251']
# ['personal', '0.1248']
# ['españa', '0.1248']
# ['reclutamiento', '0.1245']
# ['capacidad', '0.1243']
# ['reflejo', '0.1236']
# ['pasado', '0.1236']
# ['problema', '0.1234']
# ['existente', '0.1231']
# ['feroz', '0.1231']
# ['drogar', '0.1230']
# ['adicionalmente', '0.1223']
# ['especialmente', '0.1220']
# ['opción', '0.1217']
# ['inversión', '0.1214']
# ['realización', '0.1212']
# ['diferencia', '0.1212']
# ['compelido', '0.1204']
# ['empate', '0.1198']
# ['maría', '0.1197']
# ['pan', '0.1192']
# ['viaje', '0.1187']
# ['popular', '0.1187']
# ['alerta', '0.1186']
# ['sucedido', '0.1185']
# ['comentario', '0.1184']
# ['empresarial', '0.1178']
# ['vacío', '0.1178']
# ['norma', '0.1174']
# ['terreno', '0.1174']
# ['execrable', '0.1163']
# ['medellín', '0.1159']
# ['asesinato', '0.1157']
# ['mayor', '0.1156']
# ['vocero', '0.1155']
# ['entrado', '0.1155']
# ['crítico', '0.1146']
# ['evidenciado', '0.1146']
# ['incidencia', '0.1145']
# ['época', '0.1144']
# ['mañana', '0.1142']
# ['actividad', '0.1141']
# ['don', '0.1137']
# ['negativo', '0.1136']
# ['estructurar', '0.1135']
# ['reto', '0.1134']
# ['plasmada', '0.1132']
# ['acá', '0.1131']
# ['financiero', '0.1128']
# ['próximo', '0.1128']
# ['margen', '0.1121']
# ['explosión', '0.1120']
# ['responsable', '0.1118']
# ['información', '0.1113']
# ['culpa', '0.1110']
# ['forma', '0.1109']
# ['incendiado', '0.1106']
# ['problemático', '0.1100']
# ['ejecutado', '0.1099']
# ['sindicato', '0.1096']
# ['irracional', '0.1093']
# ['efectivo', '0.1089']
# ['drásticamente', '0.1088']
# ['formar', '0.1088']
# ['arma', '0.1086']
# ['alimentación', '0.1085']
# ['gaza', '0.1085']
# ['herida', '0.1083']
# ['luz', '0.1082']
# ['reactiva', '0.1076']
# ['quintero', '0.1074']
# ['actual', '0.1072']
# ['presencio', '0.1063']
# ['firma', '0.1059']
# ['clasismo', '0.1057']
# ['exministra', '0.1056']
# ['cultivo', '0.1049']
# ['propiedad', '0.1045']
# ['avatar', '0.1044']
# ['trágico', '0.1043']
# ['tradicional', '0.1039']
# ['cara', '0.1038']
# ['proyecto', '0.1032']
# ['distinto', '0.1029']
# ['activo', '0.1027']
# ['vido', '0.1022']
# ['preguntar', '0.1020']
# ['compañía', '0.1017']
# ['golfo', '0.1014']
# ['control', '0.1003']
# ['minero', '0.1002']
# ['factible', '0.1001']
# ['europa', '0.0999']
# ['grieta', '0.0998']
# ['sólido', '0.0995']
# ['ucraniano', '0.0995']
# ['demanda', '0.0991']
# ['reciente', '0.0989']
# ['público', '0.0981']
# ['desplazamiento', '0.0978']
# ['balance', '0.0971']
# ['cabeza', '0.0961']
# ['efecto', '0.0958']
# ['miranda', '0.0956']
# ['ossa', '0.0953']
# ['lutte', '0.0951']
# ['general', '0.0947']
# ['celebrado', '0.0939']
# ['cuatrienio', '0.0937']
# ['grave', '0.0935']
# ['papel', '0.0932']
# ['respectivo', '0.0931']
# ['empresario', '0.0931']
# ['vereda', '0.0929']
# ['organizado', '0.0929']
# ['deterioro', '0.0928']
# ['falta', '0.0927']
# ['bogotá', '0.0915']
# ['alcista', '0.0915']
# ['fórmula', '0.0914']
# ['ingenuo', '0.0903']
# ['ee', '0.0900']
# ['especial', '0.0896']
# ['verificación', '0.0892']
# ['campo', '0.0892']
# ['incorporación', '0.0882']
# ['clase', '0.0881']
# ['ricardo', '0.0873']
# ['complejo', '0.0872']
# ['actualmente', '0.0872']
# ['mano', '0.0871']
# ['finale', '0.0870']
# ['pensado', '0.0867']
# ['complejidades', '0.0867']
# ['interesante', '0.0862']
# ['senador', '0.0861']
# ['paro', '0.0856']
# ['gremio', '0.0854']
# ['fría', '0.0853']
# ['embrollo', '0.0850']
# ['magnitud', '0.0849']
# ['cuento', '0.0844']
# ['central', '0.0844']
# ['centro', '0.0843']
# ['pablo', '0.0840']
# ['hora', '0.0837']
# ['truncada', '0.0836']
# ['barco', '0.0831']
# ['desdén', '0.0820']
# ['aspecto', '0.0814']
# ['extremo', '0.0813']
# ['descabezado', '0.0810']
# ['ocurrido', '0.0809']
# ['plazo', '0.0809']
# ['haberla', '0.0807']
# ['sic', '0.0807']
# ['incógnita', '0.0802']
# ['gabinete', '0.0798']
# ['completo', '0.0795']
# ['siglo', '0.0792']
# ['función', '0.0791']
# ['centenar', '0.0790']
# ['relevante', '0.0784']
# ['certero', '0.0783']
# ['negocio', '0.0778']
# ['experimento', '0.0765']
# ['capaz', '0.0764']
# ['geografía', '0.0762']
# ['reconocido', '0.0761']
# ['clasificación', '0.0761']
# ['excluido', '0.0760']
# ['mediano', '0.0757']
# ['conformado', '0.0756']
# ['individual', '0.0756']
# ['complejísimo', '0.0747']
# ['servicio', '0.0744']
# ['zona', '0.0744']
# ['ejercicio', '0.0743']
# ['llamado', '0.0740']
# ['reich', '0.0739']
# ['columnista', '0.0736']
# ['pequeño', '0.0735']
# ['valle', '0.0735']
# ['criterio', '0.0733']
# ['raza', '0.0731']
# ['haber', '0.0730']
# ['sinónimo', '0.0729']
# ['excelente', '0.0728']
# ['daño', '0.0726']
# ['listo', '0.0724']
# ['carne', '0.0724']
# ['apostar', '0.0722']
# ['rendido', '0.0722']
# ['foro', '0.0721']
# ['joven', '0.0720']
# ['fácil', '0.0720']
# ['ser', '0.0716']
# ['período', '0.0715']
# ['pese', '0.0711']
# ['acento', '0.0709']
# ['juan', '0.0709']
# ['ilegal', '0.0709']
# ['sol', '0.0708']
# ['departamento', '0.0708']
# ['concepto', '0.0704']
# ['alto', '0.0701']
# ['pérdida', '0.0697']
# ['mostrar', '0.0696']
# ['anuncio', '0.0696']
# ['fondo', '0.0694']
# ['jorge', '0.0689']
# ['ataque', '0.0684']
# ['sur', '0.0681']
# ['futbolista', '0.0680']
# ['temo', '0.0680']
# ['indeseado', '0.0679']
# ['conocedor', '0.0679']
# ['punto', '0.0674']
# ['increíble', '0.0666']
# ['gustavo', '0.0666']
# ['errática', '0.0664']
# ['duración', '0.0662']
# ['ilícito', '0.0659']
# ['alzado', '0.0650']
# ['narrativo', '0.0645']
# ['protocolo', '0.0636']
# ['sistémico', '0.0624']
# ['tema', '0.0622']
# ['diario', '0.0618']
# ['plano', '0.0617']
# ['semana', '0.0612']
# ['transmisión', '0.0612']
# ['jefe', '0.0612']
# ['simple', '0.0599']
# ['reflejado', '0.0599']
# ['coordinadora', '0.0598']
# ['causado', '0.0595']
# ['dinámico', '0.0594']
# ['afectado', '0.0593']
# ['exitoso', '0.0589']
# ['tejido', '0.0587']
# ['origen', '0.0572']
# ['anterior', '0.0568']
# ['inflama', '0.0563']
# ['renta', '0.0562']
# ['gestión', '0.0559']
# ['vedado', '0.0557']
# ['amplio', '0.0557']
# ['anti', '0.0556']
# ['documentado', '0.0553']
# ['táctico', '0.0553']
# ['delito', '0.0552']
# ['enfocar', '0.0551']
# ['libro', '0.0550']
# ['dea', '0.0547']
# ['vía', '0.0547']
# ['podido', '0.0544']
# ['valor', '0.0539']
# ['catastrofista', '0.0538']
# ['prematuro', '0.0538']
# ['juego', '0.0536']
# ['marcado', '0.0535']
# ['salomon', '0.0530']
# ['asalto', '0.0520']
# ['requerida', '0.0519']
# ['fase', '0.0501']
# ['aprovechado', '0.0501']
# ['cox', '0.0497']
# ['empresa', '0.0495']
# ['oficial', '0.0494']
# ['cargo', '0.0492']
# ['cincuenta', '0.0491']
# ['máximo', '0.0485']
# ['informado', '0.0485']
# ['vivo', '0.0479']
# ['luis', '0.0472']
# ['díaz', '0.0472']
# ['principal', '0.0469']
# ['identificado', '0.0468']
# ['enmarcar', '0.0467']
# ['recurso', '0.0466']
# ['concisa', '0.0460']
# ['manuel', '0.0459']
# ['suboficial', '0.0456']
# ['equipo', '0.0456']
# ['pecho', '0.0447']
# ['parcial', '0.0443']
# ['redireccionamiento', '0.0442']
# ['punible', '0.0436']
# ['falto', '0.0428']
# ['mencionado', '0.0423']
# ['movido', '0.0421']
# ['ámbito', '0.0411']
# ['incremento', '0.0407']
# ['panorama', '0.0405']
# ['cerro', '0.0403']
# ['rápido', '0.0403']
# ['ii', '0.0401']
# ['noviembre', '0.0400']
# ['acompañado', '0.0399']
# ['escueto', '0.0398']
# ['calle', '0.0392']
# ['práctico', '0.0392']
# ['cali', '0.0392']
# ['humberto', '0.0390']
# ['factor', '0.0387']
# ['medición', '0.0381']
# ['eco', '0.0380']
# ['izquierdo', '0.0378']
# ['banda', '0.0369']
# ['cocaína', '0.0368']
# ['limitado', '0.0367']
# ['nombre', '0.0365']
# ['anunciado', '0.0362']
# ['informe', '0.0355']
# ['cantidad', '0.0353']
# ['opinador', '0.0351']
# ['polémico', '0.0345']
# ['presentación', '0.0345']
# ['tecnología', '0.0338']
# ['cicatriz', '0.0338']
# ['término', '0.0330']
# ['ayer', '0.0327']
# ['urbano', '0.0326']
# ['directriz', '0.0326']
# ['robusto', '0.0321']
# ['visto', '0.0320']
# ['mercado', '0.0316']
# ['portavoz', '0.0307']
# ['experto', '0.0306']
# ['carrera', '0.0303']
# ['agua', '0.0300']
# ['ah', '0.0296']
# ['temático', '0.0293']
# ['cáncer', '0.0292']
# ['sencillo', '0.0291']
# ['aire', '0.0290']
# ['disruptivo', '0.0289']
# ['corto', '0.0288']
# ['miembro', '0.0282']
# ['banquero', '0.0280']
# ['mayo', '0.0279']
# ['sector', '0.0267']
# ['golpeado', '0.0264']
# ['nocivo', '0.0260']
# ['eduardo', '0.0258']
# ['observatorio', '0.0257']
# ['plataforma', '0.0256']
# ['sistema', '0.0254']
# ['gana', '0.0244']
# ['ciento', '0.0239']
# ['més', '0.0225']
# ['previo', '0.0225']
# ['disímil', '0.0223']
# ['obvio', '0.0221']
# ['v', '0.0220']
# ['enero', '0.0214']
# ['cuarto', '0.0211']
# ['asesor', '0.0207']
# ['iván', '0.0206']
# ['producción', '0.0206']
# ['uniformado', '0.0200']
# ['calificado', '0.0193']
# ['octubre', '0.0191']
# ['grupo', '0.0190']
# ['gallo', '0.0187']
# ['sicarial', '0.0185']
# ['abril', '0.0180']
# ['ganadero', '0.0180']
# ['tono', '0.0179']
# ['surgen', '0.0176']
# ['contenido', '0.0160']
# ['saldo', '0.0157']
# ['niveles', '0.0148']
# ['encuesta', '0.0143']
# ['citar', '0.0143']
# ['explicado', '0.0138']
# ['titulado', '0.0130']
# ['incrementado', '0.0130']
# ['ajedrez', '0.0127']
# ['julián', '0.0123']
# ['edad', '0.0123']
# ['nivel', '0.0121']
# ['cuyo', '0.0119']
# ['mipyme', '0.0119']
# ['riesgo', '0.0116']
# ['r', '0.0109']
# ['síntoma', '0.0103']
# ['error', '0.0097']
# ['médico', '0.0094']
# ['investigador', '0.0087']
# ['salido', '0.0082']
# ['numeroso', '0.0077']
# ['acceso', '0.0069']
# ['cifra', '0.0069']
# ['remezón', '0.0064']
# ['timba', '0.0061']
# ['alemán', '0.0056']
# ['homicidio', '0.0040']
# ['rama', '0.0040']
# ['mil', '0.0030']
# ['revista', '0.0026']
# ['surtir', '0.0022']
# ['basado', '0.0020']
# ['local', '0.0019']
# ['quince', '0.0019']
# ['muestra', '0.0019']
# ['caso', '0.0017']
# ['pardo', '0.0014']
# ['navia', '0.0008']
# ['hamá', '0.0000']
# ['villavez', '0.0000']
# ['cocar', '0.0000']
# ['zelensky', '0.0000']
# ['restrepox', '0.0000']
# ['fedesarrollo', '0.0000']
# ['gaviria', '0.0000']
# ['persón', '0.0000']
# ['pérdidar', '0.0000']
# ['autodefenso', '0.0000']
# ['futuristo', '0.0000']
# ['delincuencio', '0.0000']
# ['carloscavelier', '0.0000']
# ['caminant', '0.0000']
# ['colombiar', '0.0000']
# ['materio', '0.0000']
# ['puntar', '0.0000']
# ['        ', '0.0000']
# ['justificant', '0.0000']
# ['puent', '0.0000']
# ['                   ', '0.0000']
# ['líneo', '0.0000']
# ['creg', '0.0000']
# ['romar', '0.0000']
# ['mineer', '0.0000']
# ['perniciós', '0.0000']
# ['epicentrir', '0.0000']
# ['cavelier', '0.0000']
# ['problemonón', '0.0000']
# ['semán', '0.0000']
# ['especiar', '0.0000']
# ['etcr', '0.0000']
# ['rupturo', '0.0000']
# ['lograrer', '0.0000']
# ['       ', '0.0000']
# ['cás', '0.0000']
# ['iniciativo', '0.0000']
# ['\xa0    ', '0.0000']
# ['rosmery', '0.0000']
# ['ering', '0.0000']
# ['jep', '0.0000']
# ['mipym', '0.0000']
# ['emprendedorar', '0.0000']
# ['siloé', '0.0000']
# ['displicencio', '0.0000']
# ['lentejismo', '0.0000']
# ['remanent', '0.0000']
# ['fasar', '0.0000']
# ['          ', '0.0000']
# ['caicedo', '0.0000']
# ['cúpular', '0.0000']
# ['ofrecerl', '0.0000']
# ['pachomirando', '0.0000']
# ['castropresidente', '0.0000']
# ['indepaz', '0.0000']
# ['acopi', '0.0000']
# ['firmezar', '0.0000']
# ['lés', '0.0000']
# ['asonado', '0.0000']
# ['  ', '0.0000']
# ['viviendir', '0.0000']
# ['mentoer', '0.0000']
# ['sorpresar', '0.0000']
# ['              ', '0.0000']
# ['masacr', '0.0000']
# ['konrad', '0.0000']
# ['                  ', '0.0000']
# ['      ', '0.0000']
# ['eleno', '0.0000']
# ['comandant', '0.0000']
# ['     ', '0.0000']
# ['clás', '0.0000']
# ['prudenciir', '0.0000']
# ['ausencio', '0.0000']
# ['caucar', '0.0000']
# ['caquetá', '0.0000']
# ['violencio', '0.0000']
# ['charl', '0.0000']
# ['catatumbir', '0.0000']
# ['violenciir', '0.0000']
# ['expectativo', '0.0000']
# ['invamer', '0.0000']
# ['aerolíneo', '0.0000']
# ['diangcotep', '0.0000']
# ['agendo', '0.0000']
# ['                    ', '0.0000']
# ['shoá', '0.0000']
# ['seuss', '0.0000']
# ['misericordiar', '0.0000']
# ['             ', '0.0000']
# ['petrir', '0.0000']
# ['consecuencio', '0.0000']
# ['repúblico', '0.0000']
# ['rutar', '0.0000']
# ['    ', '0.0000']
# ['episodar', '0.0000']
# ['bucaramanguir', '0.0000']
# ['habán', '0.0000']
# ['simultánear', '0.0000']
# ['malcolm', '0.0000']
# ['kassin', '0.0000']
# ['tierraltar', '0.0000']
# ['           ', '0.0000']
# ['industrio', '0.0000']
# ['epl', '0.0000']
# ['cadén', '0.0000']
# ['guerro', '0.0000']
# ['emergenciar', '0.0000']
# ['            ', '0.0000']
# ['confianzar', '0.0000']
# ['ápizar', '0.0000']
# ['         ', '0.0000']
# ['adenauer', '0.0000']
# ['hamás', '0.0000']
# ['tendient', '0.0000']
# ['memorio', '0.0000']
# ['drasticidad', '0.0000']
# ['himlers', '0.0000']
# ['alcald', '0.0000']
# ['santamaríaanalista', '0.0000']
# ['propacífico', '0.0000']
# ['sabiduer', '0.0000']
# ['turbaco', '0.0000']
# ['destacado', '-0.0002']
# ['exceso', '-0.0013']
# ['sábado', '-0.0026']
# ['asociado', '-0.0028']
# ['simultáneo', '-0.0032']
# ['yahoo', '-0.0033']
# ['lunes', '-0.0034']
# ['procesado', '-0.0036']
# ['programa', '-0.0037']
# ['remoto', '-0.0039']
# ['agudo', '-0.0039']
# ['estadística', '-0.0042']
# ['oslo', '-0.0047']
# ['consultor', '-0.0050']
# ['g', '-0.0064']
# ['columnar', '-0.0065']
# ['variopinto', '-0.0068']
# ['ginebra', '-0.0069']
# ['formador', '-0.0091']
# ['frenazo', '-0.0097']
# ['incendio', '-0.0099']
# ['tercerizado', '-0.0104']
# ['rasgo', '-0.0108']
# ['emc', '-0.0113']
# ['actor', '-0.0120']
# ['adicional', '-0.0125']
# ['motor', '-0.0145']
# ['serie', '-0.0149']
# ['monitoreo', '-0.0166']
# ['menor', '-0.0168']
# ['básico', '-0.0172']
# ['exdirector', '-0.0191']
# ['presentado', '-0.0197']
# ['p', '-0.0200']
# ['abanico', '-0.0201']
# ['exponencial', '-0.0206']
# ['año', '-0.0211']
# ['usuario', '-0.0220']
# ['indicador', '-0.0235']
# ['dr', '-0.0243']
# ['modelo', '-0.0244']
# ['episodio', '-0.0247']
# ['tasa', '-0.0279']
# ['hectárea', '-0.0281']
# ['art', '-0.0299']
# ['acumulado', '-0.0313']
# ['curso', '-0.0317']
# ['consumo', '-0.0319']
# ['digital', '-0.0333']
# ['twittero', '-0.0338']
# ['cote', '-0.0341']
# ['gmail', '-0.0362']
# ['juegos', '-0.0365']
# ['laxa', '-0.0380']
# ['mes', '-0.0395']
# ['grueso', '-0.0399']
# ['plateado', '-0.0418']
# ['técnico', '-0.0427']
# ['manejo', '-0.0452']
# ['registrado', '-0.0453']
# ['director', '-0.0455']
# ['reducido', '-0.0465']
# ['incluido', '-0.0467']
# ['similar', '-0.0492']
# ['análisis', '-0.0492']
# ['área', '-0.0505']
# ['mea', '-0.0515']
# ['peña', '-0.0527']
# ['com', '-0.0527']
# ['ultra', '-0.0531']
# ['líneas', '-0.0534']
# ['línea', '-0.0544']
# ['gestor', '-0.0562']
# ['tarifa', '-0.0568']
# ['empalmes', '-0.0569']
# ['mordisco', '-0.0572']
# ['infantil', '-0.0588']
# ['estudio', '-0.0592']
# ['elaborado', '-0.0610']
# ['air', '-0.0625']
# ['analizado', '-0.0634']
# ['introducido', '-0.0635']
# ['er', '-0.0700']
# ['h', '-0.0710']
# ['s', '-0.0719']
# ['x', '-0.0722']
# ['portafolio', '-0.0736']
# ['pizarro', '-0.0740']
# ['agrupado', '-0.0755']
# ['famoso', '-0.0773']
# ['flojo', '-0.0790']
# ['m', '-0.0806']
# ['apliqué', '-0.0814']
# ['ojo', '-0.0826']
# ['tipo', '-0.0836']
# ['doble', '-0.0880']
# ['ángulo', '-0.0908']
# ['guapi', '-0.0932']
# ['robo', '-0.0980']
# ['múltiple', '-0.1072']
# ['panel', '-0.1170']
# ['micro', '-0.1207']
# ['hurto', '-0.1252']

# %%
# Generar una nube de palabras
word_freq = {palabra: float(similitud) for palabra, similitud in palabras_similares}

wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(word_freq)

# Mostrar la nube de palabras
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
# Define la palabra objetivo
palabra_objetivo = 'guerra'

# Aplanar el corpus a una sola lista de palabras y eliminar duplicados
palabras_corpus = list(set([palabra for sublist in contenido_lemas for palabra in sublist]))

# Procesar la palabra objetivo con el modelo spaCy
doc_objetivo = nlp(palabra_objetivo)

# Encuentra palabras similares a la palabra objetivo en el corpus definido
palabras_similares = []

# Calcular la similitud entre la palabra objetivo y cada palabra del corpus
for palabra in palabras_corpus:
    doc_p = nlp(palabra)
    similitud = doc_objetivo.similarity(doc_p)
    palabras_similares.append((palabra, similitud))

# Ordenar las palabras por similitud en orden descendente
palabras_similares = sorted(palabras_similares, key=lambda item: -item[1])

# Preparar los datos para escribir en el archivo CSV
contenido_lemas_csv = [['Palabra', 'Similitud']]  # Encabezados del CSV
for palabra, similitud in palabras_similares:  
    contenido_lemas_csv.append([palabra, f"{similitud:.4f}"])

# Escribir los datos en un nuevo archivo CSV
with open('similitud_guerra_portafolio.csv', 'w', newline='', encoding='utf-8-sig') as archivo:
    escritor_csv = csv.writer(archivo)
    escritor_csv.writerows(contenido_lemas_csv)

# Leer y mostrar el contenido del archivo CSV
with open('similitud_guerra_portafolio.csv', 'r', newline='', encoding='utf-8-sig') as archivo:
    lector_csv = csv.reader(archivo)
    for fila in lector_csv:
        print(fila)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_41484\58168021.py:16: UserWarning: [W008] Evaluating Doc.similarity based on empty vectors.
#   similitud = doc_objetivo.similarity(doc_p)
# ['Palabra', 'Similitud']
# ['guerra', '1.0000']
# ['guerrilla', '0.6411']
# ['conflicto', '0.6187']
# ['lucha', '0.6163']
# ['represión', '0.6102']
# ['combatiente', '0.5914']
# ['militar', '0.5857']
# ['insurgente', '0.5835']
# ['excombatiente', '0.5763']
# ['enfrentamiento', '0.5725']
# ['confrontación', '0.5670']
# ['nazismo', '0.5607']
# ['destrucción', '0.5607']
# ['hostilidad', '0.5599']
# ['ejército', '0.5574']
# ['nación', '0.5343']
# ['matanza', '0.5334']
# ['guerrillero', '0.5326']
# ['crisis', '0.5313']
# ['masacre', '0.5308']
# ['liberación', '0.5298']
# ['agresión', '0.5125']
# ['terrorista', '0.5070']
# ['república', '0.5020']
# ['disidencia', '0.4999']
# ['violencia', '0.4987']
# ['desmovilización', '0.4985']
# ['protestante', '0.4978']
# ['paramilitar', '0.4969']
# ['muerte', '0.4843']
# ['política', '0.4823']
# ['humanidad', '0.4780']
# ['democracia', '0.4741']
# ['explosión', '0.4712']
# ['coalición', '0.4704']
# ['campaña', '0.4678']
# ['gobiernista', '0.4640']
# ['enemigo', '0.4611']
# ['recrudecimiento', '0.4591']
# ['gobernante', '0.4576']
# ['historia', '0.4567']
# ['defensa', '0.4564']
# ['ambición', '0.4553']
# ['disuasión', '0.4549']
# ['estallido', '0.4541']
# ['armadas', '0.4520']
# ['época', '0.4492']
# ['desmovilizada', '0.4478']
# ['confusión', '0.4475']
# ['contrainteligencia', '0.4443']
# ['delincuencia', '0.4438']
# ['históricamente', '0.4434']
# ['patria', '0.4432']
# ['transición', '0.4425']
# ['postconflicto', '0.4415']
# ['alemania', '0.4414']
# ['barbarie', '0.4408']
# ['instigación', '0.4399']
# ['movilización', '0.4397']
# ['convención', '0.4390']
# ['luchar', '0.4387']
# ['fuerza', '0.4376']
# ['consternación', '0.4362']
# ['fuerzas', '0.4356']
# ['influencia', '0.4354']
# ['protesta', '0.4326']
# ['violento', '0.4288']
# ['fortaleza', '0.4279']
# ['gobierno', '0.4276']
# ['socialismo', '0.4272']
# ['territorios', '0.4269']
# ['democráticamente', '0.4253']
# ['enquistado', '0.4234']
# ['ataque', '0.4219']
# ['liberal', '0.4217']
# ['reacción', '0.4214']
# ['afrenta', '0.4212']
# ['transgresión', '0.4206']
# ['finalmente', '0.4198']
# ['situación', '0.4194']
# ['consecuencia', '0.4182']
# ['acción', '0.4181']
# ['sufrimiento', '0.4173']
# ['desarme', '0.4165']
# ['herencia', '0.4123']
# ['desmovilizado', '0.4112']
# ['paz', '0.4110']
# ['debilidad', '0.4108']
# ['inevitablemente', '0.4087']
# ['religión', '0.4079']
# ['soldado', '0.4074']
# ['causa', '0.4073']
# ['sociedad', '0.4070']
# ['armas', '0.4064']
# ['político', '0.4060']
# ['población', '0.4056']
# ['violación', '0.4052']
# ['criminal', '0.4044']
# ['reyerta', '0.4024']
# ['discusión', '0.4005']
# ['desafortunadamente', '0.4002']
# ['polarización', '0.3986']
# ['armado', '0.3973']
# ['palestino', '0.3969']
# ['convicción', '0.3965']
# ['memorablemente', '0.3958']
# ['advenimiento', '0.3951']
# ['militante', '0.3945']
# ['manifestante', '0.3931']
# ['inteligencia', '0.3929']
# ['segregación', '0.3925']
# ['temporalmente', '0.3901']
# ['asalto', '0.3898']
# ['desmantelamiento', '0.3885']
# ['israel', '0.3881']
# ['narcotráfico', '0.3880']
# ['territorio', '0.3876']
# ['públicamente', '0.3876']
# ['disparidad', '0.3872']
# ['economía', '0.3866']
# ['complicidad', '0.3866']
# ['preocupación', '0.3855']
# ['gobernado', '0.3849']
# ['particularmente', '0.3848']
# ['atentado', '0.3840']
# ['presidencia', '0.3835']
# ['probablemente', '0.3832']
# ['subversiva', '0.3820']
# ['lucho', '0.3818']
# ['conversación', '0.3818']
# ['diplomático', '0.3818']
# ['erradicación', '0.3812']
# ['civil', '0.3808']
# ['gubernamental', '0.3788']
# ['protestar', '0.3778']
# ['coyuntura', '0.3764']
# ['disputa', '0.3760']
# ['discriminación', '0.3746']
# ['aniquilado', '0.3745']
# ['nuevamente', '0.3744']
# ['legitimidad', '0.3736']
# ['construcción', '0.3732']
# ['autocrático', '0.3731']
# ['estigmatización', '0.3724']
# ['trascendencia', '0.3716']
# ['asesinato', '0.3715']
# ['esperanza', '0.3714']
# ['derrotado', '0.3697']
# ['socialista', '0.3697']
# ['movimiento', '0.3696']
# ['negociación', '0.3693']
# ['justicia', '0.3690']
# ['realidad', '0.3681']
# ['reclutamiento', '0.3676']
# ['condena', '0.3664']
# ['humanitario', '0.3650']
# ['vida', '0.3631']
# ['racista', '0.3631']
# ['condición', '0.3620']
# ['secuestro', '0.3612']
# ['región', '0.3610']
# ['estratégicamente', '0.3610']
# ['fundación', '0.3595']
# ['consecución', '0.3593']
# ['gobernabilidad', '0.3585']
# ['formalmente', '0.3583']
# ['tradicionalmente', '0.3582']
# ['municiones', '0.3575']
# ['tendencia', '0.3570']
# ['creciente', '0.3563']
# ['tensión', '0.3562']
# ['autoridad', '0.3547']
# ['campesino', '0.3541']
# ['secuestrado', '0.3534']
# ['incendiado', '0.3525']
# ['extorsión', '0.3524']
# ['drásticamente', '0.3522']
# ['desigualdad', '0.3521']
# ['conservador', '0.3517']
# ['rápidamente', '0.3514']
# ['democrático', '0.3509']
# ['gradualismo', '0.3504']
# ['aspiración', '0.3497']
# ['recientemente', '0.3493']
# ['relación', '0.3485']
# ['claramente', '0.3471']
# ['libertad', '0.3462']
# ['fuerzo', '0.3460']
# ['declaración', '0.3460']
# ['régimen', '0.3457']
# ['inseguridad', '0.3457']
# ['conclusión', '0.3451']
# ['recomposición', '0.3451']
# ['excepción', '0.3444']
# ['frente', '0.3442']
# ['delincuente', '0.3437']
# ['intento', '0.3426']
# ['feroz', '0.3423']
# ['enfrentado', '0.3410']
# ['agricultura', '0.3400']
# ['afortunadamente', '0.3396']
# ['igualmente', '0.3391']
# ['transformación', '0.3389']
# ['influyente', '0.3382']
# ['organización', '0.3377']
# ['ocurrencia', '0.3372']
# ['desarmar', '0.3369']
# ['mediación', '0.3360']
# ['territorial', '0.3356']
# ['posición', '0.3348']
# ['siglo', '0.3348']
# ['israelí', '0.3344']
# ['contrapeso', '0.3343']
# ['ciudad', '0.3336']
# ['cinismo', '0.3334']
# ['determinación', '0.3331']
# ['fumigación', '0.3326']
# ['debilitado', '0.3323']
# ['catastrofista', '0.3310']
# ['absolutamente', '0.3306']
# ['golpe', '0.3304']
# ['tolerancia', '0.3298']
# ['universalmente', '0.3283']
# ['contrario', '0.3280']
# ['oriental', '0.3273']
# ['clasismo', '0.3269']
# ['inexistencia', '0.3259']
# ['parlamento', '0.3259']
# ['simultáneamente', '0.3252']
# ['administración', '0.3250']
# ['perpetrado', '0.3248']
# ['policía', '0.3233']
# ['intención', '0.3231']
# ['concesión', '0.3229']
# ['capital', '0.3226']
# ['desmotivación', '0.3225']
# ['voluntad', '0.3214']
# ['fuego', '0.3213']
# ['especialmente', '0.3211']
# ['predicción', '0.3208']
# ['decisión', '0.3203']
# ['muert', '0.3195']
# ['miserable', '0.3192']
# ['adversario', '0.3189']
# ['exclusión', '0.3157']
# ['clase', '0.3149']
# ['horripilante', '0.3134']
# ['arma', '0.3130']
# ['estrategia', '0.3108']
# ['cristo', '0.3104']
# ['estabilidad', '0.3104']
# ['imposibilidad', '0.3098']
# ['inhumano', '0.3098']
# ['desplegado', '0.3093']
# ['cultura', '0.3093']
# ['abandonado', '0.3092']
# ['contundente', '0.3087']
# ['elección', '0.3079']
# ['élite', '0.3077']
# ['venezuela', '0.3072']
# ['odio', '0.3069']
# ['comunidad', '0.3060']
# ['mandato', '0.3056']
# ['incendio', '0.3052']
# ['creación', '0.3048']
# ['locura', '0.3046']
# ['reforma', '0.3039']
# ['visión', '0.3037']
# ['irracional', '0.3033']
# ['desconcertante', '0.3028']
# ['petrolero', '0.3024']
# ['incidencia', '0.3016']
# ['europa', '0.3013']
# ['producción', '0.3013']
# ['país', '0.3012']
# ['institución', '0.3010']
# ['despreciable', '0.3004']
# ['representación', '0.3002']
# ['egipto', '0.2999']
# ['experimento', '0.2991']
# ['ciudadanía', '0.2989']
# ['fuerte', '0.2981']
# ['incapacidad', '0.2979']
# ['adopción', '0.2977']
# ['estamento', '0.2976']
# ['codicia', '0.2975']
# ['tremendamente', '0.2969']
# ['mando', '0.2967']
# ['vanguardia', '0.2963']
# ['consiguiente', '0.2960']
# ['corregimiento', '0.2959']
# ['discurso', '0.2956']
# ['protección', '0.2955']
# ['demencial', '0.2954']
# ['judío', '0.2937']
# ['necesariamente', '0.2928']
# ['latente', '0.2926']
# ['responsabilidad', '0.2925']
# ['definición', '0.2923']
# ['sangre', '0.2908']
# ['desplazamiento', '0.2905']
# ['explicación', '0.2901']
# ['ucraniano', '0.2894']
# ['delegación', '0.2893']
# ['implicación', '0.2890']
# ['cincuenta', '0.2889']
# ['retroceso', '0.2884']
# ['españa', '0.2880']
# ['impensable', '0.2870']
# ['presidencial', '0.2868']
# ['víctima', '0.2867']
# ['bananeras', '0.2864']
# ['marchar', '0.2864']
# ['asimismo', '0.2857']
# ['parte', '0.2856']
# ['exigencia', '0.2853']
# ['integración', '0.2849']
# ['improvisación', '0.2847']
# ['destrozado', '0.2841']
# ['diferencia', '0.2841']
# ['carrera', '0.2841']
# ['quiebra', '0.2841']
# ['económico', '0.2840']
# ['infinidad', '0.2835']
# ['comunicación', '0.2834']
# ['mundo', '0.2833']
# ['pasión', '0.2820']
# ['acercamiento', '0.2818']
# ['totalmente', '0.2808']
# ['atlántico', '0.2788']
# ['totalidad', '0.2787']
# ['ambigüedad', '0.2787']
# ['semejante', '0.2786']
# ['sacrificio', '0.2777']
# ['actividad', '0.2773']
# ['particularidad', '0.2768']
# ['presidente', '0.2766']
# ['importancia', '0.2765']
# ['matrimonio', '0.2760']
# ['limitación', '0.2751']
# ['demanda', '0.2749']
# ['argumento', '0.2746']
# ['realmente', '0.2744']
# ['período', '0.2743']
# ['multiplicidad', '0.2732']
# ['reconocimiento', '0.2731']
# ['histórico', '0.2729']
# ['familia', '0.2728']
# ['geografía', '0.2728']
# ['decisivo', '0.2727']
# ['muerto', '0.2721']
# ['internacional', '0.2719']
# ['preservación', '0.2715']
# ['raza', '0.2714']
# ['paciencia', '0.2713']
# ['protagonismo', '0.2706']
# ['problemático', '0.2702']
# ['reina', '0.2702']
# ['buenaventura', '0.2687']
# ['contexto', '0.2682']
# ['descabezado', '0.2664']
# ['ocasión', '0.2664']
# ['razón', '0.2658']
# ['pérdida', '0.2656']
# ['errática', '0.2654']
# ['trágico', '0.2649']
# ['alemán', '0.2648']
# ['rechazo', '0.2645']
# ['preocupante', '0.2643']
# ['dimensión', '0.2643']
# ['riqueza', '0.2642']
# ['flagrante', '0.2640']
# ['partido', '0.2639']
# ['nacional', '0.2633']
# ['reciente', '0.2631']
# ['cerco', '0.2628']
# ['disciplina', '0.2624']
# ['financiación', '0.2622']
# ['falsedad', '0.2615']
# ['participación', '0.2615']
# ['avance', '0.2612']
# ['organizaciones', '0.2601']
# ['brecha', '0.2598']
# ['actualmente', '0.2594']
# ['orden', '0.2593']
# ['columnista', '0.2592']
# ['serie', '0.2592']
# ['estratégico', '0.2590']
# ['existente', '0.2578']
# ['negociado', '0.2572']
# ['objetividad', '0.2570']
# ['relevancia', '0.2570']
# ['cesar', '0.2565']
# ['clasificación', '0.2560']
# ['articulación', '0.2559']
# ['sanción', '0.2556']
# ['congresista', '0.2554']
# ['búsqueda', '0.2551']
# ['adicionalmente', '0.2548']
# ['cometido', '0.2543']
# ['origen', '0.2542']
# ['indígena', '0.2538']
# ['ilegítimo', '0.2534']
# ['insuficiente', '0.2527']
# ['tranquilidad', '0.2518']
# ['causado', '0.2517']
# ['formación', '0.2510']
# ['planeación', '0.2506']
# ['forzado', '0.2505']
# ['aprobación', '0.2499']
# ['directamente', '0.2497']
# ['control', '0.2493']
# ['legado', '0.2475']
# ['ilegal', '0.2472']
# ['solución', '0.2470']
# ['negociador', '0.2469']
# ['medición', '0.2461']
# ['pensión', '0.2459']
# ['forzoso', '0.2454']
# ['execrable', '0.2454']
# ['poder', '0.2453']
# ['ilusión', '0.2450']
# ['prioridad', '0.2446']
# ['particular', '0.2446']
# ['conducta', '0.2441']
# ['cualidad', '0.2439']
# ['refrendación', '0.2429']
# ['fijación', '0.2428']
# ['ciudadano', '0.2426']
# ['renunciar', '0.2426']
# ['medida', '0.2426']
# ['necesidad', '0.2423']
# ['posibilidad', '0.2420']
# ['grieta', '0.2420']
# ['trance', '0.2417']
# ['seguridad', '0.2416']
# ['general', '0.2411']
# ['poblado', '0.2405']
# ['tiempo', '0.2402']
# ['consenso', '0.2401']
# ['respuesta', '0.2401']
# ['difusión', '0.2400']
# ['popular', '0.2397']
# ['reunión', '0.2393']
# ['mandatario', '0.2388']
# ['presenciar', '0.2388']
# ['interno', '0.2387']
# ['momento', '0.2385']
# ['crítico', '0.2385']
# ['glorioso', '0.2381']
# ['escenario', '0.2376']
# ['hombre', '0.2359']
# ['compañía', '0.2358']
# ['profundidad', '0.2356']
# ['inclusión', '0.2354']
# ['desafío', '0.2348']
# ['evidenciado', '0.2347']
# ['imposible', '0.2334']
# ['cambio', '0.2327']
# ['fortalecimiento', '0.2324']
# ['experiencia', '0.2313']
# ['significativo', '0.2312']
# ['atención', '0.2310']
# ['sucedido', '0.2305']
# ['confuso', '0.2297']
# ['prudente', '0.2296']
# ['dedicación', '0.2295']
# ['oportunidad', '0.2294']
# ['incorporación', '0.2290']
# ['implementación', '0.2285']
# ['terreno', '0.2282']
# ['crecimiento', '0.2276']
# ['testimonio', '0.2270']
# ['ocurrido', '0.2261']
# ['ambos', '0.2257']
# ['escudo', '0.2248']
# ['institucional', '0.2246']
# ['urgente', '0.2244']
# ['iniciativa', '0.2242']
# ['deterioro', '0.2242']
# ['desprecio', '0.2240']
# ['interior', '0.2240']
# ['propiedad', '0.2231']
# ['proceso', '0.2226']
# ['fase', '0.2222']
# ['sensibilidad', '0.2221']
# ['diversidad', '0.2219']
# ['duración', '0.2214']
# ['interés', '0.2211']
# ['confianza', '0.2208']
# ['transmisión', '0.2204']
# ['ministro', '0.2202']
# ['asistencia', '0.2202']
# ['prevención', '0.2190']
# ['realización', '0.2189']
# ['comisión', '0.2186']
# ['apresurado', '0.2181']
# ['ejecutado', '0.2178']
# ['inversión', '0.2177']
# ['colaboración', '0.2168']
# ['acorralado', '0.2159']
# ['mirada', '0.2155']
# ['profundo', '0.2151']
# ['expectativa', '0.2150']
# ['extremo', '0.2149']
# ['canciller', '0.2148']
# ['padre', '0.2146']
# ['respetable', '0.2145']
# ['reprobable', '0.2145']
# ['saliente', '0.2143']
# ['asunto', '0.2138']
# ['mayoritario', '0.2136']
# ['alimentación', '0.2135']
# ['sur', '0.2132']
# ['palabra', '0.2130']
# ['inmenso', '0.2129']
# ['suspensión', '0.2127']
# ['zozobrar', '0.2125']
# ['derechos', '0.2123']
# ['opositor', '0.2122']
# ['socioeconómico', '0.2122']
# ['manera', '0.2118']
# ['tajante', '0.2118']
# ['sostenibilidad', '0.2114']
# ['efectividad', '0.2111']
# ['sustancial', '0.2110']
# ['herida', '0.2109']
# ['táctico', '0.2109']
# ['cuerdo', '0.2106']
# ['presente', '0.2105']
# ['triunfo', '0.2105']
# ['anti', '0.2104']
# ['perspectivo', '0.2101']
# ['conocimiento', '0.2099']
# ['tradicional', '0.2098']
# ['estructurar', '0.2092']
# ['cultural', '0.2088']
# ['sembrado', '0.2084']
# ['cultivo', '0.2079']
# ['polémico', '0.2079']
# ['reflexión', '0.2078']
# ['social', '0.2077']
# ['adoptado', '0.2073']
# ['antioquia', '0.2065']
# ['ambicioso', '0.2059']
# ['miedo', '0.2057']
# ['petro', '0.2052']
# ['grave', '0.2047']
# ['opinión', '0.2046']
# ['importante', '0.2046']
# ['suficiente', '0.2038']
# ['comisionado', '0.2030']
# ['magnitud', '0.2029']
# ['referendo', '0.2026']
# ['farc', '0.2023']
# ['habitante', '0.2022']
# ['venezolano', '0.2019']
# ['electo', '0.2018']
# ['vigente', '0.2002']
# ['esperado', '0.1995']
# ['comienzo', '0.1992']
# ['financiero', '0.1985']
# ['empresariado', '0.1985']
# ['problema', '0.1982']
# ['resultado', '0.1979']
# ['honestidad', '0.1978']
# ['disperso', '0.1978']
# ['complejidades', '0.1975']
# ['reich', '0.1967']
# ['ofrecimiento', '0.1967']
# ['central', '0.1965']
# ['aseguramiento', '0.1962']
# ['apoyar', '0.1961']
# ['golfo', '0.1954']
# ['puerto', '0.1947']
# ['flagelo', '0.1947']
# ['ambiente', '0.1946']
# ['emprendimiento', '0.1945']
# ['camino', '0.1940']
# ['minero', '0.1939']
# ['zona', '0.1939']
# ['estadística', '0.1939']
# ['ley', '0.1937']
# ['reactiva', '0.1937']
# ['francisco', '0.1931']
# ['medio', '0.1931']
# ['idea', '0.1923']
# ['culpa', '0.1920']
# ['inquietud', '0.1917']
# ['derecho', '0.1908']
# ['centenar', '0.1903']
# ['éxito', '0.1893']
# ['energía', '0.1885']
# ['enseñanza', '0.1884']
# ['innovación', '0.1879']
# ['noticia', '0.1878']
# ['invitación', '0.1875']
# ['presentación', '0.1873']
# ['eta', '0.1868']
# ['actual', '0.1868']
# ['hecho', '0.1865']
# ['angustioso', '0.1863']
# ['colombiano', '0.1854']
# ['documentado', '0.1853']
# ['suboficial', '0.1849']
# ['tecnología', '0.1849']
# ['humano', '0.1845']
# ['principal', '0.1838']
# ['compelido', '0.1830']
# ['esfuerzo', '0.1829']
# ['ilícito', '0.1824']
# ['mencionado', '0.1822']
# ['organismo', '0.1820']
# ['universo', '0.1815']
# ['viaje', '0.1812']
# ['espalda', '0.1801']
# ['revolcón', '0.1801']
# ['dificultad', '0.1795']
# ['injusto', '0.1793']
# ['pasado', '0.1791']
# ['apoyo', '0.1791']
# ['líder', '0.1790']
# ['colombia', '0.1789']
# ['rama', '0.1782']
# ['campo', '0.1782']
# ['horrible', '0.1779']
# ['capacidad', '0.1778']
# ['afectado', '0.1777']
# ['chávez', '0.1777']
# ['negativo', '0.1769']
# ['verificación', '0.1768']
# ['alerta', '0.1768']
# ['futuro', '0.1766']
# ['forma', '0.1765']
# ['reconocido', '0.1764']
# ['diálogo', '0.1760']
# ['fiscalía', '0.1760']
# ['función', '0.1756']
# ['cantidad', '0.1756']
# ['ordenado', '0.1749']
# ['daño', '0.1736']
# ['acuerdo', '0.1735']
# ['acto', '0.1734']
# ['cabeza', '0.1734']
# ['mecanismo', '0.1732']
# ['complejo', '0.1730']
# ['persona', '0.1728']
# ['sumido', '0.1718']
# ['complejísimo', '0.1717']
# ['federal', '0.1715']
# ['información', '0.1714']
# ['línea', '0.1706']
# ['esencial', '0.1706']
# ['propuesta', '0.1700']
# ['gaza', '0.1699']
# ['inaudito', '0.1698']
# ['santos', '0.1696']
# ['difícil', '0.1694']
# ['homicidio', '0.1693']
# ['estatuto', '0.1692']
# ['visible', '0.1683']
# ['char él', '0.1683']
# ['mercado', '0.1672']
# ['narrativo', '0.1671']
# ['activo', '0.1671']
# ['sentido', '0.1669']
# ['interdisciplinario', '0.1669']
# ['relevante', '0.1664']
# ['procesado', '0.1662']
# ['semana', '0.1660']
# ['uniformado', '0.1660']
# ['empresario', '0.1658']
# ['propósito', '0.1654']
# ['maría', '0.1650']
# ['alcista', '0.1646']
# ['presencio', '0.1645']
# ['congreso', '0.1644']
# ['cáncer', '0.1640']
# ['retiro', '0.1631']
# ['impulsado', '0.1629']
# ['banda', '0.1626']
# ['carlos', '0.1625']
# ['golpeado', '0.1620']
# ['apoyado', '0.1617']
# ['forzar', '0.1613']
# ['opción', '0.1613']
# ['incremento', '0.1611']
# ['haber', '0.1610']
# ['recuerdo', '0.1606']
# ['dudar', '0.1605']
# ['cupu él', '0.1604']
# ['incrementado', '0.1604']
# ['embrollo', '0.1602']
# ['barco', '0.1602']
# ['cosa', '0.1601']
# ['sagrado', '0.1595']
# ['identificado', '0.1592']
# ['mayor', '0.1587']
# ['formar', '0.1584']
# ['fe', '0.1582']
# ['alejandro', '0.1573']
# ['carne', '0.1569']
# ['caucano', '0.1563']
# ['responsable', '0.1560']
# ['común', '0.1557']
# ['empleabilidad', '0.1554']
# ['gestión', '0.1553']
# ['investigador', '0.1551']
# ['efecto', '0.1551']
# ['compromiso', '0.1547']
# ['corazón', '0.1543']
# ['entrado', '0.1542']
# ['reinsertado', '0.1538']
# ['rendido', '0.1533']
# ['cuba', '0.1529']
# ['drogar', '0.1529']
# ['calma', '0.1522']
# ['real', '0.1520']
# ['contemplado', '0.1516']
# ['entrante', '0.1515']
# ['ingenuo', '0.1506']
# ['cuatrienio', '0.1501']
# ['tal', '0.1499']
# ['oficial', '0.1496']
# ['numeroso', '0.1495']
# ['delito', '0.1495']
# ['encuesta', '0.1494']
# ['fecho', '0.1489']
# ['lograr', '0.1489']
# ['eln', '0.1486']
# ['izquierdo', '0.1479']
# ['diverso', '0.1475']
# ['mano', '0.1467']
# ['enfático', '0.1466']
# ['doloroso', '0.1455']
# ['edad', '0.1450']
# ['exponencial', '0.1444']
# ['respeto', '0.1438']
# ['iniciado', '0.1436']
# ['cocaína', '0.1429']
# ['dinero', '0.1425']
# ['limitado', '0.1425']
# ['ético', '0.1412']
# ['citar', '0.1407']
# ['inicio', '0.1406']
# ['comunitario', '0.1402']
# ['pese', '0.1399']
# ['banquero', '0.1393']
# ['decreto', '0.1389']
# ['optimista', '0.1383']
# ['propuesto', '0.1379']
# ['pactado', '0.1369']
# ['regional', '0.1368']
# ['público', '0.1366']
# ['consumo', '0.1363']
# ['dolor', '0.1363']
# ['serio', '0.1356']
# ['deseable', '0.1355']
# ['recurso', '0.1342']
# ['agenda', '0.1340']
# ['acento', '0.1338']
# ['término', '0.1337']
# ['certeza', '0.1334']
# ['juego', '0.1332']
# ['ímpetu', '0.1332']
# ['senador', '0.1323']
# ['ser', '0.1319']
# ['utópico', '0.1315']
# ['redireccionamiento', '0.1307']
# ['promisorio', '0.1304']
# ['cese', '0.1299']
# ['renta', '0.1295']
# ['norma', '0.1293']
# ['ciento', '0.1288']
# ['impulsar', '0.1281']
# ['prematuro', '0.1281']
# ['jaramillo', '0.1281']
# ['jefe', '0.1270']
# ['revista', '0.1269']
# ['similar', '0.1266']
# ['fría', '0.1265']
# ['paro', '0.1263']
# ['observatorio', '0.1260']
# ['marcado', '0.1259']
# ['lugar', '0.1253']
# ['joven', '0.1251']
# ['dicho', '0.1242']
# ['directriz', '0.1238']
# ['muestra', '0.1237']
# ['urb', '0.1232']
# ['robo', '0.1229']
# ['exministra', '0.1225']
# ['cuento', '0.1222']
# ['organizado', '0.1219']
# ['efectivo', '0.1218']
# ['viejo', '0.1215']
# ['himno', '0.1214']
# ['consejo', '0.1210']
# ['mediano', '0.1209']
# ['alzado', '0.1209']
# ['productivo', '0.1206']
# ['llamado', '0.1205']
# ['beneplácito', '0.1205']
# ['mostrar', '0.1201']
# ['personal', '0.1191']
# ['introducido', '0.1191']
# ['anterior', '0.1190']
# ['haberla', '0.1186']
# ['único', '0.1185']
# ['episodio', '0.1184']
# ['vía', '0.1184']
# ['conocedor', '0.1181']
# ['vido', '0.1175']
# ['escobar', '0.1169']
# ['fórmula', '0.1166']
# ['apropiado', '0.1166']
# ['concepto', '0.1160']
# ['loable', '0.1159']
# ['estar', '0.1158']
# ['interesante', '0.1151']
# ['finale', '0.1141']
# ['ansiado', '0.1133']
# ['falta', '0.1132']
# ['tercerizado', '0.1132']
# ['exceso', '0.1130']
# ['cuyo', '0.1126']
# ['sindicato', '0.1125']
# ['pena', '0.1121']
# ['sistema', '0.1116']
# ['grupo', '0.1112']
# ['respectivo', '0.1106']
# ['lideresa', '0.1106']
# ['convocado', '0.1095']
# ['beneficio', '0.1095']
# ['cara', '0.1094']
# ['margen', '0.1091']
# ['ejercicio', '0.1090']
# ['trabajo', '0.1089']
# ['calificado', '0.1084']
# ['grueso', '0.1084']
# ['preguntar', '0.1081']
# ['lutte', '0.1079']
# ['visto', '0.1079']
# ['organizativo', '0.1075']
# ['palabras', '0.1070']
# ['divino', '0.1070']
# ['firma', '0.1069']
# ['mauricio', '0.1062']
# ['objetivo', '0.1059']
# ['temático', '0.1057']
# ['papel', '0.1048']
# ['negocio', '0.1046']
# ['frágil', '0.1045']
# ['cifra', '0.1045']
# ['cicatriz', '0.1045']
# ['empresa', '0.1044']
# ['surgen', '0.1035']
# ['análisis', '0.1032']
# ['miembro', '0.1032']
# ['reflejo', '0.1029']
# ['riesgo', '0.1028']
# ['ámbito', '0.1027']
# ['cuerpo', '0.1023']
# ['unido', '0.1014']
# ['acumulado', '0.1013']
# ['comunicar', '0.1013']
# ['allá', '0.1012']
# ['excluido', '0.1012']
# ['plataforma', '0.1012']
# ['necesario', '0.1010']
# ['reducido', '0.1005']
# ['duda', '0.0997']
# ['claro', '0.0996']
# ['ganadero', '0.0994']
# ['panorama', '0.0992']
# ['distinto', '0.0982']
# ['conformado', '0.0977']
# ['vocero', '0.0975']
# ['truncada', '0.0973']
# ['práctico', '0.0967']
# ['departamento', '0.0966']
# ['punto', '0.0965']
# ['clar', '0.0965']
# ['hijo', '0.0960']
# ['rumbo', '0.0959']
# ['quince', '0.0955']
# ['duradero', '0.0953']
# ['empleo', '0.0947']
# ['punible', '0.0934']
# ['empresarial', '0.0933']
# ['variopinto', '0.0930']
# ['sistémico', '0.0929']
# ['futbolista', '0.0928']
# ['asociado', '0.0925']
# ['caso', '0.0923']
# ['ee', '0.0918']
# ['inflama', '0.0912']
# ['vedado', '0.0912']
# ['alcaldías', '0.0909']
# ['quintero', '0.0907']
# ['valle', '0.0906']
# ['bejarano', '0.0902']
# ['sector', '0.0895']
# ['salud', '0.0893']
# ['noviembre', '0.0885']
# ['aspecto', '0.0880']
# ['respaldo', '0.0879']
# ['centro', '0.0873']
# ['sic', '0.0872']
# ['menor', '0.0869']
# ['completo', '0.0867']
# ['simultáneo', '0.0863']
# ['plano', '0.0862']
# ['portavoz', '0.0854']
# ['orgullo', '0.0854']
# ['ultra', '0.0852']
# ['pequeño', '0.0851']
# ['luz', '0.0849']
# ['santo', '0.0848']
# ['pedagogía', '0.0848']
# ['informado', '0.0845']
# ['año', '0.0842']
# ['experto', '0.0837']
# ['cargo', '0.0835']
# ['celebrado', '0.0835']
# ['registrado', '0.0824']
# ['error', '0.0823']
# ['hora', '0.0820']
# ['alegría', '0.0818']
# ['basado', '0.0813']
# ['positivo', '0.0813']
# ['incógnita', '0.0811']
# ['desdén', '0.0802']
# ['nombre', '0.0799']
# ['empate', '0.0796']
# ['navia', '0.0793']
# ['rural', '0.0788']
# ['alivio', '0.0785']
# ['comentario', '0.0785']
# ['niveles', '0.0783']
# ['libre', '0.0781']
# ['capaz', '0.0778']
# ['actor', '0.0776']
# ['frenazo', '0.0770']
# ['tasa', '0.0769']
# ['tangible', '0.0768']
# ['parcial', '0.0766']
# ['uu', '0.0762']
# ['agudo', '0.0759']
# ['presentado', '0.0758']
# ['diario', '0.0756']
# ['factor', '0.0748']
# ['destacado', '0.0741']
# ['enrique', '0.0735']
# ['mayo', '0.0734']
# ['opinador', '0.0733']
# ['plazo', '0.0731']
# ['urbano', '0.0724']
# ['laboral', '0.0717']
# ['barranquilla', '0.0711']
# ['ajedrez', '0.0707']
# ['logro', '0.0705']
# ['vallar', '0.0705']
# ['ginebra', '0.0703']
# ['firmado', '0.0703']
# ['enero', '0.0699']
# ['cautelar', '0.0690']
# ['honor', '0.0685']
# ['servicio', '0.0685']
# ['cauca', '0.0683']
# ['explicado', '0.0678']
# ['movido', '0.0678']
# ['entorno', '0.0675']
# ['gabinete', '0.0674']
# ['informe', '0.0664']
# ['acordado', '0.0655']
# ['octubre', '0.0648']
# ['fruto', '0.0645']
# ['putumayo', '0.0631']
# ['pecho', '0.0629']
# ['área', '0.0623']
# ['alto', '0.0620']
# ['proyecto', '0.0619']
# ['agua', '0.0615']
# ['analizado', '0.0611']
# ['anunciado', '0.0608']
# ['especial', '0.0606']
# ['balance', '0.0605']
# ['concisa', '0.0603']
# ['espacio', '0.0600']
# ['cuarto', '0.0600']
# ['fondo', '0.0600']
# ['abril', '0.0598']
# ['sicarial', '0.0597']
# ['adicional', '0.0594']
# ['líneas', '0.0594']
# ['formador', '0.0593']
# ['timba', '0.0592']
# ['vacío', '0.0589']
# ['emprendedor', '0.0589']
# ['exdirector', '0.0587']
# ['manejo', '0.0586']
# ['estudio', '0.0586']
# ['factible', '0.0584']
# ['temo', '0.0577']
# ['señor', '0.0575']
# ['plasmada', '0.0569']
# ['ajeno', '0.0567']
# ['nocivo', '0.0566']
# ['individual', '0.0565']
# ['cuidado', '0.0557']
# ['calle', '0.0555']
# ['reflejado', '0.0553']
# ['marco', '0.0552']
# ['motivado', '0.0551']
# ['libro', '0.0532']
# ['remoto', '0.0532']
# ['aprovechado', '0.0522']
# ['avatar', '0.0514']
# ['incluido', '0.0513']
# ['miranda', '0.0509']
# ['corto', '0.0502']
# ['escueto', '0.0499']
# ['podido', '0.0497']
# ['contenido', '0.0497']
# ['exitoso', '0.0496']
# ['titulado', '0.0492']
# ['anhelado', '0.0488']
# ['meta', '0.0471']
# ['don', '0.0467']
# ['síntoma', '0.0467']
# ['pensado', '0.0465']
# ['nivel', '0.0465']
# ['criterio', '0.0454']
# ['médico', '0.0449']
# ['tejido', '0.0439']
# ['famoso', '0.0438']
# ['privado', '0.0429']
# ['director', '0.0419']
# ['juegos', '0.0415']
# ['columnar', '0.0413']
# ['quehacer', '0.0408']
# ['maduro', '0.0408']
# ['cumplido', '0.0405']
# ['sólido', '0.0405']
# ['consultor', '0.0400']
# ['equipo', '0.0389']
# ['amplio', '0.0385']
# ['manuel', '0.0384']
# ['disímil', '0.0382']
# ['curso', '0.0377']
# ['pablo', '0.0367']
# ['inaplazable', '0.0366']
# ['mañana', '0.0363']
# ['indeseado', '0.0351']
# ['remezón', '0.0349']
# ['salido', '0.0325']
# ['acompañado', '0.0310']
# ['requerida', '0.0288']
# ['vereda', '0.0284']
# ['pardo', '0.0281']
# ['elaborado', '0.0274']
# ['modelo', '0.0273']
# ['cerro', '0.0270']
# ['hectárea', '0.0267']
# ['indicador', '0.0266']
# ['asesor', '0.0262']
# ['més', '0.0258']
# ['previo', '0.0256']
# ['ricardo', '0.0253']
# ['abanico', '0.0247']
# ['apostar', '0.0246']
# ['trabaje', '0.0242']
# ['tema', '0.0239']
# ['mensaje', '0.0234']
# ['mil', '0.0226']
# ['falto', '0.0221']
# ['valor', '0.0215']
# ['rasgo', '0.0209']
# ['desear', '0.0208']
# ['dea', '0.0201']
# ['pan', '0.0194']
# ['aire', '0.0189']
# ['gremio', '0.0185']
# ['coordinadora', '0.0179']
# ['v', '0.0177']
# ['anuncio', '0.0174']
# ['certero', '0.0172']
# ['múltiple', '0.0161']
# ['tipo', '0.0153']
# ['saldo', '0.0153']
# ['querido', '0.0153']
# ['jorge', '0.0151']
# ['yahoo', '0.0135']
# ['hurto', '0.0124']
# ['enfocar', '0.0123']
# ['luis', '0.0119']
# ['soñador', '0.0118']
# ['protocolo', '0.0111']
# ['cerrar', '0.0109']
# ['valioso', '0.0105']
# ['ossa', '0.0104']
# ['disruptivo', '0.0103']
# ['correcto', '0.0100']
# ['obvio', '0.0080']
# ['sinónimo', '0.0073']
# ['acceso', '0.0068']
# ['simple', '0.0064']
# ['díaz', '0.0056']
# ['juan', '0.0052']
# ['programa', '0.0048']
# ['gallo', '0.0039']
# ['dinámico', '0.0035']
# ['cox', '0.0027']
# ['amigo', '0.0023']
# ['julián', '0.0012']
# ['motor', '0.0009']
# ['eco', '0.0008']
# ['laxa', '0.0005']
# ['hamá', '0.0000']
# ['villavez', '0.0000']
# ['cocar', '0.0000']
# ['zelensky', '0.0000']
# ['restrepox', '0.0000']
# ['fedesarrollo', '0.0000']
# ['gaviria', '0.0000']
# ['persón', '0.0000']
# ['pérdidar', '0.0000']
# ['autodefenso', '0.0000']
# ['futuristo', '0.0000']
# ['delincuencio', '0.0000']
# ['carloscavelier', '0.0000']
# ['caminant', '0.0000']
# ['colombiar', '0.0000']
# ['materio', '0.0000']
# ['puntar', '0.0000']
# ['        ', '0.0000']
# ['justificant', '0.0000']
# ['puent', '0.0000']
# ['                   ', '0.0000']
# ['líneo', '0.0000']
# ['creg', '0.0000']
# ['romar', '0.0000']
# ['mineer', '0.0000']
# ['perniciós', '0.0000']
# ['epicentrir', '0.0000']
# ['cavelier', '0.0000']
# ['problemonón', '0.0000']
# ['semán', '0.0000']
# ['especiar', '0.0000']
# ['etcr', '0.0000']
# ['rupturo', '0.0000']
# ['lograrer', '0.0000']
# ['       ', '0.0000']
# ['cás', '0.0000']
# ['iniciativo', '0.0000']
# ['\xa0    ', '0.0000']
# ['rosmery', '0.0000']
# ['ering', '0.0000']
# ['jep', '0.0000']
# ['mipym', '0.0000']
# ['emprendedorar', '0.0000']
# ['siloé', '0.0000']
# ['displicencio', '0.0000']
# ['lentejismo', '0.0000']
# ['remanent', '0.0000']
# ['fasar', '0.0000']
# ['          ', '0.0000']
# ['caicedo', '0.0000']
# ['cúpular', '0.0000']
# ['ofrecerl', '0.0000']
# ['pachomirando', '0.0000']
# ['castropresidente', '0.0000']
# ['indepaz', '0.0000']
# ['acopi', '0.0000']
# ['firmezar', '0.0000']
# ['lés', '0.0000']
# ['asonado', '0.0000']
# ['  ', '0.0000']
# ['viviendir', '0.0000']
# ['mentoer', '0.0000']
# ['sorpresar', '0.0000']
# ['              ', '0.0000']
# ['masacr', '0.0000']
# ['konrad', '0.0000']
# ['                  ', '0.0000']
# ['      ', '0.0000']
# ['eleno', '0.0000']
# ['comandant', '0.0000']
# ['     ', '0.0000']
# ['clás', '0.0000']
# ['prudenciir', '0.0000']
# ['ausencio', '0.0000']
# ['caucar', '0.0000']
# ['caquetá', '0.0000']
# ['violencio', '0.0000']
# ['charl', '0.0000']
# ['catatumbir', '0.0000']
# ['violenciir', '0.0000']
# ['expectativo', '0.0000']
# ['invamer', '0.0000']
# ['aerolíneo', '0.0000']
# ['diangcotep', '0.0000']
# ['agendo', '0.0000']
# ['                    ', '0.0000']
# ['shoá', '0.0000']
# ['seuss', '0.0000']
# ['misericordiar', '0.0000']
# ['             ', '0.0000']
# ['petrir', '0.0000']
# ['consecuencio', '0.0000']
# ['repúblico', '0.0000']
# ['rutar', '0.0000']
# ['    ', '0.0000']
# ['episodar', '0.0000']
# ['bucaramanguir', '0.0000']
# ['habán', '0.0000']
# ['simultánear', '0.0000']
# ['malcolm', '0.0000']
# ['kassin', '0.0000']
# ['tierraltar', '0.0000']
# ['           ', '0.0000']
# ['industrio', '0.0000']
# ['epl', '0.0000']
# ['cadén', '0.0000']
# ['guerro', '0.0000']
# ['emergenciar', '0.0000']
# ['            ', '0.0000']
# ['confianzar', '0.0000']
# ['ápizar', '0.0000']
# ['         ', '0.0000']
# ['adenauer', '0.0000']
# ['hamás', '0.0000']
# ['tendient', '0.0000']
# ['memorio', '0.0000']
# ['drasticidad', '0.0000']
# ['himlers', '0.0000']
# ['alcald', '0.0000']
# ['santamaríaanalista', '0.0000']
# ['propacífico', '0.0000']
# ['sabiduer', '0.0000']
# ['turbaco', '0.0000']
# ['agrupado', '-0.0013']
# ['excelente', '-0.0018']
# ['reto', '-0.0021']
# ['surtir', '-0.0022']
# ['mipyme', '-0.0057']
# ['curul', '-0.0065']
# ['sol', '-0.0089']
# ['dr', '-0.0096']
# ['ayer', '-0.0103']
# ['local', '-0.0109']
# ['salomon', '-0.0112']
# ['ii', '-0.0113']
# ['rápido', '-0.0124']
# ['humberto', '-0.0125']
# ['danilo', '-0.0133']
# ['mes', '-0.0134']
# ['plateado', '-0.0143']
# ['técnico', '-0.0153']
# ['infantil', '-0.0175']
# ['fácil', '-0.0185']
# ['nariño', '-0.0211']
# ['ah', '-0.0219']
# ['tono', '-0.0221']
# ['peña', '-0.0231']
# ['enmarcar', '-0.0232']
# ['r', '-0.0236']
# ['mesa', '-0.0237']
# ['manso', '-0.0241']
# ['robusto', '-0.0265']
# ['adecuado', '-0.0305']
# ['increíble', '-0.0310']
# ['art', '-0.0329']
# ['próximo', '-0.0345']
# ['usuario', '-0.0348']
# ['gana', '-0.0361']
# ['oslo', '-0.0374']
# ['tarifa', '-0.0383']
# ['bogotá', '-0.0431']
# ['mea', '-0.0441']
# ['p', '-0.0444']
# ['doble', '-0.0446']
# ['monitoreo', '-0.0450']
# ['com', '-0.0453']
# ['ángulo', '-0.0482']
# ['mordisco', '-0.0493']
# ['sábado', '-0.0502']
# ['eduardo', '-0.0511']
# ['g', '-0.0513']
# ['medellín', '-0.0534']
# ['máximo', '-0.0551']
# ['empalmes', '-0.0553']
# ['emc', '-0.0565']
# ['ojo', '-0.0583']
# ['iván', '-0.0585']
# ['acá', '-0.0588']
# ['digital', '-0.0594']
# ['sencillo', '-0.0600']
# ['twittero', '-0.0607']
# ['básico', '-0.0614']
# ['pizarro', '-0.0621']
# ['apliqué', '-0.0630']
# ['er', '-0.0648']
# ['m', '-0.0668']
# ['foro', '-0.0691']
# ['lunes', '-0.0720']
# ['flojo', '-0.0822']
# ['vivo', '-0.0836']
# ['gestor', '-0.0841']
# ['cote', '-0.0858']
# ['s', '-0.0914']
# ['air', '-0.0931']
# ['cali', '-0.0978']
# ['gmail', '-0.0988']
# ['h', '-0.1022']
# ['ojalá', '-0.1029']
# ['portafolio', '-0.1087']
# ['sano', '-0.1088']
# ['listo', '-0.1174']
# ['gustavo', '-0.1186']
# ['micro', '-0.1236']
# ['panel', '-0.1285']
# ['x', '-0.1337']
# ['guapi', '-0.1900']

# %%
# Generar una nube de palabras
word_freq = {palabra: float(similitud) for palabra, similitud in palabras_similares}

wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(word_freq)

# Mostrar la nube de palabras
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# ## Word2vec

# %%
import gensim.downloader as api
import csv

# Descargar el modelo pre-entrenado de Word2Vec en español
modelo_word2vec = api.load('word2vec-google-news-300')

# Define la palabra objetivo
palabra_objetivo = 'paz'

# Aplanar el corpus a una sola lista de palabras y eliminar duplicados
palabras_corpus = list(set([palabra for sublist in contenido_lemas for palabra in sublist]))

# Encontrar palabras similares a la palabra objetivo en el corpus definido
palabras_similares = []

for palabra in palabras_corpus:
    if palabra in modelo_word2vec:
        similitud = modelo_word2vec.similarity(palabra_objetivo, palabra)
        palabras_similares.append((palabra, similitud))

# Ordenar las palabras por similitud en orden descendente
palabras_similares = sorted(palabras_similares, key=lambda item: -item[1])

# Preparar los datos para escribir en el archivo CSV
contenido_lemas_csv = [['Palabra', 'Similitud']]  # Encabezados del CSV
for palabra, similitud in palabras_similares:  
    contenido_lemas_csv.append([palabra, f"{similitud:.4f}"])

# Escribir los datos en un nuevo archivo CSV
with open('word2vec_paz_portafolio.csv', 'w', newline='', encoding='utf-8-sig') as archivo:
    escritor_csv = csv.writer(archivo)
    escritor_csv.writerows(contenido_lemas_csv)

# Leer y mostrar el contenido del archivo CSV
with open('word2vec_paz_portafolio.csv', 'r', newline='', encoding='utf-8-sig') as archivo:
    lector_csv = csv.reader(archivo)
    for fila in lector_csv:
        print(fila)
# Out:
# ['Palabra', 'Similitud']
# ['paz', '1.0000']
# ['estar', '0.7547']
# ['ciudad', '0.7374']
# ['palabras', '0.7367']
# ['mundo', '0.7254']
# ['falta', '0.7242']
# ['difícil', '0.7114']
# ['semana', '0.7101']
# ['noticia', '0.7078']
# ['guerra', '0.7072']
# ['país', '0.7032']
# ['poder', '0.7029']
# ['trabajo', '0.7024']
# ['libertad', '0.7017']
# ['oportunidad', '0.6942']
# ['tiempo', '0.6925']
# ['muerto', '0.6922']
# ['querido', '0.6902']
# ['palabra', '0.6888']
# ['hecho', '0.6860']
# ['único', '0.6813']
# ['año', '0.6802']
# ['hijo', '0.6774']
# ['espacio', '0.6760']
# ['respeto', '0.6750']
# ['realmente', '0.6746']
# ['odio', '0.6709']
# ['duda', '0.6698']
# ['muerte', '0.6691']
# ['nacional', '0.6678']
# ['visto', '0.6674']
# ['clase', '0.6649']
# ['excelente', '0.6618']
# ['haber', '0.6618']
# ['recientemente', '0.6617']
# ['fácil', '0.6614']
# ['finalmente', '0.6610']
# ['pasado', '0.6607']
# ['cuerpo', '0.6594']
# ['apoyo', '0.6591']
# ['señor', '0.6587']
# ['actividad', '0.6562']
# ['miedo', '0.6561']
# ['actualmente', '0.6556']
# ['sentido', '0.6550']
# ['cuyo', '0.6540']
# ['gobierno', '0.6538']
# ['presente', '0.6537']
# ['cuidado', '0.6529']
# ['humano', '0.6521']
# ['cultura', '0.6512']
# ['internacional', '0.6503']
# ['situación', '0.6501']
# ['lograr', '0.6493']
# ['comunidad', '0.6489']
# ['razón', '0.6487']
# ['juego', '0.6485']
# ['llamado', '0.6482']
# ['éxito', '0.6479']
# ['proyecto', '0.6470']
# ['campaña', '0.6468']
# ['corazón', '0.6460']
# ['fuerte', '0.6456']
# ['justicia', '0.6446']
# ['líder', '0.6444']
# ['futuro', '0.6442']
# ['ayer', '0.6440']
# ['luz', '0.6428']
# ['papel', '0.6414']
# ['atención', '0.6413']
# ['venezolano', '0.6412']
# ['técnico', '0.6411']
# ['cuento', '0.6400']
# ['pequeño', '0.6396']
# ['cosa', '0.6387']
# ['protesta', '0.6387']
# ['totalmente', '0.6386']
# ['crecimiento', '0.6380']
# ['orden', '0.6357']
# ['economía', '0.6350']
# ['completo', '0.6346']
# ['posición', '0.6340']
# ['mensaje', '0.6335']
# ['público', '0.6331']
# ['barco', '0.6319']
# ['realidad', '0.6319']
# ['estrategia', '0.6311']
# ['importante', '0.6307']
# ['esfuerzo', '0.6290']
# ['necesario', '0.6285']
# ['historia', '0.6281']
# ['vida', '0.6281']
# ['gana', '0.6277']
# ['caso', '0.6268']
# ['diario', '0.6267']
# ['económico', '0.6266']
# ['especialmente', '0.6263']
# ['violencia', '0.6260']
# ['claro', '0.6252']
# ['política', '0.6240']
# ['tipo', '0.6232']
# ['máximo', '0.6229']
# ['cara', '0.6227']
# ['triunfo', '0.6223']
# ['período', '0.6217']
# ['opinión', '0.6216']
# ['siglo', '0.6215']
# ['territorio', '0.6206']
# ['viaje', '0.6202']
# ['línea', '0.6200']
# ['acuerdo', '0.6195']
# ['partido', '0.6176']
# ['ataque', '0.6176']
# ['ojo', '0.6169']
# ['curso', '0.6169']
# ['tradicional', '0.6165']
# ['próximo', '0.6164']
# ['tono', '0.6154']
# ['conocimiento', '0.6152']
# ['estudio', '0.6149']
# ['servicio', '0.6149']
# ['edad', '0.6148']
# ['muestra', '0.6121']
# ['región', '0.6118']
# ['punto', '0.6114']
# ['cuarto', '0.6113']
# ['información', '0.6106']
# ['mañana', '0.6104']
# ['modelo', '0.6101']
# ['doble', '0.6100']
# ['patria', '0.6098']
# ['allá', '0.6095']
# ['joven', '0.6093']
# ['seguridad', '0.6084']
# ['defensa', '0.6079']
# ['parte', '0.6077']
# ['político', '0.6074']
# ['objetivo', '0.6073']
# ['presentado', '0.6065']
# ['población', '0.6064']
# ['confianza', '0.6060']
# ['dicho', '0.6053']
# ['viejo', '0.6052']
# ['resultado', '0.6049']
# ['matrimonio', '0.6046']
# ['producción', '0.6040']
# ['directamente', '0.6038']
# ['fuego', '0.6038']
# ['uu', '0.6037']
# ['programa', '0.6012']
# ['cesar', '0.6007']
# ['importancia', '0.6006']
# ['respuesta', '0.6005']
# ['nombre', '0.5997']
# ['democracia', '0.5997']
# ['manera', '0.5996']
# ['grupo', '0.5984']
# ['movimiento', '0.5982']
# ['familia', '0.5976']
# ['derechos', '0.5965']
# ['compañía', '0.5964']
# ['problema', '0.5961']
# ['salud', '0.5960']
# ['común', '0.5953']
# ['compromiso', '0.5950']
# ['lunes', '0.5947']
# ['relación', '0.5945']
# ['reciente', '0.5945']
# ['santo', '0.5941']
# ['revista', '0.5940']
# ['acceso', '0.5940']
# ['área', '0.5928']
# ['negocio', '0.5919']
# ['empresa', '0.5911']
# ['menor', '0.5899']
# ['demanda', '0.5897']
# ['terrorista', '0.5896']
# ['inversión', '0.5885']
# ['plataforma', '0.5878']
# ['dolor', '0.5869']
# ['reforma', '0.5867']
# ['ministro', '0.5865']
# ['sábado', '0.5857']
# ['lugar', '0.5856']
# ['octubre', '0.5849']
# ['vía', '0.5838']
# ['esperanza', '0.5834']
# ['informe', '0.5833']
# ['fuerzas', '0.5824']
# ['organización', '0.5821']
# ['discurso', '0.5818']
# ['interesante', '0.5818']
# ['ambiente', '0.5808']
# ['carlos', '0.5808']
# ['puerto', '0.5802']
# ['juan', '0.5801']
# ['campo', '0.5799']
# ['reina', '0.5793']
# ['opción', '0.5791']
# ['fuerza', '0.5785']
# ['libro', '0.5785']
# ['tema', '0.5768']
# ['camino', '0.5765']
# ['efecto', '0.5763']
# ['abril', '0.5740']
# ['pena', '0.5736']
# ['consecuencia', '0.5734']
# ['luis', '0.5727']
# ['noviembre', '0.5723']
# ['militar', '0.5715']
# ['frente', '0.5712']
# ['sociedad', '0.5704']
# ['contrario', '0.5702']
# ['agua', '0.5695']
# ['niveles', '0.5695']
# ['centro', '0.5693']
# ['cifra', '0.5681']
# ['organizaciones', '0.5680']
# ['senador', '0.5677']
# ['presentación', '0.5675']
# ['acción', '0.5664']
# ['orgullo', '0.5664']
# ['causa', '0.5660']
# ['alemán', '0.5659']
# ['cabeza', '0.5656']
# ['inicio', '0.5632']
# ['miembro', '0.5625']
# ['origen', '0.5623']
# ['posibilidad', '0.5623']
# ['búsqueda', '0.5623']
# ['sistema', '0.5611']
# ['francisco', '0.5605']
# ['propuesta', '0.5598']
# ['experiencia', '0.5586']
# ['decisión', '0.5584']
# ['unido', '0.5582']
# ['interés', '0.5582']
# ['conflicto', '0.5564']
# ['juegos', '0.5558']
# ['valle', '0.5542']
# ['beneficio', '0.5539']
# ['contenido', '0.5535']
# ['fondo', '0.5491']
# ['diferencia', '0.5481']
# ['necesidad', '0.5481']
# ['sangre', '0.5477']
# ['firma', '0.5465']
# ['ricardo', '0.5459']
# ['solución', '0.5439']
# ['presidente', '0.5430']
# ['suficiente', '0.5425']
# ['propiedad', '0.5421']
# ['proceso', '0.5421']
# ['departamento', '0.5416']
# ['responsabilidad', '0.5410']
# ['profundo', '0.5408']
# ['culpa', '0.5403']
# ['mostrar', '0.5392']
# ['iniciativa', '0.5384']
# ['gallo', '0.5380']
# ['comunicación', '0.5377']
# ['protección', '0.5372']
# ['avance', '0.5372']
# ['armas', '0.5372']
# ['participación', '0.5371']
# ['raza', '0.5344']
# ['rápido', '0.5338']
# ['enero', '0.5326']
# ['amigo', '0.5320']
# ['colombia', '0.5295']
# ['hora', '0.5284']
# ['función', '0.5277']
# ['usuario', '0.5271']
# ['plazo', '0.5268']
# ['medida', '0.5268']
# ['santos', '0.5268']
# ['reunión', '0.5256']
# ['presidencial', '0.5253']
# ['mano', '0.5252']
# ['norma', '0.5252']
# ['propósito', '0.5242']
# ['mando', '0.5238']
# ['elección', '0.5228']
# ['organismo', '0.5184']
# ['nivel', '0.5181']
# ['interno', '0.5169']
# ['equipo', '0.5162']
# ['policía', '0.5139']
# ['capacidad', '0.5111']
# ['ah', '0.5104']
# ['cuba', '0.5078']
# ['listo', '0.5073']
# ['ser', '0.5061']
# ['paro', '0.5049']
# ['construcción', '0.5043']
# ['formación', '0.5038']
# ['libre', '0.5038']
# ['calle', '0.5019']
# ['pérdida', '0.5018']
# ['aire', '0.5014']
# ['análisis', '0.5012']
# ['manuel', '0.5000']
# ['mes', '0.4992']
# ['electo', '0.4975']
# ['marco', '0.4962']
# ['ee', '0.4962']
# ['acto', '0.4941']
# ['eta', '0.4926']
# ['tecnología', '0.4921']
# ['pablo', '0.4888']
# ['golpe', '0.4874']
# ['carne', '0.4858']
# ['hombre', '0.4853']
# ['riesgo', '0.4844']
# ['oficial', '0.4843']
# ['consumo', '0.4833']
# ['carrera', '0.4786']
# ['sano', '0.4778']
# ['fase', '0.4777']
# ['tendencia', '0.4775']
# ['venezuela', '0.4765']
# ['mirada', '0.4764']
# ['cote', '0.4760']
# ['plano', '0.4737']
# ['lutte', '0.4735']
# ['cambio', '0.4731']
# ['serio', '0.4720']
# ['imposible', '0.4703']
# ['zona', '0.4683']
# ['empleo', '0.4681']
# ['arma', '0.4636']
# ['energía', '0.4529']
# ['miranda', '0.4490']
# ['malcolm', '0.4465']
# ['gestión', '0.4453']
# ['foro', '0.4445']
# ['jefe', '0.4440']
# ['jorge', '0.4431']
# ['ilegal', '0.4396']
# ['corto', '0.4378']
# ['dinero', '0.4328']
# ['sur', '0.4223']
# ['fe', '0.4217']
# ['tal', '0.4182']
# ['responsable', '0.4172']
# ['mea', '0.4098']
# ['renta', '0.4084']
# ['r', '0.4073']
# ['europa', '0.4067']
# ['cali', '0.4060']
# ['serie', '0.4056']
# ['maduro', '0.4048']
# ['er', '0.4042']
# ['forma', '0.4013']
# ['banda', '0.3963']
# ['masacre', '0.3953']
# ['empresario', '0.3929']
# ['sic', '0.3846']
# ['mercado', '0.3816']
# ['derecho', '0.3794']
# ['eduardo', '0.3747']
# ['robusto', '0.3678']
# ['ering', '0.3646']
# ['lucha', '0.3622']
# ['epl', '0.3612']
# ['dea', '0.3611']
# ['dr', '0.3599']
# ['israel', '0.3523']
# ['padre', '0.3513']
# ['gaza', '0.3513']
# ['quince', '0.3471']
# ['medio', '0.3466']
# ['previo', '0.3435']
# ['momento', '0.3378']
# ['sol', '0.3363']
# ['ley', '0.3358']
# ['emc', '0.3320']
# ['com', '0.3250']
# ['escudo', '0.3164']
# ['h', '0.3095']
# ['rama', '0.3086']
# ['timba', '0.3064']
# ['campesino', '0.3058']
# ['consultor', '0.3054']
# ['reich', '0.2839']
# ['matanza', '0.2774']
# ['ambos', '0.2655']
# ['yahoo', '0.2557']
# ['g', '0.2456']
# ['mayo', '0.2422']
# ['v', '0.2410']
# ['especial', '0.2313']
# ['alto', '0.2282']
# ['oriental', '0.2277']
# ['p', '0.2246']
# ['meta', '0.2183']
# ['vivo', '0.2135']
# ['x', '0.2097']
# ['flagrante', '0.2056']
# ['m', '0.2048']
# ['don', '0.2031']
# ['s', '0.2022']
# ['urb', '0.2000']
# ['trance', '0.1976']
# ['ii', '0.1958']
# ['execrable', '0.1870']
# ['mil', '0.1775']
# ['guerrilla', '0.1746']
# ['gmail', '0.1665']
# ['cultural', '0.1560']
# ['mesa', '0.1517']
# ['armadas', '0.1451']
# ['valor', '0.1420']
# ['panorama', '0.1325']
# ['columnar', '0.1304']
# ['remanent', '0.1292']
# ['anterior', '0.1272']
# ['horrible', '0.1178']
# ['avatar', '0.1046']
# ['robo', '0.1024']
# ['cox', '0.1001']
# ['finale', '0.0982']
# ['art', '0.0977']
# ['social', '0.0968']
# ['civil', '0.0932']
# ['popular', '0.0858']
# ['miserable', '0.0812']
# ['anti', '0.0785']
# ['liberal', '0.0783']
# ['persona', '0.0712']
# ['grave', '0.0695']
# ['petro', '0.0681']
# ['criminal', '0.0608']
# ['territorial', '0.0567']
# ['actor', '0.0539']
# ['eco', '0.0531']
# ['honor', '0.0511']
# ['simple', '0.0509']
# ['cargo', '0.0464']
# ['capital', '0.0446']
# ['pan', '0.0445']
# ['interior', '0.0382']
# ['micro', '0.0373']
# ['real', '0.0334']
# ['digital', '0.0284']
# ['air', '0.0269']
# ['mayor', '0.0257']
# ['crisis', '0.0224']
# ['visible', '0.0221']
# ['ultra', '0.0220']
# ['actual', '0.0162']
# ['central', '0.0136']
# ['élite', '0.0107']
# ['local', '0.0005']
# ['error', '-0.0011']
# ['tangible', '-0.0013']
# ['director', '-0.0057']
# ['personal', '-0.0083']
# ['general', '-0.0129']
# ['principal', '-0.0155']
# ['motor', '-0.0198']
# ['agenda', '-0.0388']
# ['factor', '-0.0399']
# ['regional', '-0.0435']
# ['panel', '-0.0467']
# ['rural', '-0.0528']
# ['particular', '-0.0534']
# ['similar', '-0.0650']
# ['sector', '-0.0661']
# ['idea', '-0.0717']
# ['balance', '-0.0774']
# ['control', '-0.0853']
# ['federal', '-0.0968']
# ['individual', '-0.1143']

# %%
# Generar una nube de palabras
word_freq = {palabra: float(similitud) for palabra, similitud in palabras_similares}

wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(word_freq)

# Mostrar la nube de palabras
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
# Define la palabra objetivo
palabra_objetivo = 'guerra'

# Aplanar el corpus a una sola lista de palabras y eliminar duplicados
palabras_corpus = list(set([palabra for sublist in contenido_lemas for palabra in sublist]))

# Encontrar palabras similares a la palabra objetivo en el corpus definido
palabras_similares = []

for palabra in palabras_corpus:
    if palabra in modelo_word2vec:
        similitud = modelo_word2vec.similarity(palabra_objetivo, palabra)
        palabras_similares.append((palabra, similitud))

# Ordenar las palabras por similitud en orden descendente
palabras_similares = sorted(palabras_similares, key=lambda item: -item[1])

# Preparar los datos para escribir en el archivo CSV
contenido_lemas_csv = [['Palabra', 'Similitud']]  # Encabezados del CSV
for palabra, similitud in palabras_similares:  
    contenido_lemas_csv.append([palabra, f"{similitud:.4f}"])

# Escribir los datos en un nuevo archivo CSV
with open('word2vec_guerra_portafolio.csv', 'w', newline='', encoding='utf-8-sig') as archivo:
    escritor_csv = csv.writer(archivo)
    escritor_csv.writerows(contenido_lemas_csv)

# Leer y mostrar el contenido del archivo CSV
with open('word2vec_guerra_portafolio.csv', 'r', newline='', encoding='utf-8-sig') as archivo:
    lector_csv = csv.reader(archivo)
    for fila in lector_csv:
       print(fila)
# Out:
# ['Palabra', 'Similitud']
# ['guerra', '1.0000']
# ['odio', '0.7495']
# ['sentido', '0.7464']
# ['noticia', '0.7442']
# ['hecho', '0.7433']
# ['único', '0.7404']
# ['palabra', '0.7397']
# ['gobierno', '0.7322']
# ['difícil', '0.7322']
# ['estar', '0.7318']
# ['protesta', '0.7316']
# ['razón', '0.7290']
# ['actividad', '0.7290']
# ['trabajo', '0.7281']
# ['militar', '0.7277']
# ['país', '0.7272']
# ['político', '0.7262']
# ['campaña', '0.7257']
# ['recientemente', '0.7251']
# ['falta', '0.7250']
# ['muerte', '0.7216']
# ['ciudad', '0.7209']
# ['proyecto', '0.7205']
# ['oportunidad', '0.7191']
# ['importancia', '0.7164']
# ['muerto', '0.7151']
# ['máximo', '0.7137']
# ['crecimiento', '0.7136']
# ['nacional', '0.7125']
# ['situación', '0.7124']
# ['respeto', '0.7123']
# ['poder', '0.7116']
# ['espacio', '0.7107']
# ['apoyo', '0.7074']
# ['paz', '0.7072']
# ['especialmente', '0.7064']
# ['ayer', '0.7053']
# ['miedo', '0.7046']
# ['tiempo', '0.7045']
# ['edad', '0.7024']
# ['año', '0.7016']
# ['cuyo', '0.7014']
# ['pequeño', '0.7012']
# ['realmente', '0.7011']
# ['ataque', '0.7003']
# ['política', '0.7000']
# ['comunidad', '0.6991']
# ['contrario', '0.6984']
# ['democracia', '0.6962']
# ['período', '0.6959']
# ['visto', '0.6956']
# ['excelente', '0.6951']
# ['pasado', '0.6944']
# ['justicia', '0.6942']
# ['haber', '0.6938']
# ['actualmente', '0.6933']
# ['terrorista', '0.6929']
# ['clase', '0.6924']
# ['movimiento', '0.6923']
# ['conocimiento', '0.6914']
# ['mundo', '0.6909']
# ['atención', '0.6898']
# ['humano', '0.6897']
# ['necesario', '0.6897']
# ['producción', '0.6893']
# ['esfuerzo', '0.6889']
# ['organización', '0.6887']
# ['venezolano', '0.6884']
# ['población', '0.6883']
# ['público', '0.6879']
# ['común', '0.6870']
# ['diario', '0.6866']
# ['económico', '0.6864']
# ['mensaje', '0.6858']
# ['internacional', '0.6854']
# ['estrategia', '0.6850']
# ['opción', '0.6849']
# ['parte', '0.6843']
# ['querido', '0.6833']
# ['compromiso', '0.6820']
# ['línea', '0.6818']
# ['fuerza', '0.6814']
# ['inversión', '0.6814']
# ['territorio', '0.6812']
# ['respuesta', '0.6786']
# ['duda', '0.6784']
# ['caso', '0.6782']
# ['palabras', '0.6779']
# ['información', '0.6779']
# ['grupo', '0.6776']
# ['barco', '0.6774']
# ['fácil', '0.6773']
# ['manera', '0.6773']
# ['semana', '0.6766']
# ['siglo', '0.6758']
# ['futuro', '0.6748']
# ['orden', '0.6747']
# ['derechos', '0.6741']
# ['próximo', '0.6740']
# ['cuerpo', '0.6739']
# ['acuerdo', '0.6722']
# ['cosa', '0.6721']
# ['posición', '0.6718']
# ['cultura', '0.6706']
# ['niveles', '0.6705']
# ['menor', '0.6694']
# ['libertad', '0.6694']
# ['reciente', '0.6687']
# ['responsabilidad', '0.6686']
# ['patria', '0.6685']
# ['economía', '0.6671']
# ['frente', '0.6670']
# ['totalmente', '0.6664']
# ['unido', '0.6654']
# ['joven', '0.6652']
# ['reforma', '0.6651']
# ['historia', '0.6638']
# ['finalmente', '0.6636']
# ['curso', '0.6632']
# ['lugar', '0.6629']
# ['nombre', '0.6627']
# ['claro', '0.6608']
# ['región', '0.6598']
# ['relación', '0.6597']
# ['importante', '0.6596']
# ['lograr', '0.6592']
# ['fuerte', '0.6587']
# ['defensa', '0.6582']
# ['tono', '0.6575']
# ['sociedad', '0.6559']
# ['matrimonio', '0.6540']
# ['opinión', '0.6522']
# ['seguridad', '0.6520']
# ['demanda', '0.6519']
# ['organizaciones', '0.6506']
# ['lunes', '0.6498']
# ['viaje', '0.6486']
# ['presente', '0.6481']
# ['armas', '0.6480']
# ['corazón', '0.6477']
# ['llamado', '0.6474']
# ['acceso', '0.6472']
# ['luz', '0.6471']
# ['realidad', '0.6469']
# ['dolor', '0.6459']
# ['medida', '0.6442']
# ['compañía', '0.6440']
# ['cuidado', '0.6429']
# ['mostrar', '0.6427']
# ['proceso', '0.6424']
# ['éxito', '0.6419']
# ['negocio', '0.6417']
# ['contenido', '0.6403']
# ['violencia', '0.6398']
# ['técnico', '0.6386']
# ['partido', '0.6377']
# ['líder', '0.6373']
# ['resultado', '0.6367']
# ['departamento', '0.6363']
# ['cifra', '0.6362']
# ['confianza', '0.6355']
# ['discurso', '0.6353']
# ['papel', '0.6330']
# ['plataforma', '0.6323']
# ['elección', '0.6310']
# ['construcción', '0.6309']
# ['hijo', '0.6283']
# ['fuerzas', '0.6282']
# ['consecuencia', '0.6271']
# ['estudio', '0.6257']
# ['acción', '0.6255']
# ['señor', '0.6255']
# ['informe', '0.6253']
# ['presentación', '0.6253']
# ['revista', '0.6251']
# ['allá', '0.6249']
# ['servicio', '0.6239']
# ['vía', '0.6230']
# ['protección', '0.6229']
# ['senador', '0.6224']
# ['tradicional', '0.6220']
# ['causa', '0.6213']
# ['directamente', '0.6213']
# ['programa', '0.6195']
# ['ministro', '0.6191']
# ['completo', '0.6189']
# ['salud', '0.6164']
# ['modelo', '0.6163']
# ['propuesta', '0.6157']
# ['origen', '0.6156']
# ['inicio', '0.6146']
# ['pena', '0.6146']
# ['ojo', '0.6146']
# ['presentado', '0.6144']
# ['experiencia', '0.6137']
# ['organismo', '0.6137']
# ['usuario', '0.6136']
# ['decisión', '0.6127']
# ['búsqueda', '0.6113']
# ['cara', '0.6112']
# ['cuarto', '0.6110']
# ['interesante', '0.6107']
# ['posibilidad', '0.6106']
# ['puerto', '0.6094']
# ['viejo', '0.6094']
# ['ambiente', '0.6092']
# ['doble', '0.6083']
# ['dicho', '0.6080']
# ['alemán', '0.6079']
# ['juego', '0.6075']
# ['diferencia', '0.6074']
# ['punto', '0.6057']
# ['formación', '0.6054']
# ['participación', '0.6051']
# ['interés', '0.6047']
# ['área', '0.6044']
# ['sábado', '0.6043']
# ['nivel', '0.6042']
# ['objetivo', '0.6040']
# ['triunfo', '0.6034']
# ['cuento', '0.6032']
# ['comunicación', '0.6029']
# ['beneficio', '0.6023']
# ['campo', '0.6022']
# ['sangre', '0.6020']
# ['efecto', '0.6015']
# ['análisis', '0.6007']
# ['conflicto', '0.6006']
# ['gana', '0.6001']
# ['fuego', '0.5999']
# ['presidencial', '0.5995']
# ['fondo', '0.5991']
# ['tendencia', '0.5985']
# ['sistema', '0.5982']
# ['problema', '0.5976']
# ['miembro', '0.5974']
# ['propósito', '0.5972']
# ['suficiente', '0.5971']
# ['vida', '0.5970']
# ['tipo', '0.5970']
# ['plazo', '0.5956']
# ['muestra', '0.5948']
# ['mano', '0.5947']
# ['mando', '0.5947']
# ['policía', '0.5908']
# ['reunión', '0.5908']
# ['empresa', '0.5896']
# ['interno', '0.5877']
# ['rápido', '0.5867']
# ['presidente', '0.5828']
# ['iniciativa', '0.5828']
# ['necesidad', '0.5824']
# ['carlos', '0.5823']
# ['cesar', '0.5817']
# ['raza', '0.5785']
# ['familia', '0.5778']
# ['octubre', '0.5775']
# ['función', '0.5768']
# ['propiedad', '0.5730']
# ['consumo', '0.5728']
# ['libro', '0.5721']
# ['centro', '0.5687']
# ['paro', '0.5679']
# ['capacidad', '0.5675']
# ['riesgo', '0.5672']
# ['norma', '0.5651']
# ['tema', '0.5646']
# ['santo', '0.5636']
# ['orgullo', '0.5633']
# ['solución', '0.5632']
# ['pérdida', '0.5583']
# ['esperanza', '0.5564']
# ['luis', '0.5554']
# ['empleo', '0.5509']
# ['cabeza', '0.5504']
# ['mañana', '0.5500']
# ['abril', '0.5490']
# ['reina', '0.5485']
# ['juan', '0.5477']
# ['gallo', '0.5473']
# ['enero', '0.5463']
# ['profundo', '0.5454']
# ['avance', '0.5451']
# ['francisco', '0.5429']
# ['hora', '0.5412']
# ['firma', '0.5384']
# ['agua', '0.5336']
# ['calle', '0.5331']
# ['serio', '0.5330']
# ['gestión', '0.5324']
# ['acto', '0.5308']
# ['uu', '0.5307']
# ['lutte', '0.5307']
# ['camino', '0.5305']
# ['santos', '0.5292']
# ['mirada', '0.5292']
# ['culpa', '0.5286']
# ['oficial', '0.5257']
# ['zona', '0.5231']
# ['noviembre', '0.5228']
# ['golpe', '0.5215']
# ['valle', '0.5191']
# ['pablo', '0.5172']
# ['juegos', '0.5172']
# ['ser', '0.5127']
# ['carne', '0.5102']
# ['libre', '0.5100']
# ['hombre', '0.5089']
# ['listo', '0.5017']
# ['energía', '0.5004']
# ['cuba', '0.4991']
# ['carrera', '0.4989']
# ['plano', '0.4950']
# ['marco', '0.4949']
# ['ilegal', '0.4936']
# ['jorge', '0.4921']
# ['colombia', '0.4906']
# ['tecnología', '0.4869']
# ['foro', '0.4861']
# ['venezuela', '0.4848']
# ['fase', '0.4844']
# ['imposible', '0.4822']
# ['ricardo', '0.4798']
# ['equipo', '0.4741']
# ['cote', '0.4739']
# ['masacre', '0.4714']
# ['corto', '0.4710']
# ['jefe', '0.4704']
# ['dinero', '0.4668']
# ['amigo', '0.4642']
# ['eta', '0.4629']
# ['mes', '0.4617']
# ['responsable', '0.4589']
# ['europa', '0.4534']
# ['electo', '0.4522']
# ['ah', '0.4508']
# ['cambio', '0.4492']
# ['previo', '0.4487']
# ['miranda', '0.4481']
# ['sur', '0.4434']
# ['ee', '0.4434']
# ['epl', '0.4424']
# ['mea', '0.4392']
# ['sic', '0.4390']
# ['derecho', '0.4382']
# ['banda', '0.4351']
# ['serie', '0.4262']
# ['israel', '0.4248']
# ['eduardo', '0.4205']
# ['empresario', '0.4196']
# ['tal', '0.4164']
# ['manuel', '0.4158']
# ['campesino', '0.4149']
# ['sano', '0.4148']
# ['mercado', '0.4143']
# ['arma', '0.4134']
# ['cali', '0.4128']
# ['forma', '0.4113']
# ['aire', '0.4082']
# ['lucha', '0.4062']
# ['renta', '0.4040']
# ['quince', '0.3966']
# ['emc', '0.3957']
# ['timba', '0.3946']
# ['malcolm', '0.3905']
# ['gaza', '0.3876']
# ['er', '0.3810']
# ['padre', '0.3759']
# ['maduro', '0.3711']
# ['medio', '0.3650']
# ['escudo', '0.3613']
# ['fe', '0.3613']
# ['robusto', '0.3608']
# ['r', '0.3569']
# ['ambos', '0.3529']
# ['h', '0.3499']
# ['consultor', '0.3418']
# ['momento', '0.3384']
# ['especial', '0.3374']
# ['dr', '0.3336']
# ['ley', '0.3304']
# ['reich', '0.3186']
# ['mayo', '0.3079']
# ['sol', '0.3062']
# ['ering', '0.3035']
# ['dea', '0.3004']
# ['guerrilla', '0.2999']
# ['alto', '0.2958']
# ['urb', '0.2953']
# ['com', '0.2822']
# ['civil', '0.2822']
# ['g', '0.2771']
# ['oriental', '0.2767']
# ['matanza', '0.2753']
# ['ii', '0.2709']
# ['yahoo', '0.2667']
# ['p', '0.2642']
# ['v', '0.2590']
# ['mesa', '0.2588']
# ['valor', '0.2387']
# ['m', '0.2379']
# ['meta', '0.2368']
# ['cultural', '0.2332']
# ['flagrante', '0.2314']
# ['armadas', '0.2267']
# ['gmail', '0.2210']
# ['trance', '0.2198']
# ['anterior', '0.2152']
# ['panorama', '0.2125']
# ['x', '0.2111']
# ['rama', '0.2083']
# ['vivo', '0.2060']
# ['mil', '0.1980']
# ['élite', '0.1896']
# ['don', '0.1891']
# ['remanent', '0.1887']
# ['columnar', '0.1795']
# ['criminal', '0.1766']
# ['execrable', '0.1755']
# ['anti', '0.1740']
# ['petro', '0.1714']
# ['social', '0.1617']
# ['territorial', '0.1574']
# ['grave', '0.1568']
# ['s', '0.1497']
# ['persona', '0.1391']
# ['finale', '0.1356']
# ['avatar', '0.1355']
# ['art', '0.1345']
# ['horrible', '0.1324']
# ['actor', '0.1291']
# ['robo', '0.1263']
# ['liberal', '0.1250']
# ['cox', '0.1180']
# ['mayor', '0.1005']
# ['central', '0.0917']
# ['miserable', '0.0885']
# ['pan', '0.0825']
# ['capital', '0.0810']
# ['interior', '0.0765']
# ['crisis', '0.0749']
# ['eco', '0.0718']
# ['ultra', '0.0632']
# ['real', '0.0630']
# ['local', '0.0602']
# ['agenda', '0.0597']
# ['cargo', '0.0591']
# ['micro', '0.0543']
# ['particular', '0.0522']
# ['general', '0.0496']
# ['honor', '0.0487']
# ['rural', '0.0459']
# ['actual', '0.0441']
# ['popular', '0.0427']
# ['regional', '0.0380']
# ['digital', '0.0366']
# ['tangible', '0.0359']
# ['air', '0.0339']
# ['principal', '0.0338']
# ['sector', '0.0287']
# ['visible', '0.0203']
# ['director', '0.0195']
# ['balance', '0.0171']
# ['control', '0.0091']
# ['idea', '-0.0073']
# ['factor', '-0.0083']
# ['error', '-0.0128']
# ['personal', '-0.0134']
# ['federal', '-0.0151']
# ['simple', '-0.0206']
# ['individual', '-0.0237']
# ['panel', '-0.0283']
# ['motor', '-0.0297']
# ['similar', '-0.0446']

# %%
# Generar una nube de palabras
word_freq = {palabra: float(similitud) for palabra, similitud in palabras_similares}

wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(word_freq)

# Mostrar la nube de palabras
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# # Analisis de sentimiento

# %%
# %pip install torch
# %pip install torchvision
# %pip install transformers
# Out:
# Collecting torch
#   Obtaining dependency information for torch from https://files.pythonhosted.org/packages/d3/1d/a257913c89572de61316461db91867f87519146e58132cdeace3d9ffbe1f/torch-2.3.1-cp311-cp311-win_amd64.whl.metadata
#   Using cached torch-2.3.1-cp311-cp311-win_amd64.whl.metadata (26 kB)
# Requirement already satisfied: filelock in c:\users\user\anaconda3\lib\site-packages (from torch) (3.9.0)
# Collecting typing-extensions>=4.8.0 (from torch)
#   Obtaining dependency information for typing-extensions>=4.8.0 from https://files.pythonhosted.org/packages/26/9f/ad63fc0248c5379346306f8668cda6e2e2e9c95e01216d2b8ffd9ff037d0/typing_extensions-4.12.2-py3-none-any.whl.metadata
#   Using cached typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: sympy in c:\users\user\anaconda3\lib\site-packages (from torch) (1.11.1)
# Requirement already satisfied: networkx in c:\users\user\anaconda3\lib\site-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in c:\users\user\anaconda3\lib\site-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec in c:\users\user\anaconda3\lib\site-packages (from torch) (2023.4.0)
# Collecting mkl<=2021.4.0,>=2021.1.1 (from torch)
#   Obtaining dependency information for mkl<=2021.4.0,>=2021.1.1 from https://files.pythonhosted.org/packages/fe/1c/5f6dbf18e8b73e0a5472466f0ea8d48ce9efae39bd2ff38cebf8dce61259/mkl-2021.4.0-py2.py3-none-win_amd64.whl.metadata
#   Using cached mkl-2021.4.0-py2.py3-none-win_amd64.whl.metadata (1.4 kB)
# Collecting intel-openmp==2021.* (from mkl<=2021.4.0,>=2021.1.1->torch)
#   Obtaining dependency information for intel-openmp==2021.* from https://files.pythonhosted.org/packages/6f/21/b590c0cc3888b24f2ac9898c41d852d7454a1695fbad34bee85dba6dc408/intel_openmp-2021.4.0-py2.py3-none-win_amd64.whl.metadata
#   Using cached intel_openmp-2021.4.0-py2.py3-none-win_amd64.whl.metadata (1.2 kB)
# Collecting tbb==2021.* (from mkl<=2021.4.0,>=2021.1.1->torch)
#   Obtaining dependency information for tbb==2021.* from https://files.pythonhosted.org/packages/7b/2d/1e1c70fae8ace27e6200fb71c2372a9aeac2baba474b1609d7d466e969b4/tbb-2021.12.0-py3-none-win_amd64.whl.metadata
#   Using cached tbb-2021.12.0-py3-none-win_amd64.whl.metadata (1.1 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\user\anaconda3\lib\site-packages (from jinja2->torch) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\user\anaconda3\lib\site-packages (from sympy->torch) (1.3.0)
# Using cached torch-2.3.1-cp311-cp311-win_amd64.whl (159.8 MB)
# Using cached mkl-2021.4.0-py2.py3-none-win_amd64.whl (228.5 MB)
# Using cached intel_openmp-2021.4.0-py2.py3-none-win_amd64.whl (3.5 MB)
# Using cached tbb-2021.12.0-py3-none-win_amd64.whl (286 kB)
# Using cached typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Installing collected packages: tbb, intel-openmp, typing-extensions, mkl, torch
#   Attempting uninstall: tbb
#     Found existing installation: TBB 0.2
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Cannot uninstall 'TBB'. It is a distutils installed project and thus we cannot accurately determine which files belong to it which would lead to only a partial uninstall.
# Collecting torchvision
#   Obtaining dependency information for torchvision from https://files.pythonhosted.org/packages/e4/c3/a21a75dd2de8114a6876f16a36b033e3e62f8ade68085a711b24f4b57c17/torchvision-0.18.1-cp311-cp311-win_amd64.whl.metadata
#   Using cached torchvision-0.18.1-cp311-cp311-win_amd64.whl.metadata (6.6 kB)
# Requirement already satisfied: numpy in c:\users\user\anaconda3\lib\site-packages (from torchvision) (1.24.4)
# Collecting torch==2.3.1 (from torchvision)
#   Obtaining dependency information for torch==2.3.1 from https://files.pythonhosted.org/packages/d3/1d/a257913c89572de61316461db91867f87519146e58132cdeace3d9ffbe1f/torch-2.3.1-cp311-cp311-win_amd64.whl.metadata
#   Using cached torch-2.3.1-cp311-cp311-win_amd64.whl.metadata (26 kB)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\user\anaconda3\lib\site-packages (from torchvision) (9.4.0)
# Requirement already satisfied: filelock in c:\users\user\anaconda3\lib\site-packages (from torch==2.3.1->torchvision) (3.9.0)
# Collecting typing-extensions>=4.8.0 (from torch==2.3.1->torchvision)
#   Obtaining dependency information for typing-extensions>=4.8.0 from https://files.pythonhosted.org/packages/26/9f/ad63fc0248c5379346306f8668cda6e2e2e9c95e01216d2b8ffd9ff037d0/typing_extensions-4.12.2-py3-none-any.whl.metadata
#   Using cached typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: sympy in c:\users\user\anaconda3\lib\site-packages (from torch==2.3.1->torchvision) (1.11.1)
# Requirement already satisfied: networkx in c:\users\user\anaconda3\lib\site-packages (from torch==2.3.1->torchvision) (3.1)
# Requirement already satisfied: jinja2 in c:\users\user\anaconda3\lib\site-packages (from torch==2.3.1->torchvision) (3.1.2)
# Requirement already satisfied: fsspec in c:\users\user\anaconda3\lib\site-packages (from torch==2.3.1->torchvision) (2023.4.0)
# Collecting mkl<=2021.4.0,>=2021.1.1 (from torch==2.3.1->torchvision)
#   Obtaining dependency information for mkl<=2021.4.0,>=2021.1.1 from https://files.pythonhosted.org/packages/fe/1c/5f6dbf18e8b73e0a5472466f0ea8d48ce9efae39bd2ff38cebf8dce61259/mkl-2021.4.0-py2.py3-none-win_amd64.whl.metadata
#   Using cached mkl-2021.4.0-py2.py3-none-win_amd64.whl.metadata (1.4 kB)
# Collecting intel-openmp==2021.* (from mkl<=2021.4.0,>=2021.1.1->torch==2.3.1->torchvision)
#   Obtaining dependency information for intel-openmp==2021.* from https://files.pythonhosted.org/packages/6f/21/b590c0cc3888b24f2ac9898c41d852d7454a1695fbad34bee85dba6dc408/intel_openmp-2021.4.0-py2.py3-none-win_amd64.whl.metadata
#   Using cached intel_openmp-2021.4.0-py2.py3-none-win_amd64.whl.metadata (1.2 kB)
# Collecting tbb==2021.* (from mkl<=2021.4.0,>=2021.1.1->torch==2.3.1->torchvision)
#   Obtaining dependency information for tbb==2021.* from https://files.pythonhosted.org/packages/7b/2d/1e1c70fae8ace27e6200fb71c2372a9aeac2baba474b1609d7d466e969b4/tbb-2021.12.0-py3-none-win_amd64.whl.metadata
#   Using cached tbb-2021.12.0-py3-none-win_amd64.whl.metadata (1.1 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\user\anaconda3\lib\site-packages (from jinja2->torch==2.3.1->torchvision) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\user\anaconda3\lib\site-packages (from sympy->torch==2.3.1->torchvision) (1.3.0)
# Using cached torchvision-0.18.1-cp311-cp311-win_amd64.whl (1.2 MB)
# Using cached torch-2.3.1-cp311-cp311-win_amd64.whl (159.8 MB)
# Using cached mkl-2021.4.0-py2.py3-none-win_amd64.whl (228.5 MB)
# Using cached intel_openmp-2021.4.0-py2.py3-none-win_amd64.whl (3.5 MB)
# Using cached tbb-2021.12.0-py3-none-win_amd64.whl (286 kB)
# Using cached typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Installing collected packages: tbb, intel-openmp, typing-extensions, mkl, torch, torchvision
#   Attempting uninstall: tbb
#     Found existing installation: TBB 0.2
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Cannot uninstall 'TBB'. It is a distutils installed project and thus we cannot accurately determine which files belong to it which would lead to only a partial uninstall.
# Requirement already satisfied: transformers in c:\users\user\anaconda3\lib\site-packages (4.32.1)
# Requirement already satisfied: filelock in c:\users\user\anaconda3\lib\site-packages (from transformers) (3.9.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.15.1 in c:\users\user\anaconda3\lib\site-packages (from transformers) (0.15.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\user\anaconda3\lib\site-packages (from transformers) (1.24.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\anaconda3\lib\site-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\user\anaconda3\lib\site-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\user\anaconda3\lib\site-packages (from transformers) (2022.7.9)
# Requirement already satisfied: requests in c:\users\user\anaconda3\lib\site-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in c:\users\user\anaconda3\lib\site-packages (from transformers) (0.13.2)
# Requirement already satisfied: safetensors>=0.3.1 in c:\users\user\anaconda3\lib\site-packages (from transformers) (0.3.2)
# Requirement already satisfied: tqdm>=4.27 in c:\users\user\anaconda3\lib\site-packages (from transformers) (4.65.0)
# Requirement already satisfied: fsspec in c:\users\user\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.15.1->transformers) (2023.4.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\user\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.15.1->transformers) (4.7.1)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\anaconda3\lib\site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests->transformers) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests->transformers) (2023.7.22)
# Note: you may need to restart the kernel to use updated packages.

# %%
from transformers import BertTokenizer, BertForSequenceClassification
import torch

modelo_bert = BertForSequenceClassification.from_pretrained('dccuchile/bert-base-spanish-wwm-cased', num_labels=3)
tokenizer = BertTokenizer.from_pretrained('dccuchile/bert-base-spanish-wwm-cased')

# Definir una función para realizar el análisis de sentimiento
def analisis_sentimiento(texto):
    # Tokenizar el texto y agregar tokens especiales
    tokens = tokenizer.encode_plus(texto, max_length=512, truncation=True, padding='max_length', return_tensors='pt')
    
    # Obtener las predicciones de sentimiento del modelo
    with torch.no_grad():
        outputs = modelo_bert(**tokens)
        predicciones = torch.softmax(outputs.logits, dim=1).squeeze()

    # Convertir las predicciones a etiquetas de sentimiento
    etiquetas = ['Negativo', 'Neutral', 'Positivo']
    sentimiento = etiquetas[int(torch.argmax(predicciones))]

    return sentimiento, predicciones.numpy().tolist()

# Realizar el análisis de sentimiento para cada frase en el corpus
resultado_analisis = []
for frase in contenido_lemas_prueba:
    texto = ' '.join(frase)
    sentimiento, confianza = analisis_sentimiento(texto)
    resultado_analisis.append((frase, sentimiento, confianza))

# Imprimir los resultados
for frase, sentimiento, confianza in resultado_analisis:
    print('Frase:', ' '.join(frase))
    print('Sentimiento:', sentimiento)
    print('Confianza:', confianza)
    print()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[41], line 2
#       1 from transformers import BertTokenizer, BertForSequenceClassification
# ----> 2 import torch
#       4 modelo_bert = BertForSequenceClassification.from_pretrained('dccuchile/bert-base-spanish-wwm-cased', num_labels=3)
#       5 tokenizer = BertTokenizer.from_pretrained('dccuchile/bert-base-spanish-wwm-cased')
#
# ModuleNotFoundError: No module named 'torch'
